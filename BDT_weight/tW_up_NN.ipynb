# %% [markdown]
# # DNN in TopFC analysis
# Author: Meisam Ghasemi Bostanabad

# %% [markdown]
# ## Loading `pandas` DataFrames
# Now we load two different `NumPy` arrays. One corresponding to the VV signal and one corresponding to the background.

# %%
import uproot
import numpy as np
import pandas as pd
import h5py
import awkward as ak
import seaborn as sns
import matplotlib.pyplot as plt
import math
from scipy import stats


# fix random seed for reproducibility
seed = 7
np.random.seed(seed)

filename = {
    'tZ':'/Users/mghasemi/Desktop/IPM/plotter/newtrees/tW_trees/tZ.root',
    'WZ':'/Users/mghasemi/Desktop/IPM/plotter/newtrees/tW_trees/WZ.root',
    'ZZ':'/Users/mghasemi/Desktop/IPM/plotter/newtrees/tW_trees/ZZ.root',
    #'signal_tW_up':'/Users/mghasemi/Desktop/IPM/plotter/newtrees/signal_tW_up.root'}
    'signal_tW_up':'/Users/mghasemi/Desktop/IPM/plotter/newtrees/tW_trees/signal_tW_up.root'}

upfile = {}
params = {}
df = {}

# choose which vars to use (multi dimensional)
#VARS = ['jetNo','jetPTLeading','bjetPT','elecPTLeading','met','testnonTopMass', 'weight'] # choose which vars to use (2d)
VARS = ['jetNo','jetPTLeading', 'jetETA', 'jetPHI',
        'elecPTLeading', 'elecETA', 'elecPHI',
        'dielecCOS', 'dielecETA', 'met','testnonTopMass'] # choose which vars to use (2d)

# define trees and branches to make DataFrame
for treename in filename.keys():
    upfile[treename] = uproot.open(filename[treename])
    params[treename] = upfile[treename][treename].arrays(VARS)
    df[treename] = ak.to_dataframe(params[treename])
    # add isSignal variable
    if treename.startswith("signal"): 
        df[treename]['isSignal'] = np.ones(len(df[treename])) 
    else:
        df[treename]['isSignal'] = np.zeros(len(df[treename]))

# %%
print(df['signal_tW_up'].shape)
print(df['tZ'].shape)
print(df['WZ'].shape)
print(df['ZZ'].shape)
# Out:
# (116829, 12)
# (175183, 12)
# (483338, 12)
# (6352, 12)

# %% [markdown]
# ## Functions

# %%
# function to plot all distributions
def hist(df1, df2, cols, bins, ncols = 3):
    nrows = math.ceil(len(cols) / ncols)
    fig, ax = plt.subplots(nrows, ncols, figsize = (5 * ncols, 4.2 * nrows), sharey = False)
    for i in range(len(cols)):
        #sns.histplot(data = df, x = cols[i], bins = bins, hue = 'isSignal', palette = ['grey', 'red'], ax = ax[i // ncols, i % ncols], stat="probability")
        sns.histplot(data = df1, x = cols[i], bins = bins, color = 'red',
                      ax = ax[i // ncols, i % ncols], stat="density", label='bkg')
        sns.histplot(data = df2, x = cols[i], bins = bins, color = 'grey',
                      ax = ax[i // ncols, i % ncols], stat="density", label='sig')       
        ax[i // ncols, i % ncols].set_xlabel(cols[i])
        ax[i // ncols, i % ncols].legend()
        if i % ncols != 0:
            ax[i // ncols, i % ncols].set_ylabel(" ")
        
    plt.tight_layout()
    plt.show()


# function to make ML output and significant plot
samples =['tZ', 'WZ', 'ZZ', 'signal_tW_up']

def plot_SoverB(data, SoverB_hist_dict):
    
    signal = r'signal_tW_up' # which sample is the signal

    # *******************
    # general definitions (shouldn't need to change)

    for x_variable,hist in SoverB_hist_dict.items(): # access the dictionary of histograms defined in the cell above

        h_bin_width = hist['bin_width'] # get the bin width defined in the cell above
        h_num_bins = hist['num_bins'] # get the number of bins defined in the cell above
        h_xrange_min = hist['xrange_min'] # get the x-range minimum defined in the cell above
        h_xlabel = hist['xlabel'] # get the x-axis label defined in the cell above
    
        bin_edges = [ h_xrange_min + x*h_bin_width for x in range(h_num_bins+1) ] # bin limits
        bin_centres = [ h_xrange_min+h_bin_width/2 + x*h_bin_width for x in range(h_num_bins) ] # bin centres
        
        signal_x = data[signal][x_variable] # histogram the signal
    
        mc_x = [] # define list to hold the Monte Carlo histogram entries

        for s in samples: # loop over samples
            if s not in ['data', signal]: # if not data nor signal
                mc_x = [*mc_x, *data[s][x_variable] ] # append to the list of Monte Carlo histogram entries
                #test=[]; test.append(df[s]['NN_output_prob'].values)


    
    
        # *************
        # Signal and background distributions
        # *************
        distributions_axes = plt.gca() # get current axes
 
        mc_heights = distributions_axes.hist(mc_x, bins=bin_edges, color='red', 
                                             label='Total background',
                                             histtype='step', # lineplot that's unfilled
                                             density=True ) # normalize to form probability density
        signal_heights = distributions_axes.hist(signal_x, bins=bin_edges, color='blue',
                                                 label=signal, 
                                                 histtype='step', # lineplot that's unfilled
                                                 density=True, # normalize to form probability density
                                                 linestyle='--' ) # dashed line
        
        distributions_axes.set_xlim( left=bin_edges[0], right=bin_edges[-1] ) # x-limits of the distributions axes
        distributions_axes.set_ylabel('Arbitrary units' ) # y-axis label for distributions axes
        y_max = max(max(signal_heights[0]), max(mc_heights[0]) )
        #distributions_axes.set_ylim( top=max(signal_heights[0])*1.3 ) # set y-axis limits
        distributions_axes.set_ylim( top=y_max*1.2 ) # set y-axis limits
        #distributions_axes.set_ylim( top=max(signal_heights[0])*1.3 ) # set y-axis limits
        plt.title('Signal and background '+x_variable+' distributions') # add title
        distributions_axes.legend() # draw the legend
        distributions_axes.set_xlabel( h_xlabel ) # x-axis label
            
        plt.show() # show the Signal and background distributions
    
    
        # *************
        # Signal to background ratio
        # *************
        plt.figure() # start new figure
        SoverB = [] # list to hold S/B values
        for cut_value in bin_edges: # loop over bins
            #signal_weights_passing_cut = sum(data[signal][data[signal][x_variable]>cut_value].totalWeight)
            signal_weights_passing_cut = len(data[signal][data[signal][x_variable]>cut_value])
            background_weights_passing_cut = 0 # start counter for background weights passing cut
            for s in samples: # loop over samples
                if s not in ['data', signal]: # if not data nor signal
                    #background_weights_passing_cut += sum(data[s][data[s][x_variable]>cut_value].totalWeight)
                    background_weights_passing_cut += len(data[s][data[s][x_variable]>cut_value])
            if background_weights_passing_cut!=0: # some background passes cut
                SoverB_value = signal_weights_passing_cut/background_weights_passing_cut
                SoverB_percent = 100*SoverB_value # multiply by 100 for percentage
                SoverB.append(SoverB_percent) # append to list of S/B values
        
        SoverB_axes = plt.gca() # get current axes
        SoverB_axes.plot( bin_edges[:len(SoverB)], SoverB ) # plot the data points
        SoverB_axes.set_xlim( left=bin_edges[0], right=bin_edges[-1] ) # set the x-limit of the main axes
        #SoverB_axes.set_ylim( 100, 1000)
        SoverB_axes.set_ylabel( 'S/B (%)' ) # write y-axis label for main axes
        plt.title('Signal to background ratio for different '+x_variable+' cut values', family='sans-serif')
        SoverB_axes.set_xlabel( h_xlabel ) # x-axis label 
        
        plt.show() # show S/B plot
    
    return    

from sklearn.metrics import roc_curve, auc, classification_report, accuracy_score, confusion_matrix

# function to draw loss-accuracy vs epoch and ROC curve
# %matplotlib inline
def loss_accuracy_plotter(history):
    # plot loss vs epoch
    plt.figure(figsize=(15,10))
    ax = plt.subplot(2, 2, 1)
    ax.plot(history.history['loss'], label='loss')
    ax.plot(history.history['val_loss'], label='val_loss')
    ax.legend(loc="upper right")
    ax.set_title('Loss over epochs')
    ax.set_xlabel('epoch')
    ax.set_ylabel('loss')

    # plot accuracy vs epoch
    ax = plt.subplot(2, 2, 2)
    ax.plot(history.history['accuracy'], label='acc')
    ax.plot(history.history['val_accuracy'], label='val_acc')
    ax.legend(loc="lower right")
    ax.set_title('Accuracy over epochs')
    ax.set_xlabel('epoch')
    ax.set_ylabel('acc')

    # Plot ROC
    Y_predict = model.predict(X_test)
    Y_predict_train = model.predict(X_train_val)
    fpr, tpr, thresholds = roc_curve(Y_test, Y_predict)
    roc_auc = auc(fpr, tpr)
    ax = plt.subplot(2, 2, 3)
    ax.plot(fpr, tpr, lw=2, color='cyan', label='auc = %.3f' % (roc_auc))
    ax.plot([0, 1], [0, 1], linestyle='--', lw=2, color='k', label='random chance')
    ax.set_xlim([0, 1.0])
    ax.set_ylim([0, 1.0])
    ax.set_xlabel('false positive rate')
    ax.set_ylabel('true positive rate')
    ax.set_title('receiver operating curve')
    ax.legend(loc="lower right")
    plt.show()

# function to report all metrics evaluation
def evaluate(model, scaler, X, Y, X_train_val, Y_train_val, X_test, Y_test):
    Y_pred_test = model.predict(X_test)
    Y_pred_test = Y_pred_test.reshape(Y_pred_test.shape[0])
    Y_pred_train = model.predict(X_train_val)
    Y_pred_train = Y_pred_train.reshape(Y_pred_train.shape[0])
    Y_pred_tot = model.predict(scaler.transform(X)).round()
    Y_pred_tot = Y_pred_tot.reshape(Y_pred_tot.shape[0])

    # accuracy score
    print("Test acc score:", accuracy_score(Y_test.round(), Y_pred_test.round()))
    print("Train acc score:", accuracy_score(Y_train_val.round(), Y_pred_train.round()))

    # classification report for the test and total sets
    print("Classification report for the test set")
    print(classification_report(Y_test.round(), Y_pred_test.round(), target_names=['background', 'signal']))
    print("Classification report for the total set")
    print(classification_report(Y.round(), Y_pred_tot.round(), target_names=['background', 'signal']))

    print("Confusion matrix for total set")
    print(confusion_matrix(Y.round(), Y_pred_tot.round()))

    fpr, tpr, thresholds = roc_curve(Y_test, Y_pred_test) # get FPRs, TPRs and thresholds for neural network
    return fpr, tpr, thresholds

# plot AMS
def AMS(tpr, fpr, b_reg): # define function to calculate AMS
    return np.sqrt(2*((tpr+fpr+b_reg)*np.log(1+tpr/(fpr+b_reg))-tpr)) # equation for AMS

def cdf(sample, x, sort = False):
    '''
    Return the value of the Cumulative Distribution Function, evaluated for a given sample and a value x.
    
    Args:
        sample: The list or array of observations.
        x: The value for which the numerical cdf is evaluated.
    
    Returns:
        cdf = CDF_{sample}(x)
    '''
    
    # Sorts the sample, if needed
    if sort:
        sample.sort()
    
    # Counts how many observations are below x
    cdf = sum(sample <= x)
    
    # Divides by the total number of observations
    cdf = cdf / len(sample)
    
    return cdf

def ks_2samp_test(sample1, sample2):
    
    # Gets all observations
    observations = np.concatenate((sample1, sample2))
    observations.sort()
    
    # Sorts the samples
    sample1.sort()
    sample2.sort()
    
    # Evaluates the KS statistic
    D_ks = [] # KS Statistic list
    for x in observations:
        cdf_sample1 = cdf(sample = sample1, x  = x)
        cdf_sample2 = cdf(sample = sample2, x  = x)
        D_ks.append(abs(cdf_sample1 - cdf_sample2))
    ks_stat = max(D_ks)
    
    # Calculates the P-Value based on the two-sided test
    # The P-Value comes from the KS Distribution Survival Function (SF = 1-CDF)
    m, n = float(len(sample1)), float(len(sample2))
    en = m * n / (m + n)
    p_value = stats.kstwo.sf(ks_stat, np.round(en))
    
    return {"ks_stat": ks_stat, "p_value" : p_value}

# plot train and test CLF distributions
def new_compare_train_test(clf, X_train, y_train, X_test, y_test, xlabel):
    decisions = [] # list to hold decisions of classifier
    for X,y in ((X_train, y_train), (X_test, y_test)): # train and test
        d1 = clf.predict(X[y<0.5]) # background
        d2 = clf.predict(X[y>0.5]) # signal
        decisions += [d1, d2] # add to list of classifier decision

    highest_decision = max(np.max(d) for d in decisions) # get maximum score
    bin_edges = [] # list to hold bin edges
    bin_edge = -0.1 # start counter for bin_edges
    while bin_edge < highest_decision: # up to highest score
        bin_edge += 0.1 # increment
        bin_edges.append(bin_edge)

    # Training plots
    plt.hist(decisions[0], # background in train set
            bins=bin_edges, # lower and upper range of the bins
            density=True, # area under the histogram will sum to 1
            histtype='stepfilled', # lineplot that's filled
            color='blue', label='Background (train)', # Background (train)
            alpha=0.5 ) # half transparency
    plt.hist(decisions[1], # signal in train set
            bins=bin_edges, # lower and upper range of the bins
            density=True, # area under the histogram will sum to 1
            histtype='stepfilled', # lineplot that's filled
            color='orange', label='Signal (train)', # Signal (train)
            alpha=0.5 ) # half transparency

    # Testing plots
    hist_background, bin_edges = np.histogram(decisions[2], # background test
                                            bins=bin_edges, # number of bins in function definition
                                            density=True ) # area under the histogram will sum to 1

    scale = len(decisions[2]) / sum(hist_background) # between raw and normalised
    err_background = np.sqrt(hist_background * scale) / scale # error on test background

    width = 0.1 # histogram bin width
    center = (bin_edges[:-1] + bin_edges[1:]) / 2 # bin centres

    plt.errorbar(x=center, y=hist_background, yerr=err_background, fmt='o', # circles
                c='blue', label='Background (test)' ) # Background (test)

    hist_signal, bin_edges = np.histogram(decisions[3], # siganl test
                                        bins=bin_edges, # number of bins in function definition
                                        density=True ) # area under the histogram will sum to 1

    scale = len(decisions[3]) / sum(hist_signal) # between raw and normalised
    err_signal = np.sqrt(hist_signal * scale) / scale # error on test background

    plt.errorbar(x=center, y=hist_signal, yerr=err_signal, fmt='*', # circles
                c='orange', label='Signal (test)' ) # Signal (test)

    plt.xlabel(xlabel) # write x-axis label
    plt.ylabel("Arbitrary units") # write y-axis label
    plt.legend() # add legend
    ks_signal = ks_2samp_test(np.array(decisions[1]), np.array(decisions[3]))
    ks_background = ks_2samp_test(np.array(decisions[0]), np.array(decisions[2]))
    print(f"Signal: ks = {ks_signal['ks_stat']} (p-value = {ks_signal['p_value']}, are equal = {ks_signal['p_value'] > 0.05})")
    print(f"Background: ks = {ks_background['ks_stat']} (p-value = {ks_background['p_value']}, are equal = {ks_background['p_value'] > 0.05})")
    #return (decisions[0], decisions[2])

# %% [markdown]
# ## Data exploration

# %%
# reduce signal DF size to have resonable Sig/Bkg ratio
#df['signal_tW_up'] = df['signal_tW_up'][:20000]
df['tZ'] = df['tZ'][:50000]
df['WZ'] = df['WZ'][:40000]
df_all = pd.concat([df[treename] for treename in filename.keys()])

# %%
# number of entries in the backgrounds and signals
sns.set_theme(style="white")

tot_bkg = 0
for treename in filename.keys():
    if not 'signal' in treename: tot_bkg += df[treename].shape[0]
    print(treename, ":", df[treename].shape)

print("signal/tot bkg:", round((df['signal_tW_up'].shape[0]/ tot_bkg),1))
#print("Null entries:", df['signal_charm'].isna().sum())

counts_signal = df['signal_tW_up'].shape[0]
counts_background = tot_bkg

plt.figure(figsize=(8,6))
plt.pie([counts_signal, counts_background], explode=[0.1,0.1], shadow=True, labels=['Signal ','Background'], textprops={'fontsize': 14}, autopct='%1.1f%%');
#plt.pie([counts_signal, counts_background], explode=[0.1,0.1], shadow=True, labels=['Signal ','Background'], textprops={'color':"b"}, autopct='%1.1f%%');
# Out:
# tZ : (50000, 12)
# WZ : (40000, 12)
# ZZ : (6352, 12)
# signal_tW_up : (116829, 12)
# signal/tot bkg: 1.2

# %%
plt.figure(figsize=(13,10))
#sns.set_theme(style="white")

# Getting the Upper Triangle of the co-relation matrix
corr = df_all.corr()
#matrix = np.triu(corr)
#mask = np.triu(np.ones_like(corr, dtype=bool))
matrix = np.triu(np.ones_like(corr))


cmap = sns.diverging_palette(200, 7, s=75, l=40,
                            n=5, center="light", as_cmap=True)

#sns.heatmap(df_test.corr(), annot=True, linewidth=.5, vmin = -1, vmax = 1,cmap = plt.cm.CMRmap_r, fmt=".1f", mask=matrix);
sns.heatmap(df_all.corr(), annot=True, linewidth=.5, vmin = -1, vmax = 1,cmap = cmap, fmt=".2f", mask=matrix);

# %%
df_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 213181 entries, (0, 0) to (75958, 1)
# Data columns (total 12 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   jetNo           213181 non-null  int32
#  1   jetPTLeading    213181 non-null  float64
#  2   jetETA          213181 non-null  float64
#  3   jetPHI          213181 non-null  float64
#  4   elecPTLeading   213181 non-null  float64
#  5   elecETA         213181 non-null  float64
#  6   elecPHI         213181 non-null  float64
#  7   dielecCOS       213181 non-null  float64
#  8   dielecETA       213181 non-null  float64
#  9   met             213181 non-null  float64
#  10  testnonTopMass  213181 non-null  float64
#  11  isSignal        213181 non-null  float64
# dtypes: float64(11), int32(1)
# memory usage: 22.3 MB

# %%
# Distributions of the float features
hist(df_all[df_all['isSignal']==0].replace(-999, np.nan),
     df_all[df_all['isSignal']==1].replace(-999, np.nan),
     #list(df_all.columns[df_all.dtypes == 'float64']),
     list(df_all.columns),
     bins = math.floor(len(df_all)**(1/3)),
     ncols = 3)

# %% [markdown]
# ## Define the models

# %% [markdown]
# ## simple NN from Tensorflow
# We'll start with a dense (fully-connected) NN layer.
# Our model will have a single fully-connected hidden layer with the same number of neurons as input variables.
# The weights are initialized using a small Gaussian random number.
# We will switch between linear and tanh activation functions for the hidden layer.
# The output layer contains a single neuron in order to make predictions.
# It uses the sigmoid activation function in order to produce a probability output in the range of 0 to 1.
#
# We are using the `binary_crossentropy` loss function during training, a standard loss function for binary classification problems.
# We will optimize the model with the Adam algorithm for stochastic gradient descent and we will collect accuracy metrics while the model is trained.

# %% [markdown]
# ## Dividing the data into testing and training dataset
#
# We will split the data into two parts (one for training+validation and one for testing).
# We will also apply "standard scaling" preprocessing: http://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.StandardScaler.html i.e. making the mean = 0 and the RMS = 1 for all input variables (based **only** on the training/validation dataset).
# We will also define our early stopping criteria to prevent over-fitting and we will save the model based on the best `val_loss`.

# %%
NDIM = len(VARS)
dataset = df_all.values
X = dataset[:,0:NDIM]
Y = dataset[:,NDIM]

from sklearn.model_selection import train_test_split
X_train_val, X_test, Y_train_val, Y_test = train_test_split(X, Y, test_size=0.2, random_state=7)

# preprocessing: standard scalar
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler().fit(X_train_val)
X_train_val = scaler.transform(X_train_val)
X_test = scaler.transform(X_test)

# baseline keras model
from keras.models import Sequential, Model
from tensorflow.keras.optimizers import SGD
#from keras.optimizers import SGD
from keras.layers import Input, Activation, Dense, Convolution2D, MaxPooling2D, Dropout, Flatten
from keras.utils import np_utils
from sklearn.model_selection import RandomizedSearchCV
from sklearn.pipeline import Pipeline
from tensorflow import keras

inputs = Input(shape=(NDIM,), name = 'input') 
hidden1 = Dense(20, name = 'hidden1', kernel_initializer='normal', activation='relu')(inputs)
hidden2 = Dense(20, name = 'hidden2', kernel_initializer='normal', activation='relu')(hidden1)
outputs = Dense(1, name = 'output', kernel_initializer='normal', activation='sigmoid')(hidden2)

# create the model
model = Model(inputs=inputs, outputs=outputs)
# compile the model
optimizer = SGD(learning_rate=1e-3) # define the optimizer
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
#model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])
# print the model summary
model.summary()

# early stopping callback
from keras.callbacks import EarlyStopping
early_stopping = EarlyStopping(monitor='val_loss', patience=10, mode='min')

# model checkpoint callback
# this saves our model architecture + parameters into dense_model.h5
from keras.callbacks import ModelCheckpoint
model_checkpoint = ModelCheckpoint(filepath='./models/up_NN_model.h5', monitor='val_loss', 
                                   verbose=0, save_best_only=True, 
                                   save_weights_only=False, mode='auto', 
                                   period=1)
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input (InputLayer)          [(None, 11)]              0
#
#  hidden1 (Dense)             (None, 20)                240
#
#  hidden2 (Dense)             (None, 20)                420
#
#  output (Dense)              (None, 1)                 21
#
# =================================================================
# Total params: 681
# Trainable params: 681
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %% [markdown]
# ## Run training
# Here, we run the training.

# %%
# Train classifier
import time
start = time.time() # time at start of whole processing

history = model.fit(X_train_val, 
                    Y_train_val, 
                    epochs=1000, 
                    batch_size=512, 
                    verbose=1, # switch to 1 for more verbosity 
                    callbacks=[early_stopping, model_checkpoint], 
                    validation_data=(X_test,Y_test))

elapsed = time.time() - start # time after whole processing
print("Time taken: "+str(round(elapsed,1))+"s") # print total time taken to process every file
# Out:
# Epoch 1/1000
# 334/334 [==============================] - 2s 3ms/step - loss: 0.6551 - accuracy: 0.6129 - val_loss: 0.6319 - val_accuracy: 0.6496
# Epoch 2/1000
# 334/334 [==============================] - 1s 2ms/step - loss: 0.6298 - accuracy: 0.6526 - val_loss: 0.6241 - val_accuracy: 0.6549
# Epoch 3/1000
# 334/334 [==============================] - 1s 2ms/step - loss: 0.6245 - accuracy: 0.6551 - val_loss: 0.6196 - val_accuracy: 0.6576
# Epoch 4/1000
# 334/334 [==============================] - 1s 2ms/step - loss: 0.6200 - accuracy: 0.6581 - val_loss: 0.6142 - val_accuracy: 0.6606
# Epoch 5/1000
# 334/334 [==============================] - 1s 3ms/step - loss: 0.6156 - accuracy: 0.6614 - val_loss: 0.6113 - val_accuracy: 0.6610
# Epoch 6/1000
# 334/334 [==============================] - 1s 2ms/step - loss: 0.6119 - accuracy: 0.6648 - val_loss: 0.6073 - val_accuracy: 0.6635
# Epoch 7/1000
# 334/334 [==============================] - 1s 2ms/step - loss: 0.6089 - accuracy: 0.6675 - val_loss: 0.6046 - val_accuracy: 0.6690
# Epoch 8/1000
# 334/334 [==============================] - 1s 2ms/step - loss: 0.6067 - accuracy: 0.6698 - val_loss: 0.6031 - val_accuracy: 0.6685
# Epoch 9/1000
# 334/334 [==============================] - 0s 1ms/step - loss: 0.6049 - accuracy: 0.6719 - val_loss: 0.6013 - val_accuracy: 0.6716
# Epoch 10/1000
# 334/334 [==============================] - 1s 2ms/step - loss: 0.6029 - accuracy: 0.6738 - val_loss: 0.5993 - val_accuracy: 0.6739
# Epoch 11/1000
# 334/334 [==============================] - 1s 2ms/step - loss: 0.6014 - accuracy: 0.6754 - val_loss: 0.5977 - val_accuracy: 0.6761
# Epoch 12/1000
# 334/334 [==============================] - 1s 2ms/step - loss: 0.5996 - accuracy: 0.6769 - val_loss: 0.5979 - val_accuracy: 0.6758
# Epoch 13/1000
# 334/334 [==============================] - 1s 2ms/step - loss: 0.5986 - accuracy: 0.6787 - val_loss: 0.5956 - val_accuracy: 0.6786
# Epoch 14/1000
# 334/334 [==============================] - 1s 2ms/step - loss: 0.5972 - accuracy: 0.6797 - val_loss: 0.5950 - val_accuracy: 0.6802
# Epoch 15/1000
# 334/334 [==============================] - 1s 2ms/step - loss: 0.5964 - accuracy: 0.6803 - val_loss: 0.5940 - val_accuracy: 0.6808
# Epoch 16/1000
# 334/334 [==============================] - 1s 2ms/step - loss: 0.5955 - accuracy: 0.6812 - val_loss: 0.5930 - val_accuracy: 0.6800
# Epoch 17/1000
# 334/334 [==============================] - 1s 2ms/step - loss: 0.5950 - accuracy: 0.6820 - val_loss: 0.5928 - val_accuracy: 0.6817
# Epoch 18/1000
# 334/334 [==============================] - 1s 2ms/step - loss: 0.5944 - accuracy: 0.6815 - val_loss: 0.5918 - val_accuracy: 0.6814
# Epoch 19/1000
# 334/334 [==============================] - 0s 1ms/step - loss: 0.5939 - accuracy: 0.6820 - val_loss: 0.5950 - val_accuracy: 0.6796
# Epoch 20/1000
# 334/334 [==============================] - 0s 1ms/step - loss: 0.5935 - accuracy: 0.6825 - val_loss: 0.5913 - val_accuracy: 0.6827
# Epoch 21/1000
# 334/334 [==============================] - 0s 1ms/step - loss: 0.5933 - accuracy: 0.6828 - val_loss: 0.5949 - val_accuracy: 0.6804
# Epoch 22/1000
# 334/334 [==============================] - 0s 1ms/step - loss: 0.5926 - accuracy: 0.6836 - val_loss: 0.5908 - val_accuracy: 0.6827
# Epoch 23/1000
# 334/334 [==============================] - 0s 1ms/step - loss: 0.5924 - accuracy: 0.6830 - val_loss: 0.5914 - val_accuracy: 0.6826
# Epoch 24/1000
# 334/334 [==============================] - 0s 1ms/step - loss: 0.5918 - accuracy: 0.6843 - val_loss: 0.5907 - val_accuracy: 0.6829
# Epoch 25/1000
# 334/334 [==============================] - 0s 1ms/step - loss: 0.5917 - accuracy: 0.6837 - val_loss: 0.5897 - val_accuracy: 0.6837
# Epoch 26/1000
# 334/334 [==============================] - 0s 1ms/step - loss: 0.5914 - accuracy: 0.6845 - val_loss: 0.5893 - val_accuracy: 0.6839
# Epoch 27/1000
# 334/334 [==============================] - 0s 1ms/step - loss: 0.5911 - accuracy: 0.6846 - val_loss: 0.5908 - val_accuracy: 0.6827
# Epoch 28/1000
# 334/334 [==============================] - 0s 1ms/step - loss: 0.5905 - accuracy: 0.6849 - val_loss: 0.5898 - val_accuracy: 0.6828
# Epoch 29/1000
# 334/334 [==============================] - 1s 2ms/step - loss: 0.5902 - accuracy: 0.6847 - val_loss: 0.5892 - val_accuracy: 0.6826
# Epoch 30/1000
# 334/334 [==============================] - 0s 1ms/step - loss: 0.5899 - accuracy: 0.6849 - val_loss: 0.5885 - val_accuracy: 0.6824
# Epoch 31/1000
# 334/334 [==============================] - 0s 1ms/step - loss: 0.5896 - accuracy: 0.6854 - val_loss: 0.5881 - val_accuracy: 0.6845
# Epoch 32/1000
# 334/334 [==============================] - 1s 2ms/step - loss: 0.5894 - accuracy: 0.6856 - val_loss: 0.5877 - val_accuracy: 0.6846
# Epoch 33/1000
# 334/334 [==============================] - 0s 1ms/step - loss: 0.5889 - accuracy: 0.6855 - val_loss: 0.5877 - val_accuracy: 0.6856
# Epoch 34/1000
# 334/334 [==============================] - 0s 1ms/step - loss: 0.5888 - accuracy: 0.6855 - val_loss: 0.5874 - val_accuracy: 0.6846
# Epoch 35/1000
# 334/334 [==============================] - 1s 2ms/step - loss: 0.5888 - accuracy: 0.6856 - val_loss: 0.5879 - val_accuracy: 0.6849
# Epoch 36/1000
# 334/334 [==============================] - 0s 1ms/step - loss: 0.5883 - accuracy: 0.6858 - val_loss: 0.5865 - val_accuracy: 0.6861
# Epoch 37/1000
# 334/334 [==============================] - 0s 1ms/step - loss: 0.5880 - accuracy: 0.6864 - val_loss: 0.5868 - val_accuracy: 0.6849
# Epoch 38/1000
# 334/334 [==============================] - 1s 2ms/step - loss: 0.5876 - accuracy: 0.6866 - val_loss: 0.5866 - val_accuracy: 0.6853
# Epoch 39/1000
# 334/334 [==============================] - 1s 2ms/step - loss: 0.5877 - accuracy: 0.6868 - val_loss: 0.5865 - val_accuracy: 0.6860
# Epoch 40/1000
# 334/334 [==============================] - 1s 3ms/step - loss: 0.5872 - accuracy: 0.6866 - val_loss: 0.5862 - val_accuracy: 0.6851
# Epoch 41/1000
# 334/334 [==============================] - 0s 1ms/step - loss: 0.5869 - accuracy: 0.6872 - val_loss: 0.5866 - val_accuracy: 0.6872
# Epoch 42/1000
# 334/334 [==============================] - 0s 1ms/step - loss: 0.5868 - accuracy: 0.6874 - val_loss: 0.5862 - val_accuracy: 0.6862
# Epoch 43/1000
# 334/334 [==============================] - 0s 1ms/step - loss: 0.5867 - accuracy: 0.6878 - val_loss: 0.5850 - val_accuracy: 0.6874
# Epoch 44/1000
# 334/334 [==============================] - 0s 1ms/step - loss: 0.5864 - accuracy: 0.6881 - val_loss: 0.5856 - val_accuracy: 0.6857
# Epoch 45/1000
# 334/334 [==============================] - 0s 1ms/step - loss: 0.5861 - accuracy: 0.6879 - val_loss: 0.5851 - val_accuracy: 0.6856
# Epoch 46/1000
# 334/334 [==============================] - 0s 1ms/step - loss: 0.5858 - accuracy: 0.6879 - val_loss: 0.5854 - val_accuracy: 0.6861
# Epoch 47/1000
# 334/334 [==============================] - 0s 1ms/step - loss: 0.5856 - accuracy: 0.6888 - val_loss: 0.5848 - val_accuracy: 0.6865
# Epoch 48/1000
# 334/334 [==============================] - 0s 1ms/step - loss: 0.5853 - accuracy: 0.6886 - val_loss: 0.5842 - val_accuracy: 0.6876
# Epoch 49/1000
# 334/334 [==============================] - 0s 1ms/step - loss: 0.5850 - accuracy: 0.6891 - val_loss: 0.5844 - val_accuracy: 0.6877
# Epoch 50/1000
# 334/334 [==============================] - 0s 1ms/step - loss: 0.5850 - accuracy: 0.6886 - val_loss: 0.5840 - val_accuracy: 0.6871
# Epoch 51/1000
# 334/334 [==============================] - 0s 1ms/step - loss: 0.5847 - accuracy: 0.6894 - val_loss: 0.5840 - val_accuracy: 0.6872
# Epoch 52/1000
# 334/334 [==============================] - 0s 1ms/step - loss: 0.5843 - accuracy: 0.6892 - val_loss: 0.5854 - val_accuracy: 0.6853
# Epoch 53/1000
# 334/334 [==============================] - 0s 1ms/step - loss: 0.5840 - accuracy: 0.6898 - val_loss: 0.5840 - val_accuracy: 0.6885
# Epoch 54/1000
# 334/334 [==============================] - 0s 1ms/step - loss: 0.5839 - accuracy: 0.6897 - val_loss: 0.5827 - val_accuracy: 0.6888
# Epoch 55/1000
# 334/334 [==============================] - 0s 1ms/step - loss: 0.5837 - accuracy: 0.6904 - val_loss: 0.5832 - val_accuracy: 0.6866
# Epoch 56/1000
# 334/334 [==============================] - 0s 1ms/step - loss: 0.5835 - accuracy: 0.6898 - val_loss: 0.5840 - val_accuracy: 0.6882
# Epoch 57/1000
# 334/334 [==============================] - 0s 1ms/step - loss: 0.5832 - accuracy: 0.6901 - val_loss: 0.5836 - val_accuracy: 0.6878
# Epoch 58/1000
# 334/334 [==============================] - 0s 1ms/step - loss: 0.5832 - accuracy: 0.6906 - val_loss: 0.5828 - val_accuracy: 0.6882
# Epoch 59/1000
# 334/334 [==============================] - 0s 1ms/step - loss: 0.5833 - accuracy: 0.6899 - val_loss: 0.5824 - val_accuracy: 0.6876
# Epoch 60/1000
# 334/334 [==============================] - 0s 1ms/step - loss: 0.5827 - accuracy: 0.6910 - val_loss: 0.5828 - val_accuracy: 0.6883
# Epoch 61/1000
# 334/334 [==============================] - 0s 1ms/step - loss: 0.5826 - accuracy: 0.6906 - val_loss: 0.5827 - val_accuracy: 0.6899
# Epoch 62/1000
# 334/334 [==============================] - 0s 1ms/step - loss: 0.5825 - accuracy: 0.6907 - val_loss: 0.5823 - val_accuracy: 0.6902
# Epoch 63/1000
# 334/334 [==============================] - 1s 2ms/step - loss: 0.5824 - accuracy: 0.6904 - val_loss: 0.5824 - val_accuracy: 0.6879
# Epoch 64/1000
# 334/334 [==============================] - 0s 1ms/step - loss: 0.5822 - accuracy: 0.6901 - val_loss: 0.5826 - val_accuracy: 0.6879
# Epoch 65/1000
# 334/334 [==============================] - 0s 1ms/step - loss: 0.5822 - accuracy: 0.6909 - val_loss: 0.5820 - val_accuracy: 0.6905
# Epoch 66/1000
# 334/334 [==============================] - 0s 1ms/step - loss: 0.5822 - accuracy: 0.6900 - val_loss: 0.5822 - val_accuracy: 0.6887
# Epoch 67/1000
# 334/334 [==============================] - 0s 1ms/step - loss: 0.5818 - accuracy: 0.6910 - val_loss: 0.5818 - val_accuracy: 0.6890
# Epoch 68/1000
# 334/334 [==============================] - 0s 1ms/step - loss: 0.5816 - accuracy: 0.6911 - val_loss: 0.5822 - val_accuracy: 0.6888
# Epoch 69/1000
# 334/334 [==============================] - 0s 1ms/step - loss: 0.5817 - accuracy: 0.6907 - val_loss: 0.5827 - val_accuracy: 0.6879
# Epoch 70/1000
# 334/334 [==============================] - 0s 1ms/step - loss: 0.5816 - accuracy: 0.6908 - val_loss: 0.5807 - val_accuracy: 0.6906
# Epoch 71/1000
# 334/334 [==============================] - 0s 1ms/step - loss: 0.5814 - accuracy: 0.6908 - val_loss: 0.5839 - val_accuracy: 0.6886
# Epoch 72/1000
# 334/334 [==============================] - 0s 1ms/step - loss: 0.5815 - accuracy: 0.6913 - val_loss: 0.5827 - val_accuracy: 0.6898
# Epoch 73/1000
# 334/334 [==============================] - 0s 1ms/step - loss: 0.5814 - accuracy: 0.6914 - val_loss: 0.5823 - val_accuracy: 0.6895
# Epoch 74/1000
# 334/334 [==============================] - 0s 1ms/step - loss: 0.5811 - accuracy: 0.6914 - val_loss: 0.5817 - val_accuracy: 0.6917
# Epoch 75/1000
# 334/334 [==============================] - 0s 1ms/step - loss: 0.5811 - accuracy: 0.6916 - val_loss: 0.5843 - val_accuracy: 0.6871
# Epoch 76/1000
# 334/334 [==============================] - 0s 1ms/step - loss: 0.5813 - accuracy: 0.6920 - val_loss: 0.5810 - val_accuracy: 0.6915
# Epoch 77/1000
# 334/334 [==============================] - 0s 1ms/step - loss: 0.5810 - accuracy: 0.6915 - val_loss: 0.5808 - val_accuracy: 0.6919
# Epoch 78/1000
# 334/334 [==============================] - 0s 1ms/step - loss: 0.5810 - accuracy: 0.6915 - val_loss: 0.5818 - val_accuracy: 0.6886
# Epoch 79/1000
# 334/334 [==============================] - 0s 1ms/step - loss: 0.5807 - accuracy: 0.6917 - val_loss: 0.5811 - val_accuracy: 0.6916
# Epoch 80/1000
# 334/334 [==============================] - 0s 1ms/step - loss: 0.5810 - accuracy: 0.6915 - val_loss: 0.5817 - val_accuracy: 0.6898
# Time taken: 41.8s

# %% [markdown]
# ## Plot performance and reports
# Here, we plot the history of the training and the peNNormance in a ROC curve

# %%
loss_accuracy_plotter(history)

fpr_nn, tpr_nn, thresholds_nn = evaluate(model, scaler, X, Y, X_train_val, Y_train_val, X_test, Y_test)
df_all['dense_NN'] = model.predict(scaler.transform(X)).round() # add prediction to array
# Out:
# 1333/1333 [==============================] - 1s 645us/step
# 5330/5330 [==============================] - 4s 658us/step
# 1333/1333 [==============================] - 1s 646us/step
# 5330/5330 [==============================] - 4s 659us/step
# 6662/6662 [==============================] - 4s 659us/step
# Test acc score: 0.6897999390201
# Train acc score: 0.6921380992588423
# Classification report for the test set
#               precision    recall  f1-score   support
#
#   background       0.68      0.60      0.64     19328
#       signal       0.70      0.76      0.73     23309
#
#     accuracy                           0.69     42637
#    macro avg       0.69      0.68      0.68     42637
# weighted avg       0.69      0.69      0.69     42637
#
# Classification report for the total set
#               precision    recall  f1-score   support
#
#   background       0.68      0.61      0.64     96352
#       signal       0.70      0.76      0.73    116829
#
#     accuracy                           0.69    213181
#    macro avg       0.69      0.68      0.69    213181
# weighted avg       0.69      0.69      0.69    213181
#
# Confusion matrix for total set
# [[58299 38053]
#  [27677 89152]]
# 6662/6662 [==============================] - 5s 734us/step

# %%
# add TF NN probability
y_tot_prob_NN = model.predict(scaler.transform(X))
y_tot_NN = model.predict(scaler.transform(X)).round()

cumulative_events = 0 # start counter for total number of events for which output is saved
for key in filename.keys(): # loop over samples
    df[key]['NN_output_prob'] = y_tot_prob_NN[cumulative_events:cumulative_events+len(df[key])]
    df[key]['NN_output'] = y_tot_NN[cumulative_events:cumulative_events+len(df[key])]
    cumulative_events += len(df[key]) # increment counter for total number of events
    #print(df[key]['NN_output']) # print the dataframe column NN_output

# probability and significance plots
NN_output_prob = { # dictionary containing plotting parameters for the mllll histogram
    # change plotting parameters
    'bin_width':0.1, # width of each histogram bin
    'num_bins':9, # number of histogram bins
    'xrange_min':0, # minimum on x-axis
    'xlabel':'Neural Network output', # x-axis label
}

SoverB_hist_dict = {'NN_output_prob':NN_output_prob}
plot_SoverB(df, SoverB_hist_dict)
# Out:
# 6662/6662 [==============================] - 4s 668us/step
# 6662/6662 [==============================] - 4s 663us/step

# %% [markdown]
# ## NN Hyperparameter optimization

# %%
def main():
        
    keras_pipeline = Pipeline([("scaler", StandardScaler()),
                               ("clf", keras.wrappers.scikit_learn.KerasClassifier(
                                   build_fn=make_model))
    ])
    
    param_grid = {'clf__network_layers': [(32, 32), (64, 64), (128, 128, 128)],
     'clf__batch_size': [64, 128, 256, 512],
     'clf__epochs': [5, 10, 15, 50, 100, 200],
     'clf__dropout_rate': [0.1, 0.01],
     'clf__optimizer': ['Nadam', 'Adam', 'SGD'],
     'clf__activation': ['selu', 'relu', 'tanh'],
     'clf__k_initializer': ['lecun_normal', 'normal'],
     'clf__verbose': [0]
    }
    
    rs_keras = RandomizedSearchCV(keras_pipeline,
                                  param_distributions=param_grid,
                                  cv=5, refit=True,
                                  verbose=0,
                                  n_iter=5,
                                  scoring="accuracy")
    
    history = rs_keras.fit(np.array(X_train_val),
                 np.array(Y_train_val))
    
    print('Best score obtained: {0}'.format(rs_keras.best_score_))
    print('Parameters:')
    for param, value in rs_keras.best_params_.items():
        print('\t{}: {}'.format(param, value))
    return  rs_keras  

def make_model(network_layers=[(32, 32)],
               dropout_rate=0,
               optimizer="Nadam",
               activation="selu",
               k_initializer='lecun_normal',
               n_input=NDIM,
               n_class=1):
    
    model = keras.models.Sequential()

    for index, layers in enumerate(network_layers):
        if not index:
            model.add(keras.layers.Dense(layers,
                                         input_dim=n_input,
                                         activation=activation,
                                         kernel_initializer=k_initializer))
        else:
            model.add(keras.layers.Dense(layers,
                                         kernel_initializer=k_initializer,
                                         activation=activation))
        if dropout_rate and index:
            model.add(keras.layers.AlphaDropout(dropout_rate))

    model.add(keras.layers.Dense(n_class,
                                 activation="sigmoid"))
    
    model.compile(loss='binary_crossentropy',
                  optimizer=optimizer,
                  metrics=['accuracy'])
    #print(model.summary())
    return model

do_opt = False
if (do_opt):
    if __name__ == '__main__':
        opt_model = main()

# %%
'''
Best score obtained: 0.7094453833758017
Parameters:
	clf__verbose: 0
	clf__optimizer: Nadam
	clf__network_layers: (128, 128, 128)
	clf__k_initializer: normal
	clf__epochs: 200
	clf__dropout_rate: 0.1
	clf__batch_size: 256
	clf__activation: selu

'''
# Out:
# '\nBest score obtained: 0.7094453833758017\nParameters:\n\tclf__verbose: 0\n\tclf__optimizer: Nadam\n\tclf__network_layers: (128, 128, 128)\n\tclf__k_initializer: normal\n\tclf__epochs: 200\n\tclf__dropout_rate: 0.1\n\tclf__batch_size: 256\n\tclf__activation: selu\n\n'

# %% [markdown]
# ## NN with dropout layer for overfit checking

# %%
# Packages for modeling
from keras import models
from keras import layers
from keras import regularizers

drop_model = models.Sequential()
drop_model.add(layers.Dense(128,  kernel_initializer='normal', activation='selu', input_shape=(NDIM,)))
drop_model.add(layers.Dropout(0.1))
drop_model.add(layers.Dense(128,  kernel_initializer='normal', activation='selu'))
drop_model.add(layers.Dropout(0.1))
drop_model.add(layers.Dense(128,  kernel_initializer='normal', activation='selu'))
drop_model.add(layers.Dropout(0.1))
drop_model.add(layers.Dense(1, kernel_initializer='normal', activation='sigmoid'))

# compile the model
drop_model.compile(optimizer='Nadam', loss='binary_crossentropy', metrics=['accuracy'])
#drop_model.compile(optimizer='Adam', loss='binary_crossentropy', metrics=['accuracy'])
# print the model summary
drop_model.summary()

# early stopping callback
from keras.callbacks import EarlyStopping
early_stopping = EarlyStopping(monitor='val_loss', patience=10, mode='min')

# Train classifier
import time
start = time.time() # time at start of whole processing

model_checkpoint = ModelCheckpoint(filepath='./models/up_NN_opt_drop_model.h5', monitor='val_loss', 
                                   verbose=0, save_best_only=True, 
                                   save_weights_only=False, mode='auto', 
                                   period=1)

drop_history = drop_model.fit(X_train_val, 
                    Y_train_val, 
                    epochs=200, 
                    batch_size=256, 
                    verbose=1, # switch to 1 for more verbosity 
                    callbacks=[early_stopping, model_checkpoint], 
                    validation_data=(X_test,Y_test))

elapsed = time.time() - start # time after whole processing
print("Time taken: "+str(round(elapsed,1))+"s") # print total time taken to process every file
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 128)               1536
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 128)               16512
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_2 (Dense)             (None, 128)               16512
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  dense_3 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 34,689
# Trainable params: 34,689
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/200
# 667/667 [==============================] - 4s 4ms/step - loss: 0.6402 - accuracy: 0.6399 - val_loss: 0.6265 - val_accuracy: 0.6530
# Epoch 2/200
# 667/667 [==============================] - 2s 3ms/step - loss: 0.6275 - accuracy: 0.6529 - val_loss: 0.6172 - val_accuracy: 0.6598
# Epoch 3/200
# 667/667 [==============================] - 2s 3ms/step - loss: 0.6232 - accuracy: 0.6562 - val_loss: 0.6115 - val_accuracy: 0.6660
# Epoch 4/200
# 667/667 [==============================] - 2s 3ms/step - loss: 0.6209 - accuracy: 0.6594 - val_loss: 0.6097 - val_accuracy: 0.6667
# Epoch 5/200
# 667/667 [==============================] - 2s 3ms/step - loss: 0.6191 - accuracy: 0.6603 - val_loss: 0.6156 - val_accuracy: 0.6590
# Epoch 6/200
# 667/667 [==============================] - 2s 3ms/step - loss: 0.6179 - accuracy: 0.6610 - val_loss: 0.6095 - val_accuracy: 0.6653
# Epoch 7/200
# 667/667 [==============================] - 2s 3ms/step - loss: 0.6165 - accuracy: 0.6615 - val_loss: 0.6124 - val_accuracy: 0.6661
# Epoch 8/200
# 667/667 [==============================] - 2s 3ms/step - loss: 0.6142 - accuracy: 0.6640 - val_loss: 0.6056 - val_accuracy: 0.6714
# Epoch 9/200
# 667/667 [==============================] - 2s 3ms/step - loss: 0.6125 - accuracy: 0.6668 - val_loss: 0.6040 - val_accuracy: 0.6714
# Epoch 10/200
# 667/667 [==============================] - 2s 3ms/step - loss: 0.6099 - accuracy: 0.6678 - val_loss: 0.6016 - val_accuracy: 0.6722
# Epoch 11/200
# 667/667 [==============================] - 2s 3ms/step - loss: 0.6084 - accuracy: 0.6696 - val_loss: 0.5990 - val_accuracy: 0.6751
# Epoch 12/200
# 667/667 [==============================] - 2s 3ms/step - loss: 0.6061 - accuracy: 0.6707 - val_loss: 0.5977 - val_accuracy: 0.6771
# Epoch 13/200
# 667/667 [==============================] - 2s 3ms/step - loss: 0.6057 - accuracy: 0.6717 - val_loss: 0.5963 - val_accuracy: 0.6811
# Epoch 14/200
# 667/667 [==============================] - 2s 3ms/step - loss: 0.6047 - accuracy: 0.6722 - val_loss: 0.5941 - val_accuracy: 0.6790
# Epoch 15/200
# 667/667 [==============================] - 2s 3ms/step - loss: 0.6029 - accuracy: 0.6746 - val_loss: 0.5955 - val_accuracy: 0.6779
# Epoch 16/200
# 667/667 [==============================] - 2s 4ms/step - loss: 0.6025 - accuracy: 0.6746 - val_loss: 0.5929 - val_accuracy: 0.6807
# Epoch 17/200
# 667/667 [==============================] - 2s 3ms/step - loss: 0.6009 - accuracy: 0.6758 - val_loss: 0.5913 - val_accuracy: 0.6799
# Epoch 18/200
# 667/667 [==============================] - 2s 3ms/step - loss: 0.6002 - accuracy: 0.6763 - val_loss: 0.5909 - val_accuracy: 0.6853
# Epoch 19/200
# 667/667 [==============================] - 2s 3ms/step - loss: 0.5983 - accuracy: 0.6771 - val_loss: 0.5907 - val_accuracy: 0.6832
# Epoch 20/200
# 667/667 [==============================] - 2s 3ms/step - loss: 0.5977 - accuracy: 0.6775 - val_loss: 0.5884 - val_accuracy: 0.6840
# Epoch 21/200
# 667/667 [==============================] - 3s 4ms/step - loss: 0.5958 - accuracy: 0.6797 - val_loss: 0.5883 - val_accuracy: 0.6842
# Epoch 22/200
# 667/667 [==============================] - 2s 3ms/step - loss: 0.5958 - accuracy: 0.6802 - val_loss: 0.5862 - val_accuracy: 0.6868
# Epoch 23/200
# 667/667 [==============================] - 2s 3ms/step - loss: 0.5933 - accuracy: 0.6818 - val_loss: 0.5867 - val_accuracy: 0.6870
# Epoch 24/200
# 667/667 [==============================] - 2s 3ms/step - loss: 0.5940 - accuracy: 0.6811 - val_loss: 0.5832 - val_accuracy: 0.6893
# Epoch 25/200
# 667/667 [==============================] - 2s 3ms/step - loss: 0.5918 - accuracy: 0.6829 - val_loss: 0.5817 - val_accuracy: 0.6914
# Epoch 26/200
# 667/667 [==============================] - 2s 3ms/step - loss: 0.5911 - accuracy: 0.6832 - val_loss: 0.5829 - val_accuracy: 0.6892
# Epoch 27/200
# 667/667 [==============================] - 2s 3ms/step - loss: 0.5910 - accuracy: 0.6832 - val_loss: 0.5811 - val_accuracy: 0.6901
# Epoch 28/200
# 667/667 [==============================] - 2s 3ms/step - loss: 0.5895 - accuracy: 0.6852 - val_loss: 0.5813 - val_accuracy: 0.6897
# Epoch 29/200
# 667/667 [==============================] - 2s 3ms/step - loss: 0.5895 - accuracy: 0.6854 - val_loss: 0.5807 - val_accuracy: 0.6906
# Epoch 30/200
# 667/667 [==============================] - 2s 3ms/step - loss: 0.5894 - accuracy: 0.6848 - val_loss: 0.5797 - val_accuracy: 0.6914
# Epoch 31/200
# 667/667 [==============================] - 2s 3ms/step - loss: 0.5887 - accuracy: 0.6864 - val_loss: 0.5810 - val_accuracy: 0.6896
# Epoch 32/200
# 667/667 [==============================] - 2s 3ms/step - loss: 0.5878 - accuracy: 0.6860 - val_loss: 0.5781 - val_accuracy: 0.6928
# Epoch 33/200
# 667/667 [==============================] - 2s 3ms/step - loss: 0.5874 - accuracy: 0.6867 - val_loss: 0.5784 - val_accuracy: 0.6903
# Epoch 34/200
# 667/667 [==============================] - 2s 3ms/step - loss: 0.5865 - accuracy: 0.6877 - val_loss: 0.5773 - val_accuracy: 0.6948
# Epoch 35/200
# 667/667 [==============================] - 2s 3ms/step - loss: 0.5865 - accuracy: 0.6879 - val_loss: 0.5788 - val_accuracy: 0.6919
# Epoch 36/200
# 667/667 [==============================] - 2s 3ms/step - loss: 0.5858 - accuracy: 0.6879 - val_loss: 0.5774 - val_accuracy: 0.6941
# Epoch 37/200
# 667/667 [==============================] - 2s 3ms/step - loss: 0.5854 - accuracy: 0.6882 - val_loss: 0.5825 - val_accuracy: 0.6895
# Epoch 38/200
# 667/667 [==============================] - 2s 3ms/step - loss: 0.5842 - accuracy: 0.6888 - val_loss: 0.5783 - val_accuracy: 0.6928
# Epoch 39/200
# 667/667 [==============================] - 2s 3ms/step - loss: 0.5844 - accuracy: 0.6899 - val_loss: 0.5765 - val_accuracy: 0.6949
# Epoch 40/200
# 667/667 [==============================] - 2s 3ms/step - loss: 0.5840 - accuracy: 0.6903 - val_loss: 0.5772 - val_accuracy: 0.6902
# Epoch 41/200
# 667/667 [==============================] - 2s 3ms/step - loss: 0.5834 - accuracy: 0.6888 - val_loss: 0.5756 - val_accuracy: 0.6970
# Epoch 42/200
# 667/667 [==============================] - 2s 3ms/step - loss: 0.5831 - accuracy: 0.6912 - val_loss: 0.5763 - val_accuracy: 0.6932
# Epoch 43/200
# 667/667 [==============================] - 2s 3ms/step - loss: 0.5831 - accuracy: 0.6902 - val_loss: 0.5767 - val_accuracy: 0.6930
# Epoch 44/200
# 667/667 [==============================] - 2s 4ms/step - loss: 0.5827 - accuracy: 0.6900 - val_loss: 0.5745 - val_accuracy: 0.6958
# Epoch 45/200
# 667/667 [==============================] - 2s 3ms/step - loss: 0.5822 - accuracy: 0.6912 - val_loss: 0.5759 - val_accuracy: 0.6945
# Epoch 46/200
# 667/667 [==============================] - 2s 3ms/step - loss: 0.5814 - accuracy: 0.6913 - val_loss: 0.5758 - val_accuracy: 0.6937
# Epoch 47/200
# 667/667 [==============================] - 2s 3ms/step - loss: 0.5816 - accuracy: 0.6920 - val_loss: 0.5755 - val_accuracy: 0.6950
# Epoch 48/200
# 667/667 [==============================] - 2s 3ms/step - loss: 0.5810 - accuracy: 0.6919 - val_loss: 0.5751 - val_accuracy: 0.6946
# Epoch 49/200
# 667/667 [==============================] - 2s 3ms/step - loss: 0.5811 - accuracy: 0.6923 - val_loss: 0.5754 - val_accuracy: 0.6938
# Epoch 50/200
# 667/667 [==============================] - 3s 4ms/step - loss: 0.5805 - accuracy: 0.6912 - val_loss: 0.5757 - val_accuracy: 0.6962
# Epoch 51/200
# 667/667 [==============================] - 2s 3ms/step - loss: 0.5800 - accuracy: 0.6914 - val_loss: 0.5732 - val_accuracy: 0.6952
# Epoch 52/200
# 667/667 [==============================] - 2s 3ms/step - loss: 0.5799 - accuracy: 0.6914 - val_loss: 0.5729 - val_accuracy: 0.6964
# Epoch 53/200
# 667/667 [==============================] - 2s 3ms/step - loss: 0.5799 - accuracy: 0.6923 - val_loss: 0.5719 - val_accuracy: 0.6974
# Epoch 54/200
# 667/667 [==============================] - 2s 4ms/step - loss: 0.5792 - accuracy: 0.6930 - val_loss: 0.5709 - val_accuracy: 0.6985
# Epoch 55/200
# 667/667 [==============================] - 2s 3ms/step - loss: 0.5791 - accuracy: 0.6927 - val_loss: 0.5718 - val_accuracy: 0.6971
# Epoch 56/200
# 667/667 [==============================] - 2s 4ms/step - loss: 0.5793 - accuracy: 0.6933 - val_loss: 0.5729 - val_accuracy: 0.6956
# Epoch 57/200
# 667/667 [==============================] - 2s 3ms/step - loss: 0.5790 - accuracy: 0.6942 - val_loss: 0.5716 - val_accuracy: 0.6988
# Epoch 58/200
# 667/667 [==============================] - 2s 4ms/step - loss: 0.5785 - accuracy: 0.6937 - val_loss: 0.5754 - val_accuracy: 0.6937
# Epoch 59/200
# 667/667 [==============================] - 2s 3ms/step - loss: 0.5785 - accuracy: 0.6939 - val_loss: 0.5719 - val_accuracy: 0.6988
# Epoch 60/200
# 667/667 [==============================] - 2s 3ms/step - loss: 0.5782 - accuracy: 0.6944 - val_loss: 0.5716 - val_accuracy: 0.6979
# Epoch 61/200
# 667/667 [==============================] - 2s 4ms/step - loss: 0.5777 - accuracy: 0.6937 - val_loss: 0.5714 - val_accuracy: 0.6979
# Epoch 62/200
# 667/667 [==============================] - 2s 4ms/step - loss: 0.5780 - accuracy: 0.6940 - val_loss: 0.5707 - val_accuracy: 0.6988
# Epoch 63/200
# 667/667 [==============================] - 2s 3ms/step - loss: 0.5773 - accuracy: 0.6937 - val_loss: 0.5738 - val_accuracy: 0.6940
# Epoch 64/200
# 667/667 [==============================] - 2s 4ms/step - loss: 0.5769 - accuracy: 0.6952 - val_loss: 0.5740 - val_accuracy: 0.6950
# Epoch 65/200
# 667/667 [==============================] - 2s 3ms/step - loss: 0.5771 - accuracy: 0.6952 - val_loss: 0.5725 - val_accuracy: 0.6984
# Epoch 66/200
# 667/667 [==============================] - 2s 4ms/step - loss: 0.5766 - accuracy: 0.6961 - val_loss: 0.5706 - val_accuracy: 0.6986
# Epoch 67/200
# 667/667 [==============================] - 2s 3ms/step - loss: 0.5766 - accuracy: 0.6958 - val_loss: 0.5729 - val_accuracy: 0.6964
# Epoch 68/200
# 667/667 [==============================] - 2s 3ms/step - loss: 0.5761 - accuracy: 0.6958 - val_loss: 0.5718 - val_accuracy: 0.6974
# Epoch 69/200
# 667/667 [==============================] - 2s 3ms/step - loss: 0.5762 - accuracy: 0.6952 - val_loss: 0.5757 - val_accuracy: 0.6968
# Epoch 70/200
# 667/667 [==============================] - 2s 3ms/step - loss: 0.5757 - accuracy: 0.6958 - val_loss: 0.5722 - val_accuracy: 0.6978
# Epoch 71/200
# 667/667 [==============================] - 2s 4ms/step - loss: 0.5760 - accuracy: 0.6952 - val_loss: 0.5705 - val_accuracy: 0.6976
# Epoch 72/200
# 667/667 [==============================] - 3s 4ms/step - loss: 0.5753 - accuracy: 0.6965 - val_loss: 0.5690 - val_accuracy: 0.6996
# Epoch 73/200
# 667/667 [==============================] - 2s 3ms/step - loss: 0.5743 - accuracy: 0.6965 - val_loss: 0.5704 - val_accuracy: 0.6985
# Epoch 74/200
# 667/667 [==============================] - 2s 3ms/step - loss: 0.5747 - accuracy: 0.6967 - val_loss: 0.5708 - val_accuracy: 0.6973
# Epoch 75/200
# 667/667 [==============================] - 2s 3ms/step - loss: 0.5748 - accuracy: 0.6974 - val_loss: 0.5695 - val_accuracy: 0.6984
# Epoch 76/200
# 667/667 [==============================] - 2s 4ms/step - loss: 0.5747 - accuracy: 0.6957 - val_loss: 0.5695 - val_accuracy: 0.6981
# Epoch 77/200
# 667/667 [==============================] - 2s 3ms/step - loss: 0.5745 - accuracy: 0.6969 - val_loss: 0.5713 - val_accuracy: 0.6960
# Epoch 78/200
# 667/667 [==============================] - 2s 3ms/step - loss: 0.5746 - accuracy: 0.6964 - val_loss: 0.5695 - val_accuracy: 0.6996
# Epoch 79/200
# 667/667 [==============================] - 2s 3ms/step - loss: 0.5739 - accuracy: 0.6963 - val_loss: 0.5700 - val_accuracy: 0.7005
# Epoch 80/200
# 667/667 [==============================] - 2s 3ms/step - loss: 0.5739 - accuracy: 0.6969 - val_loss: 0.5710 - val_accuracy: 0.7000
# Epoch 81/200
# 667/667 [==============================] - 2s 3ms/step - loss: 0.5734 - accuracy: 0.6973 - val_loss: 0.5674 - val_accuracy: 0.6992
# Epoch 82/200
# 667/667 [==============================] - 2s 3ms/step - loss: 0.5738 - accuracy: 0.6980 - val_loss: 0.5703 - val_accuracy: 0.6976
# Epoch 83/200
# 667/667 [==============================] - 2s 3ms/step - loss: 0.5738 - accuracy: 0.6977 - val_loss: 0.5687 - val_accuracy: 0.6994
# Epoch 84/200
# 667/667 [==============================] - 2s 4ms/step - loss: 0.5734 - accuracy: 0.6975 - val_loss: 0.5702 - val_accuracy: 0.6986
# Epoch 85/200
# 667/667 [==============================] - 2s 4ms/step - loss: 0.5732 - accuracy: 0.6968 - val_loss: 0.5684 - val_accuracy: 0.6998
# Epoch 86/200
# 667/667 [==============================] - 2s 3ms/step - loss: 0.5734 - accuracy: 0.6983 - val_loss: 0.5687 - val_accuracy: 0.6973
# Epoch 87/200
# 667/667 [==============================] - 2s 3ms/step - loss: 0.5724 - accuracy: 0.6978 - val_loss: 0.5726 - val_accuracy: 0.6947
# Epoch 88/200
# 667/667 [==============================] - 2s 3ms/step - loss: 0.5727 - accuracy: 0.6975 - val_loss: 0.5699 - val_accuracy: 0.6973
# Epoch 89/200
# 667/667 [==============================] - 2s 4ms/step - loss: 0.5726 - accuracy: 0.6980 - val_loss: 0.5679 - val_accuracy: 0.7003
# Epoch 90/200
# 667/667 [==============================] - 2s 3ms/step - loss: 0.5727 - accuracy: 0.6974 - val_loss: 0.5675 - val_accuracy: 0.7012
# Epoch 91/200
# 667/667 [==============================] - 2s 3ms/step - loss: 0.5722 - accuracy: 0.6980 - val_loss: 0.5693 - val_accuracy: 0.6992
# Time taken: 209.3s

# %%
drop_model1 = models.Sequential()
drop_model1.add(layers.Dense(32,  kernel_initializer='normal', activation='selu', input_shape=(NDIM,)))
drop_model1.add(layers.Dropout(0.1))
drop_model1.add(layers.Dense(32,  kernel_initializer='normal', activation='selu'))
drop_model1.add(layers.Dropout(0.1))
drop_model1.add(layers.Dense(1, kernel_initializer='normal', activation='sigmoid'))

# compile the model
drop_model1.compile(optimizer='Adam', loss='binary_crossentropy', metrics=['accuracy'])
# print the model summary
drop_model1.summary()

# early stopping callback
from keras.callbacks import EarlyStopping
early_stopping = EarlyStopping(monitor='val_loss', patience=10, mode='min')

# Train classifier
import time
start = time.time() # time at start of whole processing

model_checkpoint = ModelCheckpoint(filepath='./models/testup_NN_opt_drop_model.h5', monitor='val_loss', 
                                   verbose=0, save_best_only=True, 
                                   save_weights_only=False, mode='auto', 
                                   period=1)

drop_history1 = drop_model1.fit(X_train_val, 
                    Y_train_val, 
                    epochs=500, 
                    batch_size=256, 
                    verbose=1, # switch to 1 for more verbosity 
                    callbacks=[early_stopping, model_checkpoint], 
                    validation_data=(X_test,Y_test))

elapsed = time.time() - start # time after whole processing
print("Time taken: "+str(round(elapsed,1))+"s") # print total time taken to process every file
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_4 (Dense)             (None, 32)                384
#
#  dropout_3 (Dropout)         (None, 32)                0
#
#  dense_5 (Dense)             (None, 32)                1056
#
#  dropout_4 (Dropout)         (None, 32)                0
#
#  dense_6 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 1,473
# Trainable params: 1,473
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/500
# 667/667 [==============================] - 2s 2ms/step - loss: 0.6516 - accuracy: 0.6279 - val_loss: 0.6409 - val_accuracy: 0.6447
# Epoch 2/500
# 667/667 [==============================] - 1s 1ms/step - loss: 0.6424 - accuracy: 0.6397 - val_loss: 0.6358 - val_accuracy: 0.6445
# Epoch 3/500
# 667/667 [==============================] - 1s 2ms/step - loss: 0.6393 - accuracy: 0.6422 - val_loss: 0.6321 - val_accuracy: 0.6513
# Epoch 4/500
# 667/667 [==============================] - 1s 1ms/step - loss: 0.6376 - accuracy: 0.6426 - val_loss: 0.6302 - val_accuracy: 0.6490
# Epoch 5/500
# 667/667 [==============================] - 1s 1ms/step - loss: 0.6357 - accuracy: 0.6444 - val_loss: 0.6271 - val_accuracy: 0.6507
# Epoch 6/500
# 667/667 [==============================] - 1s 1ms/step - loss: 0.6347 - accuracy: 0.6459 - val_loss: 0.6275 - val_accuracy: 0.6533
# Epoch 7/500
# 667/667 [==============================] - 1s 2ms/step - loss: 0.6333 - accuracy: 0.6459 - val_loss: 0.6242 - val_accuracy: 0.6546
# Epoch 8/500
# 667/667 [==============================] - 1s 1ms/step - loss: 0.6326 - accuracy: 0.6480 - val_loss: 0.6229 - val_accuracy: 0.6560
# Epoch 9/500
# 667/667 [==============================] - 1s 1ms/step - loss: 0.6312 - accuracy: 0.6492 - val_loss: 0.6216 - val_accuracy: 0.6565
# Epoch 10/500
# 667/667 [==============================] - 1s 2ms/step - loss: 0.6313 - accuracy: 0.6490 - val_loss: 0.6219 - val_accuracy: 0.6562
# Epoch 11/500
# 667/667 [==============================] - 1s 1ms/step - loss: 0.6307 - accuracy: 0.6491 - val_loss: 0.6220 - val_accuracy: 0.6551
# Epoch 12/500
# 667/667 [==============================] - 1s 2ms/step - loss: 0.6301 - accuracy: 0.6502 - val_loss: 0.6201 - val_accuracy: 0.6578
# Epoch 13/500
# 667/667 [==============================] - 1s 1ms/step - loss: 0.6294 - accuracy: 0.6498 - val_loss: 0.6189 - val_accuracy: 0.6580
# Epoch 14/500
# 667/667 [==============================] - 1s 2ms/step - loss: 0.6297 - accuracy: 0.6501 - val_loss: 0.6193 - val_accuracy: 0.6594
# Epoch 15/500
# 667/667 [==============================] - 1s 1ms/step - loss: 0.6289 - accuracy: 0.6504 - val_loss: 0.6186 - val_accuracy: 0.6604
# Epoch 16/500
# 667/667 [==============================] - 1s 1ms/step - loss: 0.6282 - accuracy: 0.6521 - val_loss: 0.6192 - val_accuracy: 0.6589
# Epoch 17/500
# 667/667 [==============================] - 1s 1ms/step - loss: 0.6275 - accuracy: 0.6515 - val_loss: 0.6168 - val_accuracy: 0.6614
# Epoch 18/500
# 667/667 [==============================] - 1s 1ms/step - loss: 0.6272 - accuracy: 0.6522 - val_loss: 0.6166 - val_accuracy: 0.6612
# Epoch 19/500
# 667/667 [==============================] - 1s 2ms/step - loss: 0.6261 - accuracy: 0.6544 - val_loss: 0.6145 - val_accuracy: 0.6636
# Epoch 20/500
# 667/667 [==============================] - 1s 1ms/step - loss: 0.6256 - accuracy: 0.6538 - val_loss: 0.6141 - val_accuracy: 0.6643
# Epoch 21/500
# 667/667 [==============================] - 1s 2ms/step - loss: 0.6247 - accuracy: 0.6554 - val_loss: 0.6139 - val_accuracy: 0.6641
# Epoch 22/500
# 667/667 [==============================] - 1s 2ms/step - loss: 0.6233 - accuracy: 0.6568 - val_loss: 0.6125 - val_accuracy: 0.6654
# Epoch 23/500
# 667/667 [==============================] - 1s 2ms/step - loss: 0.6227 - accuracy: 0.6564 - val_loss: 0.6116 - val_accuracy: 0.6661
# Epoch 24/500
# 667/667 [==============================] - 1s 2ms/step - loss: 0.6221 - accuracy: 0.6574 - val_loss: 0.6110 - val_accuracy: 0.6667
# Epoch 25/500
# 667/667 [==============================] - 1s 2ms/step - loss: 0.6210 - accuracy: 0.6596 - val_loss: 0.6097 - val_accuracy: 0.6686
# Epoch 26/500
# 667/667 [==============================] - 1s 2ms/step - loss: 0.6203 - accuracy: 0.6603 - val_loss: 0.6108 - val_accuracy: 0.6664
# Epoch 27/500
# 667/667 [==============================] - 1s 2ms/step - loss: 0.6204 - accuracy: 0.6601 - val_loss: 0.6088 - val_accuracy: 0.6686
# Epoch 28/500
# 667/667 [==============================] - 1s 2ms/step - loss: 0.6192 - accuracy: 0.6618 - val_loss: 0.6085 - val_accuracy: 0.6688
# Epoch 29/500
# 667/667 [==============================] - 1s 2ms/step - loss: 0.6190 - accuracy: 0.6614 - val_loss: 0.6079 - val_accuracy: 0.6714
# Epoch 30/500
# 667/667 [==============================] - 1s 2ms/step - loss: 0.6184 - accuracy: 0.6622 - val_loss: 0.6075 - val_accuracy: 0.6717
# Epoch 31/500
# 667/667 [==============================] - 2s 3ms/step - loss: 0.6178 - accuracy: 0.6625 - val_loss: 0.6073 - val_accuracy: 0.6721
# Epoch 32/500
# 667/667 [==============================] - 1s 2ms/step - loss: 0.6179 - accuracy: 0.6634 - val_loss: 0.6074 - val_accuracy: 0.6727
# Epoch 33/500
# 667/667 [==============================] - 2s 3ms/step - loss: 0.6175 - accuracy: 0.6633 - val_loss: 0.6078 - val_accuracy: 0.6716
# Epoch 34/500
# 667/667 [==============================] - 1s 2ms/step - loss: 0.6175 - accuracy: 0.6630 - val_loss: 0.6065 - val_accuracy: 0.6725
# Epoch 35/500
# 667/667 [==============================] - 1s 2ms/step - loss: 0.6166 - accuracy: 0.6645 - val_loss: 0.6064 - val_accuracy: 0.6734
# Epoch 36/500
# 667/667 [==============================] - 1s 2ms/step - loss: 0.6164 - accuracy: 0.6644 - val_loss: 0.6060 - val_accuracy: 0.6724
# Epoch 37/500
# 667/667 [==============================] - 1s 2ms/step - loss: 0.6164 - accuracy: 0.6648 - val_loss: 0.6064 - val_accuracy: 0.6742
# Epoch 38/500
# 667/667 [==============================] - 1s 2ms/step - loss: 0.6167 - accuracy: 0.6635 - val_loss: 0.6053 - val_accuracy: 0.6730
# Epoch 39/500
# 667/667 [==============================] - 1s 2ms/step - loss: 0.6156 - accuracy: 0.6654 - val_loss: 0.6056 - val_accuracy: 0.6726
# Epoch 40/500
# 667/667 [==============================] - 1s 2ms/step - loss: 0.6163 - accuracy: 0.6646 - val_loss: 0.6049 - val_accuracy: 0.6745
# Epoch 41/500
# 667/667 [==============================] - 1s 2ms/step - loss: 0.6146 - accuracy: 0.6664 - val_loss: 0.6031 - val_accuracy: 0.6759
# Epoch 42/500
# 667/667 [==============================] - 1s 2ms/step - loss: 0.6142 - accuracy: 0.6657 - val_loss: 0.6036 - val_accuracy: 0.6758
# Epoch 43/500
# 667/667 [==============================] - 1s 2ms/step - loss: 0.6138 - accuracy: 0.6670 - val_loss: 0.6026 - val_accuracy: 0.6757
# Epoch 44/500
# 667/667 [==============================] - 1s 2ms/step - loss: 0.6136 - accuracy: 0.6670 - val_loss: 0.6017 - val_accuracy: 0.6763
# Epoch 45/500
# 667/667 [==============================] - 1s 2ms/step - loss: 0.6138 - accuracy: 0.6664 - val_loss: 0.6024 - val_accuracy: 0.6776
# Epoch 46/500
# 667/667 [==============================] - 1s 2ms/step - loss: 0.6131 - accuracy: 0.6669 - val_loss: 0.6017 - val_accuracy: 0.6769
# Epoch 47/500
# 667/667 [==============================] - 1s 2ms/step - loss: 0.6130 - accuracy: 0.6661 - val_loss: 0.6030 - val_accuracy: 0.6754
# Epoch 48/500
# 667/667 [==============================] - 1s 2ms/step - loss: 0.6125 - accuracy: 0.6672 - val_loss: 0.6016 - val_accuracy: 0.6758
# Epoch 49/500
# 667/667 [==============================] - 1s 2ms/step - loss: 0.6128 - accuracy: 0.6678 - val_loss: 0.6014 - val_accuracy: 0.6767
# Epoch 50/500
# 667/667 [==============================] - 1s 2ms/step - loss: 0.6121 - accuracy: 0.6674 - val_loss: 0.6015 - val_accuracy: 0.6747
# Epoch 51/500
# 667/667 [==============================] - 1s 2ms/step - loss: 0.6118 - accuracy: 0.6681 - val_loss: 0.6016 - val_accuracy: 0.6754
# Epoch 52/500
# 667/667 [==============================] - 1s 2ms/step - loss: 0.6122 - accuracy: 0.6672 - val_loss: 0.6010 - val_accuracy: 0.6772
# Epoch 53/500
# 667/667 [==============================] - 1s 2ms/step - loss: 0.6117 - accuracy: 0.6674 - val_loss: 0.6006 - val_accuracy: 0.6768
# Epoch 54/500
# 667/667 [==============================] - 1s 2ms/step - loss: 0.6116 - accuracy: 0.6673 - val_loss: 0.6002 - val_accuracy: 0.6769
# Epoch 55/500
# 667/667 [==============================] - 1s 2ms/step - loss: 0.6107 - accuracy: 0.6683 - val_loss: 0.5993 - val_accuracy: 0.6775
# Epoch 56/500
# 667/667 [==============================] - 1s 2ms/step - loss: 0.6110 - accuracy: 0.6677 - val_loss: 0.5990 - val_accuracy: 0.6785
# Epoch 57/500
# 667/667 [==============================] - 1s 2ms/step - loss: 0.6103 - accuracy: 0.6679 - val_loss: 0.5998 - val_accuracy: 0.6777
# Epoch 58/500
# 667/667 [==============================] - 1s 2ms/step - loss: 0.6101 - accuracy: 0.6692 - val_loss: 0.5984 - val_accuracy: 0.6790
# Epoch 59/500
# 667/667 [==============================] - 1s 2ms/step - loss: 0.6102 - accuracy: 0.6680 - val_loss: 0.5987 - val_accuracy: 0.6780
# Epoch 60/500
# 667/667 [==============================] - 1s 2ms/step - loss: 0.6100 - accuracy: 0.6689 - val_loss: 0.5989 - val_accuracy: 0.6780
# Epoch 61/500
# 667/667 [==============================] - 1s 2ms/step - loss: 0.6097 - accuracy: 0.6694 - val_loss: 0.5977 - val_accuracy: 0.6794
# Epoch 62/500
# 667/667 [==============================] - 1s 2ms/step - loss: 0.6099 - accuracy: 0.6682 - val_loss: 0.5979 - val_accuracy: 0.6771
# Epoch 63/500
# 667/667 [==============================] - 1s 2ms/step - loss: 0.6096 - accuracy: 0.6688 - val_loss: 0.5981 - val_accuracy: 0.6796
# Epoch 64/500
# 667/667 [==============================] - 1s 2ms/step - loss: 0.6090 - accuracy: 0.6696 - val_loss: 0.5978 - val_accuracy: 0.6784
# Epoch 65/500
# 667/667 [==============================] - 1s 2ms/step - loss: 0.6080 - accuracy: 0.6696 - val_loss: 0.5966 - val_accuracy: 0.6794
# Epoch 66/500
# 667/667 [==============================] - 1s 2ms/step - loss: 0.6082 - accuracy: 0.6696 - val_loss: 0.5962 - val_accuracy: 0.6799
# Epoch 67/500
# 667/667 [==============================] - 1s 2ms/step - loss: 0.6083 - accuracy: 0.6700 - val_loss: 0.5972 - val_accuracy: 0.6805
# Epoch 68/500
# 667/667 [==============================] - 1s 2ms/step - loss: 0.6083 - accuracy: 0.6716 - val_loss: 0.5947 - val_accuracy: 0.6817
# Epoch 69/500
# 667/667 [==============================] - 1s 2ms/step - loss: 0.6076 - accuracy: 0.6698 - val_loss: 0.5950 - val_accuracy: 0.6812
# Epoch 70/500
# 667/667 [==============================] - 1s 2ms/step - loss: 0.6072 - accuracy: 0.6706 - val_loss: 0.5945 - val_accuracy: 0.6801
# Epoch 71/500
# 667/667 [==============================] - 1s 2ms/step - loss: 0.6064 - accuracy: 0.6711 - val_loss: 0.5945 - val_accuracy: 0.6824
# Epoch 72/500
# 667/667 [==============================] - 1s 2ms/step - loss: 0.6068 - accuracy: 0.6715 - val_loss: 0.5947 - val_accuracy: 0.6823
# Epoch 73/500
# 667/667 [==============================] - 1s 2ms/step - loss: 0.6060 - accuracy: 0.6720 - val_loss: 0.5932 - val_accuracy: 0.6818
# Epoch 74/500
# 667/667 [==============================] - 1s 2ms/step - loss: 0.6059 - accuracy: 0.6725 - val_loss: 0.5930 - val_accuracy: 0.6807
# Epoch 75/500
# 667/667 [==============================] - 1s 1ms/step - loss: 0.6063 - accuracy: 0.6722 - val_loss: 0.5947 - val_accuracy: 0.6802
# Epoch 76/500
# 667/667 [==============================] - 1s 2ms/step - loss: 0.6067 - accuracy: 0.6705 - val_loss: 0.5931 - val_accuracy: 0.6818
# Epoch 77/500
# 667/667 [==============================] - 1s 2ms/step - loss: 0.6056 - accuracy: 0.6723 - val_loss: 0.5928 - val_accuracy: 0.6809
# Epoch 78/500
# 667/667 [==============================] - 1s 2ms/step - loss: 0.6054 - accuracy: 0.6723 - val_loss: 0.5935 - val_accuracy: 0.6826
# Epoch 79/500
# 667/667 [==============================] - 1s 2ms/step - loss: 0.6055 - accuracy: 0.6729 - val_loss: 0.5931 - val_accuracy: 0.6826
# Epoch 80/500
# 667/667 [==============================] - 1s 2ms/step - loss: 0.6056 - accuracy: 0.6731 - val_loss: 0.5932 - val_accuracy: 0.6821
# Epoch 81/500
# 667/667 [==============================] - 1s 2ms/step - loss: 0.6051 - accuracy: 0.6715 - val_loss: 0.5931 - val_accuracy: 0.6812
# Epoch 82/500
# 667/667 [==============================] - 1s 2ms/step - loss: 0.6052 - accuracy: 0.6726 - val_loss: 0.5922 - val_accuracy: 0.6833
# Epoch 83/500
# 667/667 [==============================] - 1s 2ms/step - loss: 0.6042 - accuracy: 0.6750 - val_loss: 0.5911 - val_accuracy: 0.6834
# Epoch 84/500
# 667/667 [==============================] - 1s 2ms/step - loss: 0.6045 - accuracy: 0.6735 - val_loss: 0.5921 - val_accuracy: 0.6827
# Epoch 85/500
# 667/667 [==============================] - 1s 2ms/step - loss: 0.6050 - accuracy: 0.6730 - val_loss: 0.5910 - val_accuracy: 0.6841
# Epoch 86/500
# 667/667 [==============================] - 1s 2ms/step - loss: 0.6045 - accuracy: 0.6735 - val_loss: 0.5920 - val_accuracy: 0.6826
# Epoch 87/500
# 667/667 [==============================] - 1s 2ms/step - loss: 0.6039 - accuracy: 0.6742 - val_loss: 0.5906 - val_accuracy: 0.6837
# Epoch 88/500
# 667/667 [==============================] - 1s 1ms/step - loss: 0.6045 - accuracy: 0.6733 - val_loss: 0.5909 - val_accuracy: 0.6839
# Epoch 89/500
# 667/667 [==============================] - 1s 1ms/step - loss: 0.6040 - accuracy: 0.6736 - val_loss: 0.5920 - val_accuracy: 0.6833
# Epoch 90/500
# 667/667 [==============================] - 1s 2ms/step - loss: 0.6044 - accuracy: 0.6731 - val_loss: 0.5905 - val_accuracy: 0.6835
# Epoch 91/500
# 667/667 [==============================] - 1s 1ms/step - loss: 0.6033 - accuracy: 0.6735 - val_loss: 0.5900 - val_accuracy: 0.6849
# Epoch 92/500
# 667/667 [==============================] - 1s 1ms/step - loss: 0.6035 - accuracy: 0.6737 - val_loss: 0.5907 - val_accuracy: 0.6840
# Epoch 93/500
# 667/667 [==============================] - 1s 1ms/step - loss: 0.6033 - accuracy: 0.6736 - val_loss: 0.5899 - val_accuracy: 0.6837
# Epoch 94/500
# 667/667 [==============================] - 1s 1ms/step - loss: 0.6031 - accuracy: 0.6744 - val_loss: 0.5899 - val_accuracy: 0.6842
# Epoch 95/500
# 667/667 [==============================] - 1s 1ms/step - loss: 0.6029 - accuracy: 0.6739 - val_loss: 0.5893 - val_accuracy: 0.6841
# Epoch 96/500
# 667/667 [==============================] - 1s 1ms/step - loss: 0.6026 - accuracy: 0.6753 - val_loss: 0.5897 - val_accuracy: 0.6853
# Epoch 97/500
# 667/667 [==============================] - 1s 1ms/step - loss: 0.6022 - accuracy: 0.6742 - val_loss: 0.5897 - val_accuracy: 0.6841
# Epoch 98/500
# 667/667 [==============================] - 1s 1ms/step - loss: 0.6026 - accuracy: 0.6749 - val_loss: 0.5908 - val_accuracy: 0.6830
# Epoch 99/500
# 667/667 [==============================] - 1s 2ms/step - loss: 0.6024 - accuracy: 0.6745 - val_loss: 0.5888 - val_accuracy: 0.6845
# Epoch 100/500
# 667/667 [==============================] - 1s 1ms/step - loss: 0.6030 - accuracy: 0.6742 - val_loss: 0.5891 - val_accuracy: 0.6863
# Epoch 101/500
# 667/667 [==============================] - 1s 1ms/step - loss: 0.6020 - accuracy: 0.6761 - val_loss: 0.5888 - val_accuracy: 0.6850
# Epoch 102/500
# 667/667 [==============================] - 1s 1ms/step - loss: 0.6017 - accuracy: 0.6756 - val_loss: 0.5885 - val_accuracy: 0.6845
# Epoch 103/500
# 667/667 [==============================] - 1s 1ms/step - loss: 0.6017 - accuracy: 0.6746 - val_loss: 0.5886 - val_accuracy: 0.6839
# Epoch 104/500
# 667/667 [==============================] - 1s 1ms/step - loss: 0.6020 - accuracy: 0.6749 - val_loss: 0.5895 - val_accuracy: 0.6860
# Epoch 105/500
# 667/667 [==============================] - 1s 2ms/step - loss: 0.6012 - accuracy: 0.6749 - val_loss: 0.5884 - val_accuracy: 0.6855
# Epoch 106/500
# 667/667 [==============================] - 1s 1ms/step - loss: 0.6016 - accuracy: 0.6757 - val_loss: 0.5887 - val_accuracy: 0.6855
# Epoch 107/500
# 667/667 [==============================] - 1s 2ms/step - loss: 0.6012 - accuracy: 0.6756 - val_loss: 0.5883 - val_accuracy: 0.6843
# Epoch 108/500
# 667/667 [==============================] - 1s 1ms/step - loss: 0.6007 - accuracy: 0.6759 - val_loss: 0.5892 - val_accuracy: 0.6840
# Epoch 109/500
# 667/667 [==============================] - 1s 1ms/step - loss: 0.6019 - accuracy: 0.6753 - val_loss: 0.5879 - val_accuracy: 0.6860
# Epoch 110/500
# 667/667 [==============================] - 1s 2ms/step - loss: 0.6014 - accuracy: 0.6757 - val_loss: 0.5885 - val_accuracy: 0.6847
# Epoch 111/500
# 667/667 [==============================] - 1s 1ms/step - loss: 0.6015 - accuracy: 0.6752 - val_loss: 0.5886 - val_accuracy: 0.6845
# Epoch 112/500
# 667/667 [==============================] - 1s 1ms/step - loss: 0.6010 - accuracy: 0.6759 - val_loss: 0.5884 - val_accuracy: 0.6863
# Epoch 113/500
# 667/667 [==============================] - 1s 2ms/step - loss: 0.6013 - accuracy: 0.6760 - val_loss: 0.5882 - val_accuracy: 0.6854
# Epoch 114/500
# 667/667 [==============================] - 1s 1ms/step - loss: 0.6008 - accuracy: 0.6770 - val_loss: 0.5880 - val_accuracy: 0.6852
# Epoch 115/500
# 667/667 [==============================] - 1s 1ms/step - loss: 0.6006 - accuracy: 0.6765 - val_loss: 0.5874 - val_accuracy: 0.6859
# Epoch 116/500
# 667/667 [==============================] - 1s 2ms/step - loss: 0.5999 - accuracy: 0.6774 - val_loss: 0.5871 - val_accuracy: 0.6854
# Epoch 117/500
# 667/667 [==============================] - 1s 1ms/step - loss: 0.6000 - accuracy: 0.6770 - val_loss: 0.5871 - val_accuracy: 0.6864
# Epoch 118/500
# 667/667 [==============================] - 1s 1ms/step - loss: 0.6006 - accuracy: 0.6761 - val_loss: 0.5875 - val_accuracy: 0.6857
# Epoch 119/500
# 667/667 [==============================] - 1s 2ms/step - loss: 0.6005 - accuracy: 0.6765 - val_loss: 0.5871 - val_accuracy: 0.6857
# Epoch 120/500
# 667/667 [==============================] - 1s 1ms/step - loss: 0.6002 - accuracy: 0.6769 - val_loss: 0.5878 - val_accuracy: 0.6854
# Epoch 121/500
# 667/667 [==============================] - 1s 1ms/step - loss: 0.6002 - accuracy: 0.6769 - val_loss: 0.5881 - val_accuracy: 0.6868
# Epoch 122/500
# 667/667 [==============================] - 1s 2ms/step - loss: 0.5994 - accuracy: 0.6778 - val_loss: 0.5878 - val_accuracy: 0.6856
# Epoch 123/500
# 667/667 [==============================] - 1s 1ms/step - loss: 0.6001 - accuracy: 0.6776 - val_loss: 0.5876 - val_accuracy: 0.6852
# Epoch 124/500
# 667/667 [==============================] - 1s 1ms/step - loss: 0.5998 - accuracy: 0.6769 - val_loss: 0.5863 - val_accuracy: 0.6864
# Epoch 125/500
# 667/667 [==============================] - 1s 1ms/step - loss: 0.5999 - accuracy: 0.6765 - val_loss: 0.5867 - val_accuracy: 0.6858
# Epoch 126/500
# 667/667 [==============================] - 1s 1ms/step - loss: 0.6006 - accuracy: 0.6768 - val_loss: 0.5871 - val_accuracy: 0.6857
# Epoch 127/500
# 667/667 [==============================] - 1s 1ms/step - loss: 0.5999 - accuracy: 0.6763 - val_loss: 0.5870 - val_accuracy: 0.6868
# Epoch 128/500
# 667/667 [==============================] - 1s 1ms/step - loss: 0.5991 - accuracy: 0.6770 - val_loss: 0.5868 - val_accuracy: 0.6846
# Epoch 129/500
# 667/667 [==============================] - 1s 1ms/step - loss: 0.5998 - accuracy: 0.6767 - val_loss: 0.5865 - val_accuracy: 0.6871
# Epoch 130/500
# 667/667 [==============================] - 1s 1ms/step - loss: 0.5995 - accuracy: 0.6775 - val_loss: 0.5869 - val_accuracy: 0.6853
# Epoch 131/500
# 667/667 [==============================] - 1s 1ms/step - loss: 0.5997 - accuracy: 0.6773 - val_loss: 0.5865 - val_accuracy: 0.6858
# Epoch 132/500
# 667/667 [==============================] - 1s 1ms/step - loss: 0.5995 - accuracy: 0.6754 - val_loss: 0.5866 - val_accuracy: 0.6875
# Epoch 133/500
# 667/667 [==============================] - 1s 2ms/step - loss: 0.5996 - accuracy: 0.6770 - val_loss: 0.5869 - val_accuracy: 0.6859
# Epoch 134/500
# 667/667 [==============================] - 1s 1ms/step - loss: 0.5996 - accuracy: 0.6777 - val_loss: 0.5874 - val_accuracy: 0.6864
# Time taken: 149.4s

# %%
loss_accuracy_plotter(drop_history)

fpr_nn_opt_drop, tpr_nn_opt_drop, thresholds_nn_opt_drop = evaluate(drop_model, scaler, X, Y, X_train_val, Y_train_val, X_test, Y_test)
df_all['dense_NN_opt_drop'] = drop_model.predict(scaler.transform(X)).round() # add prediction to array
# Out:
# 1333/1333 [==============================] - 1s 686us/step
# 5330/5330 [==============================] - 4s 662us/step
# 1333/1333 [==============================] - 1s 709us/step
# 5330/5330 [==============================] - 4s 720us/step
# 6662/6662 [==============================] - 5s 701us/step
# Test acc score: 0.699158008302648
# Train acc score: 0.707541748756919
# Classification report for the test set
#               precision    recall  f1-score   support
#
#   background       0.71      0.57      0.63     19328
#       signal       0.69      0.81      0.75     23309
#
#     accuracy                           0.70     42637
#    macro avg       0.70      0.69      0.69     42637
# weighted avg       0.70      0.70      0.69     42637
#
# Classification report for the total set
#               precision    recall  f1-score   support
#
#   background       0.72      0.58      0.64     96352
#       signal       0.70      0.81      0.75    116829
#
#     accuracy                           0.71    213181
#    macro avg       0.71      0.69      0.70    213181
# weighted avg       0.71      0.71      0.70    213181
#
# Confusion matrix for total set
# [[55755 40597]
#  [22107 94722]]
# 6662/6662 [==============================] - 5s 735us/step

# %%
# add TF NN probability
y_tot_prob_NN_opt_drop = drop_model.predict(scaler.transform(X))
y_tot_NN_opt_drop = drop_model.predict(scaler.transform(X)).round()

cumulative_events = 0 # start counter for total number of events for which output is saved
for key in filename.keys(): # loop over samples
    df[key]['NN_opt_drop_output_prob'] = y_tot_prob_NN_opt_drop[cumulative_events:cumulative_events+len(df[key])]
    df[key]['NN_opt_drop_output'] = y_tot_NN_opt_drop[cumulative_events:cumulative_events+len(df[key])]
    cumulative_events += len(df[key]) # increment counter for total number of events
    #print(df[key]['NN_output']) # print the dataframe column NN_output

# probability and significance plots
NN_opt_drop_output_prob = { # dictionary containing plotting parameters for the mllll histogram
    # change plotting parameters
    'bin_width':0.1, # width of each histogram bin
    'num_bins':8, # number of histogram bins
    'xrange_min':0, # minimum on x-axis
    'xlabel':'Neural Network optimized dropout', # x-axis label
}

SoverB_hist_dict = {'NN_opt_drop_output_prob':NN_opt_drop_output_prob}
plot_SoverB(df, SoverB_hist_dict)
# Out:
#    1/6662 [..............................] - ETA: 2:58
# 6662/6662 [==============================] - 5s 788us/step
# 6662/6662 [==============================] - 5s 803us/step

# %% [markdown]
# ## Optimal model with early stopping

# %%
inputs = Input(shape=(NDIM,), name = 'input') 
hidden1 = Dense(128, name = 'hidden1', kernel_initializer='lecun_normal', activation='selu')(inputs)
hidden2 = Dense(128, name = 'hidden2', kernel_initializer='lecun_normal', activation='selu')(hidden1)
hidden3 = Dense(128, name = 'hidden3', kernel_initializer='lecun_normal', activation='selu')(hidden2)
outputs = Dense(1, name = 'output', kernel_initializer='lecun_normal', activation='sigmoid')(hidden3)

# create the model
opt_model = Model(inputs=inputs, outputs=outputs)
# compile the model
opt_model.compile(optimizer='Adam', loss='binary_crossentropy', metrics=['accuracy'])
# print the model summary
opt_model.summary()

# early stopping callback
from keras.callbacks import EarlyStopping
early_stopping = EarlyStopping(monitor='val_loss', patience=10, mode='min')

# model checkpoint callback
# this saves our model architecture + parameters into dense_model.h5
from keras.callbacks import ModelCheckpoint
model_checkpoint = ModelCheckpoint('./models/up_NN_opt_model.h5', monitor='val_loss', 
                                   verbose=0, save_best_only=True,                                    
                                   save_weights_only=False, mode='auto', 
                                   period=1)
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input (InputLayer)          [(None, 11)]              0
#
#  hidden1 (Dense)             (None, 128)               1536
#
#  hidden2 (Dense)             (None, 128)               16512
#
#  hidden3 (Dense)             (None, 128)               16512
#
#  output (Dense)              (None, 1)                 129
#
# =================================================================
# Total params: 34,689
# Trainable params: 34,689
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
# Train classifier
import time
start = time.time() # time at start of whole processing

opt_history = opt_model.fit(X_train_val, 
                    Y_train_val, 
                    epochs=500, 
                    batch_size=256, 
                    verbose=1, # switch to 1 for more verbosity 
                    callbacks=[early_stopping, model_checkpoint], 
                    validation_data=(X_test,Y_test))

elapsed = time.time() - start # time after whole processing
print("Time taken: "+str(round(elapsed,1))+"s") # print total time taken to process every file
# Out:
# Epoch 1/500
# 667/667 [==============================] - 2s 2ms/step - loss: 0.6275 - accuracy: 0.6488 - val_loss: 0.6088 - val_accuracy: 0.6665
# Epoch 2/500
# 667/667 [==============================] - 1s 2ms/step - loss: 0.6085 - accuracy: 0.6675 - val_loss: 0.5999 - val_accuracy: 0.6717
# Epoch 3/500
# 667/667 [==============================] - 1s 2ms/step - loss: 0.6017 - accuracy: 0.6745 - val_loss: 0.5969 - val_accuracy: 0.6761
# Epoch 4/500
# 667/667 [==============================] - 1s 2ms/step - loss: 0.5974 - accuracy: 0.6784 - val_loss: 0.5927 - val_accuracy: 0.6804
# Epoch 5/500
# 667/667 [==============================] - 1s 2ms/step - loss: 0.5938 - accuracy: 0.6820 - val_loss: 0.5947 - val_accuracy: 0.6786
# Epoch 6/500
# 667/667 [==============================] - 1s 2ms/step - loss: 0.5906 - accuracy: 0.6841 - val_loss: 0.5898 - val_accuracy: 0.6860
# Epoch 7/500
# 667/667 [==============================] - 1s 2ms/step - loss: 0.5882 - accuracy: 0.6864 - val_loss: 0.5840 - val_accuracy: 0.6873
# Epoch 8/500
# 667/667 [==============================] - 1s 2ms/step - loss: 0.5864 - accuracy: 0.6875 - val_loss: 0.5863 - val_accuracy: 0.6854
# Epoch 9/500
# 667/667 [==============================] - 1s 2ms/step - loss: 0.5845 - accuracy: 0.6886 - val_loss: 0.5845 - val_accuracy: 0.6857
# Epoch 10/500
# 667/667 [==============================] - 2s 2ms/step - loss: 0.5830 - accuracy: 0.6898 - val_loss: 0.5851 - val_accuracy: 0.6878
# Epoch 11/500
# 667/667 [==============================] - 2s 2ms/step - loss: 0.5814 - accuracy: 0.6920 - val_loss: 0.5834 - val_accuracy: 0.6870
# Epoch 12/500
# 667/667 [==============================] - 2s 2ms/step - loss: 0.5803 - accuracy: 0.6921 - val_loss: 0.5815 - val_accuracy: 0.6904
# Epoch 13/500
# 667/667 [==============================] - 2s 3ms/step - loss: 0.5790 - accuracy: 0.6942 - val_loss: 0.5807 - val_accuracy: 0.6909
# Epoch 14/500
# 667/667 [==============================] - 2s 2ms/step - loss: 0.5776 - accuracy: 0.6953 - val_loss: 0.5817 - val_accuracy: 0.6894
# Epoch 15/500
# 667/667 [==============================] - 2s 2ms/step - loss: 0.5771 - accuracy: 0.6946 - val_loss: 0.5816 - val_accuracy: 0.6925
# Epoch 16/500
# 667/667 [==============================] - 1s 2ms/step - loss: 0.5757 - accuracy: 0.6964 - val_loss: 0.5789 - val_accuracy: 0.6921
# Epoch 17/500
# 667/667 [==============================] - 1s 2ms/step - loss: 0.5753 - accuracy: 0.6963 - val_loss: 0.5766 - val_accuracy: 0.6941
# Epoch 18/500
# 667/667 [==============================] - 1s 2ms/step - loss: 0.5743 - accuracy: 0.6965 - val_loss: 0.5770 - val_accuracy: 0.6941
# Epoch 19/500
# 667/667 [==============================] - 2s 2ms/step - loss: 0.5732 - accuracy: 0.6975 - val_loss: 0.5753 - val_accuracy: 0.6965
# Epoch 20/500
# 667/667 [==============================] - 2s 2ms/step - loss: 0.5727 - accuracy: 0.6985 - val_loss: 0.5779 - val_accuracy: 0.6921
# Epoch 21/500
# 667/667 [==============================] - 1s 2ms/step - loss: 0.5718 - accuracy: 0.6996 - val_loss: 0.5769 - val_accuracy: 0.6943
# Epoch 22/500
# 667/667 [==============================] - 1s 2ms/step - loss: 0.5707 - accuracy: 0.6997 - val_loss: 0.5763 - val_accuracy: 0.6960
# Epoch 23/500
# 667/667 [==============================] - 1s 2ms/step - loss: 0.5707 - accuracy: 0.6999 - val_loss: 0.5767 - val_accuracy: 0.6963
# Epoch 24/500
# 667/667 [==============================] - 2s 2ms/step - loss: 0.5692 - accuracy: 0.7006 - val_loss: 0.5762 - val_accuracy: 0.6939
# Epoch 25/500
# 667/667 [==============================] - 1s 2ms/step - loss: 0.5694 - accuracy: 0.7010 - val_loss: 0.5759 - val_accuracy: 0.6919
# Epoch 26/500
# 667/667 [==============================] - 1s 2ms/step - loss: 0.5683 - accuracy: 0.7013 - val_loss: 0.5754 - val_accuracy: 0.6943
# Epoch 27/500
# 667/667 [==============================] - 1s 2ms/step - loss: 0.5676 - accuracy: 0.7028 - val_loss: 0.5761 - val_accuracy: 0.6957
# Epoch 28/500
# 667/667 [==============================] - 1s 2ms/step - loss: 0.5671 - accuracy: 0.7024 - val_loss: 0.5751 - val_accuracy: 0.6980
# Epoch 29/500
# 667/667 [==============================] - 1s 2ms/step - loss: 0.5664 - accuracy: 0.7034 - val_loss: 0.5754 - val_accuracy: 0.6943
# Epoch 30/500
# 667/667 [==============================] - 1s 2ms/step - loss: 0.5659 - accuracy: 0.7043 - val_loss: 0.5767 - val_accuracy: 0.6938
# Epoch 31/500
# 667/667 [==============================] - 1s 2ms/step - loss: 0.5648 - accuracy: 0.7047 - val_loss: 0.5767 - val_accuracy: 0.6938
# Epoch 32/500
# 667/667 [==============================] - 1s 2ms/step - loss: 0.5646 - accuracy: 0.7042 - val_loss: 0.5819 - val_accuracy: 0.6909
# Epoch 33/500
# 667/667 [==============================] - 1s 2ms/step - loss: 0.5646 - accuracy: 0.7054 - val_loss: 0.5746 - val_accuracy: 0.6961
# Epoch 34/500
# 667/667 [==============================] - 1s 2ms/step - loss: 0.5640 - accuracy: 0.7055 - val_loss: 0.5742 - val_accuracy: 0.6958
# Epoch 35/500
# 667/667 [==============================] - 1s 2ms/step - loss: 0.5626 - accuracy: 0.7053 - val_loss: 0.5753 - val_accuracy: 0.6955
# Epoch 36/500
# 667/667 [==============================] - 1s 2ms/step - loss: 0.5629 - accuracy: 0.7056 - val_loss: 0.5734 - val_accuracy: 0.6956
# Epoch 37/500
# 667/667 [==============================] - 2s 2ms/step - loss: 0.5621 - accuracy: 0.7058 - val_loss: 0.5732 - val_accuracy: 0.6965
# Epoch 38/500
# 667/667 [==============================] - 2s 2ms/step - loss: 0.5619 - accuracy: 0.7063 - val_loss: 0.5760 - val_accuracy: 0.6949
# Epoch 39/500
# 667/667 [==============================] - 1s 2ms/step - loss: 0.5611 - accuracy: 0.7064 - val_loss: 0.5729 - val_accuracy: 0.6972
# Epoch 40/500
# 667/667 [==============================] - 1s 2ms/step - loss: 0.5605 - accuracy: 0.7076 - val_loss: 0.5732 - val_accuracy: 0.6985
# Epoch 41/500
# 667/667 [==============================] - 1s 2ms/step - loss: 0.5596 - accuracy: 0.7078 - val_loss: 0.5759 - val_accuracy: 0.6956
# Epoch 42/500
# 667/667 [==============================] - 1s 2ms/step - loss: 0.5594 - accuracy: 0.7090 - val_loss: 0.5729 - val_accuracy: 0.6962
# Epoch 43/500
# 667/667 [==============================] - 2s 2ms/step - loss: 0.5589 - accuracy: 0.7086 - val_loss: 0.5744 - val_accuracy: 0.6958
# Epoch 44/500
# 667/667 [==============================] - 1s 2ms/step - loss: 0.5583 - accuracy: 0.7092 - val_loss: 0.5752 - val_accuracy: 0.6951
# Epoch 45/500
# 667/667 [==============================] - 1s 2ms/step - loss: 0.5578 - accuracy: 0.7107 - val_loss: 0.5732 - val_accuracy: 0.6964
# Epoch 46/500
# 667/667 [==============================] - 1s 2ms/step - loss: 0.5569 - accuracy: 0.7105 - val_loss: 0.5740 - val_accuracy: 0.6970
# Epoch 47/500
# 667/667 [==============================] - 2s 2ms/step - loss: 0.5561 - accuracy: 0.7112 - val_loss: 0.5853 - val_accuracy: 0.6848
# Epoch 48/500
# 667/667 [==============================] - 1s 2ms/step - loss: 0.5567 - accuracy: 0.7103 - val_loss: 0.5742 - val_accuracy: 0.6947
# Epoch 49/500
# 667/667 [==============================] - 1s 2ms/step - loss: 0.5553 - accuracy: 0.7110 - val_loss: 0.5753 - val_accuracy: 0.6953
# Time taken: 72.7s

# %%
loss_accuracy_plotter(opt_history)

fpr_nn_opt, tpr_nn_opt, thresholds_nn_opt = evaluate(opt_model, scaler, X, Y, X_train_val, Y_train_val, X_test, Y_test)
df_all['dense_NN_opt'] = opt_model.predict(scaler.transform(X)).round() # add prediction to array
# Out:
# 1333/1333 [==============================] - 1s 682us/step
# 5330/5330 [==============================] - 4s 666us/step
# 1333/1333 [==============================] - 1s 709us/step
# 5330/5330 [==============================] - 4s 722us/step
# 6662/6662 [==============================] - 5s 716us/step
# Test acc score: 0.69528813002791
# Train acc score: 0.713604700253307
# Classification report for the test set
#               precision    recall  f1-score   support
#
#   background       0.69      0.59      0.64     19328
#       signal       0.70      0.78      0.74     23309
#
#     accuracy                           0.70     42637
#    macro avg       0.69      0.69      0.69     42637
# weighted avg       0.69      0.70      0.69     42637
#
# Classification report for the total set
#               precision    recall  f1-score   support
#
#   background       0.71      0.61      0.66     96352
#       signal       0.71      0.79      0.75    116829
#
#     accuracy                           0.71    213181
#    macro avg       0.71      0.70      0.70    213181
# weighted avg       0.71      0.71      0.71    213181
#
# Confusion matrix for total set
# [[58705 37647]
#  [24188 92641]]
# 6662/6662 [==============================] - 5s 728us/step

# %%
# add TF NN probability
y_tot_prob_NN_opt = opt_model.predict(scaler.transform(X))
y_tot_NN_opt = opt_model.predict(scaler.transform(X)).round()

cumulative_events = 0 # start counter for total number of events for which output is saved
for key in filename.keys(): # loop over samples
    df[key]['NN_opt_output_prob'] = y_tot_prob_NN_opt[cumulative_events:cumulative_events+len(df[key])]
    df[key]['NN_opt_output'] = y_tot_NN_opt[cumulative_events:cumulative_events+len(df[key])]
    cumulative_events += len(df[key]) # increment counter for total number of events
    #print(df[key]['NN_output']) # print the dataframe column NN_output

# probability and significance plots
NN_opt_output_prob = { # dictionary containing plotting parameters for the mllll histogram
    # change plotting parameters
    'bin_width':0.1, # width of each histogram bin
    'num_bins':8, # number of histogram bins
    'xrange_min':0, # minimum on x-axis
    'xlabel':'Neural Network optimized output', # x-axis label
}

SoverB_hist_dict = {'NN_opt_output_prob':NN_opt_output_prob}
plot_SoverB(df, SoverB_hist_dict)
# Out:
# 6662/6662 [==============================] - 5s 726us/step
# 6662/6662 [==============================] - 5s 727us/step

# %%
# plot ROC curve
plt.plot(fpr_nn, tpr_nn, label='Neural Network') # plot neural network ROC
plt.plot(fpr_nn_opt, tpr_nn_opt, linestyle='dashed', label='Neural Network optimized') # plot neural network optimized ROC
plt.plot(fpr_nn_opt_drop, tpr_nn_opt_drop, linestyle='dashed', label='Neural Network optimized (dropout)') # plot neural network optimized and dropout ROC
plt.plot([0, 1], [0, 1], linestyle='dotted', color='grey', label='Luck') # plot diagonal line to indicate luck
plt.xlabel('False Positive Rate') # x-axis label
plt.ylabel('True Positive Rate') # y-axis label
plt.grid() # add a grid to the plot
plt.legend() # add a legend

# %%
ams_nn = AMS(tpr_nn, fpr_nn, 0.001) # get AMS for NN classifier
ams_nn_opt = AMS(tpr_nn_opt, fpr_nn_opt, 0.001) # get AMS for NN-opt classifier
ams_nn_opt_drop = AMS(tpr_nn_opt_drop, fpr_nn_opt_drop, 0.001) # get AMS for NN-opt classifier


plt.plot(thresholds_nn, ams_nn, label="Neural Netwrok")  # plot NN AMS
plt.plot(thresholds_nn_opt, ams_nn_opt, linestyle='dashed', label="Neural Netwrok optimized")  # plot NN-opt AMS
plt.plot(thresholds_nn_opt_drop, ams_nn_opt_drop, linestyle='dashed', label="Neural Netwrok optimized (dropout)")  # plot NN-opt AMS
plt.xlabel("Threshold")  # x-axis label
plt.ylabel("AMS")  # y-axis label
plt.title("AMS with $b_r=0.001$")  # add plot title
plt.legend()  # add legend

# %%
ams_nn = AMS(tpr_nn, fpr_nn, 1) # get AMS for NN classifier
ams_nn_opt = AMS(tpr_nn_opt, fpr_nn_opt, 1) # get AMS for NN-opt classifier
ams_nn_opt_drop = AMS(tpr_nn_opt_drop, fpr_nn_opt_drop, 1) # get AMS for NN-opt classifier


plt.plot(thresholds_nn, ams_nn, label="Neural Netwrok")  # plot NN AMS
plt.plot(thresholds_nn_opt, ams_nn_opt, linestyle='dashed', label="Neural Netwrok optimized")  # plot NN-opt AMS
plt.plot(thresholds_nn_opt_drop, ams_nn_opt_drop, linestyle='dashed', label="Neural Netwrok optimized (dropout)")  # plot NN-opt AMS
plt.xlabel("Threshold")  # x-axis label
plt.ylabel("AMS")  # y-axis label
plt.title("AMS with $b_r=1$")  # add plot title
plt.legend()  # add legend

# %% [markdown]
# ## Overfit checking

# %%
new_compare_train_test(model, X_train_val, Y_train_val, X_test, Y_test, 'Neural Netwrok output')
# Out:
# 308/308 [==============================] - 0s 901us/step
# 499/499 [==============================] - 0s 783us/step
# 75/75 [==============================] - 0s 909us/step
# 127/127 [==============================] - 0s 833us/step
# Signal: ks = [0.0100042] (p-value = [0.89915736], are equal = [ True])
# Background: ks = [0.02401509] (p-value = [0.21489541], are equal = [ True])

# %%
new_compare_train_test(opt_model, X_train_val, Y_train_val, X_test, Y_test, 'Neural Netwrok optimized output')
# Out:
# 308/308 [==============================] - 0s 734us/step
# 499/499 [==============================] - 0s 719us/step
# 75/75 [==============================] - 0s 759us/step
# 127/127 [==============================] - 0s 770us/step
# Signal: ks = [0.06470548] (p-value = [3.21874341e-12], are equal = [False])
# Background: ks = [0.0934753] (p-value = [4.82057078e-15], are equal = [False])

# %%
new_compare_train_test(drop_model, X_train_val, Y_train_val, X_test, Y_test, 'Neural Netwrok optimized dropoutoutput')
# Out:
# 308/308 [==============================] - 0s 705us/step
# 499/499 [==============================] - 0s 725us/step
# 75/75 [==============================] - 0s 726us/step
# 127/127 [==============================] - 0s 708us/step
# Signal: ks = [0.01461888] (p-value = [0.48933004], are equal = [ True])
# Background: ks = [0.01524889] (p-value = [0.75758902], are equal = [ True])

# %% [markdown]
# ## Save all models

# %%
# simple NN
#model.save('models/tt_charm_NN/')
model.save('models/tW_up_NN.h5')
#new_model = keras.models.load_model('models/tt_charm_NN/')

# NN optimized 
#opt_model.save('models/tt_charm_NN_opt/')
opt_model.save('models/tW_up_NN_opt.h5')
#new_model = keras.models.load_model('models/tt_charm_NN_opt/')

# NN optimized with drop
#drop_model.save('models/tt_charm_NN_drop/')
drop_model.save('models/tW_up_NN_drop.h5')
#new_model = keras.models.load_model('models/tt_charm_NN_drop/')

# %% [markdown]
# ## Extend to the whole dataset

# %%
filename = {
    'tZ':'/Users/mghasemi/Desktop/IPM/plotter/newtrees/tW_trees/tZ.root',
    'WZ':'/Users/mghasemi/Desktop/IPM/plotter/newtrees/tW_trees/WZ.root',
    'ZZ':'/Users/mghasemi/Desktop/IPM/plotter/newtrees/tW_trees/ZZ.root',    
    'signal_tW_up':'/Users/mghasemi/Desktop/IPM/plotter/newtrees/tW_trees/signal_tW_up.root'}

VARS = ['jetNo','jetPTLeading', 'jetETA', 'jetPHI',
        'elecPTLeading', 'elecETA', 'elecPHI',
        'dielecCOS', 'dielecETA', 'met','testnonTopMass', 'weight'] 

upfile = {}
params = {}
df = {}
NDIM = len(VARS)

# define trees and branches to make DataFrame
for treename in filename.keys():
    upfile[treename] = uproot.open(filename[treename])
    params[treename] = upfile[treename][treename].arrays(VARS)
    df[treename] = ak.to_dataframe(params[treename])
    # add isSignal variable
    if treename.startswith("signal"): 
        df[treename]['isSignal'] = np.ones(len(df[treename])) 
    else:
        df[treename]['isSignal'] = np.zeros(len(df[treename])) 
    tmp_dataset = df[treename].values
    X_tmp = tmp_dataset[:,0:NDIM-1]
    Y_tmp = tmp_dataset[:,NDIM]
    df[treename]['dense_NN'] = model.predict(scaler.transform(X_tmp)) # add prediction to array   
    df[treename]['dense_NN_opt'] = opt_model.predict(scaler.transform(X_tmp)) # add prediction to array
    df[treename]['dense_NN_opt_drop'] = drop_model.predict(scaler.transform(X_tmp)) # add prediction to array
    df[treename].to_csv("~/Desktop/IPM/Analysis/Dataframes/tW_up/"+treename+"_df.csv")
    

df_all = pd.concat([df[treename] for treename in filename.keys()])
dataset = df_all.values
X = dataset[:,0:NDIM-1]
Y = dataset[:,NDIM]
# Out:
# 5475/5475 [==============================] - 4s 691us/step
# 5475/5475 [==============================] - 4s 734us/step
# 5475/5475 [==============================] - 4s 735us/step
# 15105/15105 [==============================] - 10s 666us/step
# 15105/15105 [==============================] - 11s 718us/step
# 15105/15105 [==============================] - 11s 733us/step
# 199/199 [==============================] - 0s 720us/step
# 199/199 [==============================] - 0s 704us/step
# 199/199 [==============================] - 0s 731us/step
# 3651/3651 [==============================] - 2s 664us/step
# 3651/3651 [==============================] - 3s 709us/step
# 3651/3651 [==============================] - 3s 724us/step

# %%
y_pred_NN_opt = opt_model.predict(X_test).round() # make predictions on the test data
y_pred_NN_train_opt = opt_model.predict(X_train_val).round()
y_pred_NN_tot_opt = opt_model.predict(scaler.transform(X)).round()

# See how well the classifier does, Acc = correct data / tot data
print("Total accuracy", accuracy_score(Y, y_pred_NN_tot_opt))

print("Classification report for the total set")
print(classification_report(Y.round(), y_pred_NN_tot_opt.round(), target_names=['background', 'signal']))

print("Confusion matrix:\n", confusion_matrix(Y.round(), y_pred_NN_tot_opt.round()))

fpr_nn_opt_tot, tpr_nn_opt_tot, thresholds_nn_opt_tot = roc_curve(Y, y_pred_NN_tot_opt.round()) # get FPRs, TPRs and thresholds for neural network

df_all['dense_NN_opt'] = opt_model.predict(scaler.transform(X)) # add prediction to array
df_all['dense_NN'] = model.predict(scaler.transform(X)) # add prediction to array
# Out:
#    1/1333 [..............................] - ETA: 30s
# 1333/1333 [==============================] - 1s 774us/step
# 5330/5330 [==============================] - 4s 726us/step
# 24429/24429 [==============================] - 18s 719us/step
# Total accuracy 0.612255053716122
# Classification report for the total set
#               precision    recall  f1-score   support
#
#   background       0.94      0.58      0.72    664873
#       signal       0.25      0.79      0.38    116829
#
#     accuracy                           0.61    781702
#    macro avg       0.60      0.69      0.55    781702
# weighted avg       0.84      0.61      0.67    781702
#
# Confusion matrix:
#  [[385960 278913]
#  [ 24188  92641]]
# 24429/24429 [==============================] - 18s 731us/step
# 24429/24429 [==============================] - 16s 668us/step

# %%
y_pred_NN_opt_fit = drop_model.predict(X_test).round() # make predictions on the test data
y_pred_NN_train_opt_fit = drop_model.predict(X_train_val).round()
y_pred_NN_tot_opt_fit = drop_model.predict(scaler.transform(X)).round()

# See how well the classifier does, Acc = correct data / tot data
print("Total accuracy", accuracy_score(Y, y_pred_NN_tot_opt_fit))

print("Classification report for the total set")
print(classification_report(Y.round(), y_pred_NN_tot_opt_fit.round(), target_names=['background', 'signal']))

print("Confusion matrix:\n", confusion_matrix(Y.round(), y_pred_NN_tot_opt_fit.round()))

fpr_nn_opt_tot_fit, tpr_nn_opt_tot_fit, thresholds_nn_opt_tot_fit = roc_curve(Y, y_pred_NN_tot_opt_fit.round()) # get FPRs, TPRs and thresholds for neural network

df_all['dense_NN_opt_drop'] = drop_model.predict(scaler.transform(X)) # add prediction to array
# Out:
# 1333/1333 [==============================] - 1s 794us/step
# 5330/5330 [==============================] - 5s 873us/step
# 24429/24429 [==============================] - 24s 994us/step
# Total accuracy 0.6048187160836227
# Classification report for the total set
#               precision    recall  f1-score   support
#
#   background       0.94      0.57      0.71    664873
#       signal       0.25      0.81      0.38    116829
#
#     accuracy                           0.60    781702
#    macro avg       0.60      0.69      0.55    781702
# weighted avg       0.84      0.60      0.66    781702
#
# Confusion matrix:
#  [[378066 286807]
#  [ 22107  94722]]
# 24429/24429 [==============================] - 20s 816us/step

# %%
# add TF NN probability
y_TOT_prob_NN_opt = opt_model.predict(scaler.transform(X))
y_TOT_NN_opt = opt_model.predict(scaler.transform(X)).round()

cumulative_events = 0 # start counter for total number of events for which output is saved
for key in filename.keys(): # loop over samples
    df[key]['NN_opt_tot_output_prob'] = y_TOT_prob_NN_opt[cumulative_events:cumulative_events+len(df[key])]
    df[key]['NN_opt_tot_output'] = y_TOT_NN_opt[cumulative_events:cumulative_events+len(df[key])]
    cumulative_events += len(df[key]) # increment counter for total number of events
    #print(df[key]['NN_output']) # print the dataframe column NN_output

# probability and significance plots
NN_opt_tot_output_prob = { # dictionary containing plotting parameters for the mllll histogram
    # change plotting parameters
    'bin_width':0.1, # width of each histogram bin
    'num_bins':8, # number of histogram bins
    'xrange_min':0, # minimum on x-axis
    'xlabel':'Neural Network optimized output', # x-axis label
}

SoverB_hist_dict = {'NN_opt_tot_output_prob':NN_opt_tot_output_prob}
plot_SoverB(df, SoverB_hist_dict)
# Out:
# 24429/24429 [==============================] - 18s 738us/step
# 24429/24429 [==============================] - 18s 736us/step

# %%
# add TF NN probability
y_TOT_prob_NN_opt_fit = drop_model.predict(scaler.transform(X))
y_TOT_NN_opt_fit = drop_model.predict(scaler.transform(X)).round()

cumulative_events = 0 # start counter for total number of events for which output is saved
for key in filename.keys(): # loop over samples
    df[key]['NN_opt_tot_output_prob_overfit'] = y_TOT_prob_NN_opt_fit[cumulative_events:cumulative_events+len(df[key])]
    df[key]['NN_opt_tot_output_overfit'] = y_TOT_NN_opt_fit[cumulative_events:cumulative_events+len(df[key])]
    cumulative_events += len(df[key]) # increment counter for total number of events
    #print(df[key]['NN_output']) # print the dataframe column NN_output

# probability and significance plots
NN_opt_tot_output_prob_fit = { # dictionary containing plotting parameters for the mllll histogram
    # change plotting parameters
    'bin_width':0.1, # width of each histogram bin
    'num_bins':8, # number of histogram bins
    'xrange_min':0, # minimum on x-axis
    'xlabel':'Neural Network optimized output', # x-axis label
}

SoverB_hist_dict = {'NN_opt_tot_output_prob_overfit':NN_opt_tot_output_prob_fit}
plot_SoverB(df, SoverB_hist_dict)
# Out:
# 24429/24429 [==============================] - 19s 785us/step
# 24429/24429 [==============================] - 19s 773us/step

# %%
# plot ROC curve
plt.plot(fpr_nn_opt_tot, tpr_nn_opt_tot, label='Neural Network total') # plot Neural net-opt ROC
plt.plot(fpr_nn_opt_tot_fit, tpr_nn_opt_tot_fit, label='Neural Network overfit total') # plot Neural net-opt w overfit ROC
plt.plot([0, 1], [0, 1], linestyle='dotted', color='grey', label='Luck') # plot diagonal line to indicate luck
plt.xlabel('False Positive Rate') # x-axis label
plt.ylabel('True Positive Rate') # y-axis label
plt.grid() # add a grid to the plot
plt.legend() # add a legend

# %%
#ams_rf = AMS(tpr_rf, fpr_rf, 0.001) # get AMS for random forest classifier
ams_rf_opt_tot = AMS(tpr_nn_opt_tot, fpr_nn_opt_tot, 0.001) # get AMS for random forest classifier
ams_rf_opt_tot_fit = AMS(tpr_nn_opt_tot_fit, fpr_nn_opt_tot_fit, 0.001) # get AMS for random forest classifier

plt.plot(thresholds_nn_opt_tot, ams_rf_opt_tot, label="Neural Netwrok")  # plot Random forest AMS
plt.plot(thresholds_nn_opt_tot_fit, ams_rf_opt_tot_fit, label="Neural Netwrok overfit")  # plot Random forest AMS
plt.xlabel("Threshold")  # x-axis label
plt.ylabel("AMS")  # y-axis label
plt.title("AMS with $b_r=0.001$")  # add plot title
plt.legend()  # add legend

# %% [markdown]
# ## Significance

# %%
df_all.head()
#print(df_all[df_all['isSignal']==0]['weight'].unique())
# Out:
#                 jetNo  jetPTLeading    jetETA    jetPHI  elecPTLeading  \
# entry subentry
# 0     0             1     61.355896 -2.602327  3.103293      60.271286
# 1     0             2     81.348595  3.860014 -1.635703      63.262257
#       1             2     81.348595 -2.360897  0.415761      63.262257
# 2     0             1     30.704407  4.726031  2.915039      61.715443
# 3     0             1    105.569740  3.427587  2.155524      86.568611
#
#                  elecETA   elecPHI  dielecCOS  dielecETA         met  \
# entry subentry
# 0     0        -1.375190 -1.056849   0.445503  -0.907034   74.087189
# 1     0         1.239766 -0.091067  -0.061392   0.030054  106.002663
#       1         1.209712  1.541160  -0.061392   0.030054  106.002663
# 2     0        -0.706659 -0.853577  -0.564199  -0.313872   20.235960
# 3     0         2.177542  0.244661   0.090134   0.311947   53.968071
#
#                 testnonTopMass  weight  isSignal  dense_NN  dense_NN_opt  \
# entry subentry
# 0     0             174.217696  0.0037       0.0  0.575790      0.699014
# 1     0             322.219863  0.0037       0.0  0.064186      0.065976
#       1             322.219863  0.0037       0.0  0.071009      0.083134
# 2     0             790.152292  0.0037       0.0  0.284387      0.213508
# 3     0             274.812373  0.0037       0.0  0.079854      0.077598
#
#                 dense_NN_opt_drop
# entry subentry
# 0     0                  0.693397
# 1     0                  0.046845
#       1                  0.064522
# 2     0                  0.352626
# 3     0                  0.081379

# %% [markdown]
# ###

# %%
sig_weight = df_all[df_all['isSignal']==1]['weight'].unique()[0]
#sig_weight = 0.0007
df_sig_75 = df_all[(df_all['dense_NN']>=0.60) & (df_all['isSignal']==1)]
n_sig_75 = df_sig_75.shape[0] * sig_weight
df_sig_80 = df_all[(df_all['dense_NN']>=0.65) & (df_all['isSignal']==1)]
n_sig_80 = df_sig_80.shape[0] * sig_weight
df_sig_85 = df_all[(df_all['dense_NN']>=0.70) & (df_all['isSignal']==1)]
n_sig_85 = df_sig_85.shape[0] * sig_weight

bkg_weights = df_all[df_all['isSignal']==0]['weight'].unique()
list_bkg_75 = [df_all[(df_all['dense_NN']>=0.60) & (df_all['isSignal']==0) & (df_all['weight'] == bkg_w)].shape[0] * bkg_w for bkg_w in bkg_weights]
list_bkg_80 = [df_all[(df_all['dense_NN']>=0.65) & (df_all['isSignal']==0) & (df_all['weight'] == bkg_w)].shape[0] * bkg_w for bkg_w in bkg_weights]
list_bkg_85 = [df_all[(df_all['dense_NN']>=0.70) & (df_all['isSignal']==0) & (df_all['weight'] == bkg_w)].shape[0] * bkg_w for bkg_w in bkg_weights]

print("60% : sig_n {:.1f}\tbkg_n {:.1f}\tsig/bkg {:.3f}".format(n_sig_75, sum(list_bkg_75), n_sig_75/sum(list_bkg_75)))
print("65% : sig_n {:.1f}\tbkg_n {:.1f}\tsig/bkg {:.3f}".format(n_sig_80, sum(list_bkg_80), n_sig_75/sum(list_bkg_80)))
print("70% : sig_n {:.1f}\tbkg_n {:.1f}\tsig/bkg {:.3f}".format(n_sig_85, sum(list_bkg_85), n_sig_75/sum(list_bkg_85)))
# Out:
# 60% : sig_n 48.7	bkg_n 4622.4	sig/bkg 0.011
# 65% : sig_n 40.2	bkg_n 3418.6	sig/bkg 0.014
# 70% : sig_n 31.3	bkg_n 2331.8	sig/bkg 0.021

# %%
df_sig_75 = df_all[(df_all['dense_NN_opt']>=0.60) & (df_all['isSignal']==1)]
n_sig_75 = df_sig_75.shape[0] * sig_weight
df_sig_80 = df_all[(df_all['dense_NN_opt']>=0.65) & (df_all['isSignal']==1)]
n_sig_80 = df_sig_80.shape[0] * sig_weight
df_sig_85 = df_all[(df_all['dense_NN_opt']>=0.70) & (df_all['isSignal']==1)]
n_sig_85 = df_sig_85.shape[0] * sig_weight

bkg_weights = df_all[df_all['isSignal']==0]['weight'].unique()
list_bkg_75 = [df_all[(df_all['dense_NN_opt']>=0.60) & (df_all['isSignal']==0) & (df_all['weight'] == bkg_w)].shape[0] * bkg_w for bkg_w in bkg_weights]
list_bkg_80 = [df_all[(df_all['dense_NN_opt']>=0.65) & (df_all['isSignal']==0) & (df_all['weight'] == bkg_w)].shape[0] * bkg_w for bkg_w in bkg_weights]
list_bkg_85 = [df_all[(df_all['dense_NN_opt']>=0.70) & (df_all['isSignal']==0) & (df_all['weight'] == bkg_w)].shape[0] * bkg_w for bkg_w in bkg_weights]

print("60% : sig_n {:.1f}\tbkg_n {:.1f}\tsig/bkg {:.3f}".format(n_sig_75, sum(list_bkg_75), n_sig_75/sum(list_bkg_75)))
print("65% : sig_n {:.1f}\tbkg_n {:.1f}\tsig/bkg {:.3f}".format(n_sig_80, sum(list_bkg_80), n_sig_75/sum(list_bkg_80)))
print("70% : sig_n {:.1f}\tbkg_n {:.1f}\tsig/bkg {:.3f}".format(n_sig_85, sum(list_bkg_85), n_sig_75/sum(list_bkg_85)))
# Out:
# 60% : sig_n 54.3	bkg_n 5162.7	sig/bkg 0.011
# 65% : sig_n 47.5	bkg_n 4101.8	sig/bkg 0.013
# 70% : sig_n 40.3	bkg_n 3106.5	sig/bkg 0.017

# %%
df_sig_75 = df_all[(df_all['dense_NN_opt_drop']>=0.60) & (df_all['isSignal']==1)]
n_sig_75 = df_sig_75.shape[0] * sig_weight
df_sig_80 = df_all[(df_all['dense_NN_opt_drop']>=0.65) & (df_all['isSignal']==1)]
n_sig_80 = df_sig_80.shape[0] * sig_weight
df_sig_85 = df_all[(df_all['dense_NN_opt_drop']>=0.70) & (df_all['isSignal']==1)]
n_sig_85 = df_sig_85.shape[0] * sig_weight

bkg_weights = df_all[df_all['isSignal']==0]['weight'].unique()
list_bkg_75 = [df_all[(df_all['dense_NN_opt_drop']>=0.60) & (df_all['isSignal']==0) & (df_all['weight'] == bkg_w)].shape[0] * bkg_w for bkg_w in bkg_weights]
list_bkg_80 = [df_all[(df_all['dense_NN_opt_drop']>=0.65) & (df_all['isSignal']==0) & (df_all['weight'] == bkg_w)].shape[0] * bkg_w for bkg_w in bkg_weights]
list_bkg_85 = [df_all[(df_all['dense_NN_opt_drop']>=0.70) & (df_all['isSignal']==0) & (df_all['weight'] == bkg_w)].shape[0] * bkg_w for bkg_w in bkg_weights]

print("60% : sig_n {:.1f}\tbkg_n {:.1f}\tsig/bkg {:.3f}".format(n_sig_75, sum(list_bkg_75), n_sig_75/sum(list_bkg_75)))
print("65% : sig_n {:.1f}\tbkg_n {:.1f}\tsig/bkg {:.3f}".format(n_sig_80, sum(list_bkg_80), n_sig_75/sum(list_bkg_80)))
print("70% : sig_n {:.1f}\tbkg_n {:.1f}\tsig/bkg {:.3f}".format(n_sig_85, sum(list_bkg_85), n_sig_75/sum(list_bkg_85)))
# Out:
# 60% : sig_n 54.8	bkg_n 5226.9	sig/bkg 0.010
# 65% : sig_n 47.3	bkg_n 4078.7	sig/bkg 0.013
# 70% : sig_n 38.7	bkg_n 2955.1	sig/bkg 0.019
