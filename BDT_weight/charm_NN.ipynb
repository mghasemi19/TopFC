# %% [markdown]
# # DNN in TopFC analysis
# Author: Meisam Ghasemi Bostanabad

# %% [markdown]
# ## Loading `pandas` DataFrames
# Now we load two different `NumPy` arrays. One corresponding to the VV signal and one corresponding to the background.

# %%
import uproot
import numpy as np
import pandas as pd
import h5py
import awkward as ak
import seaborn as sns
import matplotlib.pyplot as plt
import math

# fix random seed for reproducibility
seed = 7
np.random.seed(seed)

filename = {
    'ttbar':'/Users/mghasemi/Desktop/IPM/plotter/newtrees/ttbar.root',
    'WZ':'/Users/mghasemi/Desktop/IPM/plotter/newtrees/WZ.root',
    'ZZ':'/Users/mghasemi/Desktop/IPM/plotter/newtrees/ZZ.root',
    'signal_charm':'/Users/mghasemi/Desktop/IPM/plotter/newtrees/signal_charm.root'
    }

'''
filename = {
    'ttbar':'/Users/mghasemi/Desktop/IPM/plotter/newtrees/ttbar.root',
    'WZ':'/Users/mghasemi/Desktop/IPM/plotter/newtrees/WZ.root',
    'ZZ':'/Users/mghasemi/Desktop/IPM/plotter/newtrees/ZZ.root',
    'signal_up':'/Users/mghasemi/Desktop/IPM/plotter/newtrees/signal_up.root'}
    }
'''

upfile = {}
params = {}
df = {}

# choose which vars to use (multi dimensional)
#VARS = ['jetNo','jetPTLeading','bjetPT','elecPTLeading','met','testnonTopMass', 'weight'] # choose which vars to use (2d)
VARS = ['jetNo','jetPTLeading', 'jetETA', 'jetPHI','bjetPT', 'bjetETA',
        'elecPTLeading', 'elecETA', 'elecPHI',
        'dielecCOS', 'dielecETA', 'met','testnonTopMass'] # choose which vars to use (2d)

# define trees and branches to make DataFrame
for treename in filename.keys():
    upfile[treename] = uproot.open(filename[treename])
    params[treename] = upfile[treename][treename].arrays(VARS)
    df[treename] = ak.to_dataframe(params[treename])
    # add isSignal variable
    if treename.startswith("signal"): 
        df[treename]['isSignal'] = np.ones(len(df[treename])) 
    else:
        df[treename]['isSignal'] = np.zeros(len(df[treename]))

# %% [markdown]
# ## Functions

# %%
# function to plot all distributions
def hist(df1, df2, cols, bins, ncols = 3):
    nrows = math.ceil(len(cols) / ncols)
    fig, ax = plt.subplots(nrows, ncols, figsize = (5 * ncols, 4.2 * nrows), sharey = False)
    for i in range(len(cols)):
        #sns.histplot(data = df, x = cols[i], bins = bins, hue = 'isSignal', palette = ['grey', 'red'], ax = ax[i // ncols, i % ncols], stat="probability")
        sns.histplot(data = df1, x = cols[i], bins = bins, color = 'red',
                      ax = ax[i // ncols, i % ncols], stat="density", label='bkg')
        sns.histplot(data = df2, x = cols[i], bins = bins, color = 'grey',
                      ax = ax[i // ncols, i % ncols], stat="density", label='sig')       
        ax[i // ncols, i % ncols].set_xlabel(cols[i])
        ax[i // ncols, i % ncols].legend()
        if i % ncols != 0:
            ax[i // ncols, i % ncols].set_ylabel(" ")
        
    plt.tight_layout()
    plt.show()


# function to make ML output and significant plot
samples =['ttbar', 'WZ', 'ZZ', 'signal_charm']

def plot_SoverB(data, SoverB_hist_dict):
    
    signal = r'signal_charm' # which sample is the signal

    # *******************
    # general definitions (shouldn't need to change)

    for x_variable,hist in SoverB_hist_dict.items(): # access the dictionary of histograms defined in the cell above

        h_bin_width = hist['bin_width'] # get the bin width defined in the cell above
        h_num_bins = hist['num_bins'] # get the number of bins defined in the cell above
        h_xrange_min = hist['xrange_min'] # get the x-range minimum defined in the cell above
        h_xlabel = hist['xlabel'] # get the x-axis label defined in the cell above
    
        bin_edges = [ h_xrange_min + x*h_bin_width for x in range(h_num_bins+1) ] # bin limits
        bin_centres = [ h_xrange_min+h_bin_width/2 + x*h_bin_width for x in range(h_num_bins) ] # bin centres
        
        signal_x = data[signal][x_variable] # histogram the signal
    
        mc_x = [] # define list to hold the Monte Carlo histogram entries

        for s in samples: # loop over samples
            if s not in ['data', signal]: # if not data nor signal
                mc_x = [*mc_x, *data[s][x_variable] ] # append to the list of Monte Carlo histogram entries
                #test=[]; test.append(df[s]['NN_output_prob'].values)


    
    
        # *************
        # Signal and background distributions
        # *************
        distributions_axes = plt.gca() # get current axes
 
        mc_heights = distributions_axes.hist(mc_x, bins=bin_edges, color='red', 
                                             label='Total background',
                                             histtype='step', # lineplot that's unfilled
                                             density=True ) # normalize to form probability density
        signal_heights = distributions_axes.hist(signal_x, bins=bin_edges, color='blue',
                                                 label=signal, 
                                                 histtype='step', # lineplot that's unfilled
                                                 density=True, # normalize to form probability density
                                                 linestyle='--' ) # dashed line
        
        distributions_axes.set_xlim( left=bin_edges[0], right=bin_edges[-1] ) # x-limits of the distributions axes
        distributions_axes.set_ylabel('Arbitrary units' ) # y-axis label for distributions axes
        y_max = max(max(signal_heights[0]), max(mc_heights[0]) )
        #distributions_axes.set_ylim( top=max(signal_heights[0])*1.3 ) # set y-axis limits
        distributions_axes.set_ylim( top=y_max*1.2 ) # set y-axis limits
        #distributions_axes.set_ylim( top=max(signal_heights[0])*1.3 ) # set y-axis limits
        plt.title('Signal and background '+x_variable+' distributions') # add title
        distributions_axes.legend() # draw the legend
        distributions_axes.set_xlabel( h_xlabel ) # x-axis label
            
        plt.show() # show the Signal and background distributions
    
    
        # *************
        # Signal to background ratio
        # *************
        plt.figure() # start new figure
        SoverB = [] # list to hold S/B values
        for cut_value in bin_edges: # loop over bins
            #signal_weights_passing_cut = sum(data[signal][data[signal][x_variable]>cut_value].totalWeight)
            signal_weights_passing_cut = len(data[signal][data[signal][x_variable]>cut_value])
            background_weights_passing_cut = 0 # start counter for background weights passing cut
            for s in samples: # loop over samples
                if s not in ['data', signal]: # if not data nor signal
                    #background_weights_passing_cut += sum(data[s][data[s][x_variable]>cut_value].totalWeight)
                    background_weights_passing_cut += len(data[s][data[s][x_variable]>cut_value])
            if background_weights_passing_cut!=0: # some background passes cut
                SoverB_value = signal_weights_passing_cut/background_weights_passing_cut
                SoverB_percent = 100*SoverB_value # multiply by 100 for percentage
                SoverB.append(SoverB_percent) # append to list of S/B values
        
        SoverB_axes = plt.gca() # get current axes
        SoverB_axes.plot( bin_edges[:len(SoverB)], SoverB ) # plot the data points
        SoverB_axes.set_xlim( left=bin_edges[0], right=bin_edges[-1] ) # set the x-limit of the main axes
        #SoverB_axes.set_ylim( 100, 1000)
        SoverB_axes.set_ylabel( 'S/B (%)' ) # write y-axis label for main axes
        plt.title('Signal to background ratio for different '+x_variable+' cut values', family='sans-serif')
        SoverB_axes.set_xlabel( h_xlabel ) # x-axis label 
        
        plt.show() # show S/B plot
    
    return    

from sklearn.metrics import roc_curve, auc, classification_report, accuracy_score, confusion_matrix

# function to draw loss-accuracy vs epoch and ROC curve
# %matplotlib inline
def loss_accuracy_plotter(history):
    # plot loss vs epoch
    plt.figure(figsize=(15,10))
    ax = plt.subplot(2, 2, 1)
    ax.plot(history.history['loss'], label='loss')
    ax.plot(history.history['val_loss'], label='val_loss')
    ax.legend(loc="upper right")
    ax.set_title('Loss over epochs')
    ax.set_xlabel('epoch')
    ax.set_ylabel('loss')

    # plot accuracy vs epoch
    ax = plt.subplot(2, 2, 2)
    ax.plot(history.history['accuracy'], label='acc')
    ax.plot(history.history['val_accuracy'], label='val_acc')
    ax.legend(loc="lower right")
    ax.set_title('Accuracy over epochs')
    ax.set_xlabel('epoch')
    ax.set_ylabel('acc')

    # Plot ROC
    Y_predict = model.predict(X_test)
    Y_predict_train = model.predict(X_train_val)
    fpr, tpr, thresholds = roc_curve(Y_test, Y_predict)
    roc_auc = auc(fpr, tpr)
    ax = plt.subplot(2, 2, 3)
    ax.plot(fpr, tpr, lw=2, color='cyan', label='auc = %.3f' % (roc_auc))
    ax.plot([0, 1], [0, 1], linestyle='--', lw=2, color='k', label='random chance')
    ax.set_xlim([0, 1.0])
    ax.set_ylim([0, 1.0])
    ax.set_xlabel('false positive rate')
    ax.set_ylabel('true positive rate')
    ax.set_title('receiver operating curve')
    ax.legend(loc="lower right")
    plt.show()

# function to report all metrics evaluation
def evaluate(model, scaler, X, Y, X_train_val, Y_train_val, X_test, Y_test):
    Y_pred_test = model.predict(X_test)
    Y_pred_test = Y_pred_test.reshape(Y_pred_test.shape[0])
    Y_pred_train = model.predict(X_train_val)
    Y_pred_train = Y_pred_train.reshape(Y_pred_train.shape[0])
    Y_pred_tot = model.predict(scaler.transform(X)).round()
    Y_pred_tot = Y_pred_tot.reshape(Y_pred_tot.shape[0])

    # accuracy score
    print("Test acc score:", accuracy_score(Y_test.round(), Y_pred_test.round()))
    print("Train acc score:", accuracy_score(Y_train_val.round(), Y_pred_train.round()))

    # classification report for the test and total sets
    print("Classification report for the test set")
    print(classification_report(Y_test.round(), Y_pred_test.round(), target_names=['background', 'signal']))
    print("Classification report for the total set")
    print(classification_report(Y.round(), Y_pred_tot.round(), target_names=['background', 'signal']))

    print("Confusion matrix for total set")
    print(confusion_matrix(Y.round(), Y_pred_tot.round()))

    fpr, tpr, thresholds = roc_curve(Y_test, Y_pred_test) # get FPRs, TPRs and thresholds for neural network
    return fpr, tpr, thresholds

# plot AMS
def AMS(tpr, fpr, b_reg): # define function to calculate AMS
    return np.sqrt(2*((tpr+fpr+b_reg)*np.log(1+tpr/(fpr+b_reg))-tpr)) # equation for AMS

# plot train and test CLF distributions
def new_compare_train_test(clf, X_train, y_train, X_test, y_test, xlabel):
    decisions = [] # list to hold decisions of classifier
    for X,y in ((X_train, y_train), (X_test, y_test)): # train and test
        d1 = clf.predict(X[y<0.5]) # background
        d2 = clf.predict(X[y>0.5]) # signal
        decisions += [d1, d2] # add to list of classifier decision

    highest_decision = max(np.max(d) for d in decisions) # get maximum score
    bin_edges = [] # list to hold bin edges
    bin_edge = -0.1 # start counter for bin_edges
    while bin_edge < highest_decision: # up to highest score
        bin_edge += 0.1 # increment
        bin_edges.append(bin_edge)

    # Training plots
    plt.hist(decisions[0], # background in train set
            bins=bin_edges, # lower and upper range of the bins
            density=True, # area under the histogram will sum to 1
            histtype='stepfilled', # lineplot that's filled
            color='blue', label='Background (train)', # Background (train)
            alpha=0.5 ) # half transparency
    plt.hist(decisions[1], # signal in train set
            bins=bin_edges, # lower and upper range of the bins
            density=True, # area under the histogram will sum to 1
            histtype='stepfilled', # lineplot that's filled
            color='orange', label='Signal (train)', # Signal (train)
            alpha=0.5 ) # half transparency

    # Testing plots
    hist_background, bin_edges = np.histogram(decisions[2], # background test
                                            bins=bin_edges, # number of bins in function definition
                                            density=True ) # area under the histogram will sum to 1

    scale = len(decisions[2]) / sum(hist_background) # between raw and normalised
    err_background = np.sqrt(hist_background * scale) / scale # error on test background

    width = 0.1 # histogram bin width
    center = (bin_edges[:-1] + bin_edges[1:]) / 2 # bin centres

    plt.errorbar(x=center, y=hist_background, yerr=err_background, fmt='o', # circles
                c='blue', label='Background (test)' ) # Background (test)

    hist_signal, bin_edges = np.histogram(decisions[3], # siganl test
                                        bins=bin_edges, # number of bins in function definition
                                        density=True ) # area under the histogram will sum to 1

    scale = len(decisions[3]) / sum(hist_signal) # between raw and normalised
    err_signal = np.sqrt(hist_signal * scale) / scale # error on test background

    plt.errorbar(x=center, y=hist_signal, yerr=err_signal, fmt='*', # circles
                c='orange', label='Signal (test)' ) # Signal (test)

    plt.xlabel(xlabel) # write x-axis label
    plt.ylabel("Arbitrary units") # write y-axis label
    plt.legend() # add legend

# %% [markdown]
# ## Data exploration

# %%
# reduce signal DF size to have resonable Sig/Bkg ratio
df['signal_charm'] = df['signal_charm'][:20000]
df_all = pd.concat([df[treename] for treename in filename.keys()])

# %%
# number of entries in the backgrounds and signals
tot_bkg = 0
for treename in filename.keys():
    if not 'signal' in treename: tot_bkg += df[treename].shape[0]
    print(treename, ":", df[treename].shape)

print("signal/tot bkg:", round((df['signal_charm'].shape[0]/ tot_bkg),1))
#print("Null entries:", df['signal_charm'].isna().sum())

counts_signal = df['signal_charm'].shape[0]
counts_background = tot_bkg
#plt.pie([counts_signal, counts_background], shadow=True, labels=['Signal ','Background'], textprops={'color':"b"}, autopct='%1.1f%%');
plt.pie([counts_signal, counts_background], explode=[0.1,0.1], shadow=True, labels=['Signal ','Background'], textprops={'color':"b"}, autopct='%1.1f%%');
# Out:
# ttbar : (1181, 14)
# WZ : (10855, 14)
# ZZ : (174, 14)
# signal_charm : (20000, 14)
# signal/tot bkg: 1.6

# %%
# show the correlation between features
plt.figure(figsize=(10,8))
#sns.heatmap(df_all.corr(), annot=True, linewidth=.5)
sns.heatmap(df_all.corr(), annot=True, linewidth=.5, vmin = -1, vmax = 1,cmap = plt.cm.CMRmap_r, fmt=".1f");

# %%
df_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 32210 entries, (0, 0) to (8122, 0)
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   jetNo           32210 non-null  int32
#  1   jetPTLeading    32210 non-null  float64
#  2   jetETA          32210 non-null  float64
#  3   jetPHI          32210 non-null  float64
#  4   bjetPT          32210 non-null  float64
#  5   bjetETA         32210 non-null  float64
#  6   elecPTLeading   32210 non-null  float64
#  7   elecETA         32210 non-null  float64
#  8   elecPHI         32210 non-null  float64
#  9   dielecCOS       32210 non-null  float64
#  10  dielecETA       32210 non-null  float64
#  11  met             32210 non-null  float64
#  12  testnonTopMass  32210 non-null  float64
#  13  isSignal        32210 non-null  float64
# dtypes: float64(13), int32(1)
# memory usage: 3.7 MB

# %%
# Distributions of the float features
hist(df_all[df_all['isSignal']==0].replace(-999, np.nan),
     df_all[df_all['isSignal']==1].replace(-999, np.nan),
     #list(df_all.columns[df_all.dtypes == 'float64']),
     list(df_all.columns),
     bins = math.floor(len(df_all)**(1/3)),
     ncols = 3)

# %% [markdown]
# ## Define the models

# %% [markdown]
# ## simple NN from Tensorflow
# We'll start with a dense (fully-connected) NN layer.
# Our model will have a single fully-connected hidden layer with the same number of neurons as input variables.
# The weights are initialized using a small Gaussian random number.
# We will switch between linear and tanh activation functions for the hidden layer.
# The output layer contains a single neuron in order to make predictions.
# It uses the sigmoid activation function in order to produce a probability output in the range of 0 to 1.
#
# We are using the `binary_crossentropy` loss function during training, a standard loss function for binary classification problems.
# We will optimize the model with the Adam algorithm for stochastic gradient descent and we will collect accuracy metrics while the model is trained.

# %% [markdown]
# ## Dividing the data into testing and training dataset
#
# We will split the data into two parts (one for training+validation and one for testing).
# We will also apply "standard scaling" preprocessing: http://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.StandardScaler.html i.e. making the mean = 0 and the RMS = 1 for all input variables (based **only** on the training/validation dataset).
# We will also define our early stopping criteria to prevent over-fitting and we will save the model based on the best `val_loss`.

# %%
NDIM = len(VARS)
dataset = df_all.values
X = dataset[:,0:NDIM]
Y = dataset[:,NDIM]

from sklearn.model_selection import train_test_split
X_train_val, X_test, Y_train_val, Y_test = train_test_split(X, Y, test_size=0.2, random_state=7)

# preprocessing: standard scalar
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler().fit(X_train_val)
X_train_val = scaler.transform(X_train_val)
X_test = scaler.transform(X_test)

# baseline keras model
from keras.models import Sequential, Model
from tensorflow.keras.optimizers import SGD
#from keras.optimizers import SGD
from keras.layers import Input, Activation, Dense, Convolution2D, MaxPooling2D, Dropout, Flatten
from keras.utils import np_utils
from sklearn.model_selection import RandomizedSearchCV
from sklearn.pipeline import Pipeline
from tensorflow import keras

inputs = Input(shape=(NDIM,), name = 'input') 
hidden1 = Dense(20, name = 'hidden1', kernel_initializer='normal', activation='relu')(inputs)
hidden2 = Dense(20, name = 'hidden2', kernel_initializer='normal', activation='relu')(hidden1)
outputs = Dense(1, name = 'output', kernel_initializer='normal', activation='sigmoid')(hidden2)

# create the model
model = Model(inputs=inputs, outputs=outputs)
# compile the model
optimizer = SGD(learning_rate=1e-3) # define the optimizer
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
#model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])
# print the model summary
model.summary()

# early stopping callback
from keras.callbacks import EarlyStopping
early_stopping = EarlyStopping(monitor='val_loss', patience=10, mode='min')

# model checkpoint callback
# this saves our model architecture + parameters into dense_model.h5
from keras.callbacks import ModelCheckpoint
model_checkpoint = ModelCheckpoint('TopFC_dense_model.h5', monitor='val_loss', 
                                   verbose=0, save_best_only=True, 
                                   save_weights_only=False, mode='auto', 
                                   period=1)
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input (InputLayer)          [(None, 13)]              0
#
#  hidden1 (Dense)             (None, 20)                280
#
#  hidden2 (Dense)             (None, 20)                420
#
#  output (Dense)              (None, 1)                 21
#
# =================================================================
# Total params: 721
# Trainable params: 721
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %% [markdown]
# ## Run training
# Here, we run the training.

# %%
# Train classifier
import time
start = time.time() # time at start of whole processing

history = model.fit(X_train_val, 
                    Y_train_val, 
                    epochs=1000, 
                    batch_size=512, 
                    verbose=1, # switch to 1 for more verbosity 
                    callbacks=[early_stopping, model_checkpoint], 
                    validation_data=(X_test,Y_test))

elapsed = time.time() - start # time after whole processing
print("Time taken: "+str(round(elapsed,1))+"s") # print total time taken to process every file
# Out:
# Epoch 1/1000
# 51/51 [==============================] - 1s 6ms/step - loss: 0.6835 - accuracy: 0.6204 - val_loss: 0.6607 - val_accuracy: 0.6455
# Epoch 2/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.6367 - accuracy: 0.6523 - val_loss: 0.6114 - val_accuracy: 0.6675
# Epoch 3/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.6115 - accuracy: 0.6644 - val_loss: 0.6030 - val_accuracy: 0.6700
# Epoch 4/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.6069 - accuracy: 0.6669 - val_loss: 0.6006 - val_accuracy: 0.6737
# Epoch 5/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.6041 - accuracy: 0.6706 - val_loss: 0.5975 - val_accuracy: 0.6762
# Epoch 6/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.6015 - accuracy: 0.6741 - val_loss: 0.5946 - val_accuracy: 0.6770
# Epoch 7/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5984 - accuracy: 0.6766 - val_loss: 0.5915 - val_accuracy: 0.6796
# Epoch 8/1000
# 51/51 [==============================] - 0s 3ms/step - loss: 0.5951 - accuracy: 0.6801 - val_loss: 0.5886 - val_accuracy: 0.6816
# Epoch 9/1000
# 51/51 [==============================] - 0s 3ms/step - loss: 0.5919 - accuracy: 0.6832 - val_loss: 0.5859 - val_accuracy: 0.6880
# Epoch 10/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5882 - accuracy: 0.6881 - val_loss: 0.5824 - val_accuracy: 0.6894
# Epoch 11/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5843 - accuracy: 0.6912 - val_loss: 0.5762 - val_accuracy: 0.6995
# Epoch 12/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5812 - accuracy: 0.6941 - val_loss: 0.5735 - val_accuracy: 0.7035
# Epoch 13/1000
# 51/51 [==============================] - 0s 3ms/step - loss: 0.5782 - accuracy: 0.6978 - val_loss: 0.5715 - val_accuracy: 0.7057
# Epoch 14/1000
# 51/51 [==============================] - 0s 5ms/step - loss: 0.5762 - accuracy: 0.6984 - val_loss: 0.5692 - val_accuracy: 0.7058
# Epoch 15/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5746 - accuracy: 0.7006 - val_loss: 0.5684 - val_accuracy: 0.7061
# Epoch 16/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5734 - accuracy: 0.6997 - val_loss: 0.5668 - val_accuracy: 0.7065
# Epoch 17/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5726 - accuracy: 0.7012 - val_loss: 0.5660 - val_accuracy: 0.7089
# Epoch 18/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5716 - accuracy: 0.7022 - val_loss: 0.5644 - val_accuracy: 0.7088
# Epoch 19/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5704 - accuracy: 0.7039 - val_loss: 0.5647 - val_accuracy: 0.7074
# Epoch 20/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5693 - accuracy: 0.7029 - val_loss: 0.5653 - val_accuracy: 0.7082
# Epoch 21/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5689 - accuracy: 0.7047 - val_loss: 0.5628 - val_accuracy: 0.7093
# Epoch 22/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5673 - accuracy: 0.7050 - val_loss: 0.5610 - val_accuracy: 0.7061
# Epoch 23/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5660 - accuracy: 0.7091 - val_loss: 0.5592 - val_accuracy: 0.7117
# Epoch 24/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5649 - accuracy: 0.7061 - val_loss: 0.5588 - val_accuracy: 0.7094
# Epoch 25/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5643 - accuracy: 0.7093 - val_loss: 0.5593 - val_accuracy: 0.7100
# Epoch 26/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5633 - accuracy: 0.7107 - val_loss: 0.5585 - val_accuracy: 0.7128
# Epoch 27/1000
# 51/51 [==============================] - 0s 6ms/step - loss: 0.5623 - accuracy: 0.7129 - val_loss: 0.5566 - val_accuracy: 0.7122
# Epoch 28/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5617 - accuracy: 0.7110 - val_loss: 0.5555 - val_accuracy: 0.7148
# Epoch 29/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5611 - accuracy: 0.7133 - val_loss: 0.5564 - val_accuracy: 0.7148
# Epoch 30/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5604 - accuracy: 0.7122 - val_loss: 0.5549 - val_accuracy: 0.7148
# Epoch 31/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5597 - accuracy: 0.7132 - val_loss: 0.5554 - val_accuracy: 0.7175
# Epoch 32/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5591 - accuracy: 0.7132 - val_loss: 0.5538 - val_accuracy: 0.7142
# Epoch 33/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5583 - accuracy: 0.7128 - val_loss: 0.5548 - val_accuracy: 0.7167
# Epoch 34/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5581 - accuracy: 0.7134 - val_loss: 0.5563 - val_accuracy: 0.7162
# Epoch 35/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5572 - accuracy: 0.7137 - val_loss: 0.5541 - val_accuracy: 0.7176
# Epoch 36/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5574 - accuracy: 0.7158 - val_loss: 0.5514 - val_accuracy: 0.7203
# Epoch 37/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5564 - accuracy: 0.7154 - val_loss: 0.5510 - val_accuracy: 0.7187
# Epoch 38/1000
# 51/51 [==============================] - 0s 5ms/step - loss: 0.5555 - accuracy: 0.7150 - val_loss: 0.5508 - val_accuracy: 0.7198
# Epoch 39/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5554 - accuracy: 0.7171 - val_loss: 0.5510 - val_accuracy: 0.7204
# Epoch 40/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5542 - accuracy: 0.7169 - val_loss: 0.5512 - val_accuracy: 0.7201
# Epoch 41/1000
# 51/51 [==============================] - 0s 3ms/step - loss: 0.5542 - accuracy: 0.7168 - val_loss: 0.5500 - val_accuracy: 0.7237
# Epoch 42/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5533 - accuracy: 0.7167 - val_loss: 0.5478 - val_accuracy: 0.7249
# Epoch 43/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5529 - accuracy: 0.7190 - val_loss: 0.5489 - val_accuracy: 0.7215
# Epoch 44/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5526 - accuracy: 0.7181 - val_loss: 0.5488 - val_accuracy: 0.7242
# Epoch 45/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5516 - accuracy: 0.7186 - val_loss: 0.5476 - val_accuracy: 0.7257
# Epoch 46/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5514 - accuracy: 0.7167 - val_loss: 0.5495 - val_accuracy: 0.7224
# Epoch 47/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5504 - accuracy: 0.7191 - val_loss: 0.5472 - val_accuracy: 0.7265
# Epoch 48/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5500 - accuracy: 0.7210 - val_loss: 0.5472 - val_accuracy: 0.7220
# Epoch 49/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5493 - accuracy: 0.7199 - val_loss: 0.5464 - val_accuracy: 0.7254
# Epoch 50/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5490 - accuracy: 0.7194 - val_loss: 0.5455 - val_accuracy: 0.7220
# Epoch 51/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5481 - accuracy: 0.7198 - val_loss: 0.5468 - val_accuracy: 0.7248
# Epoch 52/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5481 - accuracy: 0.7202 - val_loss: 0.5452 - val_accuracy: 0.7251
# Epoch 53/1000
# 51/51 [==============================] - 0s 3ms/step - loss: 0.5474 - accuracy: 0.7197 - val_loss: 0.5441 - val_accuracy: 0.7283
# Epoch 54/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5475 - accuracy: 0.7218 - val_loss: 0.5446 - val_accuracy: 0.7293
# Epoch 55/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5469 - accuracy: 0.7197 - val_loss: 0.5456 - val_accuracy: 0.7262
# Epoch 56/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5468 - accuracy: 0.7221 - val_loss: 0.5446 - val_accuracy: 0.7305
# Epoch 57/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5457 - accuracy: 0.7230 - val_loss: 0.5446 - val_accuracy: 0.7260
# Epoch 58/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5462 - accuracy: 0.7216 - val_loss: 0.5461 - val_accuracy: 0.7229
# Epoch 59/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5447 - accuracy: 0.7228 - val_loss: 0.5436 - val_accuracy: 0.7283
# Epoch 60/1000
# 51/51 [==============================] - 0s 3ms/step - loss: 0.5448 - accuracy: 0.7221 - val_loss: 0.5432 - val_accuracy: 0.7305
# Epoch 61/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5447 - accuracy: 0.7238 - val_loss: 0.5428 - val_accuracy: 0.7296
# Epoch 62/1000
# 51/51 [==============================] - 0s 3ms/step - loss: 0.5439 - accuracy: 0.7247 - val_loss: 0.5445 - val_accuracy: 0.7276
# Epoch 63/1000
# 51/51 [==============================] - 0s 4ms/step - loss: 0.5439 - accuracy: 0.7235 - val_loss: 0.5435 - val_accuracy: 0.7297
# Epoch 64/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5432 - accuracy: 0.7231 - val_loss: 0.5442 - val_accuracy: 0.7277
# Epoch 65/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5430 - accuracy: 0.7250 - val_loss: 0.5420 - val_accuracy: 0.7304
# Epoch 66/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5426 - accuracy: 0.7249 - val_loss: 0.5427 - val_accuracy: 0.7293
# Epoch 67/1000
# 51/51 [==============================] - 0s 3ms/step - loss: 0.5424 - accuracy: 0.7246 - val_loss: 0.5425 - val_accuracy: 0.7301
# Epoch 68/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5419 - accuracy: 0.7252 - val_loss: 0.5442 - val_accuracy: 0.7276
# Epoch 69/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5414 - accuracy: 0.7265 - val_loss: 0.5420 - val_accuracy: 0.7338
# Epoch 70/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5413 - accuracy: 0.7261 - val_loss: 0.5448 - val_accuracy: 0.7263
# Epoch 71/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5414 - accuracy: 0.7266 - val_loss: 0.5432 - val_accuracy: 0.7290
# Epoch 72/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5412 - accuracy: 0.7262 - val_loss: 0.5427 - val_accuracy: 0.7299
# Epoch 73/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5407 - accuracy: 0.7245 - val_loss: 0.5426 - val_accuracy: 0.7283
# Epoch 74/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5404 - accuracy: 0.7255 - val_loss: 0.5415 - val_accuracy: 0.7318
# Epoch 75/1000
# 51/51 [==============================] - 0s 3ms/step - loss: 0.5397 - accuracy: 0.7273 - val_loss: 0.5413 - val_accuracy: 0.7319
# Epoch 76/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5400 - accuracy: 0.7257 - val_loss: 0.5440 - val_accuracy: 0.7251
# Epoch 77/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5398 - accuracy: 0.7278 - val_loss: 0.5432 - val_accuracy: 0.7283
# Epoch 78/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5397 - accuracy: 0.7272 - val_loss: 0.5432 - val_accuracy: 0.7319
# Epoch 79/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5394 - accuracy: 0.7262 - val_loss: 0.5416 - val_accuracy: 0.7302
# Epoch 80/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5386 - accuracy: 0.7281 - val_loss: 0.5447 - val_accuracy: 0.7248
# Epoch 81/1000
# 51/51 [==============================] - 0s 3ms/step - loss: 0.5393 - accuracy: 0.7265 - val_loss: 0.5446 - val_accuracy: 0.7277
# Epoch 82/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5383 - accuracy: 0.7282 - val_loss: 0.5424 - val_accuracy: 0.7310
# Epoch 83/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5381 - accuracy: 0.7292 - val_loss: 0.5415 - val_accuracy: 0.7297
# Epoch 84/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5380 - accuracy: 0.7284 - val_loss: 0.5446 - val_accuracy: 0.7271
# Epoch 85/1000
# 51/51 [==============================] - 0s 3ms/step - loss: 0.5376 - accuracy: 0.7298 - val_loss: 0.5415 - val_accuracy: 0.7302
# Time taken: 11.4s

# %% [markdown]
# ## Plot performance and reports
# Here, we plot the history of the training and the peNNormance in a ROC curve

# %%
loss_accuracy_plotter(history)

fpr_nn, tpr_nn, thresholds_nn = evaluate(model, scaler, X, Y, X_train_val, Y_train_val, X_test, Y_test)
df_all['dense_NN'] = model.predict(scaler.transform(X)).round() # add prediction to array
# Out:
# 202/202 [==============================] - 0s 718us/step
# 806/806 [==============================] - 1s 675us/step
# 202/202 [==============================] - 0s 1ms/step
# 806/806 [==============================] - 1s 668us/step
# 1007/1007 [==============================] - 1s 728us/step
# Test acc score: 0.7302080099348028
# Train acc score: 0.7279571561626824
# Classification report for the test set
#               precision    recall  f1-score   support
#
#   background       0.67      0.53      0.59      2384
#       signal       0.75      0.85      0.80      4058
#
#     accuracy                           0.73      6442
#    macro avg       0.71      0.69      0.70      6442
# weighted avg       0.72      0.73      0.72      6442
#
# Classification report for the total set
#               precision    recall  f1-score   support
#
#   background       0.68      0.53      0.60     12210
#       signal       0.75      0.85      0.79     20000
#
#     accuracy                           0.73     32210
#    macro avg       0.71      0.69      0.70     32210
# weighted avg       0.72      0.73      0.72     32210
#
# Confusion matrix for total set
# [[ 6501  5709]
#  [ 3039 16961]]
# 1007/1007 [==============================] - 1s 908us/step

# %%
# add TF NN probability
y_tot_prob_NN = model.predict(scaler.transform(X))
y_tot_NN = model.predict(scaler.transform(X)).round()

cumulative_events = 0 # start counter for total number of events for which output is saved
for key in filename.keys(): # loop over samples
    df[key]['NN_output_prob'] = y_tot_prob_NN[cumulative_events:cumulative_events+len(df[key])]
    df[key]['NN_output'] = y_tot_NN[cumulative_events:cumulative_events+len(df[key])]
    cumulative_events += len(df[key]) # increment counter for total number of events
    #print(df[key]['NN_output']) # print the dataframe column NN_output

# probability and significance plots
NN_output_prob = { # dictionary containing plotting parameters for the mllll histogram
    # change plotting parameters
    'bin_width':0.1, # width of each histogram bin
    'num_bins':8, # number of histogram bins
    'xrange_min':0, # minimum on x-axis
    'xlabel':'Neural Network output', # x-axis label
}

SoverB_hist_dict = {'NN_output_prob':NN_output_prob}
plot_SoverB(df, SoverB_hist_dict)
# Out:
# 1007/1007 [==============================] - 1s 741us/step
# 1007/1007 [==============================] - 1s 747us/step

# %% [markdown]
# ## NN Hyperparameter optimization

# %%
def main():
        
    keras_pipeline = Pipeline([("scaler", StandardScaler()),
                               ("clf", keras.wrappers.scikit_learn.KerasClassifier(
                                   build_fn=make_model))
    ])
    
    param_grid = {'clf__network_layers': [(32, 32), (64, 64), (128, 128, 128)],
     'clf__batch_size': [64, 128, 256, 512],
     'clf__epochs': [5, 10, 15, 50, 100, 200],
     'clf__dropout_rate': [0.1, 0.01],
     'clf__optimizer': ['Nadam', 'Adam', 'SGD'],
     'clf__activation': ['selu', 'relu', 'tanh'],
     'clf__k_initializer': ['lecun_normal', 'normal'],
     'clf__verbose': [0]
    }
    
    rs_keras = RandomizedSearchCV(keras_pipeline,
                                  param_distributions=param_grid,
                                  cv=5, refit=True,
                                  verbose=0,
                                  n_iter=5,
                                  scoring="accuracy")
    
    history = rs_keras.fit(np.array(X_train_val),
                 np.array(Y_train_val))
    
    print('Best score obtained: {0}'.format(rs_keras.best_score_))
    print('Parameters:')
    for param, value in rs_keras.best_params_.items():
        print('\t{}: {}'.format(param, value))
    return  rs_keras  

def make_model(network_layers=[(32, 32)],
               dropout_rate=0,
               optimizer="Nadam",
               activation="selu",
               k_initializer='lecun_normal',
               n_input=NDIM,
               n_class=1):
    
    model = keras.models.Sequential()

    for index, layers in enumerate(network_layers):
        if not index:
            model.add(keras.layers.Dense(layers,
                                         input_dim=n_input,
                                         activation=activation,
                                         kernel_initializer=k_initializer))
        else:
            model.add(keras.layers.Dense(layers,
                                         kernel_initializer=k_initializer,
                                         activation=activation))
        if dropout_rate and index:
            model.add(keras.layers.AlphaDropout(dropout_rate))

    model.add(keras.layers.Dense(n_class,
                                 activation="sigmoid"))
    
    model.compile(loss='binary_crossentropy',
                  optimizer=optimizer,
                  metrics=['accuracy'])
    #print(model.summary())
    return model

if __name__ == '__main__':
    opt_model = main()
# Out:
# <ipython-input-12-7b86a5d1fe7c>:4: DeprecationWarning: KerasClassifier is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   ("clf", keras.wrappers.scikit_learn.KerasClassifier(
# 162/162 [==============================] - 0s 1ms/step
# 162/162 [==============================] - 0s 944us/step
# 162/162 [==============================] - 0s 929us/step
# 162/162 [==============================] - 0s 916us/step
# 162/162 [==============================] - 0s 916us/step
# 162/162 [==============================] - 0s 828us/step
# 162/162 [==============================] - 0s 826us/step
# 162/162 [==============================] - 0s 797us/step
# 162/162 [==============================] - 0s 806us/step
# 162/162 [==============================] - 0s 820us/step
# 162/162 [==============================] - 0s 1ms/step
# 162/162 [==============================] - 0s 941us/step
# 162/162 [==============================] - 0s 979us/step
# 162/162 [==============================] - 0s 1ms/step
# 162/162 [==============================] - 0s 1ms/step
# 162/162 [==============================] - 0s 775us/step
# 162/162 [==============================] - 0s 767us/step
# 162/162 [==============================] - 0s 980us/step
# 162/162 [==============================] - 0s 789us/step
# 162/162 [==============================] - 0s 775us/step
# 162/162 [==============================] - 0s 869us/step
# 162/162 [==============================] - 0s 865us/step
# 162/162 [==============================] - 0s 835us/step
# 162/162 [==============================] - 0s 1ms/step
# 162/162 [==============================] - 0s 991us/step
# Best score obtained: 0.7577227185718864
# Parameters:
# 	clf__verbose: 0
# 	clf__optimizer: Nadam
# 	clf__network_layers: (128, 128, 128)
# 	clf__k_initializer: normal
# 	clf__epochs: 200
# 	clf__dropout_rate: 0.1
# 	clf__batch_size: 256
# 	clf__activation: selu

# %%
'''
Best score obtained: 0.7943613693928067
Parameters:
	clf__verbose: 0
	clf__optimizer: Nadam
	clf__network_layers: (128, 128, 128)
	clf__k_initializer: normal
	clf__epochs: 200
	clf__dropout_rate: 0.1
	clf__batch_size: 256
	clf__activation: selu
    
Best score obtained: 0.7577227185718864
Parameters:
	clf__verbose: 0
	clf__optimizer: Nadam
	clf__network_layers: (128, 128, 128)
	clf__k_initializer: normal
	clf__epochs: 200
	clf__dropout_rate: 0.1
	clf__batch_size: 256
	clf__activation: selu
'''
# Out:
# '\nBest score obtained: 0.7943613693928067\nParameters:\n\tclf__verbose: 0\n\tclf__optimizer: Nadam\n\tclf__network_layers: (128, 128, 128)\n\tclf__k_initializer: normal\n\tclf__epochs: 200\n\tclf__dropout_rate: 0.1\n\tclf__batch_size: 256\n\tclf__activation: selu\n}\n'

# %% [markdown]
# ## NN with dropout layer for overfit checking

# %%
# Packages for modeling
from keras import models
from keras import layers
from keras import regularizers

drop_model = models.Sequential()
drop_model.add(layers.Dense(128,  kernel_initializer='lecun_normal', activation='selu', input_shape=(NDIM,)))
drop_model.add(layers.Dropout(0.1))
drop_model.add(layers.Dense(128,  kernel_initializer='lecun_normal', activation='selu'))
drop_model.add(layers.Dropout(0.1))
drop_model.add(layers.Dense(128,  kernel_initializer='lecun_normal', activation='selu'))
drop_model.add(layers.Dropout(0.1))
drop_model.add(layers.Dense(1, kernel_initializer='lecun_normal', activation='sigmoid'))

# compile the model
drop_model.compile(optimizer='Adam', loss='binary_crossentropy', metrics=['accuracy'])
# print the model summary
drop_model.summary()

# early stopping callback
from keras.callbacks import EarlyStopping
early_stopping = EarlyStopping(monitor='val_loss', patience=10, mode='min')

# Train classifier
import time
start = time.time() # time at start of whole processing

drop_history = drop_model.fit(X_train_val, 
                    Y_train_val, 
                    epochs=500, 
                    batch_size=256, 
                    verbose=1, # switch to 1 for more verbosity 
                    callbacks=[early_stopping], 
                    validation_data=(X_test,Y_test))

elapsed = time.time() - start # time after whole processing
print("Time taken: "+str(round(elapsed,1))+"s") # print total time taken to process every file
# Out:
# Model: "sequential_26"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_84 (Dense)            (None, 128)               1792
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_85 (Dense)            (None, 128)               16512
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_86 (Dense)            (None, 128)               16512
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  dense_87 (Dense)            (None, 1)                 129
#
# =================================================================
# Total params: 34,945
# Trainable params: 34,945
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/500
# 101/101 [==============================] - 1s 5ms/step - loss: 0.6308 - accuracy: 0.6527 - val_loss: 0.5789 - val_accuracy: 0.6978
# Epoch 2/500
# 101/101 [==============================] - 0s 4ms/step - loss: 0.5967 - accuracy: 0.6843 - val_loss: 0.5672 - val_accuracy: 0.7060
# Epoch 3/500
# 101/101 [==============================] - 1s 5ms/step - loss: 0.5882 - accuracy: 0.6897 - val_loss: 0.5644 - val_accuracy: 0.7063
# Epoch 4/500
# 101/101 [==============================] - 0s 4ms/step - loss: 0.5794 - accuracy: 0.6996 - val_loss: 0.5566 - val_accuracy: 0.7145
# Epoch 5/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.5751 - accuracy: 0.7007 - val_loss: 0.5550 - val_accuracy: 0.7175
# Epoch 6/500
# 101/101 [==============================] - 1s 6ms/step - loss: 0.5731 - accuracy: 0.6999 - val_loss: 0.5521 - val_accuracy: 0.7228
# Epoch 7/500
# 101/101 [==============================] - 0s 4ms/step - loss: 0.5710 - accuracy: 0.7048 - val_loss: 0.5517 - val_accuracy: 0.7145
# Epoch 8/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.5654 - accuracy: 0.7053 - val_loss: 0.5491 - val_accuracy: 0.7209
# Epoch 9/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.5665 - accuracy: 0.7048 - val_loss: 0.5482 - val_accuracy: 0.7186
# Epoch 10/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.5615 - accuracy: 0.7114 - val_loss: 0.5431 - val_accuracy: 0.7245
# Epoch 11/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.5615 - accuracy: 0.7093 - val_loss: 0.5451 - val_accuracy: 0.7223
# Epoch 12/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.5583 - accuracy: 0.7149 - val_loss: 0.5414 - val_accuracy: 0.7265
# Epoch 13/500
# 101/101 [==============================] - 1s 7ms/step - loss: 0.5566 - accuracy: 0.7145 - val_loss: 0.5400 - val_accuracy: 0.7299
# Epoch 14/500
# 101/101 [==============================] - 1s 7ms/step - loss: 0.5560 - accuracy: 0.7143 - val_loss: 0.5472 - val_accuracy: 0.7201
# Epoch 15/500
# 101/101 [==============================] - 0s 4ms/step - loss: 0.5550 - accuracy: 0.7171 - val_loss: 0.5390 - val_accuracy: 0.7274
# Epoch 16/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.5529 - accuracy: 0.7195 - val_loss: 0.5387 - val_accuracy: 0.7273
# Epoch 17/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.5521 - accuracy: 0.7198 - val_loss: 0.5379 - val_accuracy: 0.7294
# Epoch 18/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.5532 - accuracy: 0.7191 - val_loss: 0.5369 - val_accuracy: 0.7279
# Epoch 19/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.5506 - accuracy: 0.7200 - val_loss: 0.5359 - val_accuracy: 0.7311
# Epoch 20/500
# 101/101 [==============================] - 0s 4ms/step - loss: 0.5488 - accuracy: 0.7209 - val_loss: 0.5365 - val_accuracy: 0.7296
# Epoch 21/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.5453 - accuracy: 0.7244 - val_loss: 0.5354 - val_accuracy: 0.7324
# Epoch 22/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.5443 - accuracy: 0.7230 - val_loss: 0.5373 - val_accuracy: 0.7307
# Epoch 23/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.5464 - accuracy: 0.7242 - val_loss: 0.5354 - val_accuracy: 0.7358
# Epoch 24/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.5451 - accuracy: 0.7228 - val_loss: 0.5340 - val_accuracy: 0.7301
# Epoch 25/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.5440 - accuracy: 0.7233 - val_loss: 0.5309 - val_accuracy: 0.7322
# Epoch 26/500
# 101/101 [==============================] - 0s 4ms/step - loss: 0.5443 - accuracy: 0.7244 - val_loss: 0.5291 - val_accuracy: 0.7327
# Epoch 27/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.5396 - accuracy: 0.7271 - val_loss: 0.5308 - val_accuracy: 0.7356
# Epoch 28/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.5400 - accuracy: 0.7280 - val_loss: 0.5319 - val_accuracy: 0.7361
# Epoch 29/500
# 101/101 [==============================] - 1s 7ms/step - loss: 0.5388 - accuracy: 0.7273 - val_loss: 0.5305 - val_accuracy: 0.7333
# Epoch 30/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.5388 - accuracy: 0.7320 - val_loss: 0.5329 - val_accuracy: 0.7325
# Epoch 31/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.5387 - accuracy: 0.7287 - val_loss: 0.5310 - val_accuracy: 0.7338
# Epoch 32/500
# 101/101 [==============================] - 0s 4ms/step - loss: 0.5362 - accuracy: 0.7311 - val_loss: 0.5285 - val_accuracy: 0.7356
# Epoch 33/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.5348 - accuracy: 0.7278 - val_loss: 0.5285 - val_accuracy: 0.7328
# Epoch 34/500
# 101/101 [==============================] - 1s 5ms/step - loss: 0.5351 - accuracy: 0.7292 - val_loss: 0.5276 - val_accuracy: 0.7383
# Epoch 35/500
# 101/101 [==============================] - 0s 4ms/step - loss: 0.5349 - accuracy: 0.7285 - val_loss: 0.5266 - val_accuracy: 0.7347
# Epoch 36/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.5337 - accuracy: 0.7315 - val_loss: 0.5279 - val_accuracy: 0.7347
# Epoch 37/500
# 101/101 [==============================] - 0s 5ms/step - loss: 0.5347 - accuracy: 0.7309 - val_loss: 0.5263 - val_accuracy: 0.7358
# Epoch 38/500
# 101/101 [==============================] - 1s 7ms/step - loss: 0.5333 - accuracy: 0.7308 - val_loss: 0.5292 - val_accuracy: 0.7310
# Epoch 39/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.5322 - accuracy: 0.7311 - val_loss: 0.5251 - val_accuracy: 0.7350
# Epoch 40/500
# 101/101 [==============================] - 0s 4ms/step - loss: 0.5306 - accuracy: 0.7325 - val_loss: 0.5248 - val_accuracy: 0.7349
# Epoch 41/500
# 101/101 [==============================] - 0s 4ms/step - loss: 0.5311 - accuracy: 0.7325 - val_loss: 0.5274 - val_accuracy: 0.7339
# Epoch 42/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.5303 - accuracy: 0.7337 - val_loss: 0.5245 - val_accuracy: 0.7373
# Epoch 43/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.5290 - accuracy: 0.7337 - val_loss: 0.5277 - val_accuracy: 0.7318
# Epoch 44/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.5311 - accuracy: 0.7352 - val_loss: 0.5233 - val_accuracy: 0.7350
# Epoch 45/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.5284 - accuracy: 0.7359 - val_loss: 0.5258 - val_accuracy: 0.7392
# Epoch 46/500
# 101/101 [==============================] - 0s 4ms/step - loss: 0.5250 - accuracy: 0.7377 - val_loss: 0.5273 - val_accuracy: 0.7367
# Epoch 47/500
# 101/101 [==============================] - 1s 5ms/step - loss: 0.5259 - accuracy: 0.7375 - val_loss: 0.5216 - val_accuracy: 0.7361
# Epoch 48/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.5272 - accuracy: 0.7322 - val_loss: 0.5279 - val_accuracy: 0.7347
# Epoch 49/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.5262 - accuracy: 0.7369 - val_loss: 0.5248 - val_accuracy: 0.7344
# Epoch 50/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.5247 - accuracy: 0.7357 - val_loss: 0.5220 - val_accuracy: 0.7415
# Epoch 51/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.5245 - accuracy: 0.7382 - val_loss: 0.5233 - val_accuracy: 0.7387
# Epoch 52/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.5246 - accuracy: 0.7363 - val_loss: 0.5212 - val_accuracy: 0.7397
# Epoch 53/500
# 101/101 [==============================] - 0s 4ms/step - loss: 0.5225 - accuracy: 0.7392 - val_loss: 0.5225 - val_accuracy: 0.7384
# Epoch 54/500
# 101/101 [==============================] - 0s 4ms/step - loss: 0.5227 - accuracy: 0.7389 - val_loss: 0.5260 - val_accuracy: 0.7352
# Epoch 55/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.5225 - accuracy: 0.7377 - val_loss: 0.5186 - val_accuracy: 0.7384
# Epoch 56/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.5214 - accuracy: 0.7397 - val_loss: 0.5215 - val_accuracy: 0.7352
# Epoch 57/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.5214 - accuracy: 0.7388 - val_loss: 0.5224 - val_accuracy: 0.7383
# Epoch 58/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.5207 - accuracy: 0.7399 - val_loss: 0.5221 - val_accuracy: 0.7369
# Epoch 59/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.5205 - accuracy: 0.7419 - val_loss: 0.5238 - val_accuracy: 0.7380
# Epoch 60/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.5190 - accuracy: 0.7415 - val_loss: 0.5209 - val_accuracy: 0.7445
# Epoch 61/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.5180 - accuracy: 0.7418 - val_loss: 0.5196 - val_accuracy: 0.7355
# Epoch 62/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.5191 - accuracy: 0.7431 - val_loss: 0.5187 - val_accuracy: 0.7369
# Epoch 63/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.5166 - accuracy: 0.7441 - val_loss: 0.5255 - val_accuracy: 0.7346
# Epoch 64/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.5177 - accuracy: 0.7403 - val_loss: 0.5190 - val_accuracy: 0.7403
# Epoch 65/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.5167 - accuracy: 0.7422 - val_loss: 0.5168 - val_accuracy: 0.7384
# Epoch 66/500
# 101/101 [==============================] - 0s 5ms/step - loss: 0.5163 - accuracy: 0.7433 - val_loss: 0.5195 - val_accuracy: 0.7400
# Epoch 67/500
# 101/101 [==============================] - 0s 4ms/step - loss: 0.5170 - accuracy: 0.7412 - val_loss: 0.5166 - val_accuracy: 0.7450
# Epoch 68/500
# 101/101 [==============================] - 1s 6ms/step - loss: 0.5159 - accuracy: 0.7425 - val_loss: 0.5211 - val_accuracy: 0.7405
# Epoch 69/500
# 101/101 [==============================] - 0s 4ms/step - loss: 0.5143 - accuracy: 0.7438 - val_loss: 0.5179 - val_accuracy: 0.7426
# Epoch 70/500
# 101/101 [==============================] - 0s 4ms/step - loss: 0.5149 - accuracy: 0.7435 - val_loss: 0.5175 - val_accuracy: 0.7394
# Epoch 71/500
# 101/101 [==============================] - 0s 4ms/step - loss: 0.5125 - accuracy: 0.7448 - val_loss: 0.5172 - val_accuracy: 0.7411
# Epoch 72/500
# 101/101 [==============================] - 0s 4ms/step - loss: 0.5112 - accuracy: 0.7459 - val_loss: 0.5151 - val_accuracy: 0.7411
# Epoch 73/500
# 101/101 [==============================] - 0s 4ms/step - loss: 0.5138 - accuracy: 0.7448 - val_loss: 0.5143 - val_accuracy: 0.7414
# Epoch 74/500
# 101/101 [==============================] - 0s 4ms/step - loss: 0.5131 - accuracy: 0.7452 - val_loss: 0.5185 - val_accuracy: 0.7409
# Epoch 75/500
# 101/101 [==============================] - 0s 4ms/step - loss: 0.5114 - accuracy: 0.7467 - val_loss: 0.5152 - val_accuracy: 0.7431
# Epoch 76/500
# 101/101 [==============================] - 0s 4ms/step - loss: 0.5150 - accuracy: 0.7433 - val_loss: 0.5224 - val_accuracy: 0.7387
# Epoch 77/500
# 101/101 [==============================] - 0s 4ms/step - loss: 0.5102 - accuracy: 0.7473 - val_loss: 0.5186 - val_accuracy: 0.7391
# Epoch 78/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.5078 - accuracy: 0.7470 - val_loss: 0.5152 - val_accuracy: 0.7420
# Epoch 79/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.5087 - accuracy: 0.7471 - val_loss: 0.5166 - val_accuracy: 0.7400
# Epoch 80/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.5067 - accuracy: 0.7494 - val_loss: 0.5124 - val_accuracy: 0.7429
# Epoch 81/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.5096 - accuracy: 0.7478 - val_loss: 0.5155 - val_accuracy: 0.7423
# Epoch 82/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.5063 - accuracy: 0.7482 - val_loss: 0.5114 - val_accuracy: 0.7460
# Epoch 83/500
# 101/101 [==============================] - 0s 4ms/step - loss: 0.5076 - accuracy: 0.7474 - val_loss: 0.5145 - val_accuracy: 0.7451
# Epoch 84/500
# 101/101 [==============================] - 0s 4ms/step - loss: 0.5079 - accuracy: 0.7489 - val_loss: 0.5105 - val_accuracy: 0.7484
# Epoch 85/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.5066 - accuracy: 0.7481 - val_loss: 0.5135 - val_accuracy: 0.7373
# Epoch 86/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.5046 - accuracy: 0.7491 - val_loss: 0.5126 - val_accuracy: 0.7465
# Epoch 87/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.5046 - accuracy: 0.7523 - val_loss: 0.5118 - val_accuracy: 0.7505
# Epoch 88/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.5026 - accuracy: 0.7526 - val_loss: 0.5110 - val_accuracy: 0.7467
# Epoch 89/500
# 101/101 [==============================] - 0s 4ms/step - loss: 0.5051 - accuracy: 0.7486 - val_loss: 0.5099 - val_accuracy: 0.7453
# Epoch 90/500
# 101/101 [==============================] - 1s 6ms/step - loss: 0.5021 - accuracy: 0.7542 - val_loss: 0.5102 - val_accuracy: 0.7477
# Epoch 91/500
# 101/101 [==============================] - 0s 5ms/step - loss: 0.5031 - accuracy: 0.7529 - val_loss: 0.5106 - val_accuracy: 0.7450
# Epoch 92/500
# 101/101 [==============================] - 0s 5ms/step - loss: 0.5008 - accuracy: 0.7523 - val_loss: 0.5108 - val_accuracy: 0.7471
# Epoch 93/500
# 101/101 [==============================] - 0s 5ms/step - loss: 0.5000 - accuracy: 0.7526 - val_loss: 0.5091 - val_accuracy: 0.7470
# Epoch 94/500
# 101/101 [==============================] - 1s 5ms/step - loss: 0.4981 - accuracy: 0.7542 - val_loss: 0.5098 - val_accuracy: 0.7499
# Epoch 95/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.4992 - accuracy: 0.7556 - val_loss: 0.5107 - val_accuracy: 0.7460
# Epoch 96/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.5015 - accuracy: 0.7500 - val_loss: 0.5120 - val_accuracy: 0.7448
# Epoch 97/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.4995 - accuracy: 0.7524 - val_loss: 0.5079 - val_accuracy: 0.7451
# Epoch 98/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.5000 - accuracy: 0.7555 - val_loss: 0.5111 - val_accuracy: 0.7471
# Epoch 99/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.4989 - accuracy: 0.7516 - val_loss: 0.5098 - val_accuracy: 0.7462
# Epoch 100/500
# 101/101 [==============================] - 0s 4ms/step - loss: 0.4968 - accuracy: 0.7563 - val_loss: 0.5082 - val_accuracy: 0.7462
# Epoch 101/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.4972 - accuracy: 0.7564 - val_loss: 0.5086 - val_accuracy: 0.7448
# Epoch 102/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.4959 - accuracy: 0.7567 - val_loss: 0.5049 - val_accuracy: 0.7518
# Epoch 103/500
# 101/101 [==============================] - 0s 4ms/step - loss: 0.4951 - accuracy: 0.7573 - val_loss: 0.5039 - val_accuracy: 0.7527
# Epoch 104/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.4954 - accuracy: 0.7553 - val_loss: 0.5076 - val_accuracy: 0.7476
# Epoch 105/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.4939 - accuracy: 0.7559 - val_loss: 0.5091 - val_accuracy: 0.7440
# Epoch 106/500
# 101/101 [==============================] - 0s 4ms/step - loss: 0.4941 - accuracy: 0.7553 - val_loss: 0.5052 - val_accuracy: 0.7504
# Epoch 107/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.4932 - accuracy: 0.7568 - val_loss: 0.5032 - val_accuracy: 0.7516
# Epoch 108/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.4914 - accuracy: 0.7579 - val_loss: 0.5064 - val_accuracy: 0.7477
# Epoch 109/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.4944 - accuracy: 0.7562 - val_loss: 0.5041 - val_accuracy: 0.7524
# Epoch 110/500
# 101/101 [==============================] - 0s 4ms/step - loss: 0.4907 - accuracy: 0.7595 - val_loss: 0.5065 - val_accuracy: 0.7484
# Epoch 111/500
# 101/101 [==============================] - 1s 6ms/step - loss: 0.4897 - accuracy: 0.7568 - val_loss: 0.5027 - val_accuracy: 0.7526
# Epoch 112/500
# 101/101 [==============================] - 1s 7ms/step - loss: 0.4891 - accuracy: 0.7614 - val_loss: 0.5017 - val_accuracy: 0.7526
# Epoch 113/500
# 101/101 [==============================] - 1s 6ms/step - loss: 0.4921 - accuracy: 0.7580 - val_loss: 0.5040 - val_accuracy: 0.7524
# Epoch 114/500
# 101/101 [==============================] - 0s 5ms/step - loss: 0.4869 - accuracy: 0.7610 - val_loss: 0.5005 - val_accuracy: 0.7560
# Epoch 115/500
# 101/101 [==============================] - 0s 5ms/step - loss: 0.4869 - accuracy: 0.7604 - val_loss: 0.5022 - val_accuracy: 0.7549
# Epoch 116/500
# 101/101 [==============================] - 0s 5ms/step - loss: 0.4887 - accuracy: 0.7613 - val_loss: 0.5011 - val_accuracy: 0.7533
# Epoch 117/500
# 101/101 [==============================] - 0s 4ms/step - loss: 0.4878 - accuracy: 0.7609 - val_loss: 0.5045 - val_accuracy: 0.7460
# Epoch 118/500
# 101/101 [==============================] - 0s 5ms/step - loss: 0.4877 - accuracy: 0.7603 - val_loss: 0.5014 - val_accuracy: 0.7493
# Epoch 119/500
# 101/101 [==============================] - 0s 5ms/step - loss: 0.4859 - accuracy: 0.7615 - val_loss: 0.5002 - val_accuracy: 0.7563
# Epoch 120/500
# 101/101 [==============================] - 1s 5ms/step - loss: 0.4824 - accuracy: 0.7638 - val_loss: 0.4990 - val_accuracy: 0.7536
# Epoch 121/500
# 101/101 [==============================] - 0s 4ms/step - loss: 0.4854 - accuracy: 0.7633 - val_loss: 0.5027 - val_accuracy: 0.7540
# Epoch 122/500
# 101/101 [==============================] - 0s 4ms/step - loss: 0.4844 - accuracy: 0.7642 - val_loss: 0.4967 - val_accuracy: 0.7558
# Epoch 123/500
# 101/101 [==============================] - 0s 4ms/step - loss: 0.4853 - accuracy: 0.7631 - val_loss: 0.4967 - val_accuracy: 0.7564
# Epoch 124/500
# 101/101 [==============================] - 0s 4ms/step - loss: 0.4819 - accuracy: 0.7625 - val_loss: 0.5017 - val_accuracy: 0.7555
# Epoch 125/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.4798 - accuracy: 0.7670 - val_loss: 0.4983 - val_accuracy: 0.7540
# Epoch 126/500
# 101/101 [==============================] - 0s 4ms/step - loss: 0.4828 - accuracy: 0.7656 - val_loss: 0.4970 - val_accuracy: 0.7533
# Epoch 127/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.4828 - accuracy: 0.7648 - val_loss: 0.4998 - val_accuracy: 0.7535
# Epoch 128/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.4811 - accuracy: 0.7667 - val_loss: 0.4960 - val_accuracy: 0.7589
# Epoch 129/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.4782 - accuracy: 0.7661 - val_loss: 0.4964 - val_accuracy: 0.7518
# Epoch 130/500
# 101/101 [==============================] - 0s 4ms/step - loss: 0.4778 - accuracy: 0.7684 - val_loss: 0.4982 - val_accuracy: 0.7547
# Epoch 131/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.4794 - accuracy: 0.7659 - val_loss: 0.4938 - val_accuracy: 0.7563
# Epoch 132/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.4803 - accuracy: 0.7638 - val_loss: 0.4954 - val_accuracy: 0.7524
# Epoch 133/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.4757 - accuracy: 0.7701 - val_loss: 0.4966 - val_accuracy: 0.7555
# Epoch 134/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.4766 - accuracy: 0.7653 - val_loss: 0.4964 - val_accuracy: 0.7530
# Epoch 135/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.4765 - accuracy: 0.7668 - val_loss: 0.4948 - val_accuracy: 0.7589
# Epoch 136/500
# 101/101 [==============================] - 0s 4ms/step - loss: 0.4747 - accuracy: 0.7656 - val_loss: 0.4988 - val_accuracy: 0.7560
# Epoch 137/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.4761 - accuracy: 0.7688 - val_loss: 0.4921 - val_accuracy: 0.7583
# Epoch 138/500
# 101/101 [==============================] - 1s 6ms/step - loss: 0.4722 - accuracy: 0.7698 - val_loss: 0.4991 - val_accuracy: 0.7550
# Epoch 139/500
# 101/101 [==============================] - 0s 4ms/step - loss: 0.4696 - accuracy: 0.7731 - val_loss: 0.4904 - val_accuracy: 0.7602
# Epoch 140/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.4729 - accuracy: 0.7697 - val_loss: 0.4933 - val_accuracy: 0.7595
# Epoch 141/500
# 101/101 [==============================] - 0s 4ms/step - loss: 0.4724 - accuracy: 0.7705 - val_loss: 0.4917 - val_accuracy: 0.7603
# Epoch 142/500
# 101/101 [==============================] - 1s 5ms/step - loss: 0.4735 - accuracy: 0.7701 - val_loss: 0.4909 - val_accuracy: 0.7603
# Epoch 143/500
# 101/101 [==============================] - 0s 4ms/step - loss: 0.4714 - accuracy: 0.7718 - val_loss: 0.4911 - val_accuracy: 0.7595
# Epoch 144/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.4687 - accuracy: 0.7698 - val_loss: 0.4889 - val_accuracy: 0.7597
# Epoch 145/500
# 101/101 [==============================] - 1s 5ms/step - loss: 0.4698 - accuracy: 0.7720 - val_loss: 0.4895 - val_accuracy: 0.7617
# Epoch 146/500
# 101/101 [==============================] - 1s 6ms/step - loss: 0.4721 - accuracy: 0.7696 - val_loss: 0.4946 - val_accuracy: 0.7583
# Epoch 147/500
# 101/101 [==============================] - 1s 5ms/step - loss: 0.4723 - accuracy: 0.7716 - val_loss: 0.4866 - val_accuracy: 0.7580
# Epoch 148/500
# 101/101 [==============================] - 0s 4ms/step - loss: 0.4696 - accuracy: 0.7713 - val_loss: 0.4907 - val_accuracy: 0.7614
# Epoch 149/500
# 101/101 [==============================] - 0s 4ms/step - loss: 0.4660 - accuracy: 0.7730 - val_loss: 0.4881 - val_accuracy: 0.7605
# Epoch 150/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.4664 - accuracy: 0.7751 - val_loss: 0.4866 - val_accuracy: 0.7642
# Epoch 151/500
# 101/101 [==============================] - 0s 4ms/step - loss: 0.4695 - accuracy: 0.7742 - val_loss: 0.4901 - val_accuracy: 0.7605
# Epoch 152/500
# 101/101 [==============================] - 0s 4ms/step - loss: 0.4675 - accuracy: 0.7750 - val_loss: 0.4872 - val_accuracy: 0.7619
# Epoch 153/500
# 101/101 [==============================] - 0s 4ms/step - loss: 0.4683 - accuracy: 0.7725 - val_loss: 0.4881 - val_accuracy: 0.7628
# Epoch 154/500
# 101/101 [==============================] - 0s 4ms/step - loss: 0.4645 - accuracy: 0.7758 - val_loss: 0.4862 - val_accuracy: 0.7642
# Epoch 155/500
# 101/101 [==============================] - 0s 4ms/step - loss: 0.4633 - accuracy: 0.7755 - val_loss: 0.4889 - val_accuracy: 0.7568
# Epoch 156/500
# 101/101 [==============================] - 0s 4ms/step - loss: 0.4605 - accuracy: 0.7779 - val_loss: 0.4907 - val_accuracy: 0.7592
# Epoch 157/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.4661 - accuracy: 0.7770 - val_loss: 0.4885 - val_accuracy: 0.7630
# Epoch 158/500
# 101/101 [==============================] - 0s 4ms/step - loss: 0.4608 - accuracy: 0.7772 - val_loss: 0.4873 - val_accuracy: 0.7645
# Epoch 159/500
# 101/101 [==============================] - 0s 4ms/step - loss: 0.4643 - accuracy: 0.7730 - val_loss: 0.4837 - val_accuracy: 0.7644
# Epoch 160/500
# 101/101 [==============================] - 0s 4ms/step - loss: 0.4612 - accuracy: 0.7774 - val_loss: 0.4839 - val_accuracy: 0.7656
# Epoch 161/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.4597 - accuracy: 0.7793 - val_loss: 0.4858 - val_accuracy: 0.7613
# Epoch 162/500
# 101/101 [==============================] - 0s 4ms/step - loss: 0.4589 - accuracy: 0.7806 - val_loss: 0.4845 - val_accuracy: 0.7681
# Epoch 163/500
# 101/101 [==============================] - 0s 4ms/step - loss: 0.4609 - accuracy: 0.7796 - val_loss: 0.4859 - val_accuracy: 0.7654
# Epoch 164/500
# 101/101 [==============================] - 0s 4ms/step - loss: 0.4590 - accuracy: 0.7771 - val_loss: 0.4860 - val_accuracy: 0.7625
# Epoch 165/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.4577 - accuracy: 0.7803 - val_loss: 0.4865 - val_accuracy: 0.7639
# Epoch 166/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.4594 - accuracy: 0.7779 - val_loss: 0.4863 - val_accuracy: 0.7664
# Epoch 167/500
# 101/101 [==============================] - 0s 4ms/step - loss: 0.4537 - accuracy: 0.7796 - val_loss: 0.4823 - val_accuracy: 0.7679
# Epoch 168/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.4536 - accuracy: 0.7799 - val_loss: 0.4812 - val_accuracy: 0.7690
# Epoch 169/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.4597 - accuracy: 0.7779 - val_loss: 0.4808 - val_accuracy: 0.7682
# Epoch 170/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.4564 - accuracy: 0.7812 - val_loss: 0.4819 - val_accuracy: 0.7661
# Epoch 171/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.4564 - accuracy: 0.7811 - val_loss: 0.4822 - val_accuracy: 0.7675
# Epoch 172/500
# 101/101 [==============================] - 0s 4ms/step - loss: 0.4553 - accuracy: 0.7795 - val_loss: 0.4825 - val_accuracy: 0.7678
# Epoch 173/500
# 101/101 [==============================] - 0s 4ms/step - loss: 0.4540 - accuracy: 0.7811 - val_loss: 0.4813 - val_accuracy: 0.7668
# Epoch 174/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.4576 - accuracy: 0.7782 - val_loss: 0.4786 - val_accuracy: 0.7662
# Epoch 175/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.4523 - accuracy: 0.7832 - val_loss: 0.4799 - val_accuracy: 0.7707
# Epoch 176/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.4524 - accuracy: 0.7816 - val_loss: 0.4812 - val_accuracy: 0.7687
# Epoch 177/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.4549 - accuracy: 0.7802 - val_loss: 0.4780 - val_accuracy: 0.7689
# Epoch 178/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.4524 - accuracy: 0.7847 - val_loss: 0.4790 - val_accuracy: 0.7699
# Epoch 179/500
# 101/101 [==============================] - 0s 4ms/step - loss: 0.4534 - accuracy: 0.7805 - val_loss: 0.4808 - val_accuracy: 0.7723
# Epoch 180/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.4505 - accuracy: 0.7836 - val_loss: 0.4796 - val_accuracy: 0.7664
# Epoch 181/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.4502 - accuracy: 0.7824 - val_loss: 0.4784 - val_accuracy: 0.7687
# Epoch 182/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.4505 - accuracy: 0.7788 - val_loss: 0.4789 - val_accuracy: 0.7681
# Epoch 183/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.4520 - accuracy: 0.7835 - val_loss: 0.4751 - val_accuracy: 0.7692
# Epoch 184/500
# 101/101 [==============================] - 0s 4ms/step - loss: 0.4500 - accuracy: 0.7845 - val_loss: 0.4749 - val_accuracy: 0.7737
# Epoch 185/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.4470 - accuracy: 0.7868 - val_loss: 0.4829 - val_accuracy: 0.7647
# Epoch 186/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.4475 - accuracy: 0.7869 - val_loss: 0.4753 - val_accuracy: 0.7726
# Epoch 187/500
# 101/101 [==============================] - 0s 4ms/step - loss: 0.4482 - accuracy: 0.7869 - val_loss: 0.4804 - val_accuracy: 0.7701
# Epoch 188/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.4484 - accuracy: 0.7867 - val_loss: 0.4719 - val_accuracy: 0.7721
# Epoch 189/500
# 101/101 [==============================] - 0s 4ms/step - loss: 0.4444 - accuracy: 0.7882 - val_loss: 0.4802 - val_accuracy: 0.7717
# Epoch 190/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.4464 - accuracy: 0.7860 - val_loss: 0.4786 - val_accuracy: 0.7721
# Epoch 191/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.4462 - accuracy: 0.7850 - val_loss: 0.4771 - val_accuracy: 0.7701
# Epoch 192/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.4431 - accuracy: 0.7887 - val_loss: 0.4766 - val_accuracy: 0.7704
# Epoch 193/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.4448 - accuracy: 0.7887 - val_loss: 0.4749 - val_accuracy: 0.7707
# Epoch 194/500
# 101/101 [==============================] - 0s 4ms/step - loss: 0.4451 - accuracy: 0.7852 - val_loss: 0.4727 - val_accuracy: 0.7712
# Epoch 195/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.4433 - accuracy: 0.7859 - val_loss: 0.4807 - val_accuracy: 0.7698
# Epoch 196/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.4435 - accuracy: 0.7861 - val_loss: 0.4759 - val_accuracy: 0.7737
# Epoch 197/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.4392 - accuracy: 0.7919 - val_loss: 0.4781 - val_accuracy: 0.7695
# Epoch 198/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.4446 - accuracy: 0.7875 - val_loss: 0.4739 - val_accuracy: 0.7754
# Time taken: 77.6s

# %%
loss_accuracy_plotter(drop_history)

fpr_nn_opt_drop, tpr_nn_opt_drop, thresholds_nn_opt_drop = evaluate(drop_model, scaler, X, Y, X_train_val, Y_train_val, X_test, Y_test)
df_all['dense_NN_opt_drop'] = drop_model.predict(scaler.transform(X)).round() # add prediction to array
# Out:
# 202/202 [==============================] - 0s 706us/step
# 806/806 [==============================] - 1s 682us/step
# 202/202 [==============================] - 0s 814us/step
# 806/806 [==============================] - 1s 778us/step
# 1007/1007 [==============================] - 1s 786us/step
# Test acc score: 0.775380316671841
# Train acc score: 0.8370459484632102
# Classification report for the test set
#               precision    recall  f1-score   support
#
#   background       0.72      0.64      0.68      2384
#       signal       0.80      0.86      0.83      4058
#
#     accuracy                           0.78      6442
#    macro avg       0.76      0.75      0.75      6442
# weighted avg       0.77      0.78      0.77      6442
#
# Classification report for the total set
#               precision    recall  f1-score   support
#
#   background       0.81      0.71      0.75     12210
#       signal       0.83      0.90      0.86     20000
#
#     accuracy                           0.82     32210
#    macro avg       0.82      0.80      0.81     32210
# weighted avg       0.82      0.82      0.82     32210
#
# Confusion matrix for total set
# [[ 8612  3598]
#  [ 2048 17952]]
# 1007/1007 [==============================] - 1s 1ms/step

# %%
# add TF NN probability
y_tot_prob_NN_opt_drop = drop_model.predict(scaler.transform(X))
y_tot_NN_opt_drop = drop_model.predict(scaler.transform(X)).round()

cumulative_events = 0 # start counter for total number of events for which output is saved
for key in filename.keys(): # loop over samples
    df[key]['NN_opt_drop_output_prob'] = y_tot_prob_NN_opt_drop[cumulative_events:cumulative_events+len(df[key])]
    df[key]['NN_opt_drop_output'] = y_tot_NN_opt_drop[cumulative_events:cumulative_events+len(df[key])]
    cumulative_events += len(df[key]) # increment counter for total number of events
    #print(df[key]['NN_output']) # print the dataframe column NN_output

# probability and significance plots
NN_opt_drop_output_prob = { # dictionary containing plotting parameters for the mllll histogram
    # change plotting parameters
    'bin_width':0.1, # width of each histogram bin
    'num_bins':8, # number of histogram bins
    'xrange_min':0, # minimum on x-axis
    'xlabel':'Neural Network optimized dropout', # x-axis label
}

SoverB_hist_dict = {'NN_opt_drop_output_prob':NN_opt_drop_output_prob}
plot_SoverB(df, SoverB_hist_dict)
# Out:
# 1007/1007 [==============================] - 1s 883us/step
# 1007/1007 [==============================] - 1s 852us/step

# %% [markdown]
# ## Optimal model with early stopping

# %%
inputs = Input(shape=(NDIM,), name = 'input') 
hidden1 = Dense(128, name = 'hidden1', kernel_initializer='lecun_normal', activation='selu')(inputs)
hidden2 = Dense(128, name = 'hidden2', kernel_initializer='lecun_normal', activation='selu')(hidden1)
hidden3 = Dense(128, name = 'hidden3', kernel_initializer='lecun_normal', activation='selu')(hidden2)
outputs = Dense(1, name = 'output', kernel_initializer='lecun_normal', activation='sigmoid')(hidden3)

# create the model
opt_model = Model(inputs=inputs, outputs=outputs)
# compile the model
opt_model.compile(optimizer='Adam', loss='binary_crossentropy', metrics=['accuracy'])
# print the model summary
opt_model.summary()

# early stopping callback
from keras.callbacks import EarlyStopping
early_stopping = EarlyStopping(monitor='val_loss', patience=10, mode='min')

# model checkpoint callback
# this saves our model architecture + parameters into dense_model.h5
from keras.callbacks import ModelCheckpoint
model_checkpoint = ModelCheckpoint('TopFC_opt_dense_model.h5', monitor='val_loss', 
                                   verbose=0, save_best_only=True,                                    
                                   save_weights_only=False, mode='auto', 
                                   period=1)
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input (InputLayer)          [(None, 13)]              0
#
#  hidden1 (Dense)             (None, 128)               1792
#
#  hidden2 (Dense)             (None, 128)               16512
#
#  hidden3 (Dense)             (None, 128)               16512
#
#  output (Dense)              (None, 1)                 129
#
# =================================================================
# Total params: 34,945
# Trainable params: 34,945
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
# Train classifier
import time
start = time.time() # time at start of whole processing

opt_history = opt_model.fit(X_train_val, 
                    Y_train_val, 
                    epochs=500, 
                    batch_size=256, 
                    verbose=1, # switch to 1 for more verbosity 
                    callbacks=[early_stopping, model_checkpoint], 
                    validation_data=(X_test,Y_test))

elapsed = time.time() - start # time after whole processing
print("Time taken: "+str(round(elapsed,1))+"s") # print total time taken to process every file
# Out:
# Epoch 1/500
# 101/101 [==============================] - 1s 6ms/step - loss: 0.6049 - accuracy: 0.6721 - val_loss: 0.5703 - val_accuracy: 0.7054
# Epoch 2/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.5762 - accuracy: 0.7002 - val_loss: 0.5661 - val_accuracy: 0.7041
# Epoch 3/500
# 101/101 [==============================] - 0s 5ms/step - loss: 0.5645 - accuracy: 0.7071 - val_loss: 0.5559 - val_accuracy: 0.7128
# Epoch 4/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.5587 - accuracy: 0.7134 - val_loss: 0.5543 - val_accuracy: 0.7139
# Epoch 5/500
# 101/101 [==============================] - 0s 5ms/step - loss: 0.5518 - accuracy: 0.7194 - val_loss: 0.5552 - val_accuracy: 0.7197
# Epoch 6/500
# 101/101 [==============================] - 1s 9ms/step - loss: 0.5494 - accuracy: 0.7181 - val_loss: 0.5507 - val_accuracy: 0.7235
# Epoch 7/500
# 101/101 [==============================] - 1s 7ms/step - loss: 0.5437 - accuracy: 0.7262 - val_loss: 0.5449 - val_accuracy: 0.7252
# Epoch 8/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.5394 - accuracy: 0.7278 - val_loss: 0.5413 - val_accuracy: 0.7341
# Epoch 9/500
# 101/101 [==============================] - 0s 2ms/step - loss: 0.5359 - accuracy: 0.7312 - val_loss: 0.5380 - val_accuracy: 0.7328
# Epoch 10/500
# 101/101 [==============================] - 0s 2ms/step - loss: 0.5343 - accuracy: 0.7306 - val_loss: 0.5413 - val_accuracy: 0.7274
# Epoch 11/500
# 101/101 [==============================] - 0s 4ms/step - loss: 0.5318 - accuracy: 0.7340 - val_loss: 0.5424 - val_accuracy: 0.7322
# Epoch 12/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.5304 - accuracy: 0.7342 - val_loss: 0.5345 - val_accuracy: 0.7336
# Epoch 13/500
# 101/101 [==============================] - 0s 5ms/step - loss: 0.5257 - accuracy: 0.7367 - val_loss: 0.5344 - val_accuracy: 0.7347
# Epoch 14/500
# 101/101 [==============================] - 1s 7ms/step - loss: 0.5246 - accuracy: 0.7395 - val_loss: 0.5400 - val_accuracy: 0.7327
# Epoch 15/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.5225 - accuracy: 0.7393 - val_loss: 0.5382 - val_accuracy: 0.7307
# Epoch 16/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.5210 - accuracy: 0.7409 - val_loss: 0.5332 - val_accuracy: 0.7318
# Epoch 17/500
# 101/101 [==============================] - 0s 2ms/step - loss: 0.5208 - accuracy: 0.7441 - val_loss: 0.5401 - val_accuracy: 0.7231
# Epoch 18/500
# 101/101 [==============================] - 0s 2ms/step - loss: 0.5178 - accuracy: 0.7414 - val_loss: 0.5423 - val_accuracy: 0.7262
# Epoch 19/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.5156 - accuracy: 0.7441 - val_loss: 0.5312 - val_accuracy: 0.7353
# Epoch 20/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.5148 - accuracy: 0.7448 - val_loss: 0.5300 - val_accuracy: 0.7358
# Epoch 21/500
# 101/101 [==============================] - 0s 2ms/step - loss: 0.5100 - accuracy: 0.7446 - val_loss: 0.5306 - val_accuracy: 0.7335
# Epoch 22/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.5101 - accuracy: 0.7477 - val_loss: 0.5229 - val_accuracy: 0.7401
# Epoch 23/500
# 101/101 [==============================] - 0s 2ms/step - loss: 0.5091 - accuracy: 0.7498 - val_loss: 0.5335 - val_accuracy: 0.7321
# Epoch 24/500
# 101/101 [==============================] - 0s 2ms/step - loss: 0.5070 - accuracy: 0.7509 - val_loss: 0.5296 - val_accuracy: 0.7327
# Epoch 25/500
# 101/101 [==============================] - 0s 2ms/step - loss: 0.5060 - accuracy: 0.7523 - val_loss: 0.5340 - val_accuracy: 0.7380
# Epoch 26/500
# 101/101 [==============================] - 0s 2ms/step - loss: 0.5052 - accuracy: 0.7523 - val_loss: 0.5272 - val_accuracy: 0.7356
# Epoch 27/500
# 101/101 [==============================] - 0s 2ms/step - loss: 0.5022 - accuracy: 0.7539 - val_loss: 0.5279 - val_accuracy: 0.7378
# Epoch 28/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.5003 - accuracy: 0.7536 - val_loss: 0.5243 - val_accuracy: 0.7358
# Epoch 29/500
# 101/101 [==============================] - 0s 2ms/step - loss: 0.4986 - accuracy: 0.7573 - val_loss: 0.5408 - val_accuracy: 0.7271
# Epoch 30/500
# 101/101 [==============================] - 0s 2ms/step - loss: 0.5005 - accuracy: 0.7554 - val_loss: 0.5316 - val_accuracy: 0.7380
# Epoch 31/500
# 101/101 [==============================] - 0s 2ms/step - loss: 0.4948 - accuracy: 0.7570 - val_loss: 0.5311 - val_accuracy: 0.7311
# Epoch 32/500
# 101/101 [==============================] - 0s 2ms/step - loss: 0.4905 - accuracy: 0.7613 - val_loss: 0.5264 - val_accuracy: 0.7381
# Time taken: 11.9s

# %%
loss_accuracy_plotter(opt_history)

fpr_nn_opt, tpr_nn_opt, thresholds_nn_opt = evaluate(opt_model, scaler, X, Y, X_train_val, Y_train_val, X_test, Y_test)
df_all['dense_NN_opt'] = opt_model.predict(scaler.transform(X)).round() # add prediction to array
# Out:
# 202/202 [==============================] - 0s 913us/step
# 806/806 [==============================] - 1s 1ms/step
# 202/202 [==============================] - 0s 767us/step
# 806/806 [==============================] - 1s 843us/step
# 1007/1007 [==============================] - 1s 855us/step
# Test acc score: 0.7381248059608817
# Train acc score: 0.7642812791058677
# Classification report for the test set
#               precision    recall  f1-score   support
#
#   background       0.68      0.54      0.61      2384
#       signal       0.76      0.85      0.80      4058
#
#     accuracy                           0.74      6442
#    macro avg       0.72      0.70      0.70      6442
# weighted avg       0.73      0.74      0.73      6442
#
# Classification report for the total set
#               precision    recall  f1-score   support
#
#   background       0.73      0.57      0.64     12210
#       signal       0.77      0.87      0.82     20000
#
#     accuracy                           0.76     32210
#    macro avg       0.75      0.72      0.73     32210
# weighted avg       0.76      0.76      0.75     32210
#
# Confusion matrix for total set
# [[ 6980  5230]
#  [ 2531 17469]]
# 1007/1007 [==============================] - 1s 764us/step

# %%
# add TF NN probability
y_tot_prob_NN_opt = opt_model.predict(scaler.transform(X))
y_tot_NN_opt = opt_model.predict(scaler.transform(X)).round()

cumulative_events = 0 # start counter for total number of events for which output is saved
for key in filename.keys(): # loop over samples
    df[key]['NN_opt_output_prob'] = y_tot_prob_NN_opt[cumulative_events:cumulative_events+len(df[key])]
    df[key]['NN_opt_output'] = y_tot_NN_opt[cumulative_events:cumulative_events+len(df[key])]
    cumulative_events += len(df[key]) # increment counter for total number of events
    #print(df[key]['NN_output']) # print the dataframe column NN_output

# probability and significance plots
NN_opt_output_prob = { # dictionary containing plotting parameters for the mllll histogram
    # change plotting parameters
    'bin_width':0.1, # width of each histogram bin
    'num_bins':8, # number of histogram bins
    'xrange_min':0, # minimum on x-axis
    'xlabel':'Neural Network optimized output', # x-axis label
}

SoverB_hist_dict = {'NN_opt_output_prob':NN_opt_output_prob}
plot_SoverB(df, SoverB_hist_dict)
# Out:
# 1007/1007 [==============================] - 1s 819us/step
# 1007/1007 [==============================] - 1s 793us/step

# %%
# plot ROC curve
plt.plot(fpr_nn, tpr_nn, label='Neural Network') # plot neural network ROC
plt.plot(fpr_nn_opt, tpr_nn_opt, linestyle='dashed', label='Neural Network optimized') # plot neural network optimized ROC
plt.plot(fpr_nn_opt_drop, tpr_nn_opt_drop, linestyle='dashed', label='Neural Network dropout optimized') # plot neural network optimized and dropout ROC
plt.plot([0, 1], [0, 1], linestyle='dotted', color='grey', label='Luck') # plot diagonal line to indicate luck
plt.xlabel('False Positive Rate') # x-axis label
plt.ylabel('True Positive Rate') # y-axis label
plt.grid() # add a grid to the plot
plt.legend() # add a legend

# %%
ams_nn = AMS(tpr_nn, fpr_nn, 0.001) # get AMS for NN classifier
ams_nn_opt = AMS(tpr_nn_opt, fpr_nn_opt, 0.001) # get AMS for NN-opt classifier
ams_nn_opt_drop = AMS(tpr_nn_opt_drop, fpr_nn_opt_drop, 0.001) # get AMS for NN-opt classifier


plt.plot(thresholds_nn, ams_nn, label="Neural Netwrok")  # plot NN AMS
plt.plot(thresholds_nn_opt, ams_nn_opt, linestyle='dashed', label="Neural Netwrok optimized")  # plot NN-opt AMS
plt.plot(thresholds_nn_opt_drop, ams_nn_opt_drop, linestyle='dashed', label="Neural Netwrok dropout optimized")  # plot NN-opt AMS
plt.xlabel("Threshold")  # x-axis label
plt.ylabel("AMS")  # y-axis label
plt.title("AMS with $b_r=0.001$")  # add plot title
plt.legend()  # add legend

# %% [markdown]
# ## Extend to the whole dataset

# %%
filename = {
    'ttbar':'/Users/mghasemi/Desktop/IPM/plotter/newtrees/ttbar.root',
    'WZ':'/Users/mghasemi/Desktop/IPM/plotter/newtrees/WZ.root',
    'ZZ':'/Users/mghasemi/Desktop/IPM/plotter/newtrees/ZZ.root',
    'signal_charm':'/Users/mghasemi/Desktop/IPM/plotter/newtrees/signal_charm.root'
    }

'''
filename = {
    'ttbar':'/Users/mghasemi/Desktop/IPM/plotter/newtrees/ttbar.root',
    'WZ':'/Users/mghasemi/Desktop/IPM/plotter/newtrees/WZ.root',
    'ZZ':'/Users/mghasemi/Desktop/IPM/plotter/newtrees/ZZ.root',
    'signal_up':'/Users/mghasemi/Desktop/IPM/plotter/newtrees/signal_up.root'}
    }
'''
VARS = ['jetNo','jetPTLeading', 'jetETA', 'jetPHI','bjetPT', 'bjetETA',
        'elecPTLeading', 'elecETA', 'elecPHI',
        'dielecCOS', 'dielecETA', 'met','testnonTopMass'] # choose which vars to use (2d)

upfile = {}
params = {}
df = {}

# define trees and branches to make DataFrame
for treename in filename.keys():
    upfile[treename] = uproot.open(filename[treename])
    params[treename] = upfile[treename][treename].arrays(VARS)
    df[treename] = ak.to_dataframe(params[treename])
    # add isSignal variable
    if treename.startswith("signal"): 
        df[treename]['isSignal'] = np.ones(len(df[treename])) 
    else:
        df[treename]['isSignal'] = np.zeros(len(df[treename])) 

NDIM = len(VARS)
df_all = pd.concat([df[treename] for treename in filename.keys()])
dataset = df_all.values
X = dataset[:,0:NDIM]
Y = dataset[:,NDIM]

#X_train_val = scaler.transform(X_train_val)
#X_test = scaler.transform(X_test)

# %%
y_pred_NN_opt = opt_model.predict(X_test).round() # make predictions on the test data
y_pred_NN_train_opt = opt_model.predict(X_train_val).round()
y_pred_NN_tot_opt = opt_model.predict(scaler.transform(X)).round()

# See how well the classifier does, Acc = correct data / tot data
# The accuracy score is defined as the ratio of correctly identified data points to all data points.
#print("Test accuracy:", accuracy_score(Y_test, y_pred_NN_opt))
#print("Train accuracy", accuracy_score(Y_train_val, y_pred_NN_train_opt))
print("Total accuracy", accuracy_score(Y, y_pred_NN_tot_opt))

#print("Classification report for the test set")
#print(classification_report(Y_test.round(), y_pred_NN_opt.round(), target_names=['background', 'signal']))
#print("Classification report for the train set")
#print(classification_report(Y_train_val.round(), y_pred_NN_train.round(), target_names=['background', 'signal']))
print("Classification report for the total set")
print(classification_report(Y.round(), y_pred_NN_tot_opt.round(), target_names=['background', 'signal']))

print("Confusion matrix:\n", confusion_matrix(Y.round(), y_pred_NN_tot_opt.round()))

fpr_nn_opt_tot, tpr_nn_opt_tot, thresholds_nn_opt_tot = roc_curve(Y, y_pred_NN_tot_opt.round()) # get FPRs, TPRs and thresholds for neural network

df_all['dense_NN_opt'] = opt_model.predict(scaler.transform(X)).round() # add prediction to array
# Out:
# 202/202 [==============================] - 0s 841us/step
# 806/806 [==============================] - 1s 867us/step
# 3340/3340 [==============================] - 3s 798us/step
# Total accuracy 0.8104779463374917
# Classification report for the total set
#               precision    recall  f1-score   support
#
#   background       0.32      0.57      0.41     12210
#       signal       0.94      0.84      0.89     94643
#
#     accuracy                           0.81    106853
#    macro avg       0.63      0.71      0.65    106853
# weighted avg       0.87      0.81      0.83    106853
#
# Confusion matrix:
#  [[ 6980  5230]
#  [15021 79622]]
# 3340/3340 [==============================] - 3s 928us/step

# %%
y_pred_NN_opt_fit = drop_model.predict(X_test).round() # make predictions on the test data
y_pred_NN_train_opt_fit = drop_model.predict(X_train_val).round()
y_pred_NN_tot_opt_fit = drop_model.predict(scaler.transform(X)).round()

# See how well the classifier does, Acc = correct data / tot data
# The accuracy score is defined as the ratio of correctly identified data points to all data points.
#print("Test accuracy:", accuracy_score(Y_test, y_pred_NN_opt))
#print("Train accuracy", accuracy_score(Y_train_val, y_pred_NN_train_opt))
print("Total accuracy", accuracy_score(Y, y_pred_NN_tot_opt_fit))

#print("Classification report for the test set")
#print(classification_report(Y_test.round(), y_pred_NN_opt.round(), target_names=['background', 'signal']))
#print("Classification report for the train set")
#print(classification_report(Y_train_val.round(), y_pred_NN_train.round(), target_names=['background', 'signal']))
print("Classification report for the total set")
print(classification_report(Y.round(), y_pred_NN_tot_opt_fit.round(), target_names=['background', 'signal']))

print("Confusion matrix:\n", confusion_matrix(Y.round(), y_pred_NN_tot_opt_fit.round()))

fpr_nn_opt_tot_fit, tpr_nn_opt_tot_fit, thresholds_nn_opt_tot_fit = roc_curve(Y, y_pred_NN_tot_opt_fit.round()) # get FPRs, TPRs and thresholds for neural network

df_all['dense_NN_opt_overfit'] = opt_model.predict(scaler.transform(X)).round() # add prediction to array
# Out:
# 202/202 [==============================] - 0s 880us/step
# 806/806 [==============================] - 1s 793us/step
# 3340/3340 [==============================] - 3s 788us/step
# Total accuracy 0.8131825966514744
# Classification report for the total set
#               precision    recall  f1-score   support
#
#   background       0.34      0.71      0.46     12210
#       signal       0.96      0.83      0.89     94643
#
#     accuracy                           0.81    106853
#    macro avg       0.65      0.77      0.68    106853
# weighted avg       0.89      0.81      0.84    106853
#
# Confusion matrix:
#  [[ 8612  3598]
#  [16364 78279]]
# 3340/3340 [==============================] - 3s 847us/step

# %%
# add TF NN probability
y_TOT_prob_NN_opt = opt_model.predict(scaler.transform(X))
y_TOT_NN_opt = opt_model.predict(scaler.transform(X)).round()

cumulative_events = 0 # start counter for total number of events for which output is saved
for key in filename.keys(): # loop over samples
    df[key]['NN_opt_tot_output_prob'] = y_TOT_prob_NN_opt[cumulative_events:cumulative_events+len(df[key])]
    df[key]['NN_opt_tot_output'] = y_TOT_NN_opt[cumulative_events:cumulative_events+len(df[key])]
    cumulative_events += len(df[key]) # increment counter for total number of events
    #print(df[key]['NN_output']) # print the dataframe column NN_output

# probability and significance plots
NN_opt_tot_output_prob = { # dictionary containing plotting parameters for the mllll histogram
    # change plotting parameters
    'bin_width':0.1, # width of each histogram bin
    'num_bins':8, # number of histogram bins
    'xrange_min':0, # minimum on x-axis
    'xlabel':'Neural Network optimized output', # x-axis label
}

SoverB_hist_dict = {'NN_opt_tot_output_prob':NN_opt_tot_output_prob}
plot_SoverB(df, SoverB_hist_dict)
# Out:
# 3340/3340 [==============================] - 3s 831us/step
# 3340/3340 [==============================] - 3s 887us/step

# %%
# add TF NN probability
y_TOT_prob_NN_opt_fit = drop_model.predict(scaler.transform(X))
y_TOT_NN_opt_fit = drop_model.predict(scaler.transform(X)).round()

cumulative_events = 0 # start counter for total number of events for which output is saved
for key in filename.keys(): # loop over samples
    df[key]['NN_opt_tot_output_prob_overfit'] = y_TOT_prob_NN_opt_fit[cumulative_events:cumulative_events+len(df[key])]
    df[key]['NN_opt_tot_output_overfit'] = y_TOT_NN_opt_fit[cumulative_events:cumulative_events+len(df[key])]
    cumulative_events += len(df[key]) # increment counter for total number of events
    #print(df[key]['NN_output']) # print the dataframe column NN_output

# probability and significance plots
NN_opt_tot_output_prob_fit = { # dictionary containing plotting parameters for the mllll histogram
    # change plotting parameters
    'bin_width':0.1, # width of each histogram bin
    'num_bins':8, # number of histogram bins
    'xrange_min':0, # minimum on x-axis
    'xlabel':'Neural Network optimized output', # x-axis label
}

SoverB_hist_dict = {'NN_opt_tot_output_prob_overfit':NN_opt_tot_output_prob_fit}
plot_SoverB(df, SoverB_hist_dict)
# Out:
# 3340/3340 [==============================] - 3s 956us/step
# 3340/3340 [==============================] - 3s 842us/step

# %%
# plot ROC curve
plt.plot(fpr_nn_opt_tot, tpr_nn_opt_tot, label='Neural Network total') # plot Neural net-opt ROC
plt.plot(fpr_nn_opt_tot_fit, tpr_nn_opt_tot_fit, label='Neural Network overfit total') # plot Neural net-opt w overfit ROC
plt.plot([0, 1], [0, 1], linestyle='dotted', color='grey', label='Luck') # plot diagonal line to indicate luck
plt.xlabel('False Positive Rate') # x-axis label
plt.ylabel('True Positive Rate') # y-axis label
plt.grid() # add a grid to the plot
plt.legend() # add a legend

# %%
#ams_rf = AMS(tpr_rf, fpr_rf, 0.001) # get AMS for random forest classifier
ams_rf_opt_tot = AMS(tpr_nn_opt_tot, fpr_nn_opt_tot, 0.001) # get AMS for random forest classifier
ams_rf_opt_tot_fit = AMS(tpr_nn_opt_tot_fit, fpr_nn_opt_tot_fit, 0.001) # get AMS for random forest classifier

plt.plot(thresholds_nn_opt_tot, ams_rf_opt_tot, label="Neural Netwrok")  # plot Random forest AMS
plt.plot(thresholds_nn_opt_tot_fit, ams_rf_opt_tot_fit, label="Neural Netwrok overfit")  # plot Random forest AMS
plt.xlabel("Threshold")  # x-axis label
plt.ylabel("AMS")  # y-axis label
plt.title("AMS with $b_r=0.001$")  # add plot title
plt.legend()  # add legend

# %% [markdown]
# ## Overfit checking

# %%
new_compare_train_test(model, X_train_val, Y_train_val, X_test, Y_test, 'Neural Netwrok output')
# Out:
# 308/308 [==============================] - 0s 1ms/step
# 499/499 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 693us/step
# 127/127 [==============================] - 0s 677us/step

# %%
new_compare_train_test(opt_model, X_train_val, Y_train_val, X_test, Y_test, 'Neural Netwrok optimized output')
# Out:
# 308/308 [==============================] - 0s 1ms/step
# 499/499 [==============================] - 0s 875us/step
# 75/75 [==============================] - 0s 918us/step
# 127/127 [==============================] - 0s 842us/step

# %%
new_compare_train_test(drop_model, X_train_val, Y_train_val, X_test, Y_test, 'Neural Netwrok optimized dropoutoutput')
# Out:
# 308/308 [==============================] - 0s 834us/step
# 499/499 [==============================] - 0s 813us/step
# 75/75 [==============================] - 0s 795us/step
# 127/127 [==============================] - 0s 779us/step

# %% [markdown]
# ## Baysian Optimization for NN model

# %%
# Import packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from keras.models import Sequential
from keras.layers import Dense, BatchNormalization, Dropout
from keras.optimizers import Adam, SGD, RMSprop, Adadelta, Adagrad, Adamax, Nadam, Ftrl
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.wrappers.scikit_learn import KerasClassifier
from math import floor
from sklearn.metrics import make_scorer, accuracy_score
#from bayes_opt import BayesianOptimization
from kerastuner.tuners import BayesianOptimization
from sklearn.model_selection import StratifiedKFold
from keras.layers import LeakyReLU
from sklearn.model_selection import RandomizedSearchCV

LeakyReLU = LeakyReLU(alpha=0.1)
import warnings
warnings.filterwarnings('ignore')
pd.set_option("display.max_columns", None)

# Load dataset
trainSet = pd.read_csv('/Users/mghasemi/Desktop/Code-factory/Python/ML/Kaggle/competitions/Titanic/input/train.csv')
# Feature generation: training data
train = trainSet.drop(columns=['Name', 'Ticket', 'Cabin'])
train = train.dropna(axis=0)
train = pd.get_dummies(train)
# train validation split
X_train, X_val, y_train, y_val = train_test_split(train.drop(columns=['PassengerId','Survived'], axis=0),
                                                  train['Survived'],
                                                  test_size=0.2, random_state=111,
                                                  stratify=train['Survived'])                                                  

# Create function
def nn_cl_bo(neurons, activation, optimizer, learning_rate,  batch_size, epochs ):
    optimizerL = ['SGD', 'Adam', 'RMSprop', 'Adadelta', 'Adagrad', 'Adamax', 'Nadam', 'Ftrl','SGD']
    optimizerD= {'Adam':Adam(lr=learning_rate), 'SGD':SGD(lr=learning_rate),
                 'RMSprop':RMSprop(lr=learning_rate), 'Adadelta':Adadelta(lr=learning_rate),
                 'Adagrad':Adagrad(lr=learning_rate), 'Adamax':Adamax(lr=learning_rate),
                 'Nadam':Nadam(lr=learning_rate), 'Ftrl':Ftrl(lr=learning_rate)}
    activationL = ['relu', 'sigmoid', 'softplus', 'softsign', 'tanh', 'selu',
                   'elu', 'exponential', LeakyReLU,'relu']
    neurons = round(neurons)
    activation = activationL[round(activation)]
    batch_size = round(batch_size)
    epochs = round(epochs)
    def nn_cl_fun():
        opt = Adam(lr = learning_rate)
        nn = Sequential()
        nn.add(Dense(neurons, input_dim=10, activation=activation))
        nn.add(Dense(neurons, activation=activation))
        nn.add(Dense(1, activation='sigmoid'))
        nn.compile(loss='binary_crossentropy', optimizer=opt, metrics=['accuracy'])
        return nn
    es = EarlyStopping(monitor='accuracy', mode='max', verbose=0, patience=20)
    nn = KerasClassifier(build_fn=nn_cl_fun, epochs=epochs, batch_size=batch_size,
                         verbose=0)
    kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=123)
    score = cross_val_score(nn, X_train, y_train, scoring=score_acc, cv=kfold, fit_params={'callbacks':[es]}).mean()
    return score


# Set paramaters
params_nn ={
    'neurons': (10, 100),
    'activation':(0, 9),
    'optimizer':(0,7),
    'learning_rate':(0.01, 1),
    'batch_size':(200, 1000),
    'epochs':(20, 100)
}
# Run Bayesian Optimization
nn_bo = BayesianOptimization(nn_cl_bo, params_nn, random_state=111)
nn_bo.maximize(init_points=25, n_iter=4)
