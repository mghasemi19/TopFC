# %% [markdown]
# # DNN in TopFC analysis
# Author: Meisam Ghasemi Bostanabad

# %% [markdown]
# ## Loading `pandas` DataFrames
# Now we load two different `NumPy` arrays. One corresponding to the VV signal and one corresponding to the background.

# %%
import uproot
import numpy as np
import pandas as pd
import h5py
import awkward as ak
import seaborn as sns
import matplotlib.pyplot as plt
import math
from scipy import stats


# fix random seed for reproducibility
seed = 7
np.random.seed(seed)

filename = {
    'ttbar':'/Users/mghasemi/Desktop/IPM/plotter/newtrees/ttbar.root',
    'WZ':'/Users/mghasemi/Desktop/IPM/plotter/newtrees/WZ.root',
    'ZZ':'/Users/mghasemi/Desktop/IPM/plotter/newtrees/ZZ.root',
    'signal_up':'/Users/mghasemi/Desktop/IPM/plotter/newtrees/signal_up.root'}

upfile = {}
params = {}
df = {}

# choose which vars to use (multi dimensional)
#VARS = ['jetNo','jetPTLeading','bjetPT','elecPTLeading','met','testnonTopMass', 'weight'] # choose which vars to use (2d)
VARS = ['jetNo','jetPTLeading', 'jetETA', 'jetPHI','bjetPT', 'bjetETA',
        'elecPTLeading', 'elecETA', 'elecPHI',
        'dielecCOS', 'dielecETA', 'met','testnonTopMass'] # choose which vars to use (2d)

# define trees and branches to make DataFrame
for treename in filename.keys():
    upfile[treename] = uproot.open(filename[treename])
    params[treename] = upfile[treename][treename].arrays(VARS)
    df[treename] = ak.to_dataframe(params[treename])
    # add isSignal variable
    if treename.startswith("signal"): 
        df[treename]['isSignal'] = np.ones(len(df[treename])) 
    else:
        df[treename]['isSignal'] = np.zeros(len(df[treename]))

# %%
df['signal_up'].shape
# Out:
# (99809, 14)

# %% [markdown]
# ## Functions

# %%
# function to plot all distributions
def hist(df1, df2, cols, bins, ncols = 3):
    nrows = math.ceil(len(cols) / ncols)
    fig, ax = plt.subplots(nrows, ncols, figsize = (5 * ncols, 4.2 * nrows), sharey = False)
    for i in range(len(cols)):
        #sns.histplot(data = df, x = cols[i], bins = bins, hue = 'isSignal', palette = ['grey', 'red'], ax = ax[i // ncols, i % ncols], stat="probability")
        sns.histplot(data = df1, x = cols[i], bins = bins, color = 'red',
                      ax = ax[i // ncols, i % ncols], stat="density", label='bkg')
        sns.histplot(data = df2, x = cols[i], bins = bins, color = 'grey',
                      ax = ax[i // ncols, i % ncols], stat="density", label='sig')       
        ax[i // ncols, i % ncols].set_xlabel(cols[i])
        ax[i // ncols, i % ncols].legend()
        if i % ncols != 0:
            ax[i // ncols, i % ncols].set_ylabel(" ")
        
    plt.tight_layout()
    plt.show()


# function to make ML output and significant plot
samples =['ttbar', 'WZ', 'ZZ', 'signal_up']

def plot_SoverB(data, SoverB_hist_dict):
    
    signal = r'signal_up' # which sample is the signal

    # *******************
    # general definitions (shouldn't need to change)

    for x_variable,hist in SoverB_hist_dict.items(): # access the dictionary of histograms defined in the cell above

        h_bin_width = hist['bin_width'] # get the bin width defined in the cell above
        h_num_bins = hist['num_bins'] # get the number of bins defined in the cell above
        h_xrange_min = hist['xrange_min'] # get the x-range minimum defined in the cell above
        h_xlabel = hist['xlabel'] # get the x-axis label defined in the cell above
    
        bin_edges = [ h_xrange_min + x*h_bin_width for x in range(h_num_bins+1) ] # bin limits
        bin_centres = [ h_xrange_min+h_bin_width/2 + x*h_bin_width for x in range(h_num_bins) ] # bin centres
        
        signal_x = data[signal][x_variable] # histogram the signal
    
        mc_x = [] # define list to hold the Monte Carlo histogram entries

        for s in samples: # loop over samples
            if s not in ['data', signal]: # if not data nor signal
                mc_x = [*mc_x, *data[s][x_variable] ] # append to the list of Monte Carlo histogram entries
                #test=[]; test.append(df[s]['NN_output_prob'].values)


    
    
        # *************
        # Signal and background distributions
        # *************
        distributions_axes = plt.gca() # get current axes
 
        mc_heights = distributions_axes.hist(mc_x, bins=bin_edges, color='red', 
                                             label='Total background',
                                             histtype='step', # lineplot that's unfilled
                                             density=True ) # normalize to form probability density
        signal_heights = distributions_axes.hist(signal_x, bins=bin_edges, color='blue',
                                                 label=signal, 
                                                 histtype='step', # lineplot that's unfilled
                                                 density=True, # normalize to form probability density
                                                 linestyle='--' ) # dashed line
        
        distributions_axes.set_xlim( left=bin_edges[0], right=bin_edges[-1] ) # x-limits of the distributions axes
        distributions_axes.set_ylabel('Arbitrary units' ) # y-axis label for distributions axes
        y_max = max(max(signal_heights[0]), max(mc_heights[0]) )
        #distributions_axes.set_ylim( top=max(signal_heights[0])*1.3 ) # set y-axis limits
        distributions_axes.set_ylim( top=y_max*1.2 ) # set y-axis limits
        #distributions_axes.set_ylim( top=max(signal_heights[0])*1.3 ) # set y-axis limits
        plt.title('Signal and background '+x_variable+' distributions') # add title
        distributions_axes.legend() # draw the legend
        distributions_axes.set_xlabel( h_xlabel ) # x-axis label
            
        plt.show() # show the Signal and background distributions
    
    
        # *************
        # Signal to background ratio
        # *************
        plt.figure() # start new figure
        SoverB = [] # list to hold S/B values
        for cut_value in bin_edges: # loop over bins
            #signal_weights_passing_cut = sum(data[signal][data[signal][x_variable]>cut_value].totalWeight)
            signal_weights_passing_cut = len(data[signal][data[signal][x_variable]>cut_value])
            background_weights_passing_cut = 0 # start counter for background weights passing cut
            for s in samples: # loop over samples
                if s not in ['data', signal]: # if not data nor signal
                    #background_weights_passing_cut += sum(data[s][data[s][x_variable]>cut_value].totalWeight)
                    background_weights_passing_cut += len(data[s][data[s][x_variable]>cut_value])
            if background_weights_passing_cut!=0: # some background passes cut
                SoverB_value = signal_weights_passing_cut/background_weights_passing_cut
                SoverB_percent = 100*SoverB_value # multiply by 100 for percentage
                SoverB.append(SoverB_percent) # append to list of S/B values
        
        SoverB_axes = plt.gca() # get current axes
        SoverB_axes.plot( bin_edges[:len(SoverB)], SoverB ) # plot the data points
        SoverB_axes.set_xlim( left=bin_edges[0], right=bin_edges[-1] ) # set the x-limit of the main axes
        #SoverB_axes.set_ylim( 100, 1000)
        SoverB_axes.set_ylabel( 'S/B (%)' ) # write y-axis label for main axes
        plt.title('Signal to background ratio for different '+x_variable+' cut values', family='sans-serif')
        SoverB_axes.set_xlabel( h_xlabel ) # x-axis label 
        
        plt.show() # show S/B plot
    
    return    

from sklearn.metrics import roc_curve, auc, classification_report, accuracy_score, confusion_matrix

# function to draw loss-accuracy vs epoch and ROC curve
# %matplotlib inline
def loss_accuracy_plotter(history):
    # plot loss vs epoch
    plt.figure(figsize=(15,10))
    ax = plt.subplot(2, 2, 1)
    ax.plot(history.history['loss'], label='loss')
    ax.plot(history.history['val_loss'], label='val_loss')
    ax.legend(loc="upper right")
    ax.set_title('Loss over epochs')
    ax.set_xlabel('epoch')
    ax.set_ylabel('loss')

    # plot accuracy vs epoch
    ax = plt.subplot(2, 2, 2)
    ax.plot(history.history['accuracy'], label='acc')
    ax.plot(history.history['val_accuracy'], label='val_acc')
    ax.legend(loc="lower right")
    ax.set_title('Accuracy over epochs')
    ax.set_xlabel('epoch')
    ax.set_ylabel('acc')

    # Plot ROC
    Y_predict = model.predict(X_test)
    Y_predict_train = model.predict(X_train_val)
    fpr, tpr, thresholds = roc_curve(Y_test, Y_predict)
    roc_auc = auc(fpr, tpr)
    ax = plt.subplot(2, 2, 3)
    ax.plot(fpr, tpr, lw=2, color='cyan', label='auc = %.3f' % (roc_auc))
    ax.plot([0, 1], [0, 1], linestyle='--', lw=2, color='k', label='random chance')
    ax.set_xlim([0, 1.0])
    ax.set_ylim([0, 1.0])
    ax.set_xlabel('false positive rate')
    ax.set_ylabel('true positive rate')
    ax.set_title('receiver operating curve')
    ax.legend(loc="lower right")
    plt.show()

# function to report all metrics evaluation
def evaluate(model, scaler, X, Y, X_train_val, Y_train_val, X_test, Y_test):
    Y_pred_test = model.predict(X_test)
    Y_pred_test = Y_pred_test.reshape(Y_pred_test.shape[0])
    Y_pred_train = model.predict(X_train_val)
    Y_pred_train = Y_pred_train.reshape(Y_pred_train.shape[0])
    Y_pred_tot = model.predict(scaler.transform(X)).round()
    Y_pred_tot = Y_pred_tot.reshape(Y_pred_tot.shape[0])

    # accuracy score
    print("Test acc score:", accuracy_score(Y_test.round(), Y_pred_test.round()))
    print("Train acc score:", accuracy_score(Y_train_val.round(), Y_pred_train.round()))

    # classification report for the test and total sets
    print("Classification report for the test set")
    print(classification_report(Y_test.round(), Y_pred_test.round(), target_names=['background', 'signal']))
    print("Classification report for the total set")
    print(classification_report(Y.round(), Y_pred_tot.round(), target_names=['background', 'signal']))

    print("Confusion matrix for total set")
    print(confusion_matrix(Y.round(), Y_pred_tot.round()))

    fpr, tpr, thresholds = roc_curve(Y_test, Y_pred_test) # get FPRs, TPRs and thresholds for neural network
    return fpr, tpr, thresholds

# plot AMS
def AMS(tpr, fpr, b_reg): # define function to calculate AMS
    return np.sqrt(2*((tpr+fpr+b_reg)*np.log(1+tpr/(fpr+b_reg))-tpr)) # equation for AMS

def cdf(sample, x, sort = False):
    '''
    Return the value of the Cumulative Distribution Function, evaluated for a given sample and a value x.
    
    Args:
        sample: The list or array of observations.
        x: The value for which the numerical cdf is evaluated.
    
    Returns:
        cdf = CDF_{sample}(x)
    '''
    
    # Sorts the sample, if needed
    if sort:
        sample.sort()
    
    # Counts how many observations are below x
    cdf = sum(sample <= x)
    
    # Divides by the total number of observations
    cdf = cdf / len(sample)
    
    return cdf

def ks_2samp_test(sample1, sample2):
    
    # Gets all observations
    observations = np.concatenate((sample1, sample2))
    observations.sort()
    
    # Sorts the samples
    sample1.sort()
    sample2.sort()
    
    # Evaluates the KS statistic
    D_ks = [] # KS Statistic list
    for x in observations:
        cdf_sample1 = cdf(sample = sample1, x  = x)
        cdf_sample2 = cdf(sample = sample2, x  = x)
        D_ks.append(abs(cdf_sample1 - cdf_sample2))
    ks_stat = max(D_ks)
    
    # Calculates the P-Value based on the two-sided test
    # The P-Value comes from the KS Distribution Survival Function (SF = 1-CDF)
    m, n = float(len(sample1)), float(len(sample2))
    en = m * n / (m + n)
    p_value = stats.kstwo.sf(ks_stat, np.round(en))
    
    return {"ks_stat": ks_stat, "p_value" : p_value}

# plot train and test CLF distributions
def new_compare_train_test(clf, X_train, y_train, X_test, y_test, xlabel):
    decisions = [] # list to hold decisions of classifier
    for X,y in ((X_train, y_train), (X_test, y_test)): # train and test
        d1 = clf.predict(X[y<0.5]) # background
        d2 = clf.predict(X[y>0.5]) # signal
        decisions += [d1, d2] # add to list of classifier decision

    highest_decision = max(np.max(d) for d in decisions) # get maximum score
    bin_edges = [] # list to hold bin edges
    bin_edge = -0.1 # start counter for bin_edges
    while bin_edge < highest_decision: # up to highest score
        bin_edge += 0.1 # increment
        bin_edges.append(bin_edge)

    # Training plots
    plt.hist(decisions[0], # background in train set
            bins=bin_edges, # lower and upper range of the bins
            density=True, # area under the histogram will sum to 1
            histtype='stepfilled', # lineplot that's filled
            color='blue', label='Background (train)', # Background (train)
            alpha=0.5 ) # half transparency
    plt.hist(decisions[1], # signal in train set
            bins=bin_edges, # lower and upper range of the bins
            density=True, # area under the histogram will sum to 1
            histtype='stepfilled', # lineplot that's filled
            color='orange', label='Signal (train)', # Signal (train)
            alpha=0.5 ) # half transparency

    # Testing plots
    hist_background, bin_edges = np.histogram(decisions[2], # background test
                                            bins=bin_edges, # number of bins in function definition
                                            density=True ) # area under the histogram will sum to 1

    scale = len(decisions[2]) / sum(hist_background) # between raw and normalised
    err_background = np.sqrt(hist_background * scale) / scale # error on test background

    width = 0.1 # histogram bin width
    center = (bin_edges[:-1] + bin_edges[1:]) / 2 # bin centres

    plt.errorbar(x=center, y=hist_background, yerr=err_background, fmt='o', # circles
                c='blue', label='Background (test)' ) # Background (test)

    hist_signal, bin_edges = np.histogram(decisions[3], # siganl test
                                        bins=bin_edges, # number of bins in function definition
                                        density=True ) # area under the histogram will sum to 1

    scale = len(decisions[3]) / sum(hist_signal) # between raw and normalised
    err_signal = np.sqrt(hist_signal * scale) / scale # error on test background

    plt.errorbar(x=center, y=hist_signal, yerr=err_signal, fmt='*', # circles
                c='orange', label='Signal (test)' ) # Signal (test)

    plt.xlabel(xlabel) # write x-axis label
    plt.ylabel("Arbitrary units") # write y-axis label
    plt.legend() # add legend
    ks_signal = ks_2samp_test(np.array(decisions[1]), np.array(decisions[3]))
    ks_background = ks_2samp_test(np.array(decisions[0]), np.array(decisions[2]))
    print(f"Signal: ks = {ks_signal['ks_stat']} (p-value = {ks_signal['p_value']}, are equal = {ks_signal['p_value'] > 0.05})")
    print(f"Background: ks = {ks_background['ks_stat']} (p-value = {ks_background['p_value']}, are equal = {ks_background['p_value'] > 0.05})")
    #return (decisions[0], decisions[2])

# %% [markdown]
# ## Data exploration

# %%
# reduce signal DF size to have resonable Sig/Bkg ratio
df['signal_up'] = df['signal_up'][:20000]
df_all = pd.concat([df[treename] for treename in filename.keys()])

# %%
# number of entries in the backgrounds and signals
sns.set_theme(style="white")

tot_bkg = 0
for treename in filename.keys():
    if not 'signal' in treename: tot_bkg += df[treename].shape[0]
    print(treename, ":", df[treename].shape)

print("signal/tot bkg:", round((df['signal_up'].shape[0]/ tot_bkg),1))
#print("Null entries:", df['signal_charm'].isna().sum())

counts_signal = df['signal_up'].shape[0]
counts_background = tot_bkg

plt.figure(figsize=(8,6))
plt.pie([counts_signal, counts_background], explode=[0.1,0.1], shadow=True, labels=['Signal ','Background'], textprops={'fontsize': 14}, autopct='%1.1f%%');
#plt.pie([counts_signal, counts_background], explode=[0.1,0.1], shadow=True, labels=['Signal ','Background'], textprops={'color':"b"}, autopct='%1.1f%%');
# Out:
# ttbar : (1181, 14)
# WZ : (10855, 14)
# ZZ : (174, 14)
# signal_up : (20000, 14)
# signal/tot bkg: 1.6

# %%
plt.figure(figsize=(13,10))
#sns.set_theme(style="white")

# Getting the Upper Triangle of the co-relation matrix
corr = df_all.corr()
#matrix = np.triu(corr)
#mask = np.triu(np.ones_like(corr, dtype=bool))
matrix = np.triu(np.ones_like(corr))


cmap = sns.diverging_palette(200, 7, s=75, l=40,
                            n=5, center="light", as_cmap=True)

#sns.heatmap(df_test.corr(), annot=True, linewidth=.5, vmin = -1, vmax = 1,cmap = plt.cm.CMRmap_r, fmt=".1f", mask=matrix);
sns.heatmap(df_all.corr(), annot=True, linewidth=.5, vmin = -1, vmax = 1,cmap = cmap, fmt=".2f", mask=matrix);

# %%
df_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 32210 entries, (0, 0) to (8088, 0)
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   jetNo           32210 non-null  int32
#  1   jetPTLeading    32210 non-null  float64
#  2   jetETA          32210 non-null  float64
#  3   jetPHI          32210 non-null  float64
#  4   bjetPT          32210 non-null  float64
#  5   bjetETA         32210 non-null  float64
#  6   elecPTLeading   32210 non-null  float64
#  7   elecETA         32210 non-null  float64
#  8   elecPHI         32210 non-null  float64
#  9   dielecCOS       32210 non-null  float64
#  10  dielecETA       32210 non-null  float64
#  11  met             32210 non-null  float64
#  12  testnonTopMass  32210 non-null  float64
#  13  isSignal        32210 non-null  float64
# dtypes: float64(13), int32(1)
# memory usage: 3.7 MB

# %%
# Distributions of the float features
hist(df_all[df_all['isSignal']==0].replace(-999, np.nan),
     df_all[df_all['isSignal']==1].replace(-999, np.nan),
     #list(df_all.columns[df_all.dtypes == 'float64']),
     list(df_all.columns),
     bins = math.floor(len(df_all)**(1/3)),
     ncols = 3)

# %% [markdown]
# ## Define the models

# %% [markdown]
# ## simple NN from Tensorflow
# We'll start with a dense (fully-connected) NN layer.
# Our model will have a single fully-connected hidden layer with the same number of neurons as input variables.
# The weights are initialized using a small Gaussian random number.
# We will switch between linear and tanh activation functions for the hidden layer.
# The output layer contains a single neuron in order to make predictions.
# It uses the sigmoid activation function in order to produce a probability output in the range of 0 to 1.
#
# We are using the `binary_crossentropy` loss function during training, a standard loss function for binary classification problems.
# We will optimize the model with the Adam algorithm for stochastic gradient descent and we will collect accuracy metrics while the model is trained.

# %% [markdown]
# ## Dividing the data into testing and training dataset
#
# We will split the data into two parts (one for training+validation and one for testing).
# We will also apply "standard scaling" preprocessing: http://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.StandardScaler.html i.e. making the mean = 0 and the RMS = 1 for all input variables (based **only** on the training/validation dataset).
# We will also define our early stopping criteria to prevent over-fitting and we will save the model based on the best `val_loss`.

# %%
NDIM = len(VARS)
dataset = df_all.values
X = dataset[:,0:NDIM]
Y = dataset[:,NDIM]

from sklearn.model_selection import train_test_split
X_train_val, X_test, Y_train_val, Y_test = train_test_split(X, Y, test_size=0.2, random_state=7)

# preprocessing: standard scalar
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler().fit(X_train_val)
X_train_val = scaler.transform(X_train_val)
X_test = scaler.transform(X_test)

# baseline keras model
from keras.models import Sequential, Model
from tensorflow.keras.optimizers import SGD
#from keras.optimizers import SGD
from keras.layers import Input, Activation, Dense, Convolution2D, MaxPooling2D, Dropout, Flatten
from keras.utils import np_utils
from sklearn.model_selection import RandomizedSearchCV
from sklearn.pipeline import Pipeline
from tensorflow import keras

inputs = Input(shape=(NDIM,), name = 'input') 
hidden1 = Dense(20, name = 'hidden1', kernel_initializer='normal', activation='relu')(inputs)
hidden2 = Dense(20, name = 'hidden2', kernel_initializer='normal', activation='relu')(hidden1)
outputs = Dense(1, name = 'output', kernel_initializer='normal', activation='sigmoid')(hidden2)

# create the model
model = Model(inputs=inputs, outputs=outputs)
# compile the model
optimizer = SGD(learning_rate=1e-3) # define the optimizer
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
#model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])
# print the model summary
model.summary()

# early stopping callback
from keras.callbacks import EarlyStopping
early_stopping = EarlyStopping(monitor='val_loss', patience=10, mode='min')

# model checkpoint callback
# this saves our model architecture + parameters into dense_model.h5
from keras.callbacks import ModelCheckpoint
model_checkpoint = ModelCheckpoint(filepath='./models/up_NN_model.h5', monitor='val_loss', 
                                   verbose=0, save_best_only=True, 
                                   save_weights_only=False, mode='auto', 
                                   period=1)
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input (InputLayer)          [(None, 13)]              0
#
#  hidden1 (Dense)             (None, 20)                280
#
#  hidden2 (Dense)             (None, 20)                420
#
#  output (Dense)              (None, 1)                 21
#
# =================================================================
# Total params: 721
# Trainable params: 721
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %% [markdown]
# ## Run training
# Here, we run the training.

# %%
# Train classifier
import time
start = time.time() # time at start of whole processing

history = model.fit(X_train_val, 
                    Y_train_val, 
                    epochs=1000, 
                    batch_size=512, 
                    verbose=1, # switch to 1 for more verbosity 
                    callbacks=[early_stopping, model_checkpoint], 
                    validation_data=(X_test,Y_test))

elapsed = time.time() - start # time after whole processing
print("Time taken: "+str(round(elapsed,1))+"s") # print total time taken to process every file
# Out:
# Epoch 1/1000
# 51/51 [==============================] - 1s 4ms/step - loss: 0.6806 - accuracy: 0.6186 - val_loss: 0.6557 - val_accuracy: 0.6344
# Epoch 2/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.6335 - accuracy: 0.6443 - val_loss: 0.6091 - val_accuracy: 0.6692
# Epoch 3/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.6063 - accuracy: 0.6678 - val_loss: 0.5988 - val_accuracy: 0.6717
# Epoch 4/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.6004 - accuracy: 0.6730 - val_loss: 0.5947 - val_accuracy: 0.6748
# Epoch 5/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5963 - accuracy: 0.6776 - val_loss: 0.5907 - val_accuracy: 0.6816
# Epoch 6/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5921 - accuracy: 0.6830 - val_loss: 0.5856 - val_accuracy: 0.6874
# Epoch 7/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5872 - accuracy: 0.6915 - val_loss: 0.5809 - val_accuracy: 0.6975
# Epoch 8/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5825 - accuracy: 0.6973 - val_loss: 0.5781 - val_accuracy: 0.6975
# Epoch 9/1000
# 51/51 [==============================] - 0s 3ms/step - loss: 0.5787 - accuracy: 0.6992 - val_loss: 0.5729 - val_accuracy: 0.7012
# Epoch 10/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5752 - accuracy: 0.7022 - val_loss: 0.5704 - val_accuracy: 0.7009
# Epoch 11/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5724 - accuracy: 0.7044 - val_loss: 0.5699 - val_accuracy: 0.7037
# Epoch 12/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5706 - accuracy: 0.7026 - val_loss: 0.5659 - val_accuracy: 0.7068
# Epoch 13/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5696 - accuracy: 0.7065 - val_loss: 0.5660 - val_accuracy: 0.7071
# Epoch 14/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5676 - accuracy: 0.7055 - val_loss: 0.5634 - val_accuracy: 0.7080
# Epoch 15/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5660 - accuracy: 0.7089 - val_loss: 0.5632 - val_accuracy: 0.7077
# Epoch 16/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5650 - accuracy: 0.7090 - val_loss: 0.5614 - val_accuracy: 0.7100
# Epoch 17/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5638 - accuracy: 0.7099 - val_loss: 0.5604 - val_accuracy: 0.7091
# Epoch 18/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5632 - accuracy: 0.7119 - val_loss: 0.5594 - val_accuracy: 0.7110
# Epoch 19/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5626 - accuracy: 0.7124 - val_loss: 0.5582 - val_accuracy: 0.7128
# Epoch 20/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5614 - accuracy: 0.7116 - val_loss: 0.5590 - val_accuracy: 0.7128
# Epoch 21/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5609 - accuracy: 0.7121 - val_loss: 0.5572 - val_accuracy: 0.7125
# Epoch 22/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5598 - accuracy: 0.7142 - val_loss: 0.5582 - val_accuracy: 0.7125
# Epoch 23/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5596 - accuracy: 0.7135 - val_loss: 0.5569 - val_accuracy: 0.7127
# Epoch 24/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5591 - accuracy: 0.7146 - val_loss: 0.5565 - val_accuracy: 0.7165
# Epoch 25/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5580 - accuracy: 0.7136 - val_loss: 0.5550 - val_accuracy: 0.7183
# Epoch 26/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5570 - accuracy: 0.7152 - val_loss: 0.5571 - val_accuracy: 0.7127
# Epoch 27/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5567 - accuracy: 0.7156 - val_loss: 0.5537 - val_accuracy: 0.7203
# Epoch 28/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5562 - accuracy: 0.7150 - val_loss: 0.5538 - val_accuracy: 0.7167
# Epoch 29/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5549 - accuracy: 0.7174 - val_loss: 0.5525 - val_accuracy: 0.7184
# Epoch 30/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5542 - accuracy: 0.7184 - val_loss: 0.5531 - val_accuracy: 0.7150
# Epoch 31/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5534 - accuracy: 0.7175 - val_loss: 0.5516 - val_accuracy: 0.7173
# Epoch 32/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5524 - accuracy: 0.7184 - val_loss: 0.5526 - val_accuracy: 0.7155
# Epoch 33/1000
# 51/51 [==============================] - 0s 4ms/step - loss: 0.5525 - accuracy: 0.7181 - val_loss: 0.5502 - val_accuracy: 0.7189
# Epoch 34/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5512 - accuracy: 0.7205 - val_loss: 0.5505 - val_accuracy: 0.7212
# Epoch 35/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5507 - accuracy: 0.7211 - val_loss: 0.5495 - val_accuracy: 0.7217
# Epoch 36/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5501 - accuracy: 0.7217 - val_loss: 0.5479 - val_accuracy: 0.7201
# Epoch 37/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5493 - accuracy: 0.7215 - val_loss: 0.5472 - val_accuracy: 0.7220
# Epoch 38/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5487 - accuracy: 0.7217 - val_loss: 0.5483 - val_accuracy: 0.7218
# Epoch 39/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5489 - accuracy: 0.7223 - val_loss: 0.5471 - val_accuracy: 0.7223
# Epoch 40/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5478 - accuracy: 0.7233 - val_loss: 0.5476 - val_accuracy: 0.7220
# Epoch 41/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5473 - accuracy: 0.7242 - val_loss: 0.5463 - val_accuracy: 0.7243
# Epoch 42/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5470 - accuracy: 0.7233 - val_loss: 0.5467 - val_accuracy: 0.7260
# Epoch 43/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5465 - accuracy: 0.7237 - val_loss: 0.5455 - val_accuracy: 0.7282
# Epoch 44/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5461 - accuracy: 0.7239 - val_loss: 0.5455 - val_accuracy: 0.7254
# Epoch 45/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5454 - accuracy: 0.7252 - val_loss: 0.5435 - val_accuracy: 0.7299
# Epoch 46/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5447 - accuracy: 0.7252 - val_loss: 0.5456 - val_accuracy: 0.7240
# Epoch 47/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5449 - accuracy: 0.7241 - val_loss: 0.5434 - val_accuracy: 0.7285
# Epoch 48/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5455 - accuracy: 0.7257 - val_loss: 0.5478 - val_accuracy: 0.7212
# Epoch 49/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5443 - accuracy: 0.7249 - val_loss: 0.5435 - val_accuracy: 0.7282
# Epoch 50/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5436 - accuracy: 0.7255 - val_loss: 0.5432 - val_accuracy: 0.7269
# Epoch 51/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5437 - accuracy: 0.7252 - val_loss: 0.5442 - val_accuracy: 0.7291
# Epoch 52/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5431 - accuracy: 0.7265 - val_loss: 0.5418 - val_accuracy: 0.7296
# Epoch 53/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5431 - accuracy: 0.7269 - val_loss: 0.5431 - val_accuracy: 0.7273
# Epoch 54/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5431 - accuracy: 0.7270 - val_loss: 0.5437 - val_accuracy: 0.7277
# Epoch 55/1000
# 51/51 [==============================] - 0s 3ms/step - loss: 0.5428 - accuracy: 0.7281 - val_loss: 0.5450 - val_accuracy: 0.7271
# Epoch 56/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5426 - accuracy: 0.7255 - val_loss: 0.5450 - val_accuracy: 0.7287
# Epoch 57/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5428 - accuracy: 0.7255 - val_loss: 0.5419 - val_accuracy: 0.7311
# Epoch 58/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5426 - accuracy: 0.7273 - val_loss: 0.5410 - val_accuracy: 0.7299
# Epoch 59/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5415 - accuracy: 0.7277 - val_loss: 0.5419 - val_accuracy: 0.7294
# Epoch 60/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5417 - accuracy: 0.7278 - val_loss: 0.5410 - val_accuracy: 0.7302
# Epoch 61/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5412 - accuracy: 0.7278 - val_loss: 0.5411 - val_accuracy: 0.7327
# Epoch 62/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5407 - accuracy: 0.7281 - val_loss: 0.5408 - val_accuracy: 0.7302
# Epoch 63/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5408 - accuracy: 0.7277 - val_loss: 0.5413 - val_accuracy: 0.7302
# Epoch 64/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5407 - accuracy: 0.7276 - val_loss: 0.5402 - val_accuracy: 0.7310
# Epoch 65/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5405 - accuracy: 0.7296 - val_loss: 0.5404 - val_accuracy: 0.7333
# Epoch 66/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5399 - accuracy: 0.7279 - val_loss: 0.5424 - val_accuracy: 0.7304
# Epoch 67/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5409 - accuracy: 0.7268 - val_loss: 0.5429 - val_accuracy: 0.7325
# Epoch 68/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5401 - accuracy: 0.7280 - val_loss: 0.5402 - val_accuracy: 0.7308
# Epoch 69/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5394 - accuracy: 0.7292 - val_loss: 0.5394 - val_accuracy: 0.7321
# Epoch 70/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5394 - accuracy: 0.7292 - val_loss: 0.5402 - val_accuracy: 0.7310
# Epoch 71/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5390 - accuracy: 0.7294 - val_loss: 0.5392 - val_accuracy: 0.7341
# Epoch 72/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5387 - accuracy: 0.7285 - val_loss: 0.5424 - val_accuracy: 0.7285
# Epoch 73/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5391 - accuracy: 0.7300 - val_loss: 0.5408 - val_accuracy: 0.7321
# Epoch 74/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5383 - accuracy: 0.7300 - val_loss: 0.5416 - val_accuracy: 0.7322
# Epoch 75/1000
# 51/51 [==============================] - 0s 3ms/step - loss: 0.5386 - accuracy: 0.7299 - val_loss: 0.5391 - val_accuracy: 0.7338
# Epoch 76/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5384 - accuracy: 0.7302 - val_loss: 0.5402 - val_accuracy: 0.7321
# Epoch 77/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5381 - accuracy: 0.7301 - val_loss: 0.5398 - val_accuracy: 0.7332
# Epoch 78/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5380 - accuracy: 0.7298 - val_loss: 0.5378 - val_accuracy: 0.7350
# Epoch 79/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5377 - accuracy: 0.7299 - val_loss: 0.5383 - val_accuracy: 0.7330
# Epoch 80/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5371 - accuracy: 0.7299 - val_loss: 0.5395 - val_accuracy: 0.7322
# Epoch 81/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5370 - accuracy: 0.7290 - val_loss: 0.5387 - val_accuracy: 0.7308
# Epoch 82/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5368 - accuracy: 0.7302 - val_loss: 0.5385 - val_accuracy: 0.7328
# Epoch 83/1000
# 51/51 [==============================] - 0s 6ms/step - loss: 0.5371 - accuracy: 0.7315 - val_loss: 0.5394 - val_accuracy: 0.7302
# Epoch 84/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5368 - accuracy: 0.7305 - val_loss: 0.5380 - val_accuracy: 0.7328
# Epoch 85/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5363 - accuracy: 0.7303 - val_loss: 0.5385 - val_accuracy: 0.7332
# Epoch 86/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5370 - accuracy: 0.7311 - val_loss: 0.5394 - val_accuracy: 0.7328
# Epoch 87/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5361 - accuracy: 0.7306 - val_loss: 0.5402 - val_accuracy: 0.7308
# Epoch 88/1000
# 51/51 [==============================] - 0s 2ms/step - loss: 0.5365 - accuracy: 0.7301 - val_loss: 0.5378 - val_accuracy: 0.7311
# Time taken: 10.2s

# %% [markdown]
# ## Plot performance and reports
# Here, we plot the history of the training and the peNNormance in a ROC curve

# %%
loss_accuracy_plotter(history)

fpr_nn, tpr_nn, thresholds_nn = evaluate(model, scaler, X, Y, X_train_val, Y_train_val, X_test, Y_test)
df_all['dense_NN'] = model.predict(scaler.transform(X)).round() # add prediction to array
# Out:
# 202/202 [==============================] - 0s 1ms/step
# 806/806 [==============================] - 1s 673us/step
# 202/202 [==============================] - 0s 766us/step
# 806/806 [==============================] - 1s 727us/step
# 1007/1007 [==============================] - 1s 691us/step
# Test acc score: 0.7311393977025769
# Train acc score: 0.7329633654144676
# Classification report for the test set
#               precision    recall  f1-score   support
#
#   background       0.67      0.53      0.60      2384
#       signal       0.76      0.85      0.80      4058
#
#     accuracy                           0.73      6442
#    macro avg       0.71      0.69      0.70      6442
# weighted avg       0.72      0.73      0.72      6442
#
# Classification report for the total set
#               precision    recall  f1-score   support
#
#   background       0.69      0.54      0.60     12210
#       signal       0.75      0.85      0.80     20000
#
#     accuracy                           0.73     32210
#    macro avg       0.72      0.69      0.70     32210
# weighted avg       0.73      0.73      0.72     32210
#
# Confusion matrix for total set
# [[ 6554  5656]
#  [ 2957 17043]]
# 1007/1007 [==============================] - 1s 672us/step

# %%
# add TF NN probability
y_tot_prob_NN = model.predict(scaler.transform(X))
y_tot_NN = model.predict(scaler.transform(X)).round()

cumulative_events = 0 # start counter for total number of events for which output is saved
for key in filename.keys(): # loop over samples
    df[key]['NN_output_prob'] = y_tot_prob_NN[cumulative_events:cumulative_events+len(df[key])]
    df[key]['NN_output'] = y_tot_NN[cumulative_events:cumulative_events+len(df[key])]
    cumulative_events += len(df[key]) # increment counter for total number of events
    #print(df[key]['NN_output']) # print the dataframe column NN_output

# probability and significance plots
NN_output_prob = { # dictionary containing plotting parameters for the mllll histogram
    # change plotting parameters
    'bin_width':0.1, # width of each histogram bin
    'num_bins':9, # number of histogram bins
    'xrange_min':0, # minimum on x-axis
    'xlabel':'Neural Network output', # x-axis label
}

SoverB_hist_dict = {'NN_output_prob':NN_output_prob}
plot_SoverB(df, SoverB_hist_dict)
# Out:
# 1007/1007 [==============================] - 1s 764us/step
# 1007/1007 [==============================] - 1s 695us/step

# %% [markdown]
# ## NN Hyperparameter optimization

# %%
def main():
        
    keras_pipeline = Pipeline([("scaler", StandardScaler()),
                               ("clf", keras.wrappers.scikit_learn.KerasClassifier(
                                   build_fn=make_model))
    ])
    
    param_grid = {'clf__network_layers': [(32, 32), (64, 64), (128, 128, 128)],
     'clf__batch_size': [64, 128, 256, 512],
     'clf__epochs': [5, 10, 15, 50, 100, 200],
     'clf__dropout_rate': [0.1, 0.01],
     'clf__optimizer': ['Nadam', 'Adam', 'SGD'],
     'clf__activation': ['selu', 'relu', 'tanh'],
     'clf__k_initializer': ['lecun_normal', 'normal'],
     'clf__verbose': [0]
    }
    
    rs_keras = RandomizedSearchCV(keras_pipeline,
                                  param_distributions=param_grid,
                                  cv=5, refit=True,
                                  verbose=0,
                                  n_iter=5,
                                  scoring="accuracy")
    
    history = rs_keras.fit(np.array(X_train_val),
                 np.array(Y_train_val))
    
    print('Best score obtained: {0}'.format(rs_keras.best_score_))
    print('Parameters:')
    for param, value in rs_keras.best_params_.items():
        print('\t{}: {}'.format(param, value))
    return  rs_keras  

def make_model(network_layers=[(32, 32)],
               dropout_rate=0,
               optimizer="Nadam",
               activation="selu",
               k_initializer='lecun_normal',
               n_input=NDIM,
               n_class=1):
    
    model = keras.models.Sequential()

    for index, layers in enumerate(network_layers):
        if not index:
            model.add(keras.layers.Dense(layers,
                                         input_dim=n_input,
                                         activation=activation,
                                         kernel_initializer=k_initializer))
        else:
            model.add(keras.layers.Dense(layers,
                                         kernel_initializer=k_initializer,
                                         activation=activation))
        if dropout_rate and index:
            model.add(keras.layers.AlphaDropout(dropout_rate))

    model.add(keras.layers.Dense(n_class,
                                 activation="sigmoid"))
    
    model.compile(loss='binary_crossentropy',
                  optimizer=optimizer,
                  metrics=['accuracy'])
    #print(model.summary())
    return model

do_opt = False
if (do_opt):
    if __name__ == '__main__':
        opt_model = main()

# %%
'''
Best score obtained: 0.763349506648741
Parameters:
	clf__verbose: 0
	clf__optimizer: Nadam
	clf__network_layers: (128, 128, 128)
	clf__k_initializer: normal
	clf__epochs: 200
	clf__dropout_rate: 0.1
	clf__batch_size: 256
	clf__activation: selu

'''
# Out:
# '\nBest score obtained: 0.763349506648741\nParameters:\n\tclf__verbose: 0\n\tclf__optimizer: Nadam\n\tclf__network_layers: (128, 128, 128)\n\tclf__k_initializer: normal\n\tclf__epochs: 200\n\tclf__dropout_rate: 0.1\n\tclf__batch_size: 256\n\tclf__activation: selu\n\n'

# %% [markdown]
# ## NN with dropout layer for overfit checking

# %%
# Packages for modeling
from keras import models
from keras import layers
from keras import regularizers

drop_model = models.Sequential()
drop_model.add(layers.Dense(128,  kernel_initializer='normal', activation='selu', input_shape=(NDIM,)))
drop_model.add(layers.Dropout(0.1))
drop_model.add(layers.Dense(128,  kernel_initializer='normal', activation='selu'))
drop_model.add(layers.Dropout(0.1))
drop_model.add(layers.Dense(128,  kernel_initializer='normal', activation='selu'))
drop_model.add(layers.Dropout(0.1))
drop_model.add(layers.Dense(1, kernel_initializer='normal', activation='sigmoid'))

# compile the model
drop_model.compile(optimizer='Nadam', loss='binary_crossentropy', metrics=['accuracy'])
#drop_model.compile(optimizer='Adam', loss='binary_crossentropy', metrics=['accuracy'])
# print the model summary
drop_model.summary()

# early stopping callback
from keras.callbacks import EarlyStopping
early_stopping = EarlyStopping(monitor='val_loss', patience=10, mode='min')

# Train classifier
import time
start = time.time() # time at start of whole processing

model_checkpoint = ModelCheckpoint(filepath='./models/up_NN_opt_drop_model.h5', monitor='val_loss', 
                                   verbose=0, save_best_only=True, 
                                   save_weights_only=False, mode='auto', 
                                   period=1)

drop_history = drop_model.fit(X_train_val, 
                    Y_train_val, 
                    epochs=500, 
                    batch_size=256, 
                    verbose=1, # switch to 1 for more verbosity 
                    callbacks=[early_stopping, model_checkpoint], 
                    validation_data=(X_test,Y_test))

elapsed = time.time() - start # time after whole processing
print("Time taken: "+str(round(elapsed,1))+"s") # print total time taken to process every file
# Out:
# Model: "sequential_27"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_88 (Dense)            (None, 128)               1792
#
#  dropout_3 (Dropout)         (None, 128)               0
#
#  dense_89 (Dense)            (None, 128)               16512
#
#  dropout_4 (Dropout)         (None, 128)               0
#
#  dense_90 (Dense)            (None, 128)               16512
#
#  dropout_5 (Dropout)         (None, 128)               0
#
#  dense_91 (Dense)            (None, 1)                 129
#
# =================================================================
# Total params: 34,945
# Trainable params: 34,945
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/500
# 101/101 [==============================] - 2s 6ms/step - loss: 0.6188 - accuracy: 0.6605 - val_loss: 0.6017 - val_accuracy: 0.6729
# Epoch 2/500
# 101/101 [==============================] - 0s 5ms/step - loss: 0.6060 - accuracy: 0.6728 - val_loss: 0.5944 - val_accuracy: 0.6787
# Epoch 3/500
# 101/101 [==============================] - 0s 4ms/step - loss: 0.5983 - accuracy: 0.6800 - val_loss: 0.5847 - val_accuracy: 0.6957
# Epoch 4/500
# 101/101 [==============================] - 0s 4ms/step - loss: 0.5905 - accuracy: 0.6872 - val_loss: 0.5733 - val_accuracy: 0.7034
# Epoch 5/500
# 101/101 [==============================] - 0s 4ms/step - loss: 0.5834 - accuracy: 0.6938 - val_loss: 0.5766 - val_accuracy: 0.7015
# Epoch 6/500
# 101/101 [==============================] - 0s 4ms/step - loss: 0.5813 - accuracy: 0.6969 - val_loss: 0.5672 - val_accuracy: 0.7065
# Epoch 7/500
# 101/101 [==============================] - 0s 4ms/step - loss: 0.5756 - accuracy: 0.7039 - val_loss: 0.5668 - val_accuracy: 0.7127
# Epoch 8/500
# 101/101 [==============================] - 0s 4ms/step - loss: 0.5736 - accuracy: 0.7049 - val_loss: 0.5621 - val_accuracy: 0.7189
# Epoch 9/500
# 101/101 [==============================] - 0s 4ms/step - loss: 0.5708 - accuracy: 0.7084 - val_loss: 0.5556 - val_accuracy: 0.7224
# Epoch 10/500
# 101/101 [==============================] - 0s 4ms/step - loss: 0.5682 - accuracy: 0.7110 - val_loss: 0.5512 - val_accuracy: 0.7162
# Epoch 11/500
# 101/101 [==============================] - 0s 4ms/step - loss: 0.5651 - accuracy: 0.7105 - val_loss: 0.5520 - val_accuracy: 0.7204
# Epoch 12/500
# 101/101 [==============================] - 1s 9ms/step - loss: 0.5652 - accuracy: 0.7118 - val_loss: 0.5465 - val_accuracy: 0.7252
# Epoch 13/500
# 101/101 [==============================] - 1s 6ms/step - loss: 0.5640 - accuracy: 0.7155 - val_loss: 0.5485 - val_accuracy: 0.7226
# Epoch 14/500
# 101/101 [==============================] - 1s 6ms/step - loss: 0.5631 - accuracy: 0.7160 - val_loss: 0.5497 - val_accuracy: 0.7193
# Epoch 15/500
# 101/101 [==============================] - 1s 5ms/step - loss: 0.5631 - accuracy: 0.7144 - val_loss: 0.5481 - val_accuracy: 0.7280
# Epoch 16/500
# 101/101 [==============================] - 1s 6ms/step - loss: 0.5631 - accuracy: 0.7151 - val_loss: 0.5461 - val_accuracy: 0.7283
# Epoch 17/500
# 101/101 [==============================] - 1s 5ms/step - loss: 0.5605 - accuracy: 0.7150 - val_loss: 0.5478 - val_accuracy: 0.7203
# Epoch 18/500
# 101/101 [==============================] - 0s 5ms/step - loss: 0.5599 - accuracy: 0.7150 - val_loss: 0.5436 - val_accuracy: 0.7232
# Epoch 19/500
# 101/101 [==============================] - 0s 4ms/step - loss: 0.5601 - accuracy: 0.7184 - val_loss: 0.5455 - val_accuracy: 0.7242
# Epoch 20/500
# 101/101 [==============================] - 0s 4ms/step - loss: 0.5607 - accuracy: 0.7151 - val_loss: 0.5416 - val_accuracy: 0.7291
# Epoch 21/500
# 101/101 [==============================] - 0s 4ms/step - loss: 0.5571 - accuracy: 0.7195 - val_loss: 0.5395 - val_accuracy: 0.7332
# Epoch 22/500
# 101/101 [==============================] - 0s 4ms/step - loss: 0.5583 - accuracy: 0.7182 - val_loss: 0.5432 - val_accuracy: 0.7273
# Epoch 23/500
# 101/101 [==============================] - 1s 5ms/step - loss: 0.5563 - accuracy: 0.7188 - val_loss: 0.5398 - val_accuracy: 0.7277
# Epoch 24/500
# 101/101 [==============================] - 0s 4ms/step - loss: 0.5560 - accuracy: 0.7208 - val_loss: 0.5436 - val_accuracy: 0.7302
# Epoch 25/500
# 101/101 [==============================] - 0s 4ms/step - loss: 0.5580 - accuracy: 0.7172 - val_loss: 0.5432 - val_accuracy: 0.7226
# Epoch 26/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.5573 - accuracy: 0.7187 - val_loss: 0.5405 - val_accuracy: 0.7243
# Epoch 27/500
# 101/101 [==============================] - 0s 4ms/step - loss: 0.5566 - accuracy: 0.7177 - val_loss: 0.5364 - val_accuracy: 0.7310
# Epoch 28/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.5539 - accuracy: 0.7195 - val_loss: 0.5393 - val_accuracy: 0.7324
# Epoch 29/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.5532 - accuracy: 0.7200 - val_loss: 0.5395 - val_accuracy: 0.7316
# Epoch 30/500
# 101/101 [==============================] - 0s 4ms/step - loss: 0.5541 - accuracy: 0.7211 - val_loss: 0.5359 - val_accuracy: 0.7324
# Epoch 31/500
# 101/101 [==============================] - 1s 8ms/step - loss: 0.5525 - accuracy: 0.7231 - val_loss: 0.5351 - val_accuracy: 0.7290
# Epoch 32/500
# 101/101 [==============================] - 1s 8ms/step - loss: 0.5536 - accuracy: 0.7199 - val_loss: 0.5345 - val_accuracy: 0.7338
# Epoch 33/500
# 101/101 [==============================] - 0s 4ms/step - loss: 0.5506 - accuracy: 0.7250 - val_loss: 0.5383 - val_accuracy: 0.7297
# Epoch 34/500
# 101/101 [==============================] - 1s 6ms/step - loss: 0.5525 - accuracy: 0.7187 - val_loss: 0.5328 - val_accuracy: 0.7302
# Epoch 35/500
# 101/101 [==============================] - 1s 7ms/step - loss: 0.5510 - accuracy: 0.7223 - val_loss: 0.5354 - val_accuracy: 0.7316
# Epoch 36/500
# 101/101 [==============================] - 0s 4ms/step - loss: 0.5478 - accuracy: 0.7242 - val_loss: 0.5343 - val_accuracy: 0.7346
# Epoch 37/500
# 101/101 [==============================] - 1s 5ms/step - loss: 0.5516 - accuracy: 0.7224 - val_loss: 0.5344 - val_accuracy: 0.7318
# Epoch 38/500
# 101/101 [==============================] - 0s 5ms/step - loss: 0.5494 - accuracy: 0.7239 - val_loss: 0.5329 - val_accuracy: 0.7338
# Epoch 39/500
# 101/101 [==============================] - 0s 5ms/step - loss: 0.5503 - accuracy: 0.7219 - val_loss: 0.5330 - val_accuracy: 0.7339
# Epoch 40/500
# 101/101 [==============================] - 0s 4ms/step - loss: 0.5488 - accuracy: 0.7262 - val_loss: 0.5385 - val_accuracy: 0.7352
# Epoch 41/500
# 101/101 [==============================] - 0s 4ms/step - loss: 0.5497 - accuracy: 0.7243 - val_loss: 0.5337 - val_accuracy: 0.7314
# Epoch 42/500
# 101/101 [==============================] - 0s 4ms/step - loss: 0.5496 - accuracy: 0.7244 - val_loss: 0.5353 - val_accuracy: 0.7339
# Epoch 43/500
# 101/101 [==============================] - 1s 6ms/step - loss: 0.5489 - accuracy: 0.7243 - val_loss: 0.5332 - val_accuracy: 0.7347
# Epoch 44/500
# 101/101 [==============================] - 0s 4ms/step - loss: 0.5495 - accuracy: 0.7239 - val_loss: 0.5333 - val_accuracy: 0.7327
# Time taken: 22.3s

# %%
drop_model1 = models.Sequential()
drop_model1.add(layers.Dense(32,  kernel_initializer='normal', activation='selu', input_shape=(NDIM,)))
drop_model1.add(layers.Dropout(0.1))
drop_model1.add(layers.Dense(32,  kernel_initializer='normal', activation='selu'))
drop_model1.add(layers.Dropout(0.1))
drop_model1.add(layers.Dense(1, kernel_initializer='normal', activation='sigmoid'))

# compile the model
drop_model1.compile(optimizer='Adam', loss='binary_crossentropy', metrics=['accuracy'])
# print the model summary
drop_model1.summary()

# early stopping callback
from keras.callbacks import EarlyStopping
early_stopping = EarlyStopping(monitor='val_loss', patience=10, mode='min')

# Train classifier
import time
start = time.time() # time at start of whole processing

model_checkpoint = ModelCheckpoint(filepath='./models/testup_NN_opt_drop_model.h5', monitor='val_loss', 
                                   verbose=0, save_best_only=True, 
                                   save_weights_only=False, mode='auto', 
                                   period=1)

drop_history1 = drop_model1.fit(X_train_val, 
                    Y_train_val, 
                    epochs=500, 
                    batch_size=256, 
                    verbose=1, # switch to 1 for more verbosity 
                    callbacks=[early_stopping, model_checkpoint], 
                    validation_data=(X_test,Y_test))

elapsed = time.time() - start # time after whole processing
print("Time taken: "+str(round(elapsed,1))+"s") # print total time taken to process every file
# Out:
# Model: "sequential_28"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_92 (Dense)            (None, 32)                448
#
#  dropout_6 (Dropout)         (None, 32)                0
#
#  dense_93 (Dense)            (None, 32)                1056
#
#  dropout_7 (Dropout)         (None, 32)                0
#
#  dense_94 (Dense)            (None, 1)                 33
#
# =================================================================
# Total params: 1,537
# Trainable params: 1,537
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/500
# 101/101 [==============================] - 1s 5ms/step - loss: 0.6343 - accuracy: 0.6560 - val_loss: 0.6063 - val_accuracy: 0.6701
# Epoch 2/500
# 101/101 [==============================] - 0s 2ms/step - loss: 0.6127 - accuracy: 0.6650 - val_loss: 0.6060 - val_accuracy: 0.6725
# Epoch 3/500
# 101/101 [==============================] - 0s 2ms/step - loss: 0.6113 - accuracy: 0.6660 - val_loss: 0.6049 - val_accuracy: 0.6712
# Epoch 4/500
# 101/101 [==============================] - 0s 2ms/step - loss: 0.6107 - accuracy: 0.6680 - val_loss: 0.6046 - val_accuracy: 0.6709
# Epoch 5/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.6093 - accuracy: 0.6670 - val_loss: 0.6040 - val_accuracy: 0.6739
# Epoch 6/500
# 101/101 [==============================] - 0s 2ms/step - loss: 0.6090 - accuracy: 0.6683 - val_loss: 0.6025 - val_accuracy: 0.6734
# Epoch 7/500
# 101/101 [==============================] - 0s 2ms/step - loss: 0.6079 - accuracy: 0.6679 - val_loss: 0.6002 - val_accuracy: 0.6732
# Epoch 8/500
# 101/101 [==============================] - 0s 2ms/step - loss: 0.6069 - accuracy: 0.6713 - val_loss: 0.5982 - val_accuracy: 0.6743
# Epoch 9/500
# 101/101 [==============================] - 0s 2ms/step - loss: 0.6057 - accuracy: 0.6718 - val_loss: 0.5977 - val_accuracy: 0.6756
# Epoch 10/500
# 101/101 [==============================] - 0s 2ms/step - loss: 0.6039 - accuracy: 0.6739 - val_loss: 0.5954 - val_accuracy: 0.6782
# Epoch 11/500
# 101/101 [==============================] - 0s 2ms/step - loss: 0.6017 - accuracy: 0.6777 - val_loss: 0.5931 - val_accuracy: 0.6815
# Epoch 12/500
# 101/101 [==============================] - 0s 2ms/step - loss: 0.6012 - accuracy: 0.6771 - val_loss: 0.5920 - val_accuracy: 0.6812
# Epoch 13/500
# 101/101 [==============================] - 0s 2ms/step - loss: 0.6007 - accuracy: 0.6788 - val_loss: 0.5908 - val_accuracy: 0.6838
# Epoch 14/500
# 101/101 [==============================] - 0s 2ms/step - loss: 0.5984 - accuracy: 0.6833 - val_loss: 0.5863 - val_accuracy: 0.6853
# Epoch 15/500
# 101/101 [==============================] - 0s 2ms/step - loss: 0.5968 - accuracy: 0.6824 - val_loss: 0.5856 - val_accuracy: 0.6898
# Epoch 16/500
# 101/101 [==============================] - 0s 2ms/step - loss: 0.5957 - accuracy: 0.6853 - val_loss: 0.5852 - val_accuracy: 0.6894
# Epoch 17/500
# 101/101 [==============================] - 0s 2ms/step - loss: 0.5945 - accuracy: 0.6862 - val_loss: 0.5823 - val_accuracy: 0.6911
# Epoch 18/500
# 101/101 [==============================] - 0s 2ms/step - loss: 0.5938 - accuracy: 0.6886 - val_loss: 0.5824 - val_accuracy: 0.6967
# Epoch 19/500
# 101/101 [==============================] - 0s 2ms/step - loss: 0.5937 - accuracy: 0.6848 - val_loss: 0.5786 - val_accuracy: 0.6973
# Epoch 20/500
# 101/101 [==============================] - 0s 2ms/step - loss: 0.5917 - accuracy: 0.6918 - val_loss: 0.5779 - val_accuracy: 0.6979
# Epoch 21/500
# 101/101 [==============================] - 0s 2ms/step - loss: 0.5897 - accuracy: 0.6901 - val_loss: 0.5791 - val_accuracy: 0.6967
# Epoch 22/500
# 101/101 [==============================] - 0s 2ms/step - loss: 0.5904 - accuracy: 0.6924 - val_loss: 0.5825 - val_accuracy: 0.6992
# Epoch 23/500
# 101/101 [==============================] - 0s 2ms/step - loss: 0.5901 - accuracy: 0.6902 - val_loss: 0.5783 - val_accuracy: 0.7006
# Epoch 24/500
# 101/101 [==============================] - 0s 2ms/step - loss: 0.5897 - accuracy: 0.6905 - val_loss: 0.5757 - val_accuracy: 0.7023
# Epoch 25/500
# 101/101 [==============================] - 0s 2ms/step - loss: 0.5888 - accuracy: 0.6928 - val_loss: 0.5747 - val_accuracy: 0.7049
# Epoch 26/500
# 101/101 [==============================] - 0s 2ms/step - loss: 0.5864 - accuracy: 0.6914 - val_loss: 0.5743 - val_accuracy: 0.7046
# Epoch 27/500
# 101/101 [==============================] - 0s 2ms/step - loss: 0.5889 - accuracy: 0.6937 - val_loss: 0.5746 - val_accuracy: 0.7063
# Epoch 28/500
# 101/101 [==============================] - 0s 2ms/step - loss: 0.5899 - accuracy: 0.6925 - val_loss: 0.5742 - val_accuracy: 0.7068
# Epoch 29/500
# 101/101 [==============================] - 0s 2ms/step - loss: 0.5869 - accuracy: 0.6924 - val_loss: 0.5737 - val_accuracy: 0.7035
# Epoch 30/500
# 101/101 [==============================] - 0s 2ms/step - loss: 0.5861 - accuracy: 0.6931 - val_loss: 0.5728 - val_accuracy: 0.7110
# Epoch 31/500
# 101/101 [==============================] - 0s 2ms/step - loss: 0.5854 - accuracy: 0.6949 - val_loss: 0.5726 - val_accuracy: 0.7100
# Epoch 32/500
# 101/101 [==============================] - 0s 2ms/step - loss: 0.5851 - accuracy: 0.6976 - val_loss: 0.5717 - val_accuracy: 0.7093
# Epoch 33/500
# 101/101 [==============================] - 0s 2ms/step - loss: 0.5864 - accuracy: 0.6964 - val_loss: 0.5690 - val_accuracy: 0.7080
# Epoch 34/500
# 101/101 [==============================] - 0s 2ms/step - loss: 0.5839 - accuracy: 0.6976 - val_loss: 0.5697 - val_accuracy: 0.7091
# Epoch 35/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.5853 - accuracy: 0.6999 - val_loss: 0.5681 - val_accuracy: 0.7100
# Epoch 36/500
# 101/101 [==============================] - 0s 2ms/step - loss: 0.5842 - accuracy: 0.6987 - val_loss: 0.5675 - val_accuracy: 0.7096
# Epoch 37/500
# 101/101 [==============================] - 0s 2ms/step - loss: 0.5826 - accuracy: 0.6989 - val_loss: 0.5691 - val_accuracy: 0.7153
# Epoch 38/500
# 101/101 [==============================] - 0s 2ms/step - loss: 0.5852 - accuracy: 0.6980 - val_loss: 0.5709 - val_accuracy: 0.7124
# Epoch 39/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.5817 - accuracy: 0.6975 - val_loss: 0.5739 - val_accuracy: 0.7052
# Epoch 40/500
# 101/101 [==============================] - 0s 2ms/step - loss: 0.5818 - accuracy: 0.7003 - val_loss: 0.5664 - val_accuracy: 0.7116
# Epoch 41/500
# 101/101 [==============================] - 0s 2ms/step - loss: 0.5805 - accuracy: 0.7007 - val_loss: 0.5647 - val_accuracy: 0.7130
# Epoch 42/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.5831 - accuracy: 0.6963 - val_loss: 0.5649 - val_accuracy: 0.7145
# Epoch 43/500
# 101/101 [==============================] - 0s 2ms/step - loss: 0.5809 - accuracy: 0.7006 - val_loss: 0.5674 - val_accuracy: 0.7108
# Epoch 44/500
# 101/101 [==============================] - 0s 2ms/step - loss: 0.5815 - accuracy: 0.7007 - val_loss: 0.5635 - val_accuracy: 0.7192
# Epoch 45/500
# 101/101 [==============================] - 0s 2ms/step - loss: 0.5820 - accuracy: 0.7008 - val_loss: 0.5654 - val_accuracy: 0.7144
# Epoch 46/500
# 101/101 [==============================] - 0s 2ms/step - loss: 0.5808 - accuracy: 0.6997 - val_loss: 0.5656 - val_accuracy: 0.7173
# Epoch 47/500
# 101/101 [==============================] - 0s 2ms/step - loss: 0.5821 - accuracy: 0.7003 - val_loss: 0.5673 - val_accuracy: 0.7105
# Epoch 48/500
# 101/101 [==============================] - 0s 2ms/step - loss: 0.5796 - accuracy: 0.7032 - val_loss: 0.5622 - val_accuracy: 0.7192
# Epoch 49/500
# 101/101 [==============================] - 0s 2ms/step - loss: 0.5804 - accuracy: 0.7027 - val_loss: 0.5620 - val_accuracy: 0.7148
# Epoch 50/500
# 101/101 [==============================] - 0s 2ms/step - loss: 0.5787 - accuracy: 0.7039 - val_loss: 0.5636 - val_accuracy: 0.7209
# Epoch 51/500
# 101/101 [==============================] - 0s 2ms/step - loss: 0.5794 - accuracy: 0.7031 - val_loss: 0.5647 - val_accuracy: 0.7170
# Epoch 52/500
# 101/101 [==============================] - 0s 2ms/step - loss: 0.5787 - accuracy: 0.7047 - val_loss: 0.5604 - val_accuracy: 0.7210
# Epoch 53/500
# 101/101 [==============================] - 0s 2ms/step - loss: 0.5773 - accuracy: 0.7032 - val_loss: 0.5596 - val_accuracy: 0.7183
# Epoch 54/500
# 101/101 [==============================] - 0s 2ms/step - loss: 0.5768 - accuracy: 0.7051 - val_loss: 0.5589 - val_accuracy: 0.7186
# Epoch 55/500
# 101/101 [==============================] - 0s 2ms/step - loss: 0.5785 - accuracy: 0.7032 - val_loss: 0.5613 - val_accuracy: 0.7197
# Epoch 56/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.5772 - accuracy: 0.7037 - val_loss: 0.5608 - val_accuracy: 0.7173
# Epoch 57/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.5785 - accuracy: 0.7031 - val_loss: 0.5603 - val_accuracy: 0.7179
# Epoch 58/500
# 101/101 [==============================] - 0s 2ms/step - loss: 0.5791 - accuracy: 0.7019 - val_loss: 0.5604 - val_accuracy: 0.7234
# Epoch 59/500
# 101/101 [==============================] - 0s 2ms/step - loss: 0.5775 - accuracy: 0.7027 - val_loss: 0.5604 - val_accuracy: 0.7172
# Epoch 60/500
# 101/101 [==============================] - 0s 2ms/step - loss: 0.5787 - accuracy: 0.7041 - val_loss: 0.5597 - val_accuracy: 0.7158
# Epoch 61/500
# 101/101 [==============================] - 0s 2ms/step - loss: 0.5785 - accuracy: 0.7016 - val_loss: 0.5588 - val_accuracy: 0.7176
# Epoch 62/500
# 101/101 [==============================] - 0s 2ms/step - loss: 0.5767 - accuracy: 0.7045 - val_loss: 0.5613 - val_accuracy: 0.7158
# Epoch 63/500
# 101/101 [==============================] - 0s 4ms/step - loss: 0.5764 - accuracy: 0.7041 - val_loss: 0.5574 - val_accuracy: 0.7198
# Epoch 64/500
# 101/101 [==============================] - 0s 2ms/step - loss: 0.5761 - accuracy: 0.7025 - val_loss: 0.5577 - val_accuracy: 0.7240
# Epoch 65/500
# 101/101 [==============================] - 0s 2ms/step - loss: 0.5762 - accuracy: 0.7031 - val_loss: 0.5611 - val_accuracy: 0.7141
# Epoch 66/500
# 101/101 [==============================] - 0s 2ms/step - loss: 0.5758 - accuracy: 0.7021 - val_loss: 0.5586 - val_accuracy: 0.7190
# Epoch 67/500
# 101/101 [==============================] - 0s 2ms/step - loss: 0.5767 - accuracy: 0.7049 - val_loss: 0.5607 - val_accuracy: 0.7274
# Epoch 68/500
# 101/101 [==============================] - 0s 2ms/step - loss: 0.5756 - accuracy: 0.7056 - val_loss: 0.5596 - val_accuracy: 0.7175
# Epoch 69/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.5783 - accuracy: 0.7020 - val_loss: 0.5569 - val_accuracy: 0.7176
# Epoch 70/500
# 101/101 [==============================] - 0s 2ms/step - loss: 0.5754 - accuracy: 0.7050 - val_loss: 0.5558 - val_accuracy: 0.7207
# Epoch 71/500
# 101/101 [==============================] - 0s 2ms/step - loss: 0.5736 - accuracy: 0.7080 - val_loss: 0.5572 - val_accuracy: 0.7224
# Epoch 72/500
# 101/101 [==============================] - 0s 2ms/step - loss: 0.5749 - accuracy: 0.7065 - val_loss: 0.5567 - val_accuracy: 0.7245
# Epoch 73/500
# 101/101 [==============================] - 0s 2ms/step - loss: 0.5750 - accuracy: 0.7044 - val_loss: 0.5593 - val_accuracy: 0.7186
# Epoch 74/500
# 101/101 [==============================] - 0s 2ms/step - loss: 0.5752 - accuracy: 0.7063 - val_loss: 0.5559 - val_accuracy: 0.7257
# Epoch 75/500
# 101/101 [==============================] - 0s 2ms/step - loss: 0.5731 - accuracy: 0.7067 - val_loss: 0.5544 - val_accuracy: 0.7259
# Epoch 76/500
# 101/101 [==============================] - 0s 2ms/step - loss: 0.5752 - accuracy: 0.7039 - val_loss: 0.5561 - val_accuracy: 0.7201
# Epoch 77/500
# 101/101 [==============================] - 0s 2ms/step - loss: 0.5750 - accuracy: 0.7070 - val_loss: 0.5571 - val_accuracy: 0.7195
# Epoch 78/500
# 101/101 [==============================] - 0s 2ms/step - loss: 0.5734 - accuracy: 0.7058 - val_loss: 0.5581 - val_accuracy: 0.7228
# Epoch 79/500
# 101/101 [==============================] - 0s 2ms/step - loss: 0.5759 - accuracy: 0.7031 - val_loss: 0.5560 - val_accuracy: 0.7170
# Epoch 80/500
# 101/101 [==============================] - 0s 2ms/step - loss: 0.5772 - accuracy: 0.7042 - val_loss: 0.5578 - val_accuracy: 0.7245
# Epoch 81/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.5741 - accuracy: 0.7062 - val_loss: 0.5571 - val_accuracy: 0.7248
# Epoch 82/500
# 101/101 [==============================] - 0s 2ms/step - loss: 0.5747 - accuracy: 0.7065 - val_loss: 0.5559 - val_accuracy: 0.7232
# Epoch 83/500
# 101/101 [==============================] - 0s 2ms/step - loss: 0.5750 - accuracy: 0.7070 - val_loss: 0.5540 - val_accuracy: 0.7263
# Epoch 84/500
# 101/101 [==============================] - 0s 2ms/step - loss: 0.5740 - accuracy: 0.7066 - val_loss: 0.5574 - val_accuracy: 0.7167
# Epoch 85/500
# 101/101 [==============================] - 0s 2ms/step - loss: 0.5750 - accuracy: 0.7062 - val_loss: 0.5568 - val_accuracy: 0.7235
# Epoch 86/500
# 101/101 [==============================] - 0s 2ms/step - loss: 0.5730 - accuracy: 0.7072 - val_loss: 0.5541 - val_accuracy: 0.7226
# Epoch 87/500
# 101/101 [==============================] - 0s 2ms/step - loss: 0.5740 - accuracy: 0.7053 - val_loss: 0.5533 - val_accuracy: 0.7262
# Epoch 88/500
# 101/101 [==============================] - 0s 2ms/step - loss: 0.5722 - accuracy: 0.7080 - val_loss: 0.5553 - val_accuracy: 0.7198
# Epoch 89/500
# 101/101 [==============================] - 0s 2ms/step - loss: 0.5747 - accuracy: 0.7049 - val_loss: 0.5549 - val_accuracy: 0.7217
# Epoch 90/500
# 101/101 [==============================] - 0s 2ms/step - loss: 0.5731 - accuracy: 0.7096 - val_loss: 0.5542 - val_accuracy: 0.7221
# Epoch 91/500
# 101/101 [==============================] - 0s 2ms/step - loss: 0.5725 - accuracy: 0.7056 - val_loss: 0.5556 - val_accuracy: 0.7183
# Epoch 92/500
# 101/101 [==============================] - 0s 2ms/step - loss: 0.5731 - accuracy: 0.7067 - val_loss: 0.5544 - val_accuracy: 0.7256
# Epoch 93/500
# 101/101 [==============================] - 0s 2ms/step - loss: 0.5745 - accuracy: 0.7034 - val_loss: 0.5543 - val_accuracy: 0.7245
# Epoch 94/500
# 101/101 [==============================] - 0s 2ms/step - loss: 0.5720 - accuracy: 0.7080 - val_loss: 0.5543 - val_accuracy: 0.7223
# Epoch 95/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.5748 - accuracy: 0.7056 - val_loss: 0.5535 - val_accuracy: 0.7245
# Epoch 96/500
# 101/101 [==============================] - 0s 2ms/step - loss: 0.5725 - accuracy: 0.7059 - val_loss: 0.5550 - val_accuracy: 0.7242
# Epoch 97/500
# 101/101 [==============================] - 0s 2ms/step - loss: 0.5733 - accuracy: 0.7085 - val_loss: 0.5558 - val_accuracy: 0.7200
# Time taken: 20.9s

# %%
loss_accuracy_plotter(drop_history1)
# Out:
# 202/202 [==============================] - 0s 776us/step
# 806/806 [==============================] - 1s 642us/step

# %%
loss_accuracy_plotter(drop_history)

fpr_nn_opt_drop, tpr_nn_opt_drop, thresholds_nn_opt_drop = evaluate(drop_model, scaler, X, Y, X_train_val, Y_train_val, X_test, Y_test)
df_all['dense_NN_opt_drop'] = drop_model.predict(scaler.transform(X)).round() # add prediction to array
# Out:
# 202/202 [==============================] - 0s 648us/step
# 806/806 [==============================] - 1s 748us/step
# 202/202 [==============================] - 0s 711us/step
# 806/806 [==============================] - 1s 699us/step
# 1007/1007 [==============================] - 1s 694us/step
# Test acc score: 0.7326917106488668
# Train acc score: 0.7332350201800683
# Classification report for the test set
#               precision    recall  f1-score   support
#
#   background       0.69      0.51      0.58      2384
#       signal       0.75      0.87      0.80      4058
#
#     accuracy                           0.73      6442
#    macro avg       0.72      0.69      0.69      6442
# weighted avg       0.73      0.73      0.72      6442
#
# Classification report for the total set
#               precision    recall  f1-score   support
#
#   background       0.71      0.51      0.59     12210
#       signal       0.74      0.87      0.80     20000
#
#     accuracy                           0.73     32210
#    macro avg       0.72      0.69      0.70     32210
# weighted avg       0.73      0.73      0.72     32210
#
# Confusion matrix for total set
# [[ 6169  6041]
#  [ 2555 17445]]
# 1007/1007 [==============================] - 1s 707us/step

# %%
# add TF NN probability
y_tot_prob_NN_opt_drop = drop_model.predict(scaler.transform(X))
y_tot_NN_opt_drop = drop_model.predict(scaler.transform(X)).round()

cumulative_events = 0 # start counter for total number of events for which output is saved
for key in filename.keys(): # loop over samples
    df[key]['NN_opt_drop_output_prob'] = y_tot_prob_NN_opt_drop[cumulative_events:cumulative_events+len(df[key])]
    df[key]['NN_opt_drop_output'] = y_tot_NN_opt_drop[cumulative_events:cumulative_events+len(df[key])]
    cumulative_events += len(df[key]) # increment counter for total number of events
    #print(df[key]['NN_output']) # print the dataframe column NN_output

# probability and significance plots
NN_opt_drop_output_prob = { # dictionary containing plotting parameters for the mllll histogram
    # change plotting parameters
    'bin_width':0.1, # width of each histogram bin
    'num_bins':8, # number of histogram bins
    'xrange_min':0, # minimum on x-axis
    'xlabel':'Neural Network optimized dropout', # x-axis label
}

SoverB_hist_dict = {'NN_opt_drop_output_prob':NN_opt_drop_output_prob}
plot_SoverB(df, SoverB_hist_dict)
# Out:
# 1007/1007 [==============================] - 1s 699us/step
# 1007/1007 [==============================] - 1s 1ms/step

# %% [markdown]
# ## Optimal model with early stopping

# %%
inputs = Input(shape=(NDIM,), name = 'input') 
hidden1 = Dense(128, name = 'hidden1', kernel_initializer='lecun_normal', activation='selu')(inputs)
hidden2 = Dense(128, name = 'hidden2', kernel_initializer='lecun_normal', activation='selu')(hidden1)
hidden3 = Dense(128, name = 'hidden3', kernel_initializer='lecun_normal', activation='selu')(hidden2)
outputs = Dense(1, name = 'output', kernel_initializer='lecun_normal', activation='sigmoid')(hidden3)

# create the model
opt_model = Model(inputs=inputs, outputs=outputs)
# compile the model
opt_model.compile(optimizer='Adam', loss='binary_crossentropy', metrics=['accuracy'])
# print the model summary
opt_model.summary()

# early stopping callback
from keras.callbacks import EarlyStopping
early_stopping = EarlyStopping(monitor='val_loss', patience=10, mode='min')

# model checkpoint callback
# this saves our model architecture + parameters into dense_model.h5
from keras.callbacks import ModelCheckpoint
model_checkpoint = ModelCheckpoint('./models/up_NN_opt_model.h5', monitor='val_loss', 
                                   verbose=0, save_best_only=True,                                    
                                   save_weights_only=False, mode='auto', 
                                   period=1)
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input (InputLayer)          [(None, 13)]              0
#
#  hidden1 (Dense)             (None, 128)               1792
#
#  hidden2 (Dense)             (None, 128)               16512
#
#  hidden3 (Dense)             (None, 128)               16512
#
#  output (Dense)              (None, 1)                 129
#
# =================================================================
# Total params: 34,945
# Trainable params: 34,945
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
# Train classifier
import time
start = time.time() # time at start of whole processing

opt_history = opt_model.fit(X_train_val, 
                    Y_train_val, 
                    epochs=500, 
                    batch_size=256, 
                    verbose=1, # switch to 1 for more verbosity 
                    callbacks=[early_stopping, model_checkpoint], 
                    validation_data=(X_test,Y_test))

elapsed = time.time() - start # time after whole processing
print("Time taken: "+str(round(elapsed,1))+"s") # print total time taken to process every file
# Out:
# Epoch 1/500
# 101/101 [==============================] - 1s 4ms/step - loss: 0.6053 - accuracy: 0.6789 - val_loss: 0.5794 - val_accuracy: 0.6987
# Epoch 2/500
# 101/101 [==============================] - 0s 2ms/step - loss: 0.5715 - accuracy: 0.7040 - val_loss: 0.5624 - val_accuracy: 0.7089
# Epoch 3/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.5573 - accuracy: 0.7145 - val_loss: 0.5561 - val_accuracy: 0.7203
# Epoch 4/500
# 101/101 [==============================] - 0s 2ms/step - loss: 0.5472 - accuracy: 0.7244 - val_loss: 0.5427 - val_accuracy: 0.7273
# Epoch 5/500
# 101/101 [==============================] - 0s 2ms/step - loss: 0.5432 - accuracy: 0.7258 - val_loss: 0.5434 - val_accuracy: 0.7252
# Epoch 6/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.5341 - accuracy: 0.7352 - val_loss: 0.5316 - val_accuracy: 0.7333
# Epoch 7/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.5316 - accuracy: 0.7347 - val_loss: 0.5354 - val_accuracy: 0.7288
# Epoch 8/500
# 101/101 [==============================] - 0s 2ms/step - loss: 0.5291 - accuracy: 0.7372 - val_loss: 0.5319 - val_accuracy: 0.7369
# Epoch 9/500
# 101/101 [==============================] - 0s 2ms/step - loss: 0.5244 - accuracy: 0.7391 - val_loss: 0.5337 - val_accuracy: 0.7341
# Epoch 10/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.5232 - accuracy: 0.7379 - val_loss: 0.5286 - val_accuracy: 0.7364
# Epoch 11/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.5193 - accuracy: 0.7427 - val_loss: 0.5301 - val_accuracy: 0.7336
# Epoch 12/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.5188 - accuracy: 0.7413 - val_loss: 0.5291 - val_accuracy: 0.7347
# Epoch 13/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.5128 - accuracy: 0.7445 - val_loss: 0.5278 - val_accuracy: 0.7394
# Epoch 14/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.5109 - accuracy: 0.7444 - val_loss: 0.5273 - val_accuracy: 0.7370
# Epoch 15/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.5088 - accuracy: 0.7496 - val_loss: 0.5267 - val_accuracy: 0.7387
# Epoch 16/500
# 101/101 [==============================] - 0s 4ms/step - loss: 0.5090 - accuracy: 0.7476 - val_loss: 0.5408 - val_accuracy: 0.7346
# Epoch 17/500
# 101/101 [==============================] - 0s 4ms/step - loss: 0.5072 - accuracy: 0.7508 - val_loss: 0.5231 - val_accuracy: 0.7339
# Epoch 18/500
# 101/101 [==============================] - 0s 4ms/step - loss: 0.5072 - accuracy: 0.7510 - val_loss: 0.5210 - val_accuracy: 0.7425
# Epoch 19/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.5013 - accuracy: 0.7537 - val_loss: 0.5227 - val_accuracy: 0.7412
# Epoch 20/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.4996 - accuracy: 0.7531 - val_loss: 0.5233 - val_accuracy: 0.7380
# Epoch 21/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.4975 - accuracy: 0.7575 - val_loss: 0.5303 - val_accuracy: 0.7367
# Epoch 22/500
# 101/101 [==============================] - 0s 4ms/step - loss: 0.4957 - accuracy: 0.7602 - val_loss: 0.5187 - val_accuracy: 0.7415
# Epoch 23/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.4950 - accuracy: 0.7580 - val_loss: 0.5237 - val_accuracy: 0.7401
# Epoch 24/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.4916 - accuracy: 0.7597 - val_loss: 0.5176 - val_accuracy: 0.7429
# Epoch 25/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.4919 - accuracy: 0.7591 - val_loss: 0.5124 - val_accuracy: 0.7429
# Epoch 26/500
# 101/101 [==============================] - 0s 4ms/step - loss: 0.4869 - accuracy: 0.7613 - val_loss: 0.5138 - val_accuracy: 0.7470
# Epoch 27/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.4894 - accuracy: 0.7632 - val_loss: 0.5166 - val_accuracy: 0.7405
# Epoch 28/500
# 101/101 [==============================] - 0s 2ms/step - loss: 0.4849 - accuracy: 0.7634 - val_loss: 0.5264 - val_accuracy: 0.7344
# Epoch 29/500
# 101/101 [==============================] - 0s 2ms/step - loss: 0.4814 - accuracy: 0.7651 - val_loss: 0.5228 - val_accuracy: 0.7386
# Epoch 30/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.4791 - accuracy: 0.7665 - val_loss: 0.5176 - val_accuracy: 0.7384
# Epoch 31/500
# 101/101 [==============================] - 0s 4ms/step - loss: 0.4766 - accuracy: 0.7680 - val_loss: 0.5156 - val_accuracy: 0.7417
# Epoch 32/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.4736 - accuracy: 0.7716 - val_loss: 0.5302 - val_accuracy: 0.7330
# Epoch 33/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.4746 - accuracy: 0.7720 - val_loss: 0.5117 - val_accuracy: 0.7429
# Epoch 34/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.4701 - accuracy: 0.7719 - val_loss: 0.5115 - val_accuracy: 0.7460
# Epoch 35/500
# 101/101 [==============================] - 0s 4ms/step - loss: 0.4731 - accuracy: 0.7707 - val_loss: 0.5179 - val_accuracy: 0.7439
# Epoch 36/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.4666 - accuracy: 0.7769 - val_loss: 0.5073 - val_accuracy: 0.7476
# Epoch 37/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.4677 - accuracy: 0.7737 - val_loss: 0.5032 - val_accuracy: 0.7516
# Epoch 38/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.4668 - accuracy: 0.7751 - val_loss: 0.5198 - val_accuracy: 0.7332
# Epoch 39/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.4643 - accuracy: 0.7771 - val_loss: 0.5198 - val_accuracy: 0.7425
# Epoch 40/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.4605 - accuracy: 0.7808 - val_loss: 0.5098 - val_accuracy: 0.7425
# Epoch 41/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.4537 - accuracy: 0.7849 - val_loss: 0.5317 - val_accuracy: 0.7305
# Epoch 42/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.4578 - accuracy: 0.7800 - val_loss: 0.5004 - val_accuracy: 0.7501
# Epoch 43/500
# 101/101 [==============================] - 1s 10ms/step - loss: 0.4500 - accuracy: 0.7854 - val_loss: 0.5110 - val_accuracy: 0.7515
# Epoch 44/500
# 101/101 [==============================] - 1s 6ms/step - loss: 0.4504 - accuracy: 0.7850 - val_loss: 0.5013 - val_accuracy: 0.7509
# Epoch 45/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.4531 - accuracy: 0.7835 - val_loss: 0.5163 - val_accuracy: 0.7490
# Epoch 46/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.4530 - accuracy: 0.7830 - val_loss: 0.5146 - val_accuracy: 0.7448
# Epoch 47/500
# 101/101 [==============================] - 0s 4ms/step - loss: 0.4487 - accuracy: 0.7866 - val_loss: 0.5070 - val_accuracy: 0.7482
# Epoch 48/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.4430 - accuracy: 0.7912 - val_loss: 0.5020 - val_accuracy: 0.7526
# Epoch 49/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.4436 - accuracy: 0.7891 - val_loss: 0.5070 - val_accuracy: 0.7510
# Epoch 50/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.4402 - accuracy: 0.7897 - val_loss: 0.4990 - val_accuracy: 0.7512
# Epoch 51/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.4375 - accuracy: 0.7907 - val_loss: 0.5052 - val_accuracy: 0.7495
# Epoch 52/500
# 101/101 [==============================] - 0s 2ms/step - loss: 0.4403 - accuracy: 0.7898 - val_loss: 0.5009 - val_accuracy: 0.7526
# Epoch 53/500
# 101/101 [==============================] - 0s 2ms/step - loss: 0.4340 - accuracy: 0.7961 - val_loss: 0.5093 - val_accuracy: 0.7502
# Epoch 54/500
# 101/101 [==============================] - 0s 2ms/step - loss: 0.4315 - accuracy: 0.7982 - val_loss: 0.5092 - val_accuracy: 0.7530
# Epoch 55/500
# 101/101 [==============================] - 0s 2ms/step - loss: 0.4307 - accuracy: 0.7969 - val_loss: 0.5065 - val_accuracy: 0.7535
# Epoch 56/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.4261 - accuracy: 0.7994 - val_loss: 0.5047 - val_accuracy: 0.7502
# Epoch 57/500
# 101/101 [==============================] - 0s 2ms/step - loss: 0.4247 - accuracy: 0.7998 - val_loss: 0.4992 - val_accuracy: 0.7566
# Epoch 58/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.4219 - accuracy: 0.7987 - val_loss: 0.5120 - val_accuracy: 0.7505
# Epoch 59/500
# 101/101 [==============================] - 0s 2ms/step - loss: 0.4241 - accuracy: 0.7995 - val_loss: 0.5146 - val_accuracy: 0.7510
# Epoch 60/500
# 101/101 [==============================] - 0s 3ms/step - loss: 0.4222 - accuracy: 0.8008 - val_loss: 0.5117 - val_accuracy: 0.7541
# Time taken: 19.9s

# %%
loss_accuracy_plotter(opt_history)

fpr_nn_opt, tpr_nn_opt, thresholds_nn_opt = evaluate(opt_model, scaler, X, Y, X_train_val, Y_train_val, X_test, Y_test)
df_all['dense_NN_opt'] = opt_model.predict(scaler.transform(X)).round() # add prediction to array
# Out:
# 202/202 [==============================] - 0s 694us/step
# 806/806 [==============================] - 1s 666us/step
# 202/202 [==============================] - 0s 743us/step
# 806/806 [==============================] - 1s 1ms/step
# 1007/1007 [==============================] - 1s 987us/step
# Test acc score: 0.7541136293076685
# Train acc score: 0.8059608817137535
# Classification report for the test set
#               precision    recall  f1-score   support
#
#   background       0.73      0.54      0.62      2384
#       signal       0.76      0.88      0.82      4058
#
#     accuracy                           0.75      6442
#    macro avg       0.75      0.71      0.72      6442
# weighted avg       0.75      0.75      0.74      6442
#
# Classification report for the total set
#               precision    recall  f1-score   support
#
#   background       0.81      0.60      0.69     12210
#       signal       0.79      0.91      0.85     20000
#
#     accuracy                           0.80     32210
#    macro avg       0.80      0.76      0.77     32210
# weighted avg       0.80      0.80      0.79     32210
#
# Confusion matrix for total set
# [[ 7338  4872]
#  [ 1712 18288]]
# 1007/1007 [==============================] - 1s 1ms/step

# %%
# add TF NN probability
y_tot_prob_NN_opt = opt_model.predict(scaler.transform(X))
y_tot_NN_opt = opt_model.predict(scaler.transform(X)).round()

cumulative_events = 0 # start counter for total number of events for which output is saved
for key in filename.keys(): # loop over samples
    df[key]['NN_opt_output_prob'] = y_tot_prob_NN_opt[cumulative_events:cumulative_events+len(df[key])]
    df[key]['NN_opt_output'] = y_tot_NN_opt[cumulative_events:cumulative_events+len(df[key])]
    cumulative_events += len(df[key]) # increment counter for total number of events
    #print(df[key]['NN_output']) # print the dataframe column NN_output

# probability and significance plots
NN_opt_output_prob = { # dictionary containing plotting parameters for the mllll histogram
    # change plotting parameters
    'bin_width':0.1, # width of each histogram bin
    'num_bins':8, # number of histogram bins
    'xrange_min':0, # minimum on x-axis
    'xlabel':'Neural Network optimized output', # x-axis label
}

SoverB_hist_dict = {'NN_opt_output_prob':NN_opt_output_prob}
plot_SoverB(df, SoverB_hist_dict)
# Out:
# 1007/1007 [==============================] - 1s 920us/step
# 1007/1007 [==============================] - 1s 1ms/step

# %%
# plot ROC curve
plt.plot(fpr_nn, tpr_nn, label='Neural Network') # plot neural network ROC
plt.plot(fpr_nn_opt, tpr_nn_opt, linestyle='dashed', label='Neural Network optimized') # plot neural network optimized ROC
plt.plot(fpr_nn_opt_drop, tpr_nn_opt_drop, linestyle='dashed', label='Neural Network optimized (dropout)') # plot neural network optimized and dropout ROC
plt.plot([0, 1], [0, 1], linestyle='dotted', color='grey', label='Luck') # plot diagonal line to indicate luck
plt.xlabel('False Positive Rate') # x-axis label
plt.ylabel('True Positive Rate') # y-axis label
plt.grid() # add a grid to the plot
plt.legend() # add a legend

# %%
ams_nn = AMS(tpr_nn, fpr_nn, 0.001) # get AMS for NN classifier
ams_nn_opt = AMS(tpr_nn_opt, fpr_nn_opt, 0.001) # get AMS for NN-opt classifier
ams_nn_opt_drop = AMS(tpr_nn_opt_drop, fpr_nn_opt_drop, 0.001) # get AMS for NN-opt classifier


plt.plot(thresholds_nn, ams_nn, label="Neural Netwrok")  # plot NN AMS
plt.plot(thresholds_nn_opt, ams_nn_opt, linestyle='dashed', label="Neural Netwrok optimized")  # plot NN-opt AMS
plt.plot(thresholds_nn_opt_drop, ams_nn_opt_drop, linestyle='dashed', label="Neural Netwrok optimized (dropout)")  # plot NN-opt AMS
plt.xlabel("Threshold")  # x-axis label
plt.ylabel("AMS")  # y-axis label
plt.title("AMS with $b_r=0.001$")  # add plot title
plt.legend()  # add legend

# %%
ams_nn = AMS(tpr_nn, fpr_nn, 1) # get AMS for NN classifier
ams_nn_opt = AMS(tpr_nn_opt, fpr_nn_opt, 1) # get AMS for NN-opt classifier
ams_nn_opt_drop = AMS(tpr_nn_opt_drop, fpr_nn_opt_drop, 1) # get AMS for NN-opt classifier


plt.plot(thresholds_nn, ams_nn, label="Neural Netwrok")  # plot NN AMS
plt.plot(thresholds_nn_opt, ams_nn_opt, linestyle='dashed', label="Neural Netwrok optimized")  # plot NN-opt AMS
plt.plot(thresholds_nn_opt_drop, ams_nn_opt_drop, linestyle='dashed', label="Neural Netwrok optimized (dropout)")  # plot NN-opt AMS
plt.xlabel("Threshold")  # x-axis label
plt.ylabel("AMS")  # y-axis label
plt.title("AMS with $b_r=1$")  # add plot title
plt.legend()  # add legend

# %% [markdown]
# ## Overfit checking

# %%
new_compare_train_test(model, X_train_val, Y_train_val, X_test, Y_test, 'Neural Netwrok output')
# Out:
# 308/308 [==============================] - 0s 799us/step
# 499/499 [==============================] - 0s 798us/step
# 75/75 [==============================] - 0s 756us/step
# 127/127 [==============================] - 0s 724us/step
# Signal: ks = [0.01135511] (p-value = [0.79395174], are equal = [ True])
# Background: ks = [0.01899793] (p-value = [0.48681922], are equal = [ True])

# %%
new_compare_train_test(opt_model, X_train_val, Y_train_val, X_test, Y_test, 'Neural Netwrok optimized output')
# Out:
# 308/308 [==============================] - 0s 734us/step
# 499/499 [==============================] - 0s 751us/step
# 75/75 [==============================] - 0s 736us/step
# 127/127 [==============================] - 0s 730us/step
# Signal: ks = [0.05690518] (p-value = [1.51229419e-09], are equal = [False])
# Background: ks = [0.08553888] (p-value = [1.15277954e-12], are equal = [False])

# %%
new_compare_train_test(drop_model, X_train_val, Y_train_val, X_test, Y_test, 'Neural Netwrok optimized dropoutoutput')
# Out:
# 308/308 [==============================] - 0s 744us/step
# 499/499 [==============================] - 1s 1ms/step
# 75/75 [==============================] - 0s 752us/step
# 127/127 [==============================] - 0s 730us/step
# Signal: ks = [0.01260527] (p-value = [0.6779766], are equal = [ True])
# Background: ks = [0.01266995] (p-value = [0.91373946], are equal = [ True])

# %% [markdown]
# ## Save all models

# %%
# simple NN
#model.save('models/tt_charm_NN/')
model.save('models/tt_up_NN.h5')
#new_model = keras.models.load_model('models/tt_charm_NN/')

# NN optimized 
#opt_model.save('models/tt_charm_NN_opt/')
opt_model.save('models/tt_up_NN_opt.h5')
#new_model = keras.models.load_model('models/tt_charm_NN_opt/')

# NN optimized with drop
#drop_model.save('models/tt_charm_NN_drop/')
drop_model.save('models/tt_up_NN_drop.h5')
#new_model = keras.models.load_model('models/tt_charm_NN_drop/')

# %% [markdown]
# ## Extend to the whole dataset

# %%
filename = {
    'ttbar':'/Users/mghasemi/Desktop/IPM/plotter/newtrees/ttbar.root',
    'WZ':'/Users/mghasemi/Desktop/IPM/plotter/newtrees/WZ.root',
    'ZZ':'/Users/mghasemi/Desktop/IPM/plotter/newtrees/ZZ.root',
    'signal_up':'/Users/mghasemi/Desktop/IPM/plotter/newtrees/signal_up.root'
    }

VARS = ['jetNo','jetPTLeading', 'jetETA', 'jetPHI','bjetPT', 'bjetETA',
        'elecPTLeading', 'elecETA', 'elecPHI',
        'dielecCOS', 'dielecETA', 'met','testnonTopMass', 'weight'] 

upfile = {}
params = {}
df = {}
NDIM = len(VARS)

# define trees and branches to make DataFrame
for treename in filename.keys():
    upfile[treename] = uproot.open(filename[treename])
    params[treename] = upfile[treename][treename].arrays(VARS)
    df[treename] = ak.to_dataframe(params[treename])
    # add isSignal variable
    if treename.startswith("signal"): 
        df[treename]['isSignal'] = np.ones(len(df[treename])) 
    else:
        df[treename]['isSignal'] = np.zeros(len(df[treename])) 
    tmp_dataset = df[treename].values
    X_tmp = tmp_dataset[:,0:NDIM-1]
    Y_tmp = tmp_dataset[:,NDIM]
    df[treename]['dense_NN'] = model.predict(scaler.transform(X_tmp)) # add prediction to array   
    df[treename]['dense_NN_opt'] = opt_model.predict(scaler.transform(X_tmp)) # add prediction to array
    df[treename]['dense_NN_opt_drop'] = drop_model.predict(scaler.transform(X_tmp)) # add prediction to array
    df[treename].to_csv("~/Desktop/IPM/Analysis/Dataframes/tt_up/"+treename+"_df.csv")
    

df_all = pd.concat([df[treename] for treename in filename.keys()])
dataset = df_all.values
X = dataset[:,0:NDIM-1]
Y = dataset[:,NDIM]
# Out:
# 37/37 [==============================] - 0s 1ms/step
# 37/37 [==============================] - 0s 1ms/step
# 37/37 [==============================] - 0s 879us/step
# 340/340 [==============================] - 0s 785us/step
# 340/340 [==============================] - 1s 1ms/step
# 340/340 [==============================] - 0s 976us/step
# 6/6 [==============================] - 0s 1ms/step
# 6/6 [==============================] - 0s 1ms/step
# 6/6 [==============================] - 0s 1ms/step
# 3120/3120 [==============================] - 3s 925us/step
# 3120/3120 [==============================] - 3s 1ms/step
# 3120/3120 [==============================] - 3s 1ms/step

# %%
y_pred_NN_opt = opt_model.predict(X_test).round() # make predictions on the test data
y_pred_NN_train_opt = opt_model.predict(X_train_val).round()
y_pred_NN_tot_opt = opt_model.predict(scaler.transform(X)).round()

# See how well the classifier does, Acc = correct data / tot data
print("Total accuracy", accuracy_score(Y, y_pred_NN_tot_opt))

print("Classification report for the total set")
print(classification_report(Y.round(), y_pred_NN_tot_opt.round(), target_names=['background', 'signal']))

print("Confusion matrix:\n", confusion_matrix(Y.round(), y_pred_NN_tot_opt.round()))

fpr_nn_opt_tot, tpr_nn_opt_tot, thresholds_nn_opt_tot = roc_curve(Y, y_pred_NN_tot_opt.round()) # get FPRs, TPRs and thresholds for neural network

df_all['dense_NN_opt'] = opt_model.predict(scaler.transform(X)) # add prediction to array
df_all['dense_NN'] = model.predict(scaler.transform(X)) # add prediction to array
# Out:
# 202/202 [==============================] - 0s 1ms/step
# 806/806 [==============================] - 1s 1ms/step
# 3501/3501 [==============================] - 4s 999us/step
# Total accuracy 0.8340370829948491
# Classification report for the total set
#               precision    recall  f1-score   support
#
#   background       0.35      0.60      0.44     12210
#       signal       0.95      0.86      0.90     99809
#
#     accuracy                           0.83    112019
#    macro avg       0.65      0.73      0.67    112019
# weighted avg       0.88      0.83      0.85    112019
#
# Confusion matrix:
#  [[ 7338  4872]
#  [13719 86090]]
# 3501/3501 [==============================] - 4s 1ms/step
# 3501/3501 [==============================] - 3s 722us/step

# %%
y_pred_NN_opt_fit = drop_model.predict(X_test).round() # make predictions on the test data
y_pred_NN_train_opt_fit = drop_model.predict(X_train_val).round()
y_pred_NN_tot_opt_fit = drop_model.predict(scaler.transform(X)).round()

# See how well the classifier does, Acc = correct data / tot data
print("Total accuracy", accuracy_score(Y, y_pred_NN_tot_opt_fit))

print("Classification report for the total set")
print(classification_report(Y.round(), y_pred_NN_tot_opt_fit.round(), target_names=['background', 'signal']))

print("Confusion matrix:\n", confusion_matrix(Y.round(), y_pred_NN_tot_opt_fit.round()))

fpr_nn_opt_tot_fit, tpr_nn_opt_tot_fit, thresholds_nn_opt_tot_fit = roc_curve(Y, y_pred_NN_tot_opt_fit.round()) # get FPRs, TPRs and thresholds for neural network

df_all['dense_NN_opt_drop'] = opt_model.predict(scaler.transform(X)) # add prediction to array
# Out:
# 202/202 [==============================] - 0s 2ms/step
# 806/806 [==============================] - 1s 737us/step
# 3501/3501 [==============================] - 3s 739us/step
# Total accuracy 0.8283594747319651
# Classification report for the total set
#               precision    recall  f1-score   support
#
#   background       0.32      0.51      0.39     12210
#       signal       0.93      0.87      0.90     99809
#
#     accuracy                           0.83    112019
#    macro avg       0.63      0.69      0.65    112019
# weighted avg       0.87      0.83      0.84    112019
#
# Confusion matrix:
#  [[ 6169  6041]
#  [13186 86623]]
# 3501/3501 [==============================] - 3s 827us/step

# %%
# add TF NN probability
y_TOT_prob_NN_opt = opt_model.predict(scaler.transform(X))
y_TOT_NN_opt = opt_model.predict(scaler.transform(X)).round()

cumulative_events = 0 # start counter for total number of events for which output is saved
for key in filename.keys(): # loop over samples
    df[key]['NN_opt_tot_output_prob'] = y_TOT_prob_NN_opt[cumulative_events:cumulative_events+len(df[key])]
    df[key]['NN_opt_tot_output'] = y_TOT_NN_opt[cumulative_events:cumulative_events+len(df[key])]
    cumulative_events += len(df[key]) # increment counter for total number of events
    #print(df[key]['NN_output']) # print the dataframe column NN_output

# probability and significance plots
NN_opt_tot_output_prob = { # dictionary containing plotting parameters for the mllll histogram
    # change plotting parameters
    'bin_width':0.1, # width of each histogram bin
    'num_bins':8, # number of histogram bins
    'xrange_min':0, # minimum on x-axis
    'xlabel':'Neural Network optimized output', # x-axis label
}

SoverB_hist_dict = {'NN_opt_tot_output_prob':NN_opt_tot_output_prob}
plot_SoverB(df, SoverB_hist_dict)
# Out:
# 3501/3501 [==============================] - 3s 860us/step
# 3501/3501 [==============================] - 4s 1ms/step

# %%
# add TF NN probability
y_TOT_prob_NN_opt_fit = drop_model.predict(scaler.transform(X))
y_TOT_NN_opt_fit = drop_model.predict(scaler.transform(X)).round()

cumulative_events = 0 # start counter for total number of events for which output is saved
for key in filename.keys(): # loop over samples
    df[key]['NN_opt_tot_output_prob_overfit'] = y_TOT_prob_NN_opt_fit[cumulative_events:cumulative_events+len(df[key])]
    df[key]['NN_opt_tot_output_overfit'] = y_TOT_NN_opt_fit[cumulative_events:cumulative_events+len(df[key])]
    cumulative_events += len(df[key]) # increment counter for total number of events
    #print(df[key]['NN_output']) # print the dataframe column NN_output

# probability and significance plots
NN_opt_tot_output_prob_fit = { # dictionary containing plotting parameters for the mllll histogram
    # change plotting parameters
    'bin_width':0.1, # width of each histogram bin
    'num_bins':8, # number of histogram bins
    'xrange_min':0, # minimum on x-axis
    'xlabel':'Neural Network optimized output', # x-axis label
}

SoverB_hist_dict = {'NN_opt_tot_output_prob_overfit':NN_opt_tot_output_prob_fit}
plot_SoverB(df, SoverB_hist_dict)
# Out:
# 3501/3501 [==============================] - 3s 809us/step
# 3501/3501 [==============================] - 3s 780us/step

# %%
# plot ROC curve
plt.plot(fpr_nn_opt_tot, tpr_nn_opt_tot, label='Neural Network total') # plot Neural net-opt ROC
plt.plot(fpr_nn_opt_tot_fit, tpr_nn_opt_tot_fit, label='Neural Network overfit total') # plot Neural net-opt w overfit ROC
plt.plot([0, 1], [0, 1], linestyle='dotted', color='grey', label='Luck') # plot diagonal line to indicate luck
plt.xlabel('False Positive Rate') # x-axis label
plt.ylabel('True Positive Rate') # y-axis label
plt.grid() # add a grid to the plot
plt.legend() # add a legend

# %%
#ams_rf = AMS(tpr_rf, fpr_rf, 0.001) # get AMS for random forest classifier
ams_rf_opt_tot = AMS(tpr_nn_opt_tot, fpr_nn_opt_tot, 0.001) # get AMS for random forest classifier
ams_rf_opt_tot_fit = AMS(tpr_nn_opt_tot_fit, fpr_nn_opt_tot_fit, 0.001) # get AMS for random forest classifier

plt.plot(thresholds_nn_opt_tot, ams_rf_opt_tot, label="Neural Netwrok")  # plot Random forest AMS
plt.plot(thresholds_nn_opt_tot_fit, ams_rf_opt_tot_fit, label="Neural Netwrok overfit")  # plot Random forest AMS
plt.xlabel("Threshold")  # x-axis label
plt.ylabel("AMS")  # y-axis label
plt.title("AMS with $b_r=0.001$")  # add plot title
plt.legend()  # add legend

# %% [markdown]
# ## Baysian Optimization for NN model

# %%
# Import packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from keras.models import Sequential
from keras.layers import Dense, BatchNormalization, Dropout
from keras.optimizers import Adam, SGD, RMSprop, Adadelta, Adagrad, Adamax, Nadam, Ftrl
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.wrappers.scikit_learn import KerasClassifier
from math import floor
from sklearn.metrics import make_scorer, accuracy_score
#from bayes_opt import BayesianOptimization
from kerastuner.tuners import BayesianOptimization
from sklearn.model_selection import StratifiedKFold
from keras.layers import LeakyReLU
from sklearn.model_selection import RandomizedSearchCV

LeakyReLU = LeakyReLU(alpha=0.1)
import warnings
warnings.filterwarnings('ignore')
pd.set_option("display.max_columns", None)

# Load dataset
trainSet = pd.read_csv('/Users/mghasemi/Desktop/Code-factory/Python/ML/Kaggle/competitions/Titanic/input/train.csv')
# Feature generation: training data
train = trainSet.drop(columns=['Name', 'Ticket', 'Cabin'])
train = train.dropna(axis=0)
train = pd.get_dummies(train)
# train validation split
X_train, X_val, y_train, y_val = train_test_split(train.drop(columns=['PassengerId','Survived'], axis=0),
                                                  train['Survived'],
                                                  test_size=0.2, random_state=111,
                                                  stratify=train['Survived'])                                                  

# Create function
def nn_cl_bo(neurons, activation, optimizer, learning_rate,  batch_size, epochs ):
    optimizerL = ['SGD', 'Adam', 'RMSprop', 'Adadelta', 'Adagrad', 'Adamax', 'Nadam', 'Ftrl','SGD']
    optimizerD= {'Adam':Adam(lr=learning_rate), 'SGD':SGD(lr=learning_rate),
                 'RMSprop':RMSprop(lr=learning_rate), 'Adadelta':Adadelta(lr=learning_rate),
                 'Adagrad':Adagrad(lr=learning_rate), 'Adamax':Adamax(lr=learning_rate),
                 'Nadam':Nadam(lr=learning_rate), 'Ftrl':Ftrl(lr=learning_rate)}
    activationL = ['relu', 'sigmoid', 'softplus', 'softsign', 'tanh', 'selu',
                   'elu', 'exponential', LeakyReLU,'relu']
    neurons = round(neurons)
    activation = activationL[round(activation)]
    batch_size = round(batch_size)
    epochs = round(epochs)
    def nn_cl_fun():
        opt = Adam(lr = learning_rate)
        nn = Sequential()
        nn.add(Dense(neurons, input_dim=10, activation=activation))
        nn.add(Dense(neurons, activation=activation))
        nn.add(Dense(1, activation='sigmoid'))
        nn.compile(loss='binary_crossentropy', optimizer=opt, metrics=['accuracy'])
        return nn
    es = EarlyStopping(monitor='accuracy', mode='max', verbose=0, patience=20)
    nn = KerasClassifier(build_fn=nn_cl_fun, epochs=epochs, batch_size=batch_size,
                         verbose=0)
    kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=123)
    score = cross_val_score(nn, X_train, y_train, scoring=score_acc, cv=kfold, fit_params={'callbacks':[es]}).mean()
    return score


# Set paramaters
params_nn ={
    'neurons': (10, 100),
    'activation':(0, 9),
    'optimizer':(0,7),
    'learning_rate':(0.01, 1),
    'batch_size':(200, 1000),
    'epochs':(20, 100)
}
# Run Bayesian Optimization
nn_bo = BayesianOptimization(nn_cl_bo, params_nn, random_state=111)
nn_bo.maximize(init_points=25, n_iter=4)

# %% [markdown]
# ## Add prediction to `ROOT` trees and Excel
# Here we'll add the precition we've computed to `ROOT` trees.

# %%
df_all.to_csv("~/Desktop/IPM/Analysis/Dataframes/tt_up/df_all.csv")
df_all.head()
# Out:
#                 jetNo  jetPTLeading    jetETA    jetPHI      bjetPT   bjetETA  \
# entry subentry
# 0     0             2    181.824814 -1.844300 -1.531607  163.677521 -0.187704
#       1             2    181.824814 -0.187704  1.283405  163.677521 -0.187704
# 1     0             3     67.292442  2.523575 -0.349919   32.879086  2.148290
#       1             3     67.292442 -0.431749  0.605245   32.879086  2.148290
#       2             3     67.292442  2.148290 -1.598545   32.879086  2.148290
#
#                 elecPTLeading   elecETA   elecPHI  dielecCOS  dielecETA  \
# entry subentry
# 0     0             88.220581 -1.844300 -1.531607  -0.952927   1.256450
#       1             88.220581 -0.187704  1.283405  -0.952927   1.256450
# 1     0             87.680885  2.523575 -0.349919   0.520453  -1.629848
#       1             87.680885 -0.431749  0.605245   0.520453  -1.629848
#       2             87.680885  2.148290 -1.598545   0.520453  -1.629848
#
#                       met  testnonTopMass  weight  isSignal  dense_NN  \
# entry subentry
# 0     0         63.312572      475.149068    0.74       0.0  0.351759
#       1         63.312572      475.149068    0.74       0.0  0.417365
# 1     0         32.989780      206.483257    0.74       0.0  0.538105
#       1         32.989780      206.483257    0.74       0.0  0.513391
#       2         32.989780      206.483257    0.74       0.0  0.550660
#
#                 dense_NN_opt  dense_NN_opt_drop
# entry subentry
# 0     0             0.149480           0.149480
#       1             0.308692           0.308692
# 1     0             0.168834           0.168834
#       1             0.087277           0.087277
#       2             0.177190           0.177190

# %%
with uproot.recreate("./signalC_NN_weights.root") as sig_file:    
    #sig_file['signalC_NN_weights'] = df_all
    sig_file['signalC_NN_weights'] = {"signalC_NN_weights": ak.zip({"dense_NN": df_all['dense_NN'], "dense_NN_opt": df_all['dense_NN_opt'], "dense_NN_opt_drop": df_all['dense_NN_opt_drop'], 'jetNo':df_all['jetNo'], 'jetETA':df_all['jetETA']})}    
with uproot.open("./signalC_NN_weights.root") as sig_file:
    tree = sig_file['signalC_NN_weights']
    print(tree.keys())
    print("arrays:", tree.arrays())
    print("arrays[10]",tree.arrays()[0].tolist())
    print(tree.arrays()[20])
    #sig_file['signalC_NN_weights'].show()
#df_all[df_all['entry']==10].head()
# Out:
# ['signalC_NN_weights_dense_NN', 'signalC_NN_weights_dense_NN_opt', 'signalC_NN_weights_dense_NN_opt_drop', 'signalC_NN_weights_jetNo', 'signalC_NN_weights_jetETA']
# arrays: [{signalC_NN_weights_dense_NN: 0, ...}, {...}, {...}, ..., {...}, {...}, {...}]
# arrays[10] {'signalC_NN_weights_dense_NN': 0.0, 'signalC_NN_weights_dense_NN_opt': 0.0, 'signalC_NN_weights_dense_NN_opt_drop': 0.0, 'signalC_NN_weights_jetNo': 2, 'signalC_NN_weights_jetETA': -1.844299554824829}
# {signalC_NN_weights_dense_NN: 1, signalC_NN_weights_dense_NN_opt: 1, ...}

# %%
from root_numpy import root2array, array2root


def get_features_from_file(filename='', treename='', branches=[]):
    t = root2array(filename, treename=treename, branches=branches) # structured numpy array 
    #print t.shape 
    t = t.view(np.float32).reshape(t.shape + (-1,)) # normal numpy array (trick from https://stackoverflow.com/questions/5957380/convert-structured-array-to-regular-numpy-array)
    #print t.shape
    return t

def write_prediction_to_file(features, model, filename='',treename='',branch=''):
    y_predict_all = model.predict(features) # normal numpy array
    #print y_predict_all.shape
    y_predict_all = np.array(y_predict_all, dtype=[(branch, np.float32)]) # structured numpy array
    #print y_predict_all.shape
    array2root(y_predict_all, filename, treename=treename, mode='recreate')
    
X_all = get_features_from_file('data/ntuple_4mu_VV.root', 
                               treename='HZZ4LeptonsAnalysisReduced', 
                               branches=VARS)

X_all = scaler.transform(X_all)

write_prediction_to_file(X_all, 
                         model, 
                         filename='data/ntuple_4mu_VV_predict.root', 
                         treename='HZZ4LeptonsAnalysisReduced', 
                         branch='dense')

X_all = get_features_from_file('data/ntuple_4mu_bkg.root', 
                               treename='HZZ4LeptonsAnalysisReduced', 
                               branches=VARS)

X_all = scaler.transform(X_all)

write_prediction_to_file(X_all, 
                         model, 
                         filename='data/ntuple_4mu_bkg_predict.root', 
                         treename='HZZ4LeptonsAnalysisReduced', 
                         branch='dense')

# %% [markdown]
# ## Significance

# %%
df_all[df_all['isSignal']==0]['weight'].unique()
# Out:
# array([0.74, 0.03, 0.67])

# %%
sig_weight = df_all[df_all['isSignal']==1]['weight'].unique()[0]
df_sig_75 = df_all[(df_all['dense_NN']>=0.75) & (df_all['isSignal']==1)]
n_sig_75 = df_sig_75.shape[0] * sig_weight
df_sig_80 = df_all[(df_all['dense_NN']>=0.80) & (df_all['isSignal']==1)]
n_sig_80 = df_sig_80.shape[0] * sig_weight
df_sig_85 = df_all[(df_all['dense_NN']>=0.85) & (df_all['isSignal']==1)]
n_sig_85 = df_sig_85.shape[0] * sig_weight

bkg_weights = df_all[df_all['isSignal']==0]['weight'].unique()
list_bkg_75 = [df_all[(df_all['dense_NN']>=0.75) & (df_all['isSignal']==0) & (df_all['weight'] == bkg_w)].shape[0] * bkg_w for bkg_w in bkg_weights]
list_bkg_80 = [df_all[(df_all['dense_NN']>=0.80) & (df_all['isSignal']==0) & (df_all['weight'] == bkg_w)].shape[0] * bkg_w for bkg_w in bkg_weights]
list_bkg_85 = [df_all[(df_all['dense_NN']>=0.85) & (df_all['isSignal']==0) & (df_all['weight'] == bkg_w)].shape[0] * bkg_w for bkg_w in bkg_weights]

print("75% : sig_n {:.1f}\tbkg_n {:.1f}\tsig/bkg {:.1f}".format(n_sig_75, sum(list_bkg_75), n_sig_75/sum(list_bkg_75)))
print("80% : sig_n {:.1f}\tbkg_n {:.1f}\tsig/bkg {:.1f}".format(n_sig_80, sum(list_bkg_80), n_sig_75/sum(list_bkg_80)))
print("85% : sig_n {:.1f}\tbkg_n {:.1f}\tsig/bkg {:.1f}".format(n_sig_85, sum(list_bkg_85), n_sig_75/sum(list_bkg_85)))
# Out:
# 75% : sig_n 496.9	bkg_n 348.4	sig/bkg 1.4
# 80% : sig_n 379.2	bkg_n 242.4	sig/bkg 2.0
# 85% : sig_n 252.1	bkg_n 141.2	sig/bkg 3.5
