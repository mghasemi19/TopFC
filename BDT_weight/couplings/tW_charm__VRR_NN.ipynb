# %% [markdown]
# # DNN in TopFC analysis
# Author: Meisam Ghasemi Bostanabad

# %% [markdown]
# ## Loading `pandas` DataFrames
# Now we load two different `NumPy` arrays. One corresponding to the VV signal and one corresponding to the background.

# %%
import uproot
import numpy as np
import pandas as pd
import h5py
import awkward as ak
import seaborn as sns
import matplotlib.pyplot as plt
import math
from scipy import stats


# fix random seed for reproducibility
seed = 7
np.random.seed(seed)

filename = {
    'tZ':'/Users/mghasemi/Desktop/IPM/plotter/newtrees/tW_trees/tZ.root',
    'WZ':'/Users/mghasemi/Desktop/IPM/plotter/newtrees/tW_trees/WZ.root',
    'ZZ':'/Users/mghasemi/Desktop/IPM/plotter/newtrees/tW_trees/ZZ.root',
    'signal_tW_charm_VRR':'/Users/mghasemi/Desktop/IPM/plotter/tW_trees/couplings/signal_tW_charm_VRR.root'}

upfile = {}
params = {}
df = {}

# choose which vars to use (multi dimensional)
#VARS = ['jetNo','jetPTLeading','bjetPT','elecPTLeading','met','testnonTopMass', 'weight'] # choose which vars to use (2d)
VARS = ['jetNo','jetPTLeading', 'jetETA', 'jetPHI',
        'elecPTLeading', 'elecETA', 'elecPHI',
        'dielecCOS', 'dielecETA', 'met','testnonTopMass'] # choose which vars to use (2d)

# define trees and branches to make DataFrame
for treename in filename.keys():
    upfile[treename] = uproot.open(filename[treename])
    params[treename] = upfile[treename][treename].arrays(VARS)
    df[treename] = ak.to_dataframe(params[treename])
    # add isSignal variable
    if treename.startswith("signal"): 
        df[treename]['isSignal'] = np.ones(len(df[treename])) 
    else:
        df[treename]['isSignal'] = np.zeros(len(df[treename]))

# %%
print(df['signal_tW_charm_VRR'].shape)
print(df['ZZ'].shape)
# Out:
# (106743, 12)
# (6352, 12)

# %% [markdown]
# ## Functions

# %%
# function to plot all distributions
def hist(df1, df2, cols, bins, ncols = 3):
    nrows = math.ceil(len(cols) / ncols)
    fig, ax = plt.subplots(nrows, ncols, figsize = (5 * ncols, 4.2 * nrows), sharey = False)
    for i in range(len(cols)):
        #sns.histplot(data = df, x = cols[i], bins = bins, hue = 'isSignal', palette = ['grey', 'red'], ax = ax[i // ncols, i % ncols], stat="probability")
        sns.histplot(data = df1, x = cols[i], bins = bins, color = 'red',
                      ax = ax[i // ncols, i % ncols], stat="density", label='bkg')
        sns.histplot(data = df2, x = cols[i], bins = bins, color = 'grey',
                      ax = ax[i // ncols, i % ncols], stat="density", label='sig')       
        ax[i // ncols, i % ncols].set_xlabel(cols[i])
        ax[i // ncols, i % ncols].legend()
        if i % ncols != 0:
            ax[i // ncols, i % ncols].set_ylabel(" ")
        
    plt.tight_layout()
    plt.show()


# function to make ML output and significant plot
samples =['tZ', 'WZ', 'ZZ', 'signal_tW_charm_VRR']

def plot_SoverB(data, SoverB_hist_dict):
    
    signal = r'signal_tW_charm_VRR' # which sample is the signal

    # *******************
    # general definitions (shouldn't need to change)

    for x_variable,hist in SoverB_hist_dict.items(): # access the dictionary of histograms defined in the cell above

        h_bin_width = hist['bin_width'] # get the bin width defined in the cell above
        h_num_bins = hist['num_bins'] # get the number of bins defined in the cell above
        h_xrange_min = hist['xrange_min'] # get the x-range minimum defined in the cell above
        h_xlabel = hist['xlabel'] # get the x-axis label defined in the cell above
    
        bin_edges = [ h_xrange_min + x*h_bin_width for x in range(h_num_bins+1) ] # bin limits
        bin_centres = [ h_xrange_min+h_bin_width/2 + x*h_bin_width for x in range(h_num_bins) ] # bin centres
        
        signal_x = data[signal][x_variable] # histogram the signal
    
        mc_x = [] # define list to hold the Monte Carlo histogram entries

        for s in samples: # loop over samples
            if s not in ['data', signal]: # if not data nor signal
                mc_x = [*mc_x, *data[s][x_variable] ] # append to the list of Monte Carlo histogram entries
                #test=[]; test.append(df[s]['NN_output_prob'].values)


    
    
        # *************
        # Signal and background distributions
        # *************
        distributions_axes = plt.gca() # get current axes
 
        mc_heights = distributions_axes.hist(mc_x, bins=bin_edges, color='red', 
                                             label='Total background',
                                             histtype='step', # lineplot that's unfilled
                                             density=True ) # normalize to form probability density
        signal_heights = distributions_axes.hist(signal_x, bins=bin_edges, color='blue',
                                                 label=signal, 
                                                 histtype='step', # lineplot that's unfilled
                                                 density=True, # normalize to form probability density
                                                 linestyle='--' ) # dashed line
        
        distributions_axes.set_xlim( left=bin_edges[0], right=bin_edges[-1] ) # x-limits of the distributions axes
        distributions_axes.set_ylabel('Arbitrary units' ) # y-axis label for distributions axes
        y_max = max(max(signal_heights[0]), max(mc_heights[0]) )
        #distributions_axes.set_ylim( top=max(signal_heights[0])*1.3 ) # set y-axis limits
        distributions_axes.set_ylim( top=y_max*1.2 ) # set y-axis limits
        #distributions_axes.set_ylim( top=max(signal_heights[0])*1.3 ) # set y-axis limits
        plt.title('Signal and background '+x_variable+' distributions') # add title
        distributions_axes.legend() # draw the legend
        distributions_axes.set_xlabel( h_xlabel ) # x-axis label
            
        plt.show() # show the Signal and background distributions
    
    
        # *************
        # Signal to background ratio
        # *************
        plt.figure() # start new figure
        SoverB = [] # list to hold S/B values
        for cut_value in bin_edges: # loop over bins
            #signal_weights_passing_cut = sum(data[signal][data[signal][x_variable]>cut_value].totalWeight)
            signal_weights_passing_cut = len(data[signal][data[signal][x_variable]>cut_value])
            background_weights_passing_cut = 0 # start counter for background weights passing cut
            for s in samples: # loop over samples
                if s not in ['data', signal]: # if not data nor signal
                    #background_weights_passing_cut += sum(data[s][data[s][x_variable]>cut_value].totalWeight)
                    background_weights_passing_cut += len(data[s][data[s][x_variable]>cut_value])
            if background_weights_passing_cut!=0: # some background passes cut
                SoverB_value = signal_weights_passing_cut/background_weights_passing_cut
                SoverB_percent = 100*SoverB_value # multiply by 100 for percentage
                SoverB.append(SoverB_percent) # append to list of S/B values
        
        SoverB_axes = plt.gca() # get current axes
        SoverB_axes.plot( bin_edges[:len(SoverB)], SoverB ) # plot the data points
        SoverB_axes.set_xlim( left=bin_edges[0], right=bin_edges[-1] ) # set the x-limit of the main axes
        #SoverB_axes.set_ylim( 100, 1000)
        SoverB_axes.set_ylabel( 'S/B (%)' ) # write y-axis label for main axes
        plt.title('Signal to background ratio for different '+x_variable+' cut values', family='sans-serif')
        SoverB_axes.set_xlabel( h_xlabel ) # x-axis label 
        
        plt.show() # show S/B plot
    
    return    

from sklearn.metrics import roc_curve, auc, classification_report, accuracy_score, confusion_matrix

# function to draw loss-accuracy vs epoch and ROC curve
# %matplotlib inline
def loss_accuracy_plotter(history):
    # plot loss vs epoch
    plt.figure(figsize=(15,10))
    ax = plt.subplot(2, 2, 1)
    ax.plot(history.history['loss'], label='loss')
    ax.plot(history.history['val_loss'], label='val_loss')
    ax.legend(loc="upper right")
    ax.set_title('Loss over epochs')
    ax.set_xlabel('epoch')
    ax.set_ylabel('loss')

    # plot accuracy vs epoch
    ax = plt.subplot(2, 2, 2)
    ax.plot(history.history['accuracy'], label='acc')
    ax.plot(history.history['val_accuracy'], label='val_acc')
    ax.legend(loc="lower right")
    ax.set_title('Accuracy over epochs')
    ax.set_xlabel('epoch')
    ax.set_ylabel('acc')

    # Plot ROC
    Y_predict = model.predict(X_test)
    Y_predict_train = model.predict(X_train_val)
    fpr, tpr, thresholds = roc_curve(Y_test, Y_predict)
    roc_auc = auc(fpr, tpr)
    ax = plt.subplot(2, 2, 3)
    ax.plot(fpr, tpr, lw=2, color='cyan', label='auc = %.3f' % (roc_auc))
    ax.plot([0, 1], [0, 1], linestyle='--', lw=2, color='k', label='random chance')
    ax.set_xlim([0, 1.0])
    ax.set_ylim([0, 1.0])
    ax.set_xlabel('false positive rate')
    ax.set_ylabel('true positive rate')
    ax.set_title('receiver operating curve')
    ax.legend(loc="lower right")
    plt.show()

# function to report all metrics evaluation
def evaluate(model, scaler, X, Y, X_train_val, Y_train_val, X_test, Y_test):
    Y_pred_test = model.predict(X_test)
    Y_pred_test = Y_pred_test.reshape(Y_pred_test.shape[0])
    Y_pred_train = model.predict(X_train_val)
    Y_pred_train = Y_pred_train.reshape(Y_pred_train.shape[0])
    Y_pred_tot = model.predict(scaler.transform(X)).round()
    Y_pred_tot = Y_pred_tot.reshape(Y_pred_tot.shape[0])

    # accuracy score
    print("Test acc score:", accuracy_score(Y_test.round(), Y_pred_test.round()))
    print("Train acc score:", accuracy_score(Y_train_val.round(), Y_pred_train.round()))

    # classification report for the test and total sets
    print("Classification report for the test set")
    print(classification_report(Y_test.round(), Y_pred_test.round(), target_names=['background', 'signal']))
    print("Classification report for the total set")
    print(classification_report(Y.round(), Y_pred_tot.round(), target_names=['background', 'signal']))

    print("Confusion matrix for total set")
    print(confusion_matrix(Y.round(), Y_pred_tot.round()))

    fpr, tpr, thresholds = roc_curve(Y_test, Y_pred_test) # get FPRs, TPRs and thresholds for neural network
    return fpr, tpr, thresholds

# plot AMS
def AMS(tpr, fpr, b_reg): # define function to calculate AMS
    return np.sqrt(2*((tpr+fpr+b_reg)*np.log(1+tpr/(fpr+b_reg))-tpr)) # equation for AMS

def cdf(sample, x, sort = False):
    '''
    Return the value of the Cumulative Distribution Function, evaluated for a given sample and a value x.
    
    Args:
        sample: The list or array of observations.
        x: The value for which the numerical cdf is evaluated.
    
    Returns:
        cdf = CDF_{sample}(x)
    '''
    
    # Sorts the sample, if needed
    if sort:
        sample.sort()
    
    # Counts how many observations are below x
    cdf = sum(sample <= x)
    
    # Divides by the total number of observations
    cdf = cdf / len(sample)
    
    return cdf

def ks_2samp_test(sample1, sample2):
    
    # Gets all observations
    observations = np.concatenate((sample1, sample2))
    observations.sort()
    
    # Sorts the samples
    sample1.sort()
    sample2.sort()
    
    # Evaluates the KS statistic
    D_ks = [] # KS Statistic list
    for x in observations:
        cdf_sample1 = cdf(sample = sample1, x  = x)
        cdf_sample2 = cdf(sample = sample2, x  = x)
        D_ks.append(abs(cdf_sample1 - cdf_sample2))
    ks_stat = max(D_ks)
    
    # Calculates the P-Value based on the two-sided test
    # The P-Value comes from the KS Distribution Survival Function (SF = 1-CDF)
    m, n = float(len(sample1)), float(len(sample2))
    en = m * n / (m + n)
    p_value = stats.kstwo.sf(ks_stat, np.round(en))
    
    return {"ks_stat": ks_stat, "p_value" : p_value}

# plot train and test CLF distributions
def new_compare_train_test(clf, X_train, y_train, X_test, y_test, xlabel):
    decisions = [] # list to hold decisions of classifier
    for X,y in ((X_train, y_train), (X_test, y_test)): # train and test
        d1 = clf.predict(X[y<0.5]) # background
        d2 = clf.predict(X[y>0.5]) # signal
        decisions += [d1, d2] # add to list of classifier decision

    highest_decision = max(np.max(d) for d in decisions) # get maximum score
    bin_edges = [] # list to hold bin edges
    bin_edge = -0.1 # start counter for bin_edges
    while bin_edge < highest_decision: # up to highest score
        bin_edge += 0.1 # increment
        bin_edges.append(bin_edge)

    # Training plots
    plt.hist(decisions[0], # background in train set
            bins=bin_edges, # lower and upper range of the bins
            density=True, # area under the histogram will sum to 1
            histtype='stepfilled', # lineplot that's filled
            color='blue', label='Background (train)', # Background (train)
            alpha=0.5 ) # half transparency
    plt.hist(decisions[1], # signal in train set
            bins=bin_edges, # lower and upper range of the bins
            density=True, # area under the histogram will sum to 1
            histtype='stepfilled', # lineplot that's filled
            color='orange', label='Signal (train)', # Signal (train)
            alpha=0.5 ) # half transparency

    # Testing plots
    hist_background, bin_edges = np.histogram(decisions[2], # background test
                                            bins=bin_edges, # number of bins in function definition
                                            density=True ) # area under the histogram will sum to 1

    scale = len(decisions[2]) / sum(hist_background) # between raw and normalised
    err_background = np.sqrt(hist_background * scale) / scale # error on test background

    width = 0.1 # histogram bin width
    center = (bin_edges[:-1] + bin_edges[1:]) / 2 # bin centres

    plt.errorbar(x=center, y=hist_background, yerr=err_background, fmt='o', # circles
                c='blue', label='Background (test)' ) # Background (test)

    hist_signal, bin_edges = np.histogram(decisions[3], # siganl test
                                        bins=bin_edges, # number of bins in function definition
                                        density=True ) # area under the histogram will sum to 1

    scale = len(decisions[3]) / sum(hist_signal) # between raw and normalised
    err_signal = np.sqrt(hist_signal * scale) / scale # error on test background

    plt.errorbar(x=center, y=hist_signal, yerr=err_signal, fmt='*', # circles
                c='orange', label='Signal (test)' ) # Signal (test)

    plt.xlabel(xlabel) # write x-axis label
    plt.ylabel("Arbitrary units") # write y-axis label
    plt.legend() # add legend
    ks_signal = ks_2samp_test(np.array(decisions[1]), np.array(decisions[3]))
    ks_background = ks_2samp_test(np.array(decisions[0]), np.array(decisions[2]))
    print(f"Signal: ks = {ks_signal['ks_stat']} (p-value = {ks_signal['p_value']}, are equal = {ks_signal['p_value'] > 0.05})")
    print(f"Background: ks = {ks_background['ks_stat']} (p-value = {ks_background['p_value']}, are equal = {ks_background['p_value'] > 0.05})")
    #return (decisions[0], decisions[2])

# %% [markdown]
# ## Data exploration

# %%
# reduce signal DF size to have resonable Sig/Bkg ratio
#df['signal_tW_charm_VRR'] = df['signal_tW_charm_VRR'][:20000]
df['tZ'] = df['tZ'][:40000]
df['WZ'] = df['WZ'][:30000]
df_all = pd.concat([df[treename] for treename in filename.keys()])

# %%
# number of entries in the backgrounds and signals
sns.set_theme(style="white")

tot_bkg = 0
for treename in filename.keys():
    if not 'signal' in treename: tot_bkg += df[treename].shape[0]
    print(treename, ":", df[treename].shape)

print("signal/tot bkg:", round((df['signal_tW_charm_VRR'].shape[0]/ tot_bkg),1))
#print("Null entries:", df['signal_charm'].isna().sum())

counts_signal = df['signal_tW_charm_VRR'].shape[0]
counts_background = tot_bkg

plt.figure(figsize=(8,6))
plt.pie([counts_signal, counts_background], explode=[0.1,0.1], shadow=True, labels=['Signal ','Background'], textprops={'fontsize': 14}, autopct='%1.1f%%');
#plt.pie([counts_signal, counts_background], explode=[0.1,0.1], shadow=True, labels=['Signal ','Background'], textprops={'color':"b"}, autopct='%1.1f%%');
# Out:
# tZ : (40000, 12)
# WZ : (30000, 12)
# ZZ : (6352, 12)
# signal_tW_charm_VRR : (106743, 12)
# signal/tot bkg: 1.4

# %%
plt.figure(figsize=(13,10))
#sns.set_theme(style="white")

# Getting the Upper Triangle of the co-relation matrix
corr = df_all.corr()
#matrix = np.triu(corr)
#mask = np.triu(np.ones_like(corr, dtype=bool))
matrix = np.triu(np.ones_like(corr))


cmap = sns.diverging_palette(200, 7, s=75, l=40,
                            n=5, center="light", as_cmap=True)

#sns.heatmap(df_test.corr(), annot=True, linewidth=.5, vmin = -1, vmax = 1,cmap = plt.cm.CMRmap_r, fmt=".1f", mask=matrix);
sns.heatmap(df_all.corr(), annot=True, linewidth=.5, vmin = -1, vmax = 1,cmap = cmap, fmt=".2f", mask=matrix);

# %%
df_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 183095 entries, (0, 0) to (70156, 0)
# Data columns (total 12 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   jetNo           183095 non-null  int32
#  1   jetPTLeading    183095 non-null  float64
#  2   jetETA          183095 non-null  float64
#  3   jetPHI          183095 non-null  float64
#  4   elecPTLeading   183095 non-null  float64
#  5   elecETA         183095 non-null  float64
#  6   elecPHI         183095 non-null  float64
#  7   dielecCOS       183095 non-null  float64
#  8   dielecETA       183095 non-null  float64
#  9   met             183095 non-null  float64
#  10  testnonTopMass  183095 non-null  float64
#  11  isSignal        183095 non-null  float64
# dtypes: float64(11), int32(1)
# memory usage: 19.5 MB

# %%
# Distributions of the float features
hist(df_all[df_all['isSignal']==0].replace(-999, np.nan),
     df_all[df_all['isSignal']==1].replace(-999, np.nan),
     #list(df_all.columns[df_all.dtypes == 'float64']),
     list(df_all.columns),
     bins = math.floor(len(df_all)**(1/3)),
     ncols = 3)

# %% [markdown]
# ## Define the models

# %% [markdown]
# ## simple NN from Tensorflow
# We'll start with a dense (fully-connected) NN layer.
# Our model will have a single fully-connected hidden layer with the same number of neurons as input variables.
# The weights are initialized using a small Gaussian random number.
# We will switch between linear and tanh activation functions for the hidden layer.
# The output layer contains a single neuron in order to make predictions.
# It uses the sigmoid activation function in order to produce a probability output in the range of 0 to 1.
#
# We are using the `binary_crossentropy` loss function during training, a standard loss function for binary classification problems.
# We will optimize the model with the Adam algorithm for stochastic gradient descent and we will collect accuracy metrics while the model is trained.

# %% [markdown]
# ## Dividing the data into testing and training dataset
#
# We will split the data into two parts (one for training+validation and one for testing).
# We will also apply "standard scaling" preprocessing: http://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.StandardScaler.html i.e. making the mean = 0 and the RMS = 1 for all input variables (based **only** on the training/validation dataset).
# We will also define our early stopping criteria to prevent over-fitting and we will save the model based on the best `val_loss`.

# %%
NDIM = len(VARS)
dataset = df_all.values
X = dataset[:,0:NDIM]
Y = dataset[:,NDIM]

from sklearn.model_selection import train_test_split
X_train_val, X_test, Y_train_val, Y_test = train_test_split(X, Y, test_size=0.2, random_state=7)

# preprocessing: standard scalar
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler().fit(X_train_val)
X_train_val = scaler.transform(X_train_val)
X_test = scaler.transform(X_test)

# baseline keras model
from keras.models import Sequential, Model
from tensorflow.keras.optimizers import SGD
#from keras.optimizers import SGD
from keras.layers import Input, Activation, Dense, Convolution2D, MaxPooling2D, Dropout, Flatten
from keras.utils import np_utils
from sklearn.model_selection import RandomizedSearchCV
from sklearn.pipeline import Pipeline
from tensorflow import keras

inputs = Input(shape=(NDIM,), name = 'input') 
hidden1 = Dense(20, name = 'hidden1', kernel_initializer='normal', activation='relu')(inputs)
hidden2 = Dense(20, name = 'hidden2', kernel_initializer='normal', activation='relu')(hidden1)
outputs = Dense(1, name = 'output', kernel_initializer='normal', activation='sigmoid')(hidden2)

# create the model
model = Model(inputs=inputs, outputs=outputs)
# compile the model
optimizer = SGD(learning_rate=1e-3) # define the optimizer
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
#model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])
# print the model summary
model.summary()

# early stopping callback
from keras.callbacks import EarlyStopping
early_stopping = EarlyStopping(monitor='val_loss', patience=10, mode='min')

# model checkpoint callback
# this saves our model architecture + parameters into dense_model.h5
from keras.callbacks import ModelCheckpoint
model_checkpoint = ModelCheckpoint(filepath='./models/tW_charm_SRR_model.h5', monitor='val_loss', 
                                   verbose=0, save_best_only=True, 
                                   save_weights_only=False, mode='auto', 
                                   period=1)
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input (InputLayer)          [(None, 11)]              0
#
#  hidden1 (Dense)             (None, 20)                240
#
#  hidden2 (Dense)             (None, 20)                420
#
#  output (Dense)              (None, 1)                 21
#
# =================================================================
# Total params: 681
# Trainable params: 681
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %% [markdown]
# ## Run training
# Here, we run the training.

# %%
# Train classifier
import time
start = time.time() # time at start of whole processing

history = model.fit(X_train_val, 
                    Y_train_val, 
                    epochs=1000, 
                    batch_size=512, 
                    verbose=1, # switch to 1 for more verbosity 
                    callbacks=[early_stopping, model_checkpoint], 
                    validation_data=(X_test,Y_test))

elapsed = time.time() - start # time after whole processing
print("Time taken: "+str(round(elapsed,1))+"s") # print total time taken to process every file
# Out:
# Epoch 1/1000
# 287/287 [==============================] - 2s 3ms/step - loss: 0.6541 - accuracy: 0.6194 - val_loss: 0.6332 - val_accuracy: 0.6481
# Epoch 2/1000
# 287/287 [==============================] - 2s 7ms/step - loss: 0.6302 - accuracy: 0.6512 - val_loss: 0.6278 - val_accuracy: 0.6514
# Epoch 3/1000
# 287/287 [==============================] - 2s 6ms/step - loss: 0.6256 - accuracy: 0.6548 - val_loss: 0.6237 - val_accuracy: 0.6549
# Epoch 4/1000
# 287/287 [==============================] - 1s 2ms/step - loss: 0.6227 - accuracy: 0.6561 - val_loss: 0.6223 - val_accuracy: 0.6594
# Epoch 5/1000
# 287/287 [==============================] - 1s 3ms/step - loss: 0.6209 - accuracy: 0.6582 - val_loss: 0.6200 - val_accuracy: 0.6591
# Epoch 6/1000
# 287/287 [==============================] - 1s 2ms/step - loss: 0.6197 - accuracy: 0.6589 - val_loss: 0.6192 - val_accuracy: 0.6591
# Epoch 7/1000
# 287/287 [==============================] - 1s 2ms/step - loss: 0.6184 - accuracy: 0.6599 - val_loss: 0.6177 - val_accuracy: 0.6602
# Epoch 8/1000
# 287/287 [==============================] - 1s 2ms/step - loss: 0.6172 - accuracy: 0.6600 - val_loss: 0.6169 - val_accuracy: 0.6588
# Epoch 9/1000
# 287/287 [==============================] - 1s 2ms/step - loss: 0.6158 - accuracy: 0.6615 - val_loss: 0.6153 - val_accuracy: 0.6601
# Epoch 10/1000
# 287/287 [==============================] - 1s 2ms/step - loss: 0.6141 - accuracy: 0.6629 - val_loss: 0.6137 - val_accuracy: 0.6647
# Epoch 11/1000
# 287/287 [==============================] - 0s 2ms/step - loss: 0.6124 - accuracy: 0.6633 - val_loss: 0.6126 - val_accuracy: 0.6625
# Epoch 12/1000
# 287/287 [==============================] - 1s 3ms/step - loss: 0.6109 - accuracy: 0.6652 - val_loss: 0.6093 - val_accuracy: 0.6662
# Epoch 13/1000
# 287/287 [==============================] - 1s 2ms/step - loss: 0.6091 - accuracy: 0.6661 - val_loss: 0.6083 - val_accuracy: 0.6655
# Epoch 14/1000
# 287/287 [==============================] - 1s 2ms/step - loss: 0.6070 - accuracy: 0.6680 - val_loss: 0.6058 - val_accuracy: 0.6692
# Epoch 15/1000
# 287/287 [==============================] - 0s 1ms/step - loss: 0.6053 - accuracy: 0.6690 - val_loss: 0.6037 - val_accuracy: 0.6713
# Epoch 16/1000
# 287/287 [==============================] - 0s 1ms/step - loss: 0.6040 - accuracy: 0.6707 - val_loss: 0.6021 - val_accuracy: 0.6720
# Epoch 17/1000
# 287/287 [==============================] - 0s 1ms/step - loss: 0.6027 - accuracy: 0.6727 - val_loss: 0.6010 - val_accuracy: 0.6734
# Epoch 18/1000
# 287/287 [==============================] - 1s 2ms/step - loss: 0.6019 - accuracy: 0.6735 - val_loss: 0.6007 - val_accuracy: 0.6733
# Epoch 19/1000
# 287/287 [==============================] - 2s 6ms/step - loss: 0.6013 - accuracy: 0.6737 - val_loss: 0.6000 - val_accuracy: 0.6758
# Epoch 20/1000
# 287/287 [==============================] - 2s 8ms/step - loss: 0.6004 - accuracy: 0.6751 - val_loss: 0.5998 - val_accuracy: 0.6754
# Epoch 21/1000
# 287/287 [==============================] - 2s 6ms/step - loss: 0.5999 - accuracy: 0.6756 - val_loss: 0.5984 - val_accuracy: 0.6763
# Epoch 22/1000
# 287/287 [==============================] - 1s 5ms/step - loss: 0.5992 - accuracy: 0.6759 - val_loss: 0.5989 - val_accuracy: 0.6780
# Epoch 23/1000
# 287/287 [==============================] - 3s 10ms/step - loss: 0.5990 - accuracy: 0.6768 - val_loss: 0.5979 - val_accuracy: 0.6788
# Epoch 24/1000
# 287/287 [==============================] - 2s 8ms/step - loss: 0.5983 - accuracy: 0.6770 - val_loss: 0.5980 - val_accuracy: 0.6764
# Epoch 25/1000
# 287/287 [==============================] - 1s 4ms/step - loss: 0.5981 - accuracy: 0.6774 - val_loss: 0.5970 - val_accuracy: 0.6792
# Epoch 26/1000
# 287/287 [==============================] - 2s 8ms/step - loss: 0.5977 - accuracy: 0.6780 - val_loss: 0.5966 - val_accuracy: 0.6807
# Epoch 27/1000
# 287/287 [==============================] - 3s 9ms/step - loss: 0.5972 - accuracy: 0.6777 - val_loss: 0.5961 - val_accuracy: 0.6813
# Epoch 28/1000
# 287/287 [==============================] - 2s 7ms/step - loss: 0.5971 - accuracy: 0.6780 - val_loss: 0.5968 - val_accuracy: 0.6792
# Epoch 29/1000
# 287/287 [==============================] - 2s 6ms/step - loss: 0.5968 - accuracy: 0.6786 - val_loss: 0.5966 - val_accuracy: 0.6803
# Epoch 30/1000
# 287/287 [==============================] - 1s 5ms/step - loss: 0.5965 - accuracy: 0.6790 - val_loss: 0.5969 - val_accuracy: 0.6789
# Epoch 31/1000
# 287/287 [==============================] - 2s 7ms/step - loss: 0.5964 - accuracy: 0.6787 - val_loss: 0.5965 - val_accuracy: 0.6792
# Epoch 32/1000
# 287/287 [==============================] - 2s 6ms/step - loss: 0.5960 - accuracy: 0.6796 - val_loss: 0.5961 - val_accuracy: 0.6798
# Epoch 33/1000
# 287/287 [==============================] - 1s 4ms/step - loss: 0.5957 - accuracy: 0.6788 - val_loss: 0.5961 - val_accuracy: 0.6810
# Epoch 34/1000
# 287/287 [==============================] - 4s 13ms/step - loss: 0.5956 - accuracy: 0.6797 - val_loss: 0.5956 - val_accuracy: 0.6813
# Epoch 35/1000
# 287/287 [==============================] - 2s 8ms/step - loss: 0.5955 - accuracy: 0.6796 - val_loss: 0.5952 - val_accuracy: 0.6825
# Epoch 36/1000
# 287/287 [==============================] - 1s 3ms/step - loss: 0.5951 - accuracy: 0.6793 - val_loss: 0.5952 - val_accuracy: 0.6826
# Epoch 37/1000
# 287/287 [==============================] - 0s 1ms/step - loss: 0.5950 - accuracy: 0.6799 - val_loss: 0.5953 - val_accuracy: 0.6821
# Epoch 38/1000
# 287/287 [==============================] - 0s 1ms/step - loss: 0.5947 - accuracy: 0.6794 - val_loss: 0.5950 - val_accuracy: 0.6826
# Epoch 39/1000
# 287/287 [==============================] - 1s 3ms/step - loss: 0.5946 - accuracy: 0.6811 - val_loss: 0.5947 - val_accuracy: 0.6818
# Epoch 40/1000
# 287/287 [==============================] - 1s 3ms/step - loss: 0.5945 - accuracy: 0.6807 - val_loss: 0.5953 - val_accuracy: 0.6821
# Epoch 41/1000
# 287/287 [==============================] - 0s 2ms/step - loss: 0.5943 - accuracy: 0.6802 - val_loss: 0.5942 - val_accuracy: 0.6812
# Epoch 42/1000
# 287/287 [==============================] - 1s 2ms/step - loss: 0.5940 - accuracy: 0.6806 - val_loss: 0.5945 - val_accuracy: 0.6816
# Epoch 43/1000
# 287/287 [==============================] - 1s 2ms/step - loss: 0.5938 - accuracy: 0.6810 - val_loss: 0.5940 - val_accuracy: 0.6834
# Epoch 44/1000
# 287/287 [==============================] - 0s 1ms/step - loss: 0.5938 - accuracy: 0.6811 - val_loss: 0.5939 - val_accuracy: 0.6831
# Epoch 45/1000
# 287/287 [==============================] - 0s 1ms/step - loss: 0.5934 - accuracy: 0.6807 - val_loss: 0.5955 - val_accuracy: 0.6800
# Epoch 46/1000
# 287/287 [==============================] - 1s 2ms/step - loss: 0.5936 - accuracy: 0.6813 - val_loss: 0.5963 - val_accuracy: 0.6808
# Epoch 47/1000
# 287/287 [==============================] - 0s 1ms/step - loss: 0.5933 - accuracy: 0.6819 - val_loss: 0.5941 - val_accuracy: 0.6812
# Epoch 48/1000
# 287/287 [==============================] - 1s 2ms/step - loss: 0.5931 - accuracy: 0.6811 - val_loss: 0.5944 - val_accuracy: 0.6830
# Epoch 49/1000
# 287/287 [==============================] - 0s 1ms/step - loss: 0.5930 - accuracy: 0.6822 - val_loss: 0.5942 - val_accuracy: 0.6839
# Epoch 50/1000
# 287/287 [==============================] - 0s 1ms/step - loss: 0.5926 - accuracy: 0.6826 - val_loss: 0.5934 - val_accuracy: 0.6824
# Epoch 51/1000
# 287/287 [==============================] - 0s 1ms/step - loss: 0.5927 - accuracy: 0.6830 - val_loss: 0.5935 - val_accuracy: 0.6825
# Epoch 52/1000
# 287/287 [==============================] - 0s 2ms/step - loss: 0.5927 - accuracy: 0.6820 - val_loss: 0.5932 - val_accuracy: 0.6816
# Epoch 53/1000
# 287/287 [==============================] - 0s 1ms/step - loss: 0.5921 - accuracy: 0.6829 - val_loss: 0.5935 - val_accuracy: 0.6820
# Epoch 54/1000
# 287/287 [==============================] - 0s 2ms/step - loss: 0.5921 - accuracy: 0.6826 - val_loss: 0.5925 - val_accuracy: 0.6839
# Epoch 55/1000
# 287/287 [==============================] - 1s 2ms/step - loss: 0.5919 - accuracy: 0.6829 - val_loss: 0.5929 - val_accuracy: 0.6831
# Epoch 56/1000
# 287/287 [==============================] - 0s 1ms/step - loss: 0.5920 - accuracy: 0.6836 - val_loss: 0.5928 - val_accuracy: 0.6817
# Epoch 57/1000
# 287/287 [==============================] - 0s 1ms/step - loss: 0.5916 - accuracy: 0.6832 - val_loss: 0.5923 - val_accuracy: 0.6844
# Epoch 58/1000
# 287/287 [==============================] - 0s 1ms/step - loss: 0.5915 - accuracy: 0.6836 - val_loss: 0.5924 - val_accuracy: 0.6839
# Epoch 59/1000
# 287/287 [==============================] - 1s 3ms/step - loss: 0.5915 - accuracy: 0.6831 - val_loss: 0.5936 - val_accuracy: 0.6824
# Epoch 60/1000
# 287/287 [==============================] - 1s 2ms/step - loss: 0.5914 - accuracy: 0.6832 - val_loss: 0.5918 - val_accuracy: 0.6850
# Epoch 61/1000
# 287/287 [==============================] - 1s 3ms/step - loss: 0.5910 - accuracy: 0.6831 - val_loss: 0.5917 - val_accuracy: 0.6855
# Epoch 62/1000
# 287/287 [==============================] - 0s 1ms/step - loss: 0.5909 - accuracy: 0.6832 - val_loss: 0.5919 - val_accuracy: 0.6850
# Epoch 63/1000
# 287/287 [==============================] - 0s 1ms/step - loss: 0.5909 - accuracy: 0.6838 - val_loss: 0.5918 - val_accuracy: 0.6836
# Epoch 64/1000
# 287/287 [==============================] - 0s 2ms/step - loss: 0.5908 - accuracy: 0.6838 - val_loss: 0.5915 - val_accuracy: 0.6840
# Epoch 65/1000
# 287/287 [==============================] - 1s 3ms/step - loss: 0.5905 - accuracy: 0.6836 - val_loss: 0.5923 - val_accuracy: 0.6822
# Epoch 66/1000
# 287/287 [==============================] - 1s 4ms/step - loss: 0.5905 - accuracy: 0.6842 - val_loss: 0.5908 - val_accuracy: 0.6862
# Epoch 67/1000
# 287/287 [==============================] - 1s 4ms/step - loss: 0.5905 - accuracy: 0.6836 - val_loss: 0.5910 - val_accuracy: 0.6846
# Epoch 68/1000
# 287/287 [==============================] - 1s 2ms/step - loss: 0.5903 - accuracy: 0.6846 - val_loss: 0.5907 - val_accuracy: 0.6851
# Epoch 69/1000
# 287/287 [==============================] - 1s 2ms/step - loss: 0.5901 - accuracy: 0.6845 - val_loss: 0.5907 - val_accuracy: 0.6855
# Epoch 70/1000
# 287/287 [==============================] - 0s 2ms/step - loss: 0.5901 - accuracy: 0.6834 - val_loss: 0.5914 - val_accuracy: 0.6866
# Epoch 71/1000
# 287/287 [==============================] - 0s 1ms/step - loss: 0.5900 - accuracy: 0.6847 - val_loss: 0.5905 - val_accuracy: 0.6857
# Epoch 72/1000
# 287/287 [==============================] - 0s 1ms/step - loss: 0.5898 - accuracy: 0.6841 - val_loss: 0.5903 - val_accuracy: 0.6863
# Epoch 73/1000
# 287/287 [==============================] - 0s 1ms/step - loss: 0.5898 - accuracy: 0.6845 - val_loss: 0.5904 - val_accuracy: 0.6868
# Epoch 74/1000
# 287/287 [==============================] - 0s 1ms/step - loss: 0.5898 - accuracy: 0.6840 - val_loss: 0.5921 - val_accuracy: 0.6841
# Epoch 75/1000
# 287/287 [==============================] - 0s 1ms/step - loss: 0.5896 - accuracy: 0.6843 - val_loss: 0.5903 - val_accuracy: 0.6873
# Epoch 76/1000
# 287/287 [==============================] - 0s 1ms/step - loss: 0.5897 - accuracy: 0.6841 - val_loss: 0.5911 - val_accuracy: 0.6850
# Epoch 77/1000
# 287/287 [==============================] - 0s 1ms/step - loss: 0.5897 - accuracy: 0.6838 - val_loss: 0.5901 - val_accuracy: 0.6871
# Epoch 78/1000
# 287/287 [==============================] - 0s 1ms/step - loss: 0.5896 - accuracy: 0.6844 - val_loss: 0.5910 - val_accuracy: 0.6842
# Epoch 79/1000
# 287/287 [==============================] - 0s 1ms/step - loss: 0.5893 - accuracy: 0.6838 - val_loss: 0.5902 - val_accuracy: 0.6867
# Epoch 80/1000
# 287/287 [==============================] - 0s 1ms/step - loss: 0.5894 - accuracy: 0.6844 - val_loss: 0.5900 - val_accuracy: 0.6862
# Epoch 81/1000
# 287/287 [==============================] - 0s 1ms/step - loss: 0.5895 - accuracy: 0.6842 - val_loss: 0.5903 - val_accuracy: 0.6863
# Epoch 82/1000
# 287/287 [==============================] - 0s 1ms/step - loss: 0.5894 - accuracy: 0.6843 - val_loss: 0.5899 - val_accuracy: 0.6864
# Epoch 83/1000
# 287/287 [==============================] - 0s 1ms/step - loss: 0.5890 - accuracy: 0.6842 - val_loss: 0.5895 - val_accuracy: 0.6871
# Epoch 84/1000
# 287/287 [==============================] - 0s 1ms/step - loss: 0.5891 - accuracy: 0.6846 - val_loss: 0.5899 - val_accuracy: 0.6863
# Epoch 85/1000
# 287/287 [==============================] - 0s 1ms/step - loss: 0.5891 - accuracy: 0.6845 - val_loss: 0.5895 - val_accuracy: 0.6881
# Epoch 86/1000
# 287/287 [==============================] - 0s 1ms/step - loss: 0.5887 - accuracy: 0.6846 - val_loss: 0.5900 - val_accuracy: 0.6873
# Epoch 87/1000
# 287/287 [==============================] - 0s 1ms/step - loss: 0.5890 - accuracy: 0.6851 - val_loss: 0.5906 - val_accuracy: 0.6852
# Epoch 88/1000
# 287/287 [==============================] - 0s 1ms/step - loss: 0.5887 - accuracy: 0.6847 - val_loss: 0.5898 - val_accuracy: 0.6878
# Epoch 89/1000
# 287/287 [==============================] - 0s 1ms/step - loss: 0.5890 - accuracy: 0.6847 - val_loss: 0.5897 - val_accuracy: 0.6861
# Epoch 90/1000
# 287/287 [==============================] - 0s 1ms/step - loss: 0.5886 - accuracy: 0.6847 - val_loss: 0.5894 - val_accuracy: 0.6858
# Epoch 91/1000
# 287/287 [==============================] - 1s 2ms/step - loss: 0.5886 - accuracy: 0.6849 - val_loss: 0.5898 - val_accuracy: 0.6870
# Epoch 92/1000
# 287/287 [==============================] - 0s 2ms/step - loss: 0.5886 - accuracy: 0.6844 - val_loss: 0.5896 - val_accuracy: 0.6875
# Epoch 93/1000
# 287/287 [==============================] - 1s 2ms/step - loss: 0.5885 - accuracy: 0.6848 - val_loss: 0.5906 - val_accuracy: 0.6849
# Epoch 94/1000
# 287/287 [==============================] - 1s 2ms/step - loss: 0.5885 - accuracy: 0.6856 - val_loss: 0.5897 - val_accuracy: 0.6869
# Epoch 95/1000
# 287/287 [==============================] - 1s 2ms/step - loss: 0.5884 - accuracy: 0.6852 - val_loss: 0.5892 - val_accuracy: 0.6876
# Epoch 96/1000
# 287/287 [==============================] - 1s 2ms/step - loss: 0.5882 - accuracy: 0.6857 - val_loss: 0.5891 - val_accuracy: 0.6889
# Epoch 97/1000
# 287/287 [==============================] - 1s 2ms/step - loss: 0.5884 - accuracy: 0.6851 - val_loss: 0.5912 - val_accuracy: 0.6846
# Epoch 98/1000
# 287/287 [==============================] - 0s 2ms/step - loss: 0.5881 - accuracy: 0.6856 - val_loss: 0.5904 - val_accuracy: 0.6866
# Epoch 99/1000
# 287/287 [==============================] - 1s 3ms/step - loss: 0.5882 - accuracy: 0.6861 - val_loss: 0.5895 - val_accuracy: 0.6885
# Epoch 100/1000
# 287/287 [==============================] - 1s 3ms/step - loss: 0.5880 - accuracy: 0.6851 - val_loss: 0.5896 - val_accuracy: 0.6867
# Epoch 101/1000
# 287/287 [==============================] - 1s 3ms/step - loss: 0.5882 - accuracy: 0.6850 - val_loss: 0.5893 - val_accuracy: 0.6884
# Epoch 102/1000
# 287/287 [==============================] - 1s 3ms/step - loss: 0.5879 - accuracy: 0.6858 - val_loss: 0.5890 - val_accuracy: 0.6888
# Epoch 103/1000
# 287/287 [==============================] - 0s 2ms/step - loss: 0.5881 - accuracy: 0.6857 - val_loss: 0.5893 - val_accuracy: 0.6877
# Epoch 104/1000
# 287/287 [==============================] - 0s 2ms/step - loss: 0.5880 - accuracy: 0.6851 - val_loss: 0.5892 - val_accuracy: 0.6875
# Epoch 105/1000
# 287/287 [==============================] - 1s 3ms/step - loss: 0.5879 - accuracy: 0.6856 - val_loss: 0.5886 - val_accuracy: 0.6895
# Epoch 106/1000
# 287/287 [==============================] - 1s 4ms/step - loss: 0.5877 - accuracy: 0.6861 - val_loss: 0.5885 - val_accuracy: 0.6880
# Epoch 107/1000
# 287/287 [==============================] - 1s 3ms/step - loss: 0.5878 - accuracy: 0.6857 - val_loss: 0.5894 - val_accuracy: 0.6862
# Epoch 108/1000
# 287/287 [==============================] - 1s 4ms/step - loss: 0.5876 - accuracy: 0.6861 - val_loss: 0.5891 - val_accuracy: 0.6874
# Epoch 109/1000
# 287/287 [==============================] - 1s 2ms/step - loss: 0.5876 - accuracy: 0.6861 - val_loss: 0.5891 - val_accuracy: 0.6888
# Epoch 110/1000
# 287/287 [==============================] - 1s 2ms/step - loss: 0.5876 - accuracy: 0.6865 - val_loss: 0.5886 - val_accuracy: 0.6885
# Epoch 111/1000
# 287/287 [==============================] - 0s 2ms/step - loss: 0.5874 - accuracy: 0.6861 - val_loss: 0.5888 - val_accuracy: 0.6879
# Epoch 112/1000
# 287/287 [==============================] - 0s 2ms/step - loss: 0.5875 - accuracy: 0.6860 - val_loss: 0.5887 - val_accuracy: 0.6890
# Epoch 113/1000
# 287/287 [==============================] - 0s 1ms/step - loss: 0.5873 - accuracy: 0.6864 - val_loss: 0.5890 - val_accuracy: 0.6889
# Epoch 114/1000
# 287/287 [==============================] - 0s 1ms/step - loss: 0.5872 - accuracy: 0.6865 - val_loss: 0.5898 - val_accuracy: 0.6872
# Epoch 115/1000
# 287/287 [==============================] - 0s 1ms/step - loss: 0.5872 - accuracy: 0.6869 - val_loss: 0.5888 - val_accuracy: 0.6879
# Epoch 116/1000
# 287/287 [==============================] - 0s 1ms/step - loss: 0.5875 - accuracy: 0.6862 - val_loss: 0.5889 - val_accuracy: 0.6859
# Time taken: 93.5s

# %% [markdown]
# ## Plot performance and reports
# Here, we plot the history of the training and the peNNormance in a ROC curve

# %%
loss_accuracy_plotter(history)

fpr_nn, tpr_nn, thresholds_nn = evaluate(model, scaler, X, Y, X_train_val, Y_train_val, X_test, Y_test)
df_all['dense_NN'] = model.predict(scaler.transform(X)).round() # add prediction to array
# Out:
# 1145/1145 [==============================] - 1s 695us/step
# 4578/4578 [==============================] - 3s 694us/step
# 1145/1145 [==============================] - 1s 777us/step
# 4578/4578 [==============================] - 4s 820us/step
# 5722/5722 [==============================] - 5s 799us/step
# Test acc score: 0.6858734536715912
# Train acc score: 0.6855252737649854
# Classification report for the test set
#               precision    recall  f1-score   support
#
#   background       0.67      0.48      0.56     15200
#       signal       0.69      0.83      0.76     21419
#
#     accuracy                           0.69     36619
#    macro avg       0.68      0.66      0.66     36619
# weighted avg       0.68      0.69      0.67     36619
#
# Classification report for the total set
#               precision    recall  f1-score   support
#
#   background       0.67      0.48      0.56     76352
#       signal       0.69      0.83      0.75    106743
#
#     accuracy                           0.69    183095
#    macro avg       0.68      0.66      0.66    183095
# weighted avg       0.68      0.69      0.67    183095
#
# Confusion matrix for total set
# [[37006 39346]
#  [18220 88523]]
# 5722/5722 [==============================] - 5s 802us/step

# %%
# add TF NN probability
y_tot_prob_NN = model.predict(scaler.transform(X))
y_tot_NN = model.predict(scaler.transform(X)).round()

cumulative_events = 0 # start counter for total number of events for which output is saved
for key in filename.keys(): # loop over samples
    df[key]['NN_output_prob'] = y_tot_prob_NN[cumulative_events:cumulative_events+len(df[key])]
    df[key]['NN_output'] = y_tot_NN[cumulative_events:cumulative_events+len(df[key])]
    cumulative_events += len(df[key]) # increment counter for total number of events
    #print(df[key]['NN_output']) # print the dataframe column NN_output

# probability and significance plots
NN_output_prob = { # dictionary containing plotting parameters for the mllll histogram
    # change plotting parameters
    'bin_width':0.1, # width of each histogram bin
    'num_bins':9, # number of histogram bins
    'xrange_min':0, # minimum on x-axis
    'xlabel':'Neural Network output', # x-axis label
}

SoverB_hist_dict = {'NN_output_prob':NN_output_prob}
plot_SoverB(df, SoverB_hist_dict)
# Out:
# 5722/5722 [==============================] - 5s 821us/step
# 5722/5722 [==============================] - 5s 814us/step

# %% [markdown]
# ## NN Hyperparameter optimization

# %%
def main():
        
    keras_pipeline = Pipeline([("scaler", StandardScaler()),
                               ("clf", keras.wrappers.scikit_learn.KerasClassifier(
                                   build_fn=make_model))
    ])
    
    param_grid = {'clf__network_layers': [(32, 32), (64, 64), (128, 128, 128)],
     'clf__batch_size': [64, 128, 256, 512],
     'clf__epochs': [5, 10, 15, 50, 100, 200],
     'clf__dropout_rate': [0.1, 0.01],
     'clf__optimizer': ['Nadam', 'Adam', 'SGD'],
     'clf__activation': ['selu', 'relu', 'tanh'],
     'clf__k_initializer': ['lecun_normal', 'normal'],
     'clf__verbose': [0]
    }
    
    rs_keras = RandomizedSearchCV(keras_pipeline,
                                  param_distributions=param_grid,
                                  cv=5, refit=True,
                                  verbose=0,
                                  n_iter=5,
                                  scoring="accuracy")
    
    history = rs_keras.fit(np.array(X_train_val),
                 np.array(Y_train_val))
    
    print('Best score obtained: {0}'.format(rs_keras.best_score_))
    print('Parameters:')
    for param, value in rs_keras.best_params_.items():
        print('\t{}: {}'.format(param, value))
    return  rs_keras  

def make_model(network_layers=[(32, 32)],
               dropout_rate=0,
               optimizer="Nadam",
               activation="selu",
               k_initializer='lecun_normal',
               n_input=NDIM,
               n_class=1):
    
    model = keras.models.Sequential()

    for index, layers in enumerate(network_layers):
        if not index:
            model.add(keras.layers.Dense(layers,
                                         input_dim=n_input,
                                         activation=activation,
                                         kernel_initializer=k_initializer))
        else:
            model.add(keras.layers.Dense(layers,
                                         kernel_initializer=k_initializer,
                                         activation=activation))
        if dropout_rate and index:
            model.add(keras.layers.AlphaDropout(dropout_rate))

    model.add(keras.layers.Dense(n_class,
                                 activation="sigmoid"))
    
    model.compile(loss='binary_crossentropy',
                  optimizer=optimizer,
                  metrics=['accuracy'])
    #print(model.summary())
    return model

do_opt = False
if (do_opt):
    if __name__ == '__main__':
        opt_model = main()

# %%
'''
Best score obtained: 0.6758319405666599
Parameters:
	clf__verbose: 0
	clf__optimizer: Nadam
	clf__network_layers: (128, 128, 128)
	clf__k_initializer: normal
	clf__epochs: 200
	clf__dropout_rate: 0.1
	clf__batch_size: 256
	clf__activation: selu
'''
# Out:
# '\nBest score obtained: 0.6758319405666599\nParameters:\n\tclf__verbose: 0\n\tclf__optimizer: Nadam\n\tclf__network_layers: (128, 128, 128)\n\tclf__k_initializer: normal\n\tclf__epochs: 200\n\tclf__dropout_rate: 0.1\n\tclf__batch_size: 256\n\tclf__activation: selu\n'

# %% [markdown]
# ## NN with dropout layer for overfit checking

# %%
# Packages for modeling
from keras import models
from keras import layers
from keras import regularizers

drop_model = models.Sequential()
drop_model.add(layers.Dense(128,  kernel_initializer='normal', activation='selu', input_shape=(NDIM,)))
drop_model.add(layers.Dropout(0.1))
drop_model.add(layers.Dense(128,  kernel_initializer='normal', activation='selu'))
drop_model.add(layers.Dropout(0.1))
drop_model.add(layers.Dense(128,  kernel_initializer='normal', activation='selu'))
drop_model.add(layers.Dropout(0.1))
drop_model.add(layers.Dense(1, kernel_initializer='normal', activation='sigmoid'))

# compile the model
drop_model.compile(optimizer='Nadam', loss='binary_crossentropy', metrics=['accuracy'])
#drop_model.compile(optimizer='Adam', loss='binary_crossentropy', metrics=['accuracy'])
# print the model summary
drop_model.summary()

# early stopping callback
from keras.callbacks import EarlyStopping
early_stopping = EarlyStopping(monitor='val_loss', patience=10, mode='min')

# Train classifier
import time
start = time.time() # time at start of whole processing

model_checkpoint = ModelCheckpoint(filepath='./models/up_NN_opt_drop_model.h5', monitor='val_loss', 
                                   verbose=0, save_best_only=True, 
                                   save_weights_only=False, mode='auto', 
                                   period=1)

drop_history = drop_model.fit(X_train_val, 
                    Y_train_val, 
                    epochs=200, 
                    batch_size=256, 
                    verbose=1, # switch to 1 for more verbosity 
                    callbacks=[early_stopping, model_checkpoint], 
                    validation_data=(X_test,Y_test))

elapsed = time.time() - start # time after whole processing
print("Time taken: "+str(round(elapsed,1))+"s") # print total time taken to process every file
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 128)               1536
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 128)               16512
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_2 (Dense)             (None, 128)               16512
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  dense_3 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 34,689
# Trainable params: 34,689
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/200
# 573/573 [==============================] - 4s 5ms/step - loss: 0.6403 - accuracy: 0.6422 - val_loss: 0.6320 - val_accuracy: 0.6517
# Epoch 2/200
# 573/573 [==============================] - 3s 4ms/step - loss: 0.6284 - accuracy: 0.6520 - val_loss: 0.6208 - val_accuracy: 0.6595
# Epoch 3/200
# 573/573 [==============================] - 3s 4ms/step - loss: 0.6235 - accuracy: 0.6557 - val_loss: 0.6254 - val_accuracy: 0.6560
# Epoch 4/200
# 573/573 [==============================] - 3s 5ms/step - loss: 0.6215 - accuracy: 0.6561 - val_loss: 0.6145 - val_accuracy: 0.6621
# Epoch 5/200
# 573/573 [==============================] - 3s 4ms/step - loss: 0.6192 - accuracy: 0.6585 - val_loss: 0.6139 - val_accuracy: 0.6653
# Epoch 6/200
# 573/573 [==============================] - 3s 4ms/step - loss: 0.6173 - accuracy: 0.6592 - val_loss: 0.6105 - val_accuracy: 0.6673
# Epoch 7/200
# 573/573 [==============================] - 3s 4ms/step - loss: 0.6159 - accuracy: 0.6611 - val_loss: 0.6096 - val_accuracy: 0.6668
# Epoch 8/200
# 573/573 [==============================] - 3s 4ms/step - loss: 0.6144 - accuracy: 0.6630 - val_loss: 0.6104 - val_accuracy: 0.6659
# Epoch 9/200
# 573/573 [==============================] - 2s 4ms/step - loss: 0.6133 - accuracy: 0.6634 - val_loss: 0.6083 - val_accuracy: 0.6685
# Epoch 10/200
# 573/573 [==============================] - 2s 4ms/step - loss: 0.6124 - accuracy: 0.6651 - val_loss: 0.6064 - val_accuracy: 0.6676
# Epoch 11/200
# 573/573 [==============================] - 3s 4ms/step - loss: 0.6111 - accuracy: 0.6661 - val_loss: 0.6046 - val_accuracy: 0.6718
# Epoch 12/200
# 573/573 [==============================] - 2s 4ms/step - loss: 0.6097 - accuracy: 0.6667 - val_loss: 0.6031 - val_accuracy: 0.6751
# Epoch 13/200
# 573/573 [==============================] - 3s 4ms/step - loss: 0.6089 - accuracy: 0.6680 - val_loss: 0.6034 - val_accuracy: 0.6758
# Epoch 14/200
# 573/573 [==============================] - 3s 4ms/step - loss: 0.6076 - accuracy: 0.6689 - val_loss: 0.6030 - val_accuracy: 0.6761
# Epoch 15/200
# 573/573 [==============================] - 2s 4ms/step - loss: 0.6064 - accuracy: 0.6704 - val_loss: 0.6019 - val_accuracy: 0.6772
# Epoch 16/200
# 573/573 [==============================] - 2s 4ms/step - loss: 0.6051 - accuracy: 0.6712 - val_loss: 0.5982 - val_accuracy: 0.6793
# Epoch 17/200
# 573/573 [==============================] - 2s 4ms/step - loss: 0.6036 - accuracy: 0.6723 - val_loss: 0.5984 - val_accuracy: 0.6784
# Epoch 18/200
# 573/573 [==============================] - 3s 4ms/step - loss: 0.6027 - accuracy: 0.6726 - val_loss: 0.5956 - val_accuracy: 0.6805
# Epoch 19/200
# 573/573 [==============================] - 2s 4ms/step - loss: 0.6019 - accuracy: 0.6744 - val_loss: 0.5931 - val_accuracy: 0.6825
# Epoch 20/200
# 573/573 [==============================] - 2s 4ms/step - loss: 0.6006 - accuracy: 0.6748 - val_loss: 0.5937 - val_accuracy: 0.6824
# Epoch 21/200
# 573/573 [==============================] - 2s 4ms/step - loss: 0.5995 - accuracy: 0.6771 - val_loss: 0.5905 - val_accuracy: 0.6843
# Epoch 22/200
# 573/573 [==============================] - 2s 4ms/step - loss: 0.5986 - accuracy: 0.6771 - val_loss: 0.5916 - val_accuracy: 0.6852
# Epoch 23/200
# 573/573 [==============================] - 2s 4ms/step - loss: 0.5982 - accuracy: 0.6769 - val_loss: 0.5906 - val_accuracy: 0.6846
# Epoch 24/200
# 573/573 [==============================] - 2s 4ms/step - loss: 0.5972 - accuracy: 0.6776 - val_loss: 0.5891 - val_accuracy: 0.6866
# Epoch 25/200
# 573/573 [==============================] - 2s 4ms/step - loss: 0.5961 - accuracy: 0.6790 - val_loss: 0.5906 - val_accuracy: 0.6840
# Epoch 26/200
# 573/573 [==============================] - 2s 4ms/step - loss: 0.5956 - accuracy: 0.6798 - val_loss: 0.5882 - val_accuracy: 0.6848
# Epoch 27/200
# 573/573 [==============================] - 2s 4ms/step - loss: 0.5942 - accuracy: 0.6810 - val_loss: 0.5884 - val_accuracy: 0.6865
# Epoch 28/200
# 573/573 [==============================] - 2s 4ms/step - loss: 0.5940 - accuracy: 0.6807 - val_loss: 0.5887 - val_accuracy: 0.6869
# Epoch 29/200
# 573/573 [==============================] - 2s 4ms/step - loss: 0.5934 - accuracy: 0.6810 - val_loss: 0.5866 - val_accuracy: 0.6888
# Epoch 30/200
# 573/573 [==============================] - 2s 4ms/step - loss: 0.5928 - accuracy: 0.6814 - val_loss: 0.5866 - val_accuracy: 0.6880
# Epoch 31/200
# 573/573 [==============================] - 2s 4ms/step - loss: 0.5924 - accuracy: 0.6825 - val_loss: 0.5857 - val_accuracy: 0.6886
# Epoch 32/200
# 573/573 [==============================] - 2s 4ms/step - loss: 0.5920 - accuracy: 0.6817 - val_loss: 0.5858 - val_accuracy: 0.6888
# Epoch 33/200
# 573/573 [==============================] - 2s 4ms/step - loss: 0.5914 - accuracy: 0.6822 - val_loss: 0.5868 - val_accuracy: 0.6880
# Epoch 34/200
# 573/573 [==============================] - 2s 4ms/step - loss: 0.5906 - accuracy: 0.6833 - val_loss: 0.5845 - val_accuracy: 0.6898
# Epoch 35/200
# 573/573 [==============================] - 2s 4ms/step - loss: 0.5907 - accuracy: 0.6841 - val_loss: 0.5863 - val_accuracy: 0.6893
# Epoch 36/200
# 573/573 [==============================] - 2s 4ms/step - loss: 0.5907 - accuracy: 0.6836 - val_loss: 0.5876 - val_accuracy: 0.6879
# Epoch 37/200
# 573/573 [==============================] - 2s 4ms/step - loss: 0.5896 - accuracy: 0.6840 - val_loss: 0.5853 - val_accuracy: 0.6885
# Epoch 38/200
# 573/573 [==============================] - 2s 4ms/step - loss: 0.5890 - accuracy: 0.6844 - val_loss: 0.5821 - val_accuracy: 0.6932
# Epoch 39/200
# 573/573 [==============================] - 2s 4ms/step - loss: 0.5887 - accuracy: 0.6850 - val_loss: 0.5823 - val_accuracy: 0.6935
# Epoch 40/200
# 573/573 [==============================] - 2s 4ms/step - loss: 0.5882 - accuracy: 0.6851 - val_loss: 0.5828 - val_accuracy: 0.6922
# Epoch 41/200
# 573/573 [==============================] - 2s 4ms/step - loss: 0.5876 - accuracy: 0.6862 - val_loss: 0.5848 - val_accuracy: 0.6897
# Epoch 42/200
# 573/573 [==============================] - 2s 4ms/step - loss: 0.5877 - accuracy: 0.6865 - val_loss: 0.5822 - val_accuracy: 0.6917
# Epoch 43/200
# 573/573 [==============================] - 2s 4ms/step - loss: 0.5870 - accuracy: 0.6864 - val_loss: 0.5824 - val_accuracy: 0.6919
# Epoch 44/200
# 573/573 [==============================] - 2s 4ms/step - loss: 0.5863 - accuracy: 0.6868 - val_loss: 0.5817 - val_accuracy: 0.6933
# Epoch 45/200
# 573/573 [==============================] - 2s 4ms/step - loss: 0.5870 - accuracy: 0.6865 - val_loss: 0.5811 - val_accuracy: 0.6917
# Epoch 46/200
# 573/573 [==============================] - 2s 4ms/step - loss: 0.5857 - accuracy: 0.6878 - val_loss: 0.5809 - val_accuracy: 0.6915
# Epoch 47/200
# 573/573 [==============================] - 2s 4ms/step - loss: 0.5857 - accuracy: 0.6871 - val_loss: 0.5810 - val_accuracy: 0.6939
# Epoch 48/200
# 573/573 [==============================] - 3s 4ms/step - loss: 0.5854 - accuracy: 0.6880 - val_loss: 0.5865 - val_accuracy: 0.6883
# Epoch 49/200
# 573/573 [==============================] - 3s 5ms/step - loss: 0.5853 - accuracy: 0.6865 - val_loss: 0.5804 - val_accuracy: 0.6936
# Epoch 50/200
# 573/573 [==============================] - 3s 5ms/step - loss: 0.5845 - accuracy: 0.6883 - val_loss: 0.5807 - val_accuracy: 0.6929
# Epoch 51/200
# 573/573 [==============================] - 3s 5ms/step - loss: 0.5843 - accuracy: 0.6871 - val_loss: 0.5799 - val_accuracy: 0.6950
# Epoch 52/200
# 573/573 [==============================] - 3s 5ms/step - loss: 0.5849 - accuracy: 0.6878 - val_loss: 0.5806 - val_accuracy: 0.6925
# Epoch 53/200
# 573/573 [==============================] - 3s 5ms/step - loss: 0.5839 - accuracy: 0.6882 - val_loss: 0.5795 - val_accuracy: 0.6932
# Epoch 54/200
# 573/573 [==============================] - 3s 5ms/step - loss: 0.5838 - accuracy: 0.6886 - val_loss: 0.5794 - val_accuracy: 0.6941
# Epoch 55/200
# 573/573 [==============================] - 3s 5ms/step - loss: 0.5833 - accuracy: 0.6901 - val_loss: 0.5791 - val_accuracy: 0.6947
# Epoch 56/200
# 573/573 [==============================] - 3s 5ms/step - loss: 0.5825 - accuracy: 0.6887 - val_loss: 0.5815 - val_accuracy: 0.6924
# Epoch 57/200
# 573/573 [==============================] - 3s 5ms/step - loss: 0.5826 - accuracy: 0.6899 - val_loss: 0.5785 - val_accuracy: 0.6949
# Epoch 58/200
# 573/573 [==============================] - 3s 5ms/step - loss: 0.5824 - accuracy: 0.6899 - val_loss: 0.5788 - val_accuracy: 0.6939
# Epoch 59/200
# 573/573 [==============================] - 3s 5ms/step - loss: 0.5821 - accuracy: 0.6899 - val_loss: 0.5790 - val_accuracy: 0.6944
# Epoch 60/200
# 573/573 [==============================] - 3s 5ms/step - loss: 0.5827 - accuracy: 0.6899 - val_loss: 0.5810 - val_accuracy: 0.6931
# Epoch 61/200
# 573/573 [==============================] - 3s 5ms/step - loss: 0.5811 - accuracy: 0.6906 - val_loss: 0.5795 - val_accuracy: 0.6929
# Epoch 62/200
# 573/573 [==============================] - 3s 5ms/step - loss: 0.5823 - accuracy: 0.6898 - val_loss: 0.5783 - val_accuracy: 0.6953
# Epoch 63/200
# 573/573 [==============================] - 3s 5ms/step - loss: 0.5816 - accuracy: 0.6906 - val_loss: 0.5795 - val_accuracy: 0.6934
# Epoch 64/200
# 573/573 [==============================] - 3s 5ms/step - loss: 0.5806 - accuracy: 0.6910 - val_loss: 0.5796 - val_accuracy: 0.6951
# Epoch 65/200
# 573/573 [==============================] - 3s 5ms/step - loss: 0.5811 - accuracy: 0.6915 - val_loss: 0.5778 - val_accuracy: 0.6944
# Epoch 66/200
# 573/573 [==============================] - 3s 5ms/step - loss: 0.5807 - accuracy: 0.6914 - val_loss: 0.5777 - val_accuracy: 0.6952
# Epoch 67/200
# 573/573 [==============================] - 3s 5ms/step - loss: 0.5807 - accuracy: 0.6913 - val_loss: 0.5780 - val_accuracy: 0.6955
# Epoch 68/200
# 573/573 [==============================] - 3s 5ms/step - loss: 0.5803 - accuracy: 0.6912 - val_loss: 0.5785 - val_accuracy: 0.6929
# Epoch 69/200
# 573/573 [==============================] - 3s 5ms/step - loss: 0.5792 - accuracy: 0.6924 - val_loss: 0.5762 - val_accuracy: 0.6956
# Epoch 70/200
# 573/573 [==============================] - 3s 5ms/step - loss: 0.5793 - accuracy: 0.6913 - val_loss: 0.5788 - val_accuracy: 0.6953
# Epoch 71/200
# 573/573 [==============================] - 3s 5ms/step - loss: 0.5794 - accuracy: 0.6922 - val_loss: 0.5773 - val_accuracy: 0.6975
# Epoch 72/200
# 573/573 [==============================] - 3s 5ms/step - loss: 0.5794 - accuracy: 0.6922 - val_loss: 0.5758 - val_accuracy: 0.6955
# Epoch 73/200
# 573/573 [==============================] - 3s 5ms/step - loss: 0.5786 - accuracy: 0.6928 - val_loss: 0.5781 - val_accuracy: 0.6938
# Epoch 74/200
# 573/573 [==============================] - 3s 5ms/step - loss: 0.5793 - accuracy: 0.6924 - val_loss: 0.5757 - val_accuracy: 0.6961
# Epoch 75/200
# 573/573 [==============================] - 3s 5ms/step - loss: 0.5789 - accuracy: 0.6928 - val_loss: 0.5769 - val_accuracy: 0.6959
# Epoch 76/200
# 573/573 [==============================] - 3s 5ms/step - loss: 0.5784 - accuracy: 0.6936 - val_loss: 0.5776 - val_accuracy: 0.6939
# Epoch 77/200
# 573/573 [==============================] - 3s 5ms/step - loss: 0.5778 - accuracy: 0.6936 - val_loss: 0.5753 - val_accuracy: 0.6977
# Epoch 78/200
# 573/573 [==============================] - 3s 5ms/step - loss: 0.5776 - accuracy: 0.6941 - val_loss: 0.5764 - val_accuracy: 0.6950
# Epoch 79/200
# 573/573 [==============================] - 3s 5ms/step - loss: 0.5779 - accuracy: 0.6933 - val_loss: 0.5766 - val_accuracy: 0.6965
# Epoch 80/200
# 573/573 [==============================] - 3s 5ms/step - loss: 0.5774 - accuracy: 0.6930 - val_loss: 0.5748 - val_accuracy: 0.6981
# Epoch 81/200
# 573/573 [==============================] - 3s 5ms/step - loss: 0.5766 - accuracy: 0.6944 - val_loss: 0.5745 - val_accuracy: 0.6987
# Epoch 82/200
# 573/573 [==============================] - 3s 5ms/step - loss: 0.5776 - accuracy: 0.6936 - val_loss: 0.5761 - val_accuracy: 0.6956
# Epoch 83/200
# 573/573 [==============================] - 3s 5ms/step - loss: 0.5768 - accuracy: 0.6943 - val_loss: 0.5750 - val_accuracy: 0.6970
# Epoch 84/200
# 573/573 [==============================] - 3s 5ms/step - loss: 0.5763 - accuracy: 0.6943 - val_loss: 0.5744 - val_accuracy: 0.7002
# Epoch 85/200
# 573/573 [==============================] - 3s 5ms/step - loss: 0.5761 - accuracy: 0.6947 - val_loss: 0.5755 - val_accuracy: 0.6977
# Epoch 86/200
# 573/573 [==============================] - 3s 5ms/step - loss: 0.5762 - accuracy: 0.6952 - val_loss: 0.5791 - val_accuracy: 0.6943
# Epoch 87/200
# 573/573 [==============================] - 3s 5ms/step - loss: 0.5764 - accuracy: 0.6952 - val_loss: 0.5762 - val_accuracy: 0.6965
# Epoch 88/200
# 573/573 [==============================] - 3s 5ms/step - loss: 0.5765 - accuracy: 0.6936 - val_loss: 0.5751 - val_accuracy: 0.6967
# Epoch 89/200
# 573/573 [==============================] - 3s 5ms/step - loss: 0.5751 - accuracy: 0.6954 - val_loss: 0.5762 - val_accuracy: 0.6950
# Epoch 90/200
# 573/573 [==============================] - 3s 5ms/step - loss: 0.5754 - accuracy: 0.6953 - val_loss: 0.5761 - val_accuracy: 0.6953
# Epoch 91/200
# 573/573 [==============================] - 3s 5ms/step - loss: 0.5759 - accuracy: 0.6951 - val_loss: 0.5753 - val_accuracy: 0.6972
# Epoch 92/200
# 573/573 [==============================] - 3s 5ms/step - loss: 0.5757 - accuracy: 0.6937 - val_loss: 0.5764 - val_accuracy: 0.6947
# Epoch 93/200
# 573/573 [==============================] - 3s 5ms/step - loss: 0.5748 - accuracy: 0.6960 - val_loss: 0.5741 - val_accuracy: 0.6985
# Epoch 94/200
# 573/573 [==============================] - 3s 5ms/step - loss: 0.5748 - accuracy: 0.6956 - val_loss: 0.5747 - val_accuracy: 0.6991
# Epoch 95/200
# 573/573 [==============================] - 3s 5ms/step - loss: 0.5749 - accuracy: 0.6959 - val_loss: 0.5763 - val_accuracy: 0.6961
# Epoch 96/200
# 573/573 [==============================] - 3s 5ms/step - loss: 0.5752 - accuracy: 0.6962 - val_loss: 0.5736 - val_accuracy: 0.6956
# Epoch 97/200
# 573/573 [==============================] - 3s 5ms/step - loss: 0.5746 - accuracy: 0.6960 - val_loss: 0.5741 - val_accuracy: 0.6972
# Epoch 98/200
# 573/573 [==============================] - 3s 5ms/step - loss: 0.5739 - accuracy: 0.6965 - val_loss: 0.5746 - val_accuracy: 0.6978
# Epoch 99/200
# 573/573 [==============================] - 3s 5ms/step - loss: 0.5742 - accuracy: 0.6966 - val_loss: 0.5739 - val_accuracy: 0.6989
# Epoch 100/200
# 573/573 [==============================] - 3s 5ms/step - loss: 0.5742 - accuracy: 0.6968 - val_loss: 0.5742 - val_accuracy: 0.6986
# Epoch 101/200
# 573/573 [==============================] - 3s 5ms/step - loss: 0.5730 - accuracy: 0.6966 - val_loss: 0.5766 - val_accuracy: 0.6954
# Epoch 102/200
# 573/573 [==============================] - 3s 5ms/step - loss: 0.5729 - accuracy: 0.6983 - val_loss: 0.5753 - val_accuracy: 0.6952
# Epoch 103/200
# 573/573 [==============================] - 3s 5ms/step - loss: 0.5736 - accuracy: 0.6955 - val_loss: 0.5738 - val_accuracy: 0.6966
# Epoch 104/200
# 573/573 [==============================] - 3s 5ms/step - loss: 0.5732 - accuracy: 0.6963 - val_loss: 0.5755 - val_accuracy: 0.6949
# Epoch 105/200
# 573/573 [==============================] - 3s 5ms/step - loss: 0.5732 - accuracy: 0.6976 - val_loss: 0.5748 - val_accuracy: 0.6970
# Epoch 106/200
# 573/573 [==============================] - 3s 5ms/step - loss: 0.5731 - accuracy: 0.6969 - val_loss: 0.5742 - val_accuracy: 0.6977
# Time taken: 277.6s

# %%
'''
drop_model1 = models.Sequential()
drop_model1.add(layers.Dense(32,  kernel_initializer='normal', activation='selu', input_shape=(NDIM,)))
drop_model1.add(layers.Dropout(0.1))
drop_model1.add(layers.Dense(32,  kernel_initializer='normal', activation='selu'))
drop_model1.add(layers.Dropout(0.1))
drop_model1.add(layers.Dense(1, kernel_initializer='normal', activation='sigmoid'))

# compile the model
drop_model1.compile(optimizer='Adam', loss='binary_crossentropy', metrics=['accuracy'])
# print the model summary
drop_model1.summary()

# early stopping callback
from keras.callbacks import EarlyStopping
early_stopping = EarlyStopping(monitor='val_loss', patience=10, mode='min')

# Train classifier
import time
start = time.time() # time at start of whole processing

model_checkpoint = ModelCheckpoint(filepath='./models/testup_NN_opt_drop_model.h5', monitor='val_loss', 
                                   verbose=0, save_best_only=True, 
                                   save_weights_only=False, mode='auto', 
                                   period=1)

drop_history1 = drop_model1.fit(X_train_val, 
                    Y_train_val, 
                    epochs=500, 
                    batch_size=256, 
                    verbose=1, # switch to 1 for more verbosity 
                    callbacks=[early_stopping, model_checkpoint], 
                    validation_data=(X_test,Y_test))

elapsed = time.time() - start # time after whole processing
print("Time taken: "+str(round(elapsed,1))+"s") # print total time taken to process every file
'''
# Out:
# '\ndrop_model1 = models.Sequential()\ndrop_model1.add(layers.Dense(32,  kernel_initializer=\'normal\', activation=\'selu\', input_shape=(NDIM,)))\ndrop_model1.add(layers.Dropout(0.1))\ndrop_model1.add(layers.Dense(32,  kernel_initializer=\'normal\', activation=\'selu\'))\ndrop_model1.add(layers.Dropout(0.1))\ndrop_model1.add(layers.Dense(1, kernel_initializer=\'normal\', activation=\'sigmoid\'))\n\n# compile the model\ndrop_model1.compile(optimizer=\'Adam\', loss=\'binary_crossentropy\', metrics=[\'accuracy\'])\n# print the model summary\ndrop_model1.summary()\n\n# early stopping callback\nfrom keras.callbacks import EarlyStopping\nearly_stopping = EarlyStopping(monitor=\'val_loss\', patience=10, mode=\'min\')\n\n# Train classifier\nimport time\nstart = time.time() # time at start of whole processing\n\nmodel_checkpoint = ModelCheckpoint(filepath=\'./models/testup_NN_opt_drop_model.h5\', monitor=\'val_loss\', \n                                   verbose=0, save_best_only=True, \n                                   save_weights_only=False, mode=\'auto\', \n                                   period=1)\n\ndrop_history1 = drop_model1.fit(X_train_val, \n                    Y_train_val, \n                    epochs=500, \n                    batch_size=256, \n                    verbose=1, # switch to 1 for more verbosity \n                    callbacks=[early_stopping, model_checkpoint], \n                    validation_data=(X_test,Y_test))\n\nelapsed = time.time() - start # time after whole processing\nprint("Time taken: "+str(round(elapsed,1))+"s") # print total time taken to process every file\n'

# %%
loss_accuracy_plotter(drop_history)

fpr_nn_opt_drop, tpr_nn_opt_drop, thresholds_nn_opt_drop = evaluate(drop_model, scaler, X, Y, X_train_val, Y_train_val, X_test, Y_test)
df_all['dense_NN_opt_drop'] = drop_model.predict(scaler.transform(X)).round() # add prediction to array
# Out:
# 1145/1145 [==============================] - 1s 1ms/step
# 4578/4578 [==============================] - 5s 1ms/step
# 1145/1145 [==============================] - 1s 1ms/step
# 4578/4578 [==============================] - 5s 1ms/step
# 5722/5722 [==============================] - 7s 1ms/step
# Test acc score: 0.6976706081542369
# Train acc score: 0.7087782298806631
# Classification report for the test set
#               precision    recall  f1-score   support
#
#   background       0.69      0.49      0.58     15200
#       signal       0.70      0.84      0.77     21419
#
#     accuracy                           0.70     36619
#    macro avg       0.70      0.67      0.67     36619
# weighted avg       0.70      0.70      0.69     36619
#
# Classification report for the total set
#               precision    recall  f1-score   support
#
#   background       0.71      0.51      0.59     76352
#       signal       0.71      0.85      0.77    106743
#
#     accuracy                           0.71    183095
#    macro avg       0.71      0.68      0.68    183095
# weighted avg       0.71      0.71      0.70    183095
#
# Confusion matrix for total set
# [[38794 37558]
#  [16170 90573]]
# 5722/5722 [==============================] - 5s 869us/step

# %%
# add TF NN probability
y_tot_prob_NN_opt_drop = drop_model.predict(scaler.transform(X))
y_tot_NN_opt_drop = drop_model.predict(scaler.transform(X)).round()

cumulative_events = 0 # start counter for total number of events for which output is saved
for key in filename.keys(): # loop over samples
    df[key]['NN_opt_drop_output_prob'] = y_tot_prob_NN_opt_drop[cumulative_events:cumulative_events+len(df[key])]
    df[key]['NN_opt_drop_output'] = y_tot_NN_opt_drop[cumulative_events:cumulative_events+len(df[key])]
    cumulative_events += len(df[key]) # increment counter for total number of events
    #print(df[key]['NN_output']) # print the dataframe column NN_output

# probability and significance plots
NN_opt_drop_output_prob = { # dictionary containing plotting parameters for the mllll histogram
    # change plotting parameters
    'bin_width':0.1, # width of each histogram bin
    'num_bins':8, # number of histogram bins
    'xrange_min':0, # minimum on x-axis
    'xlabel':'Neural Network optimized dropout', # x-axis label
}

SoverB_hist_dict = {'NN_opt_drop_output_prob':NN_opt_drop_output_prob}
plot_SoverB(df, SoverB_hist_dict)
# Out:
# 5722/5722 [==============================] - 5s 833us/step
# 5722/5722 [==============================] - 5s 844us/step

# %% [markdown]
# ## Optimal model with early stopping

# %%
inputs = Input(shape=(NDIM,), name = 'input') 
hidden1 = Dense(128, name = 'hidden1', kernel_initializer='lecun_normal', activation='selu')(inputs)
hidden2 = Dense(128, name = 'hidden2', kernel_initializer='lecun_normal', activation='selu')(hidden1)
hidden3 = Dense(128, name = 'hidden3', kernel_initializer='lecun_normal', activation='selu')(hidden2)
outputs = Dense(1, name = 'output', kernel_initializer='lecun_normal', activation='sigmoid')(hidden3)

# create the model
opt_model = Model(inputs=inputs, outputs=outputs)
# compile the model
opt_model.compile(optimizer='Adam', loss='binary_crossentropy', metrics=['accuracy'])
# print the model summary
opt_model.summary()

# early stopping callback
from keras.callbacks import EarlyStopping
early_stopping = EarlyStopping(monitor='val_loss', patience=10, mode='min')

# model checkpoint callback
# this saves our model architecture + parameters into dense_model.h5
from keras.callbacks import ModelCheckpoint
model_checkpoint = ModelCheckpoint('./models/up_NN_opt_model.h5', monitor='val_loss', 
                                   verbose=0, save_best_only=True,                                    
                                   save_weights_only=False, mode='auto', 
                                   period=1)
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input (InputLayer)          [(None, 11)]              0
#
#  hidden1 (Dense)             (None, 128)               1536
#
#  hidden2 (Dense)             (None, 128)               16512
#
#  hidden3 (Dense)             (None, 128)               16512
#
#  output (Dense)              (None, 1)                 129
#
# =================================================================
# Total params: 34,689
# Trainable params: 34,689
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
# Train classifier
import time
start = time.time() # time at start of whole processing

opt_history = opt_model.fit(X_train_val, 
                    Y_train_val, 
                    epochs=500, 
                    batch_size=256, 
                    verbose=1, # switch to 1 for more verbosity 
                    callbacks=[early_stopping, model_checkpoint], 
                    validation_data=(X_test,Y_test))

elapsed = time.time() - start # time after whole processing
print("Time taken: "+str(round(elapsed,1))+"s") # print total time taken to process every file
# Out:
# Epoch 1/500
# 573/573 [==============================] - 3s 3ms/step - loss: 0.6305 - accuracy: 0.6459 - val_loss: 0.6199 - val_accuracy: 0.6554
# Epoch 2/500
# 573/573 [==============================] - 2s 3ms/step - loss: 0.6127 - accuracy: 0.6647 - val_loss: 0.6076 - val_accuracy: 0.6697
# Epoch 3/500
# 573/573 [==============================] - 2s 3ms/step - loss: 0.6063 - accuracy: 0.6693 - val_loss: 0.6039 - val_accuracy: 0.6702
# Epoch 4/500
# 573/573 [==============================] - 2s 3ms/step - loss: 0.6030 - accuracy: 0.6712 - val_loss: 0.6023 - val_accuracy: 0.6714
# Epoch 5/500
# 573/573 [==============================] - 1s 3ms/step - loss: 0.5987 - accuracy: 0.6755 - val_loss: 0.5989 - val_accuracy: 0.6787
# Epoch 6/500
# 573/573 [==============================] - 2s 3ms/step - loss: 0.5962 - accuracy: 0.6782 - val_loss: 0.6012 - val_accuracy: 0.6790
# Epoch 7/500
# 573/573 [==============================] - 2s 3ms/step - loss: 0.5937 - accuracy: 0.6797 - val_loss: 0.5934 - val_accuracy: 0.6841
# Epoch 8/500
# 573/573 [==============================] - 2s 3ms/step - loss: 0.5926 - accuracy: 0.6813 - val_loss: 0.5933 - val_accuracy: 0.6831
# Epoch 9/500
# 573/573 [==============================] - 2s 3ms/step - loss: 0.5902 - accuracy: 0.6833 - val_loss: 0.5920 - val_accuracy: 0.6853
# Epoch 10/500
# 573/573 [==============================] - 2s 3ms/step - loss: 0.5882 - accuracy: 0.6837 - val_loss: 0.5892 - val_accuracy: 0.6870
# Epoch 11/500
# 573/573 [==============================] - 2s 3ms/step - loss: 0.5876 - accuracy: 0.6852 - val_loss: 0.5893 - val_accuracy: 0.6887
# Epoch 12/500
# 573/573 [==============================] - 2s 3ms/step - loss: 0.5851 - accuracy: 0.6876 - val_loss: 0.5919 - val_accuracy: 0.6809
# Epoch 13/500
# 573/573 [==============================] - 2s 3ms/step - loss: 0.5856 - accuracy: 0.6865 - val_loss: 0.5861 - val_accuracy: 0.6873
# Epoch 14/500
# 573/573 [==============================] - 2s 3ms/step - loss: 0.5841 - accuracy: 0.6888 - val_loss: 0.5869 - val_accuracy: 0.6890
# Epoch 15/500
# 573/573 [==============================] - 2s 3ms/step - loss: 0.5826 - accuracy: 0.6901 - val_loss: 0.5866 - val_accuracy: 0.6899
# Epoch 16/500
# 573/573 [==============================] - 2s 3ms/step - loss: 0.5816 - accuracy: 0.6898 - val_loss: 0.5860 - val_accuracy: 0.6863
# Epoch 17/500
# 573/573 [==============================] - 1s 2ms/step - loss: 0.5808 - accuracy: 0.6903 - val_loss: 0.5901 - val_accuracy: 0.6864
# Epoch 18/500
# 573/573 [==============================] - 2s 3ms/step - loss: 0.5804 - accuracy: 0.6918 - val_loss: 0.5878 - val_accuracy: 0.6854
# Epoch 19/500
# 573/573 [==============================] - 2s 3ms/step - loss: 0.5788 - accuracy: 0.6929 - val_loss: 0.5923 - val_accuracy: 0.6841
# Epoch 20/500
# 573/573 [==============================] - 2s 3ms/step - loss: 0.5784 - accuracy: 0.6933 - val_loss: 0.5885 - val_accuracy: 0.6835
# Epoch 21/500
# 573/573 [==============================] - 2s 3ms/step - loss: 0.5768 - accuracy: 0.6936 - val_loss: 0.5849 - val_accuracy: 0.6903
# Epoch 22/500
# 573/573 [==============================] - 2s 3ms/step - loss: 0.5769 - accuracy: 0.6946 - val_loss: 0.5832 - val_accuracy: 0.6924
# Epoch 23/500
# 573/573 [==============================] - 2s 3ms/step - loss: 0.5764 - accuracy: 0.6943 - val_loss: 0.5837 - val_accuracy: 0.6899
# Epoch 24/500
# 573/573 [==============================] - 2s 3ms/step - loss: 0.5751 - accuracy: 0.6951 - val_loss: 0.5825 - val_accuracy: 0.6912
# Epoch 25/500
# 573/573 [==============================] - 2s 3ms/step - loss: 0.5746 - accuracy: 0.6961 - val_loss: 0.5834 - val_accuracy: 0.6909
# Epoch 26/500
# 573/573 [==============================] - 2s 4ms/step - loss: 0.5738 - accuracy: 0.6963 - val_loss: 0.5871 - val_accuracy: 0.6849
# Epoch 27/500
# 573/573 [==============================] - 3s 4ms/step - loss: 0.5739 - accuracy: 0.6959 - val_loss: 0.5855 - val_accuracy: 0.6910
# Epoch 28/500
# 573/573 [==============================] - 4s 7ms/step - loss: 0.5731 - accuracy: 0.6965 - val_loss: 0.5868 - val_accuracy: 0.6889
# Epoch 29/500
# 573/573 [==============================] - 3s 5ms/step - loss: 0.5724 - accuracy: 0.6973 - val_loss: 0.5867 - val_accuracy: 0.6853
# Epoch 30/500
# 573/573 [==============================] - 3s 5ms/step - loss: 0.5714 - accuracy: 0.6980 - val_loss: 0.5838 - val_accuracy: 0.6901
# Epoch 31/500
# 573/573 [==============================] - 2s 3ms/step - loss: 0.5710 - accuracy: 0.6992 - val_loss: 0.5875 - val_accuracy: 0.6871
# Epoch 32/500
# 573/573 [==============================] - 2s 3ms/step - loss: 0.5703 - accuracy: 0.6989 - val_loss: 0.5870 - val_accuracy: 0.6871
# Epoch 33/500
# 573/573 [==============================] - 2s 3ms/step - loss: 0.5702 - accuracy: 0.6998 - val_loss: 0.5818 - val_accuracy: 0.6918
# Epoch 34/500
# 573/573 [==============================] - 2s 4ms/step - loss: 0.5689 - accuracy: 0.7011 - val_loss: 0.5824 - val_accuracy: 0.6897
# Epoch 35/500
# 573/573 [==============================] - 2s 4ms/step - loss: 0.5682 - accuracy: 0.7015 - val_loss: 0.5835 - val_accuracy: 0.6913
# Epoch 36/500
# 573/573 [==============================] - 2s 3ms/step - loss: 0.5682 - accuracy: 0.7014 - val_loss: 0.5847 - val_accuracy: 0.6893
# Epoch 37/500
# 573/573 [==============================] - 2s 4ms/step - loss: 0.5674 - accuracy: 0.7019 - val_loss: 0.5847 - val_accuracy: 0.6893
# Epoch 38/500
# 573/573 [==============================] - 2s 3ms/step - loss: 0.5669 - accuracy: 0.7015 - val_loss: 0.5837 - val_accuracy: 0.6879
# Epoch 39/500
# 573/573 [==============================] - 2s 3ms/step - loss: 0.5671 - accuracy: 0.7014 - val_loss: 0.5822 - val_accuracy: 0.6910
# Epoch 40/500
# 573/573 [==============================] - 2s 3ms/step - loss: 0.5662 - accuracy: 0.7024 - val_loss: 0.5851 - val_accuracy: 0.6901
# Epoch 41/500
# 573/573 [==============================] - 2s 3ms/step - loss: 0.5657 - accuracy: 0.7020 - val_loss: 0.5819 - val_accuracy: 0.6923
# Epoch 42/500
# 573/573 [==============================] - 2s 3ms/step - loss: 0.5650 - accuracy: 0.7030 - val_loss: 0.5838 - val_accuracy: 0.6880
# Epoch 43/500
# 573/573 [==============================] - 2s 3ms/step - loss: 0.5651 - accuracy: 0.7039 - val_loss: 0.5820 - val_accuracy: 0.6878
# Time taken: 83.0s

# %%
loss_accuracy_plotter(opt_history)

fpr_nn_opt, tpr_nn_opt, thresholds_nn_opt = evaluate(opt_model, scaler, X, Y, X_train_val, Y_train_val, X_test, Y_test)
df_all['dense_NN_opt'] = opt_model.predict(scaler.transform(X)).round() # add prediction to array
# Out:
# 1145/1145 [==============================] - 1s 1ms/step
# 4578/4578 [==============================] - 5s 1ms/step
# 1145/1145 [==============================] - 1s 1ms/step
# 4578/4578 [==============================] - 5s 1ms/step
# 5722/5722 [==============================] - 6s 1ms/step
# Test acc score: 0.6877850296294273
# Train acc score: 0.7075152243370928
# Classification report for the test set
#               precision    recall  f1-score   support
#
#   background       0.66      0.51      0.58     15200
#       signal       0.70      0.81      0.75     21419
#
#     accuracy                           0.69     36619
#    macro avg       0.68      0.66      0.66     36619
# weighted avg       0.68      0.69      0.68     36619
#
# Classification report for the total set
#               precision    recall  f1-score   support
#
#   background       0.68      0.54      0.60     76352
#       signal       0.71      0.82      0.76    106743
#
#     accuracy                           0.70    183095
#    macro avg       0.70      0.68      0.68    183095
# weighted avg       0.70      0.70      0.70    183095
#
# Confusion matrix for total set
# [[41138 35214]
#  [19061 87682]]
# 5722/5722 [==============================] - 7s 1ms/step

# %%
# add TF NN probability
y_tot_prob_NN_opt = opt_model.predict(scaler.transform(X))
y_tot_NN_opt = opt_model.predict(scaler.transform(X)).round()

cumulative_events = 0 # start counter for total number of events for which output is saved
for key in filename.keys(): # loop over samples
    df[key]['NN_opt_output_prob'] = y_tot_prob_NN_opt[cumulative_events:cumulative_events+len(df[key])]
    df[key]['NN_opt_output'] = y_tot_NN_opt[cumulative_events:cumulative_events+len(df[key])]
    cumulative_events += len(df[key]) # increment counter for total number of events
    #print(df[key]['NN_output']) # print the dataframe column NN_output

# probability and significance plots
NN_opt_output_prob = { # dictionary containing plotting parameters for the mllll histogram
    # change plotting parameters
    'bin_width':0.1, # width of each histogram bin
    'num_bins':8, # number of histogram bins
    'xrange_min':0, # minimum on x-axis
    'xlabel':'Neural Network optimized output', # x-axis label
}

SoverB_hist_dict = {'NN_opt_output_prob':NN_opt_output_prob}
plot_SoverB(df, SoverB_hist_dict)
# Out:
# 5722/5722 [==============================] - 6s 998us/step
# 5722/5722 [==============================] - 5s 787us/step

# %% [markdown]
# ## ROC and AMS curves

# %%
# plot ROC curve
plt.plot(fpr_nn, tpr_nn, label='Neural Network') # plot neural network ROC
plt.plot(fpr_nn_opt, tpr_nn_opt, linestyle='dashed', label='Neural Network optimized') # plot neural network optimized ROC
plt.plot(fpr_nn_opt_drop, tpr_nn_opt_drop, linestyle='dashed', label='Neural Network optimized (dropout)') # plot neural network optimized and dropout ROC
plt.plot([0, 1], [0, 1], linestyle='dotted', color='grey', label='Luck') # plot diagonal line to indicate luck
plt.xlabel('False Positive Rate') # x-axis label
plt.ylabel('True Positive Rate') # y-axis label
plt.grid() # add a grid to the plot
plt.legend() # add a legend

# %%
ams_nn = AMS(tpr_nn, fpr_nn, 0.001) # get AMS for NN classifier
ams_nn_opt = AMS(tpr_nn_opt, fpr_nn_opt, 0.001) # get AMS for NN-opt classifier
ams_nn_opt_drop = AMS(tpr_nn_opt_drop, fpr_nn_opt_drop, 0.001) # get AMS for NN-opt classifier


plt.plot(thresholds_nn, ams_nn, label="Neural Netwrok")  # plot NN AMS
plt.plot(thresholds_nn_opt, ams_nn_opt, linestyle='dashed', label="Neural Netwrok optimized")  # plot NN-opt AMS
plt.plot(thresholds_nn_opt_drop, ams_nn_opt_drop, linestyle='dashed', label="Neural Netwrok optimized (dropout)")  # plot NN-opt AMS
plt.xlabel("Threshold")  # x-axis label
plt.ylabel("AMS")  # y-axis label
plt.title("AMS with $b_r=0.001$")  # add plot title
plt.legend()  # add legend

# %%
ams_nn = AMS(tpr_nn, fpr_nn, 1) # get AMS for NN classifier
ams_nn_opt = AMS(tpr_nn_opt, fpr_nn_opt, 1) # get AMS for NN-opt classifier
ams_nn_opt_drop = AMS(tpr_nn_opt_drop, fpr_nn_opt_drop, 1) # get AMS for NN-opt classifier


plt.plot(thresholds_nn, ams_nn, label="Neural Netwrok")  # plot NN AMS
plt.plot(thresholds_nn_opt, ams_nn_opt, linestyle='dashed', label="Neural Netwrok optimized")  # plot NN-opt AMS
plt.plot(thresholds_nn_opt_drop, ams_nn_opt_drop, linestyle='dashed', label="Neural Netwrok optimized (dropout)")  # plot NN-opt AMS
plt.xlabel("Threshold")  # x-axis label
plt.ylabel("AMS")  # y-axis label
plt.title("AMS with $b_r=1$")  # add plot title
plt.legend()  # add legend

# %% [markdown]
# ## Overfit checking

# %%
#new_compare_train_test(model, X_train_val, Y_train_val, X_test, Y_test, 'Neural Netwrok output')
# Out:
# 308/308 [==============================] - 0s 901us/step
# 499/499 [==============================] - 0s 783us/step
# 75/75 [==============================] - 0s 909us/step
# 127/127 [==============================] - 0s 833us/step
# Signal: ks = [0.0100042] (p-value = [0.89915736], are equal = [ True])
# Background: ks = [0.02401509] (p-value = [0.21489541], are equal = [ True])

# %%
#new_compare_train_test(opt_model, X_train_val, Y_train_val, X_test, Y_test, 'Neural Netwrok optimized output')
# Out:
# 308/308 [==============================] - 0s 734us/step
# 499/499 [==============================] - 0s 719us/step
# 75/75 [==============================] - 0s 759us/step
# 127/127 [==============================] - 0s 770us/step
# Signal: ks = [0.06470548] (p-value = [3.21874341e-12], are equal = [False])
# Background: ks = [0.0934753] (p-value = [4.82057078e-15], are equal = [False])

# %%
#new_compare_train_test(drop_model, X_train_val, Y_train_val, X_test, Y_test, 'Neural Netwrok optimized dropoutoutput')
# Out:
# 308/308 [==============================] - 0s 705us/step
# 499/499 [==============================] - 0s 725us/step
# 75/75 [==============================] - 0s 726us/step
# 127/127 [==============================] - 0s 708us/step
# Signal: ks = [0.01461888] (p-value = [0.48933004], are equal = [ True])
# Background: ks = [0.01524889] (p-value = [0.75758902], are equal = [ True])

# %% [markdown]
# ## Save all models

# %%
# simple NN
#model.save('models/tt_charm_NN/')
model.save('models/tW_charm_VRR_NN.h5')
#new_model = keras.models.load_model('models/tt_charm_NN/')

# NN optimized 
#opt_model.save('models/tt_charm_NN_opt/')
opt_model.save('models/tW_charm_VRR_NN_opt.h5')
#new_model = keras.models.load_model('models/tt_charm_NN_opt/')

# NN optimized with drop
#drop_model.save('models/tt_charm_NN_drop/')
drop_model.save('models/tW_charm_VRR_NN_drop.h5')
#new_model = keras.models.load_model('models/tt_charm_NN_drop/')

# %% [markdown]
# ## Extend to the whole dataset

# %%
filename = {
    'tZ':'/Users/mghasemi/Desktop/IPM/plotter/newtrees/tW_trees/tZ.root',
    'WZ':'/Users/mghasemi/Desktop/IPM/plotter/newtrees/tW_trees/WZ.root',
    'ZZ':'/Users/mghasemi/Desktop/IPM/plotter/newtrees/tW_trees/ZZ.root',
    'signal_tW_charm_VRR':'/Users/mghasemi/Desktop/IPM/plotter/tW_trees/couplings/signal_tW_charm_VRR.root'}

VARS = ['jetNo','jetPTLeading', 'jetETA', 'jetPHI',
        'elecPTLeading', 'elecETA', 'elecPHI',
        'dielecCOS', 'dielecETA', 'met','testnonTopMass', 'weight'] 

upfile = {}
params = {}
df = {}
NDIM = len(VARS)

# define trees and branches to make DataFrame
for treename in filename.keys():
    upfile[treename] = uproot.open(filename[treename])
    params[treename] = upfile[treename][treename].arrays(VARS)
    df[treename] = ak.to_dataframe(params[treename])
    # add isSignal variable
    if treename.startswith("signal"): 
        df[treename]['isSignal'] = np.ones(len(df[treename])) 
    else:
        df[treename]['isSignal'] = np.zeros(len(df[treename])) 
    tmp_dataset = df[treename].values
    X_tmp = tmp_dataset[:,0:NDIM-1]
    Y_tmp = tmp_dataset[:,NDIM]
    df[treename]['dense_NN'] = model.predict(scaler.transform(X_tmp)) # add prediction to array   
    df[treename]['dense_NN_opt'] = opt_model.predict(scaler.transform(X_tmp)) # add prediction to array
    df[treename]['dense_NN_opt_drop'] = drop_model.predict(scaler.transform(X_tmp)) # add prediction to array
    df[treename].to_csv("~/Desktop/IPM/Analysis/Dataframes/tW_charm_VRR/"+treename+"_df.csv")
    

df_all = pd.concat([df[treename] for treename in filename.keys()])
dataset = df_all.values
X = dataset[:,0:NDIM-1]
Y = dataset[:,NDIM]
# Out:
# 5475/5475 [==============================] - 4s 794us/step
# 5475/5475 [==============================] - 5s 982us/step
# 5475/5475 [==============================] - 4s 763us/step
# 15105/15105 [==============================] - 11s 694us/step
# 15105/15105 [==============================] - 11s 741us/step
# 15105/15105 [==============================] - 11s 754us/step
# 199/199 [==============================] - 0s 686us/step
# 199/199 [==============================] - 0s 806us/step
# 199/199 [==============================] - 0s 733us/step
# 3336/3336 [==============================] - 2s 689us/step
# 3336/3336 [==============================] - 2s 744us/step
# 3336/3336 [==============================] - 3s 749us/step

# %%
y_pred_NN_opt = opt_model.predict(X_test).round() # make predictions on the test data
y_pred_NN_train_opt = opt_model.predict(X_train_val).round()
y_pred_NN_tot_opt = opt_model.predict(scaler.transform(X)).round()

# See how well the classifier does, Acc = correct data / tot data
print("Total accuracy", accuracy_score(Y, y_pred_NN_tot_opt))

print("Classification report for the total set")
print(classification_report(Y.round(), y_pred_NN_tot_opt.round(), target_names=['background', 'signal']))

print("Confusion matrix:\n", confusion_matrix(Y.round(), y_pred_NN_tot_opt.round()))

fpr_nn_opt_tot, tpr_nn_opt_tot, thresholds_nn_opt_tot = roc_curve(Y, y_pred_NN_tot_opt.round()) # get FPRs, TPRs and thresholds for neural network

df_all['dense_NN_opt'] = opt_model.predict(scaler.transform(X)) # add prediction to array
df_all['dense_NN'] = model.predict(scaler.transform(X)) # add prediction to array
# Out:
#    1/1145 [..............................] - ETA: 27s
# 1145/1145 [==============================] - 1s 749us/step
# 4578/4578 [==============================] - 3s 739us/step
# 24113/24113 [==============================] - 19s 796us/step
# Total accuracy 0.5400004665533115
# Classification report for the total set
#               precision    recall  f1-score   support
#
#   background       0.95      0.49      0.65    664873
#       signal       0.21      0.82      0.33    106743
#
#     accuracy                           0.54    771616
#    macro avg       0.58      0.66      0.49    771616
# weighted avg       0.84      0.54      0.61    771616
#
# Confusion matrix:
#  [[328991 335882]
#  [ 19061  87682]]
# 24113/24113 [==============================] - 19s 786us/step
# 24113/24113 [==============================] - 18s 726us/step

# %%
y_pred_NN_opt_fit = drop_model.predict(X_test).round() # make predictions on the test data
y_pred_NN_train_opt_fit = drop_model.predict(X_train_val).round()
y_pred_NN_tot_opt_fit = drop_model.predict(scaler.transform(X)).round()

# See how well the classifier does, Acc = correct data / tot data
print("Total accuracy", accuracy_score(Y, y_pred_NN_tot_opt_fit))

print("Classification report for the total set")
print(classification_report(Y.round(), y_pred_NN_tot_opt_fit.round(), target_names=['background', 'signal']))

print("Confusion matrix:\n", confusion_matrix(Y.round(), y_pred_NN_tot_opt_fit.round()))

fpr_nn_opt_tot_fit, tpr_nn_opt_tot_fit, thresholds_nn_opt_tot_fit = roc_curve(Y, y_pred_NN_tot_opt_fit.round()) # get FPRs, TPRs and thresholds for neural network

df_all['dense_NN_opt_drop'] = drop_model.predict(scaler.transform(X)) # add prediction to array
# Out:
#    1/1145 [..............................] - ETA: 27s
# 1145/1145 [==============================] - 1s 737us/step
# 4578/4578 [==============================] - 3s 726us/step
# 24113/24113 [==============================] - 19s 791us/step
# Total accuracy 0.5323865757060506
# Classification report for the total set
#               precision    recall  f1-score   support
#
#   background       0.95      0.48      0.64    664873
#       signal       0.21      0.85      0.33    106743
#
#     accuracy                           0.53    771616
#    macro avg       0.58      0.67      0.49    771616
# weighted avg       0.85      0.53      0.60    771616
#
# Confusion matrix:
#  [[320225 344648]
#  [ 16170  90573]]
# 24113/24113 [==============================] - 19s 784us/step

# %%
# add TF NN probability
y_TOT_prob_NN_opt = opt_model.predict(scaler.transform(X))
y_TOT_NN_opt = opt_model.predict(scaler.transform(X)).round()

cumulative_events = 0 # start counter for total number of events for which output is saved
for key in filename.keys(): # loop over samples
    df[key]['NN_opt_tot_output_prob'] = y_TOT_prob_NN_opt[cumulative_events:cumulative_events+len(df[key])]
    df[key]['NN_opt_tot_output'] = y_TOT_NN_opt[cumulative_events:cumulative_events+len(df[key])]
    cumulative_events += len(df[key]) # increment counter for total number of events
    #print(df[key]['NN_output']) # print the dataframe column NN_output

# probability and significance plots
NN_opt_tot_output_prob = { # dictionary containing plotting parameters for the mllll histogram
    # change plotting parameters
    'bin_width':0.1, # width of each histogram bin
    'num_bins':8, # number of histogram bins
    'xrange_min':0, # minimum on x-axis
    'xlabel':'Neural Network optimized output', # x-axis label
}

SoverB_hist_dict = {'NN_opt_tot_output_prob':NN_opt_tot_output_prob}
plot_SoverB(df, SoverB_hist_dict)
# Out:
# 24113/24113 [==============================] - 19s 786us/step
# 24113/24113 [==============================] - 19s 785us/step

# %%
# add TF NN probability
y_TOT_prob_NN_opt_fit = drop_model.predict(scaler.transform(X))
y_TOT_NN_opt_fit = drop_model.predict(scaler.transform(X)).round()

cumulative_events = 0 # start counter for total number of events for which output is saved
for key in filename.keys(): # loop over samples
    df[key]['NN_opt_tot_output_prob_overfit'] = y_TOT_prob_NN_opt_fit[cumulative_events:cumulative_events+len(df[key])]
    df[key]['NN_opt_tot_output_overfit'] = y_TOT_NN_opt_fit[cumulative_events:cumulative_events+len(df[key])]
    cumulative_events += len(df[key]) # increment counter for total number of events
    #print(df[key]['NN_output']) # print the dataframe column NN_output

# probability and significance plots
NN_opt_tot_output_prob_fit = { # dictionary containing plotting parameters for the mllll histogram
    # change plotting parameters
    'bin_width':0.1, # width of each histogram bin
    'num_bins':8, # number of histogram bins
    'xrange_min':0, # minimum on x-axis
    'xlabel':'Neural Network optimized output', # x-axis label
}

SoverB_hist_dict = {'NN_opt_tot_output_prob_overfit':NN_opt_tot_output_prob_fit}
plot_SoverB(df, SoverB_hist_dict)
# Out:
# 24113/24113 [==============================] - 19s 789us/step
# 24113/24113 [==============================] - 19s 794us/step

# %%
# plot ROC curve
plt.plot(fpr_nn_opt_tot, tpr_nn_opt_tot, label='Neural Network total') # plot Neural net-opt ROC
plt.plot(fpr_nn_opt_tot_fit, tpr_nn_opt_tot_fit, label='Neural Network overfit total') # plot Neural net-opt w overfit ROC
plt.plot([0, 1], [0, 1], linestyle='dotted', color='grey', label='Luck') # plot diagonal line to indicate luck
plt.xlabel('False Positive Rate') # x-axis label
plt.ylabel('True Positive Rate') # y-axis label
plt.grid() # add a grid to the plot
plt.legend() # add a legend

# %%
#ams_rf = AMS(tpr_rf, fpr_rf, 0.001) # get AMS for random forest classifier
ams_rf_opt_tot = AMS(tpr_nn_opt_tot, fpr_nn_opt_tot, 0.001) # get AMS for random forest classifier
ams_rf_opt_tot_fit = AMS(tpr_nn_opt_tot_fit, fpr_nn_opt_tot_fit, 0.001) # get AMS for random forest classifier

plt.plot(thresholds_nn_opt_tot, ams_rf_opt_tot, label="Neural Netwrok")  # plot Random forest AMS
plt.plot(thresholds_nn_opt_tot_fit, ams_rf_opt_tot_fit, label="Neural Netwrok overfit")  # plot Random forest AMS
plt.xlabel("Threshold")  # x-axis label
plt.ylabel("AMS")  # y-axis label
plt.title("AMS with $b_r=0.001$")  # add plot title
plt.legend()  # add legend

# %% [markdown]
# ## Add prediction to `ROOT` trees and Excel
# Here we'll add the precition we've computed to `ROOT` trees.

# %%
df_all.to_csv("~/Desktop/IPM/Analysis/Dataframes/tW_charm_VRR/df_all.csv")
df_all.head()
# Out:
#                 jetNo  jetPTLeading    jetETA    jetPHI  elecPTLeading  \
# entry subentry
# 0     0             1     61.355896 -2.602327  3.103293      60.271286
# 1     0             2     81.348595  3.860014 -1.635703      63.262257
#       1             2     81.348595 -2.360897  0.415761      63.262257
# 2     0             1     30.704407  4.726031  2.915039      61.715443
# 3     0             1    105.569740  3.427587  2.155524      86.568611
#
#                  elecETA   elecPHI  dielecCOS  dielecETA         met  \
# entry subentry
# 0     0        -1.375190 -1.056849   0.445503  -0.907034   74.087189
# 1     0         1.239766 -0.091067  -0.061392   0.030054  106.002663
#       1         1.209712  1.541160  -0.061392   0.030054  106.002663
# 2     0        -0.706659 -0.853577  -0.564199  -0.313872   20.235960
# 3     0         2.177542  0.244661   0.090134   0.311947   53.968071
#
#                 testnonTopMass  weight  isSignal  dense_NN  dense_NN_opt  \
# entry subentry
# 0     0             174.217696  0.0037       0.0  0.642121      0.650282
# 1     0             322.219863  0.0037       0.0  0.089996      0.092337
#       1             322.219863  0.0037       0.0  0.142491      0.096317
# 2     0             790.152292  0.0037       0.0  0.478236      0.537485
# 3     0             274.812373  0.0037       0.0  0.153267      0.076985
#
#                 dense_NN_opt_drop
# entry subentry
# 0     0                  0.656430
# 1     0                  0.158791
#       1                  0.167801
# 2     0                  0.526169
# 3     0                  0.141671

# %% [markdown]
# ## Significance

# %%
df_all.head()
#print(df_all[df_all['isSignal']==0]['weight'].unique())
# Out:
#                 jetNo  jetPTLeading    jetETA    jetPHI  elecPTLeading  \
# entry subentry
# 0     0             1     61.355896 -2.602327  3.103293      60.271286
# 1     0             2     81.348595  3.860014 -1.635703      63.262257
#       1             2     81.348595 -2.360897  0.415761      63.262257
# 2     0             1     30.704407  4.726031  2.915039      61.715443
# 3     0             1    105.569740  3.427587  2.155524      86.568611
#
#                  elecETA   elecPHI  dielecCOS  dielecETA         met  \
# entry subentry
# 0     0        -1.375190 -1.056849   0.445503  -0.907034   74.087189
# 1     0         1.239766 -0.091067  -0.061392   0.030054  106.002663
#       1         1.209712  1.541160  -0.061392   0.030054  106.002663
# 2     0        -0.706659 -0.853577  -0.564199  -0.313872   20.235960
# 3     0         2.177542  0.244661   0.090134   0.311947   53.968071
#
#                 testnonTopMass  weight  isSignal  dense_NN  dense_NN_opt  \
# entry subentry
# 0     0             174.217696  0.0037       0.0  0.642121      0.650282
# 1     0             322.219863  0.0037       0.0  0.089996      0.092337
#       1             322.219863  0.0037       0.0  0.142491      0.096317
# 2     0             790.152292  0.0037       0.0  0.478236      0.537485
# 3     0             274.812373  0.0037       0.0  0.153267      0.076985
#
#                 dense_NN_opt_drop
# entry subentry
# 0     0                  0.656430
# 1     0                  0.158791
#       1                  0.167801
# 2     0                  0.526169
# 3     0                  0.141671

# %% [markdown]
# ###

# %%
sig_weight = df_all[df_all['isSignal']==1]['weight'].unique()[0]
sig_weight = 4.8e-5
df_sig_75 = df_all[(df_all['dense_NN']>=0.60) & (df_all['isSignal']==1)]
n_sig_75 = df_sig_75.shape[0] * sig_weight
df_sig_80 = df_all[(df_all['dense_NN']>=0.65) & (df_all['isSignal']==1)]
n_sig_80 = df_sig_80.shape[0] * sig_weight
df_sig_85 = df_all[(df_all['dense_NN']>=0.70) & (df_all['isSignal']==1)]
n_sig_85 = df_sig_85.shape[0] * sig_weight

bkg_weights = df_all[df_all['isSignal']==0]['weight'].unique()
list_bkg_75 = [df_all[(df_all['dense_NN']>=0.60) & (df_all['isSignal']==0) & (df_all['weight'] == bkg_w)].shape[0] * bkg_w for bkg_w in bkg_weights]
list_bkg_80 = [df_all[(df_all['dense_NN']>=0.65) & (df_all['isSignal']==0) & (df_all['weight'] == bkg_w)].shape[0] * bkg_w for bkg_w in bkg_weights]
list_bkg_85 = [df_all[(df_all['dense_NN']>=0.70) & (df_all['isSignal']==0) & (df_all['weight'] == bkg_w)].shape[0] * bkg_w for bkg_w in bkg_weights]

print("60% : sig_n {:.10f}\tbkg_n {:.3f}\tsig/bkg {:.5f}".format(n_sig_75, sum(list_bkg_75), n_sig_75/sum(list_bkg_75)))
print("65% : sig_n {:.10f}\tbkg_n {:.3f}\tsig/bkg {:.5f}".format(n_sig_80, sum(list_bkg_80), n_sig_75/sum(list_bkg_80)))
print("70% : sig_n {:.10f}\tbkg_n {:.3f}\tsig/bkg {:.5f}".format(n_sig_85, sum(list_bkg_85), n_sig_75/sum(list_bkg_85)))
# Out:
# 60% : sig_n 3.4678560000	bkg_n 6413.631	sig/bkg 0.00054
# 65% : sig_n 2.9659200000	bkg_n 4974.940	sig/bkg 0.00070
# 70% : sig_n 2.4144000000	bkg_n 3588.045	sig/bkg 0.00097

# %%
df_sig_75 = df_all[(df_all['dense_NN_opt']>=0.60) & (df_all['isSignal']==1)]
n_sig_75 = df_sig_75.shape[0] * sig_weight
df_sig_80 = df_all[(df_all['dense_NN_opt']>=0.65) & (df_all['isSignal']==1)]
n_sig_80 = df_sig_80.shape[0] * sig_weight
df_sig_85 = df_all[(df_all['dense_NN_opt']>=0.70) & (df_all['isSignal']==1)]
n_sig_85 = df_sig_85.shape[0] * sig_weight

bkg_weights = df_all[df_all['isSignal']==0]['weight'].unique()
list_bkg_75 = [df_all[(df_all['dense_NN_opt']>=0.75) & (df_all['isSignal']==0) & (df_all['weight'] == bkg_w)].shape[0] * bkg_w for bkg_w in bkg_weights]
list_bkg_80 = [df_all[(df_all['dense_NN_opt']>=0.80) & (df_all['isSignal']==0) & (df_all['weight'] == bkg_w)].shape[0] * bkg_w for bkg_w in bkg_weights]
list_bkg_85 = [df_all[(df_all['dense_NN_opt']>=0.85) & (df_all['isSignal']==0) & (df_all['weight'] == bkg_w)].shape[0] * bkg_w for bkg_w in bkg_weights]

print("60% : sig_n {:.1f}\tbkg_n {:.1f}\tsig/bkg {:.5f}".format(n_sig_75, sum(list_bkg_75), n_sig_75/sum(list_bkg_75)))
print("65% : sig_n {:.1f}\tbkg_n {:.1f}\tsig/bkg {:.5f}".format(n_sig_80, sum(list_bkg_80), n_sig_75/sum(list_bkg_80)))
print("70% : sig_n {:.1f}\tbkg_n {:.1f}\tsig/bkg {:.5f}".format(n_sig_85, sum(list_bkg_85), n_sig_75/sum(list_bkg_85)))
# Out:
# 60% : sig_n 3.5	bkg_n 2580.7	sig/bkg 0.00136
# 65% : sig_n 3.1	bkg_n 1590.7	sig/bkg 0.00221
# 70% : sig_n 2.6	bkg_n 781.2	sig/bkg 0.00450

# %%
df_sig_75 = df_all[(df_all['dense_NN_opt_drop']>=0.60) & (df_all['isSignal']==1)]
n_sig_75 = df_sig_75.shape[0] * sig_weight
df_sig_80 = df_all[(df_all['dense_NN_opt_drop']>=0.65) & (df_all['isSignal']==1)]
n_sig_80 = df_sig_80.shape[0] * sig_weight
df_sig_85 = df_all[(df_all['dense_NN_opt_drop']>=0.70) & (df_all['isSignal']==1)]
n_sig_85 = df_sig_85.shape[0] * sig_weight

bkg_weights = df_all[df_all['isSignal']==0]['weight'].unique()
list_bkg_75 = [df_all[(df_all['dense_NN_opt_drop']>=0.75) & (df_all['isSignal']==0) & (df_all['weight'] == bkg_w)].shape[0] * bkg_w for bkg_w in bkg_weights]
list_bkg_80 = [df_all[(df_all['dense_NN_opt_drop']>=0.80) & (df_all['isSignal']==0) & (df_all['weight'] == bkg_w)].shape[0] * bkg_w for bkg_w in bkg_weights]
list_bkg_85 = [df_all[(df_all['dense_NN_opt_drop']>=0.85) & (df_all['isSignal']==0) & (df_all['weight'] == bkg_w)].shape[0] * bkg_w for bkg_w in bkg_weights]

print("60% : sig_n {:.1f}\tbkg_n {:.1f}\tsig/bkg {:.5f}".format(n_sig_75, sum(list_bkg_75), n_sig_75/sum(list_bkg_75)))
print("65% : sig_n {:.1f}\tbkg_n {:.1f}\tsig/bkg {:.5f}".format(n_sig_80, sum(list_bkg_80), n_sig_75/sum(list_bkg_80)))
print("70% : sig_n {:.1f}\tbkg_n {:.1f}\tsig/bkg {:.5f}".format(n_sig_85, sum(list_bkg_85), n_sig_75/sum(list_bkg_85)))
# Out:
# 60% : sig_n 3.7	bkg_n 2537.7	sig/bkg 0.00145
# 65% : sig_n 3.2	bkg_n 1503.5	sig/bkg 0.00244
# 70% : sig_n 2.7	bkg_n 702.6	sig/bkg 0.00522
