# %% [markdown]
# # DNN in TopFC analysis
# Author: Meisam Ghasemi Bostanabad

# %% [markdown]
# ## Loading `pandas` DataFrames
# Now we load two different `NumPy` arrays. One corresponding to the VV signal and one corresponding to the background.

# %%
import uproot
import numpy as np
import pandas as pd
import h5py
import awkward as ak
import seaborn as sns
import matplotlib.pyplot as plt
import math
from scipy import stats


# fix random seed for reproducibility
seed = 7
np.random.seed(seed)

filename = {
    'tZ':'/Users/mghasemi/Desktop/IPM/plotter/newtrees/tZ.root',
    'WZ':'/Users/mghasemi/Desktop/IPM/plotter/newtrees/WZ.root',
    'ZZ':'/Users/mghasemi/Desktop/IPM/plotter/newtrees/ZZ.root',
    'signal_tW_up_TRR':'/Users/mghasemi/Desktop/IPM/plotter/tW_trees/couplings/signal_tW_up_TRR.root'}

upfile = {}
params = {}
df = {}

# choose which vars to use (multi dimensional)
#VARS = ['jetNo','jetPTLeading','bjetPT','elecPTLeading','met','testnonTopMass', 'weight'] # choose which vars to use (2d)
VARS = ['jetNo','jetPTLeading', 'jetETA', 'jetPHI',
        'elecPTLeading', 'elecETA', 'elecPHI',
        'dielecCOS', 'dielecETA', 'met','testnonTopMass'] # choose which vars to use (2d)

# define trees and branches to make DataFrame
for treename in filename.keys():
    upfile[treename] = uproot.open(filename[treename])
    params[treename] = upfile[treename][treename].arrays(VARS)
    df[treename] = ak.to_dataframe(params[treename])
    # add isSignal variable
    if treename.startswith("signal"): 
        df[treename]['isSignal'] = np.ones(len(df[treename])) 
    else:
        df[treename]['isSignal'] = np.zeros(len(df[treename]))

# %%
print(df['signal_tW_up_TRR'].shape)
print(df['tZ'].shape)
print(df['WZ'].shape)
print(df['ZZ'].shape)
# Out:
# (77718, 12)
# (319733, 12)
# (10855, 12)
# (174, 12)

# %% [markdown]
# ## Functions

# %%
# function to plot all distributions
def hist(df1, df2, cols, bins, ncols = 3):
    nrows = math.ceil(len(cols) / ncols)
    fig, ax = plt.subplots(nrows, ncols, figsize = (5 * ncols, 4.2 * nrows), sharey = False)
    for i in range(len(cols)):
        #sns.histplot(data = df, x = cols[i], bins = bins, hue = 'isSignal', palette = ['grey', 'red'], ax = ax[i // ncols, i % ncols], stat="probability")
        sns.histplot(data = df1, x = cols[i], bins = bins, color = 'red',
                      ax = ax[i // ncols, i % ncols], stat="density", label='bkg')
        sns.histplot(data = df2, x = cols[i], bins = bins, color = 'grey',
                      ax = ax[i // ncols, i % ncols], stat="density", label='sig')       
        ax[i // ncols, i % ncols].set_xlabel(cols[i])
        ax[i // ncols, i % ncols].legend()
        if i % ncols != 0:
            ax[i // ncols, i % ncols].set_ylabel(" ")
        
    plt.tight_layout()
    plt.show()


# function to make ML output and significant plot
samples =['tZ', 'WZ', 'ZZ', 'signal_tW_up_TRR']

def plot_SoverB(data, SoverB_hist_dict):
    
    signal = r'signal_tW_up_TRR' # which sample is the signal

    # *******************
    # general definitions (shouldn't need to change)

    for x_variable,hist in SoverB_hist_dict.items(): # access the dictionary of histograms defined in the cell above

        h_bin_width = hist['bin_width'] # get the bin width defined in the cell above
        h_num_bins = hist['num_bins'] # get the number of bins defined in the cell above
        h_xrange_min = hist['xrange_min'] # get the x-range minimum defined in the cell above
        h_xlabel = hist['xlabel'] # get the x-axis label defined in the cell above
    
        bin_edges = [ h_xrange_min + x*h_bin_width for x in range(h_num_bins+1) ] # bin limits
        bin_centres = [ h_xrange_min+h_bin_width/2 + x*h_bin_width for x in range(h_num_bins) ] # bin centres
        
        signal_x = data[signal][x_variable] # histogram the signal
    
        mc_x = [] # define list to hold the Monte Carlo histogram entries

        for s in samples: # loop over samples
            if s not in ['data', signal]: # if not data nor signal
                mc_x = [*mc_x, *data[s][x_variable] ] # append to the list of Monte Carlo histogram entries
                #test=[]; test.append(df[s]['NN_output_prob'].values)


    
    
        # *************
        # Signal and background distributions
        # *************
        distributions_axes = plt.gca() # get current axes
 
        mc_heights = distributions_axes.hist(mc_x, bins=bin_edges, color='red', 
                                             label='Total background',
                                             histtype='step', # lineplot that's unfilled
                                             density=True ) # normalize to form probability density
        signal_heights = distributions_axes.hist(signal_x, bins=bin_edges, color='blue',
                                                 label=signal, 
                                                 histtype='step', # lineplot that's unfilled
                                                 density=True, # normalize to form probability density
                                                 linestyle='--' ) # dashed line
        
        distributions_axes.set_xlim( left=bin_edges[0], right=bin_edges[-1] ) # x-limits of the distributions axes
        distributions_axes.set_ylabel('Arbitrary units' ) # y-axis label for distributions axes
        y_max = max(max(signal_heights[0]), max(mc_heights[0]) )
        #distributions_axes.set_ylim( top=max(signal_heights[0])*1.3 ) # set y-axis limits
        distributions_axes.set_ylim( top=y_max*1.2 ) # set y-axis limits
        #distributions_axes.set_ylim( top=max(signal_heights[0])*1.3 ) # set y-axis limits
        plt.title('Signal and background '+x_variable+' distributions') # add title
        distributions_axes.legend() # draw the legend
        distributions_axes.set_xlabel( h_xlabel ) # x-axis label
            
        plt.show() # show the Signal and background distributions
    
    
        # *************
        # Signal to background ratio
        # *************
        plt.figure() # start new figure
        SoverB = [] # list to hold S/B values
        for cut_value in bin_edges: # loop over bins
            #signal_weights_passing_cut = sum(data[signal][data[signal][x_variable]>cut_value].totalWeight)
            signal_weights_passing_cut = len(data[signal][data[signal][x_variable]>cut_value])
            background_weights_passing_cut = 0 # start counter for background weights passing cut
            for s in samples: # loop over samples
                if s not in ['data', signal]: # if not data nor signal
                    #background_weights_passing_cut += sum(data[s][data[s][x_variable]>cut_value].totalWeight)
                    background_weights_passing_cut += len(data[s][data[s][x_variable]>cut_value])
            if background_weights_passing_cut!=0: # some background passes cut
                SoverB_value = signal_weights_passing_cut/background_weights_passing_cut
                SoverB_percent = 100*SoverB_value # multiply by 100 for percentage
                SoverB.append(SoverB_percent) # append to list of S/B values
        
        SoverB_axes = plt.gca() # get current axes
        SoverB_axes.plot( bin_edges[:len(SoverB)], SoverB ) # plot the data points
        SoverB_axes.set_xlim( left=bin_edges[0], right=bin_edges[-1] ) # set the x-limit of the main axes
        #SoverB_axes.set_ylim( 100, 1000)
        SoverB_axes.set_ylabel( 'S/B (%)' ) # write y-axis label for main axes
        plt.title('Signal to background ratio for different '+x_variable+' cut values', family='sans-serif')
        SoverB_axes.set_xlabel( h_xlabel ) # x-axis label 
        
        plt.show() # show S/B plot
    
    return    

from sklearn.metrics import roc_curve, auc, classification_report, accuracy_score, confusion_matrix

# function to draw loss-accuracy vs epoch and ROC curve
# %matplotlib inline
def loss_accuracy_plotter(history):
    # plot loss vs epoch
    plt.figure(figsize=(15,10))
    ax = plt.subplot(2, 2, 1)
    ax.plot(history.history['loss'], label='loss')
    ax.plot(history.history['val_loss'], label='val_loss')
    ax.legend(loc="upper right")
    ax.set_title('Loss over epochs')
    ax.set_xlabel('epoch')
    ax.set_ylabel('loss')

    # plot accuracy vs epoch
    ax = plt.subplot(2, 2, 2)
    ax.plot(history.history['accuracy'], label='acc')
    ax.plot(history.history['val_accuracy'], label='val_acc')
    ax.legend(loc="lower right")
    ax.set_title('Accuracy over epochs')
    ax.set_xlabel('epoch')
    ax.set_ylabel('acc')

    # Plot ROC
    Y_predict = model.predict(X_test)
    Y_predict_train = model.predict(X_train_val)
    fpr, tpr, thresholds = roc_curve(Y_test, Y_predict)
    roc_auc = auc(fpr, tpr)
    ax = plt.subplot(2, 2, 3)
    ax.plot(fpr, tpr, lw=2, color='cyan', label='auc = %.3f' % (roc_auc))
    ax.plot([0, 1], [0, 1], linestyle='--', lw=2, color='k', label='random chance')
    ax.set_xlim([0, 1.0])
    ax.set_ylim([0, 1.0])
    ax.set_xlabel('false positive rate')
    ax.set_ylabel('true positive rate')
    ax.set_title('receiver operating curve')
    ax.legend(loc="lower right")
    plt.show()

# function to report all metrics evaluation
def evaluate(model, scaler, X, Y, X_train_val, Y_train_val, X_test, Y_test):
    Y_pred_test = model.predict(X_test)
    Y_pred_test = Y_pred_test.reshape(Y_pred_test.shape[0])
    Y_pred_train = model.predict(X_train_val)
    Y_pred_train = Y_pred_train.reshape(Y_pred_train.shape[0])
    Y_pred_tot = model.predict(scaler.transform(X)).round()
    Y_pred_tot = Y_pred_tot.reshape(Y_pred_tot.shape[0])

    # accuracy score
    print("Test acc score:", accuracy_score(Y_test.round(), Y_pred_test.round()))
    print("Train acc score:", accuracy_score(Y_train_val.round(), Y_pred_train.round()))

    # classification report for the test and total sets
    print("Classification report for the test set")
    print(classification_report(Y_test.round(), Y_pred_test.round(), target_names=['background', 'signal']))
    print("Classification report for the total set")
    print(classification_report(Y.round(), Y_pred_tot.round(), target_names=['background', 'signal']))

    print("Confusion matrix for total set")
    print(confusion_matrix(Y.round(), Y_pred_tot.round()))

    fpr, tpr, thresholds = roc_curve(Y_test, Y_pred_test) # get FPRs, TPRs and thresholds for neural network
    return fpr, tpr, thresholds

# plot AMS
def AMS(tpr, fpr, b_reg): # define function to calculate AMS
    return np.sqrt(2*((tpr+fpr+b_reg)*np.log(1+tpr/(fpr+b_reg))-tpr)) # equation for AMS

def cdf(sample, x, sort = False):
    '''
    Return the value of the Cumulative Distribution Function, evaluated for a given sample and a value x.
    
    Args:
        sample: The list or array of observations.
        x: The value for which the numerical cdf is evaluated.
    
    Returns:
        cdf = CDF_{sample}(x)
    '''
    
    # Sorts the sample, if needed
    if sort:
        sample.sort()
    
    # Counts how many observations are below x
    cdf = sum(sample <= x)
    
    # Divides by the total number of observations
    cdf = cdf / len(sample)
    
    return cdf

def ks_2samp_test(sample1, sample2):
    
    # Gets all observations
    observations = np.concatenate((sample1, sample2))
    observations.sort()
    
    # Sorts the samples
    sample1.sort()
    sample2.sort()
    
    # Evaluates the KS statistic
    D_ks = [] # KS Statistic list
    for x in observations:
        cdf_sample1 = cdf(sample = sample1, x  = x)
        cdf_sample2 = cdf(sample = sample2, x  = x)
        D_ks.append(abs(cdf_sample1 - cdf_sample2))
    ks_stat = max(D_ks)
    
    # Calculates the P-Value based on the two-sided test
    # The P-Value comes from the KS Distribution Survival Function (SF = 1-CDF)
    m, n = float(len(sample1)), float(len(sample2))
    en = m * n / (m + n)
    p_value = stats.kstwo.sf(ks_stat, np.round(en))
    
    return {"ks_stat": ks_stat, "p_value" : p_value}

# plot train and test CLF distributions
def new_compare_train_test(clf, X_train, y_train, X_test, y_test, xlabel):
    decisions = [] # list to hold decisions of classifier
    for X,y in ((X_train, y_train), (X_test, y_test)): # train and test
        d1 = clf.predict(X[y<0.5]) # background
        d2 = clf.predict(X[y>0.5]) # signal
        decisions += [d1, d2] # add to list of classifier decision

    highest_decision = max(np.max(d) for d in decisions) # get maximum score
    bin_edges = [] # list to hold bin edges
    bin_edge = -0.1 # start counter for bin_edges
    while bin_edge < highest_decision: # up to highest score
        bin_edge += 0.1 # increment
        bin_edges.append(bin_edge)

    # Training plots
    plt.hist(decisions[0], # background in train set
            bins=bin_edges, # lower and upper range of the bins
            density=True, # area under the histogram will sum to 1
            histtype='stepfilled', # lineplot that's filled
            color='blue', label='Background (train)', # Background (train)
            alpha=0.5 ) # half transparency
    plt.hist(decisions[1], # signal in train set
            bins=bin_edges, # lower and upper range of the bins
            density=True, # area under the histogram will sum to 1
            histtype='stepfilled', # lineplot that's filled
            color='orange', label='Signal (train)', # Signal (train)
            alpha=0.5 ) # half transparency

    # Testing plots
    hist_background, bin_edges = np.histogram(decisions[2], # background test
                                            bins=bin_edges, # number of bins in function definition
                                            density=True ) # area under the histogram will sum to 1

    scale = len(decisions[2]) / sum(hist_background) # between raw and normalised
    err_background = np.sqrt(hist_background * scale) / scale # error on test background

    width = 0.1 # histogram bin width
    center = (bin_edges[:-1] + bin_edges[1:]) / 2 # bin centres

    plt.errorbar(x=center, y=hist_background, yerr=err_background, fmt='o', # circles
                c='blue', label='Background (test)' ) # Background (test)

    hist_signal, bin_edges = np.histogram(decisions[3], # siganl test
                                        bins=bin_edges, # number of bins in function definition
                                        density=True ) # area under the histogram will sum to 1

    scale = len(decisions[3]) / sum(hist_signal) # between raw and normalised
    err_signal = np.sqrt(hist_signal * scale) / scale # error on test background

    plt.errorbar(x=center, y=hist_signal, yerr=err_signal, fmt='*', # circles
                c='orange', label='Signal (test)' ) # Signal (test)

    plt.xlabel(xlabel) # write x-axis label
    plt.ylabel("Arbitrary units") # write y-axis label
    plt.legend() # add legend
    ks_signal = ks_2samp_test(np.array(decisions[1]), np.array(decisions[3]))
    ks_background = ks_2samp_test(np.array(decisions[0]), np.array(decisions[2]))
    print(f"Signal: ks = {ks_signal['ks_stat']} (p-value = {ks_signal['p_value']}, are equal = {ks_signal['p_value'] > 0.05})")
    print(f"Background: ks = {ks_background['ks_stat']} (p-value = {ks_background['p_value']}, are equal = {ks_background['p_value'] > 0.05})")
    #return (decisions[0], decisions[2])

# %% [markdown]
# ## Data exploration

# %%
# reduce signal DF size to have resonable Sig/Bkg ratio
#df['signal_tW_up_TRR'] = df['signal_tW_up_TRR'][:20000]
df['tZ'] = df['tZ'][:10000]
df_all = pd.concat([df[treename] for treename in filename.keys()])

# %%
# number of entries in the backgrounds and signals
sns.set_theme(style="white")

tot_bkg = 0
for treename in filename.keys():
    if not 'signal' in treename: tot_bkg += df[treename].shape[0]
    print(treename, ":", df[treename].shape)

print("signal/tot bkg:", round((df['signal_tW_up_TRR'].shape[0]/ tot_bkg),1))
#print("Null entries:", df['signal_charm'].isna().sum())

counts_signal = df['signal_tW_up_TRR'].shape[0]
counts_background = tot_bkg

plt.figure(figsize=(8,6))
plt.pie([counts_signal, counts_background], explode=[0.1,0.1], shadow=True, labels=['Signal ','Background'], textprops={'fontsize': 14}, autopct='%1.1f%%');
#plt.pie([counts_signal, counts_background], explode=[0.1,0.1], shadow=True, labels=['Signal ','Background'], textprops={'color':"b"}, autopct='%1.1f%%');
# Out:
# tZ : (10000, 12)
# WZ : (10855, 12)
# ZZ : (174, 12)
# signal_tW_up_TRR : (77718, 12)
# signal/tot bkg: 3.7

# %%
plt.figure(figsize=(13,10))
#sns.set_theme(style="white")

# Getting the Upper Triangle of the co-relation matrix
corr = df_all.corr()
#matrix = np.triu(corr)
#mask = np.triu(np.ones_like(corr, dtype=bool))
matrix = np.triu(np.ones_like(corr))


cmap = sns.diverging_palette(200, 7, s=75, l=40,
                            n=5, center="light", as_cmap=True)

#sns.heatmap(df_test.corr(), annot=True, linewidth=.5, vmin = -1, vmax = 1,cmap = plt.cm.CMRmap_r, fmt=".1f", mask=matrix);
sns.heatmap(df_all.corr(), annot=True, linewidth=.5, vmin = -1, vmax = 1,cmap = cmap, fmt=".2f", mask=matrix);

# %%
df_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 56873 entries, (0, 0) to (14432, 1)
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   jetNo           56873 non-null  int32
#  1   jetPTLeading    56873 non-null  float64
#  2   jetETA          56873 non-null  float64
#  3   jetPHI          56873 non-null  float64
#  4   elecPTLeading   56873 non-null  float64
#  5   elecETA         56873 non-null  float64
#  6   elecPHI         56873 non-null  float64
#  7   dielecCOS       56873 non-null  float64
#  8   dielecETA       56873 non-null  float64
#  9   met             56873 non-null  float64
#  10  testnonTopMass  56873 non-null  float64
#  11  isSignal        56873 non-null  float64
# dtypes: float64(11), int32(1)
# memory usage: 5.8 MB

# %%
# Distributions of the float features
hist(df_all[df_all['isSignal']==0].replace(-999, np.nan),
     df_all[df_all['isSignal']==1].replace(-999, np.nan),
     #list(df_all.columns[df_all.dtypes == 'float64']),
     list(df_all.columns),
     bins = math.floor(len(df_all)**(1/3)),
     ncols = 3)

# %% [markdown]
# ## Define the models

# %% [markdown]
# ## simple NN from Tensorflow
# We'll start with a dense (fully-connected) NN layer.
# Our model will have a single fully-connected hidden layer with the same number of neurons as input variables.
# The weights are initialized using a small Gaussian random number.
# We will switch between linear and tanh activation functions for the hidden layer.
# The output layer contains a single neuron in order to make predictions.
# It uses the sigmoid activation function in order to produce a probability output in the range of 0 to 1.
#
# We are using the `binary_crossentropy` loss function during training, a standard loss function for binary classification problems.
# We will optimize the model with the Adam algorithm for stochastic gradient descent and we will collect accuracy metrics while the model is trained.

# %% [markdown]
# ## Dividing the data into testing and training dataset
#
# We will split the data into two parts (one for training+validation and one for testing).
# We will also apply "standard scaling" preprocessing: http://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.StandardScaler.html i.e. making the mean = 0 and the RMS = 1 for all input variables (based **only** on the training/validation dataset).
# We will also define our early stopping criteria to prevent over-fitting and we will save the model based on the best `val_loss`.

# %%
NDIM = len(VARS)
dataset = df_all.values
X = dataset[:,0:NDIM]
Y = dataset[:,NDIM]

from sklearn.model_selection import train_test_split
X_train_val, X_test, Y_train_val, Y_test = train_test_split(X, Y, test_size=0.2, random_state=7)

# preprocessing: standard scalar
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler().fit(X_train_val)
X_train_val = scaler.transform(X_train_val)
X_test = scaler.transform(X_test)

# baseline keras model
from keras.models import Sequential, Model
from tensorflow.keras.optimizers import SGD
#from keras.optimizers import SGD
from keras.layers import Input, Activation, Dense, Convolution2D, MaxPooling2D, Dropout, Flatten
from keras.utils import np_utils
from sklearn.model_selection import RandomizedSearchCV
from sklearn.pipeline import Pipeline
from tensorflow import keras

inputs = Input(shape=(NDIM,), name = 'input') 
hidden1 = Dense(20, name = 'hidden1', kernel_initializer='normal', activation='relu')(inputs)
hidden2 = Dense(20, name = 'hidden2', kernel_initializer='normal', activation='relu')(hidden1)
outputs = Dense(1, name = 'output', kernel_initializer='normal', activation='sigmoid')(hidden2)

# create the model
model = Model(inputs=inputs, outputs=outputs)
# compile the model
optimizer = SGD(learning_rate=1e-3) # define the optimizer
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
#model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])
# print the model summary
model.summary()

# early stopping callback
from keras.callbacks import EarlyStopping
early_stopping = EarlyStopping(monitor='val_loss', patience=10, mode='min')

# model checkpoint callback
# this saves our model architecture + parameters into dense_model.h5
from keras.callbacks import ModelCheckpoint
model_checkpoint = ModelCheckpoint(filepath='./models/up_NN_model.h5', monitor='val_loss', 
                                   verbose=0, save_best_only=True, 
                                   save_weights_only=False, mode='auto', 
                                   period=1)
# Out:
# Model: "model_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input (InputLayer)          [(None, 11)]              0
#
#  hidden1 (Dense)             (None, 20)                240
#
#  hidden2 (Dense)             (None, 20)                420
#
#  output (Dense)              (None, 1)                 21
#
# =================================================================
# Total params: 681
# Trainable params: 681
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %% [markdown]
# ## Run training
# Here, we run the training.

# %%
# Train classifier
import time
start = time.time() # time at start of whole processing

history = model.fit(X_train_val, 
                    Y_train_val, 
                    epochs=1000, 
                    batch_size=512, 
                    verbose=1, # switch to 1 for more verbosity 
                    callbacks=[early_stopping, model_checkpoint], 
                    validation_data=(X_test,Y_test))

elapsed = time.time() - start # time after whole processing
print("Time taken: "+str(round(elapsed,1))+"s") # print total time taken to process every file
# Out:
# Epoch 1/1000
# 89/89 [==============================] - 1s 3ms/step - loss: 0.6702 - accuracy: 0.6275 - val_loss: 0.6427 - val_accuracy: 0.6265
# Epoch 2/1000
# 89/89 [==============================] - 0s 2ms/step - loss: 0.6278 - accuracy: 0.6381 - val_loss: 0.6226 - val_accuracy: 0.6670
# Epoch 3/1000
# 89/89 [==============================] - 0s 2ms/step - loss: 0.6089 - accuracy: 0.6867 - val_loss: 0.6083 - val_accuracy: 0.6920
# Epoch 4/1000
# 89/89 [==============================] - 0s 2ms/step - loss: 0.6010 - accuracy: 0.6990 - val_loss: 0.6033 - val_accuracy: 0.7005
# Epoch 5/1000
# 89/89 [==============================] - 0s 2ms/step - loss: 0.5983 - accuracy: 0.7019 - val_loss: 0.6010 - val_accuracy: 0.7022
# Epoch 6/1000
# 89/89 [==============================] - 0s 3ms/step - loss: 0.5961 - accuracy: 0.7039 - val_loss: 0.5989 - val_accuracy: 0.7036
# Epoch 7/1000
# 89/89 [==============================] - 0s 2ms/step - loss: 0.5942 - accuracy: 0.7057 - val_loss: 0.5969 - val_accuracy: 0.7044
# Epoch 8/1000
# 89/89 [==============================] - 0s 2ms/step - loss: 0.5922 - accuracy: 0.7058 - val_loss: 0.5951 - val_accuracy: 0.7052
# Epoch 9/1000
# 89/89 [==============================] - 0s 3ms/step - loss: 0.5903 - accuracy: 0.7075 - val_loss: 0.5943 - val_accuracy: 0.7054
# Epoch 10/1000
# 89/89 [==============================] - 0s 2ms/step - loss: 0.5886 - accuracy: 0.7079 - val_loss: 0.5927 - val_accuracy: 0.7043
# Epoch 11/1000
# 89/89 [==============================] - 0s 2ms/step - loss: 0.5870 - accuracy: 0.7089 - val_loss: 0.5911 - val_accuracy: 0.7060
# Epoch 12/1000
# 89/89 [==============================] - 0s 2ms/step - loss: 0.5858 - accuracy: 0.7086 - val_loss: 0.5895 - val_accuracy: 0.7056
# Epoch 13/1000
# 89/89 [==============================] - 0s 2ms/step - loss: 0.5845 - accuracy: 0.7100 - val_loss: 0.5881 - val_accuracy: 0.7069
# Epoch 14/1000
# 89/89 [==============================] - 0s 2ms/step - loss: 0.5835 - accuracy: 0.7104 - val_loss: 0.5874 - val_accuracy: 0.7081
# Epoch 15/1000
# 89/89 [==============================] - 0s 2ms/step - loss: 0.5831 - accuracy: 0.7094 - val_loss: 0.5874 - val_accuracy: 0.7048
# Epoch 16/1000
# 89/89 [==============================] - 0s 2ms/step - loss: 0.5821 - accuracy: 0.7095 - val_loss: 0.5859 - val_accuracy: 0.7080
# Epoch 17/1000
# 89/89 [==============================] - 0s 1ms/step - loss: 0.5813 - accuracy: 0.7099 - val_loss: 0.5865 - val_accuracy: 0.7069
# Epoch 18/1000
# 89/89 [==============================] - 0s 2ms/step - loss: 0.5805 - accuracy: 0.7103 - val_loss: 0.5851 - val_accuracy: 0.7079
# Epoch 19/1000
# 89/89 [==============================] - 0s 2ms/step - loss: 0.5801 - accuracy: 0.7105 - val_loss: 0.5839 - val_accuracy: 0.7106
# Epoch 20/1000
# 89/89 [==============================] - 0s 2ms/step - loss: 0.5792 - accuracy: 0.7108 - val_loss: 0.5842 - val_accuracy: 0.7093
# Epoch 21/1000
# 89/89 [==============================] - 0s 2ms/step - loss: 0.5787 - accuracy: 0.7113 - val_loss: 0.5834 - val_accuracy: 0.7095
# Epoch 22/1000
# 89/89 [==============================] - 0s 5ms/step - loss: 0.5781 - accuracy: 0.7115 - val_loss: 0.5830 - val_accuracy: 0.7101
# Epoch 23/1000
# 89/89 [==============================] - 0s 4ms/step - loss: 0.5778 - accuracy: 0.7117 - val_loss: 0.5823 - val_accuracy: 0.7110
# Epoch 24/1000
# 89/89 [==============================] - 0s 5ms/step - loss: 0.5774 - accuracy: 0.7121 - val_loss: 0.5830 - val_accuracy: 0.7096
# Epoch 25/1000
# 89/89 [==============================] - 0s 2ms/step - loss: 0.5772 - accuracy: 0.7128 - val_loss: 0.5825 - val_accuracy: 0.7099
# Epoch 26/1000
# 89/89 [==============================] - 0s 3ms/step - loss: 0.5764 - accuracy: 0.7126 - val_loss: 0.5828 - val_accuracy: 0.7099
# Epoch 27/1000
# 89/89 [==============================] - 0s 5ms/step - loss: 0.5760 - accuracy: 0.7130 - val_loss: 0.5814 - val_accuracy: 0.7101
# Epoch 28/1000
# 89/89 [==============================] - 0s 2ms/step - loss: 0.
# Classification report for the test set
#               precision    recall  f1-score   support
#
#   background       0.69      0.43      0.53      4249
#       signal       0.72      0.88      0.79      7126
#
#     accuracy                           0.71     11375
#    macro avg       0.70      0.66      0.66     11375
# weighted avg       0.71      0.71      0.70     11375
#
# Classification report for the total set
#               precision    recall  f1-score   support
#
#   background       0.69      0.44      0.54     21029
#       signal       0.73      0.88      0.80     35844
#
#     accuracy                           0.72     56873
#    macro avg       0.71      0.66      0.67     56873
# weighted avg       0.72      0.72      0.70     56873
#
# Confusion matrix for total set
# [[ 9284 11745]
#  [ 4139 31705]]
# 1778/1778 [==============================] - 1s 781us/step

# %%
# add TF NN probability
y_tot_prob_NN = model.predict(scaler.transform(X))
y_tot_NN = model.predict(scaler.transform(X)).round()

cumulative_events = 0 # start counter for total number of events for which output is saved
for key in filename.keys(): # loop over samples
    df[key]['NN_output_prob'] = y_tot_prob_NN[cumulative_events:cumulative_events+len(df[key])]
    df[key]['NN_output'] = y_tot_NN[cumulative_events:cumulative_events+len(df[key])]
    cumulative_events += len(df[key]) # increment counter for total number of events
    #print(df[key]['NN_output']) # print the dataframe column NN_output

# probability and significance plots
NN_output_prob = { # dictionary containing plotting parameters for the mllll histogram
    # change plotting parameters
    'bin_width':0.1, # width of each histogram bin
    'num_bins':9, # number of histogram bins
    'xrange_min':0, # minimum on x-axis
    'xlabel':'Neural Network output', # x-axis label
}

SoverB_hist_dict = {'NN_output_prob':NN_output_prob}
plot_SoverB(df, SoverB_hist_dict)
# Out:
# 1778/1778 [==============================] - 1s 802us/step
# 1778/1778 [==============================] - 2s 1ms/step

# %% [markdown]
# ## NN Hyperparameter optimization

# %%
def main():
        
    keras_pipeline = Pipeline([("scaler", StandardScaler()),
                               ("clf", keras.wrappers.scikit_learn.KerasClassifier(
                                   build_fn=make_model))
    ])
    
    param_grid = {'clf__network_layers': [(32, 32), (64, 64), (128, 128, 128)],
     'clf__batch_size': [64, 128, 256, 512],
     'clf__epochs': [5, 10, 15, 50, 100, 200],
     'clf__dropout_rate': [0.1, 0.01],
     'clf__optimizer': ['Nadam', 'Adam', 'SGD'],
     'clf__activation': ['selu', 'relu', 'tanh'],
     'clf__k_initializer': ['lecun_normal', 'normal'],
     'clf__verbose': [0]
    }
    
    rs_keras = RandomizedSearchCV(keras_pipeline,
                                  param_distributions=param_grid,
                                  cv=5, refit=True,
                                  verbose=0,
                                  n_iter=5,
                                  scoring="accuracy")
    
    history = rs_keras.fit(np.array(X_train_val),
                 np.array(Y_train_val))
    
    print('Best score obtained: {0}'.format(rs_keras.best_score_))
    print('Parameters:')
    for param, value in rs_keras.best_params_.items():
        print('\t{}: {}'.format(param, value))
    return  rs_keras  

def make_model(network_layers=[(32, 32)],
               dropout_rate=0,
               optimizer="Nadam",
               activation="selu",
               k_initializer='lecun_normal',
               n_input=NDIM,
               n_class=1):
    
    model = keras.models.Sequential()

    for index, layers in enumerate(network_layers):
        if not index:
            model.add(keras.layers.Dense(layers,
                                         input_dim=n_input,
                                         activation=activation,
                                         kernel_initializer=k_initializer))
        else:
            model.add(keras.layers.Dense(layers,
                                         kernel_initializer=k_initializer,
                                         activation=activation))
        if dropout_rate and index:
            model.add(keras.layers.AlphaDropout(dropout_rate))

    model.add(keras.layers.Dense(n_class,
                                 activation="sigmoid"))
    
    model.compile(loss='binary_crossentropy',
                  optimizer=optimizer,
                  metrics=['accuracy'])
    #print(model.summary())
    return model

do_opt = False
if (do_opt):
    if __name__ == '__main__':
        opt_model = main()
# Out:
# <ipython-input-86-bde57a8852a8>:4: DeprecationWarning: KerasClassifier is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   ("clf", keras.wrappers.scikit_learn.KerasClassifier(
# 162/162 [==============================] - 0s 1ms/step
# 162/162 [==============================] - 1s 722us/step
# 162/162 [==============================] - 0s 675us/step
# 162/162 [==============================] - 0s 794us/step
# 162/162 [==============================] - 0s 1ms/step
# 162/162 [==============================] - 0s 1ms/step
# 162/162 [==============================] - 0s 823us/step
# 162/162 [==============================] - 0s 806us/step
# 162/162 [==============================] - 0s 852us/step
# 162/162 [==============================] - 0s 825us/step
# 162/162 [==============================] - 0s 959us/step
# 162/162 [==============================] - 0s 974us/step
# 162/162 [==============================] - 0s 984us/step
# 162/162 [==============================] - 0s 1ms/step
# 162/162 [==============================] - 0s 969us/step
# 162/162 [==============================] - 0s 816us/step
# 162/162 [==============================] - 0s 771us/step
# 162/162 [==============================] - 0s 856us/step
# 162/162 [==============================] - 0s 1ms/step
# 162/162 [==============================] - 0s 2ms/step
# 162/162 [==============================] - 0s 884us/step
# 162/162 [==============================] - 0s 872us/step
# 162/162 [==============================] - 0s 871us/step
# 162/162 [==============================] - 0s 1ms/step
# 162/162 [==============================] - 0s 905us/step
# Best score obtained: 0.7095234975447843
# Parameters:
# 	clf__verbose: 0
# 	clf__optimizer: Nadam
# 	clf__network_layers: (128, 128, 128)
# 	clf__k_initializer: normal
# 	clf__epochs: 200
# 	clf__dropout_rate: 0.1
# 	clf__batch_size: 256
# 	clf__activation: selu

# %%
'''
Best score obtained: 0.7094453833758017
Parameters:
	clf__verbose: 0
	clf__optimizer: Nadam
	clf__network_layers: (128, 128, 128)
	clf__k_initializer: normal
	clf__epochs: 200
	clf__dropout_rate: 0.1
	clf__batch_size: 256
	clf__activation: selu

'''
# Out:
# '\nBest score obtained: 0.7094453833758017\nParameters:\n\tclf__verbose: 0\n\tclf__optimizer: Nadam\n\tclf__network_layers: (128, 128, 128)\n\tclf__k_initializer: normal\n\tclf__epochs: 200\n\tclf__dropout_rate: 0.1\n\tclf__batch_size: 256\n\tclf__activation: selu\n\n'

# %% [markdown]
# ## NN with dropout layer for overfit checking

# %%
# Packages for modeling
from keras import models
from keras import layers
from keras import regularizers

drop_model = models.Sequential()
drop_model.add(layers.Dense(128,  kernel_initializer='normal', activation='selu', input_shape=(NDIM,)))
drop_model.add(layers.Dropout(0.1))
drop_model.add(layers.Dense(128,  kernel_initializer='normal', activation='selu'))
drop_model.add(layers.Dropout(0.1))
drop_model.add(layers.Dense(128,  kernel_initializer='normal', activation='selu'))
drop_model.add(layers.Dropout(0.1))
drop_model.add(layers.Dense(1, kernel_initializer='normal', activation='sigmoid'))

# compile the model
drop_model.compile(optimizer='Nadam', loss='binary_crossentropy', metrics=['accuracy'])
#drop_model.compile(optimizer='Adam', loss='binary_crossentropy', metrics=['accuracy'])
# print the model summary
drop_model.summary()

# early stopping callback
from keras.callbacks import EarlyStopping
early_stopping = EarlyStopping(monitor='val_loss', patience=10, mode='min')

# Train classifier
import time
start = time.time() # time at start of whole processing

model_checkpoint = ModelCheckpoint(filepath='./models/up_NN_opt_drop_model.h5', monitor='val_loss', 
                                   verbose=0, save_best_only=True, 
                                   save_weights_only=False, mode='auto', 
                                   period=1)

drop_history = drop_model.fit(X_train_val, 
                    Y_train_val, 
                    epochs=200, 
                    batch_size=256, 
                    verbose=1, # switch to 1 for more verbosity 
                    callbacks=[early_stopping, model_checkpoint], 
                    validation_data=(X_test,Y_test))

elapsed = time.time() - start # time after whole processing
print("Time taken: "+str(round(elapsed,1))+"s") # print total time taken to process every file
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_7 (Dense)             (None, 128)               1536
#
#  dropout_5 (Dropout)         (None, 128)               0
#
#  dense_8 (Dense)             (None, 128)               16512
#
#  dropout_6 (Dropout)         (None, 128)               0
#
#  dense_9 (Dense)             (None, 128)               16512
#
#  dropout_7 (Dropout)         (None, 128)               0
#
#  dense_10 (Dense)            (None, 1)                 129
#
# =================================================================
# Total params: 34,689
# Trainable params: 34,689
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/200
# 178/178 [==============================] - 3s 5ms/step - loss: 0.6197 - accuracy: 0.6796 - val_loss: 0.6151 - val_accuracy: 0.6855
# Epoch 2/200
# 178/178 [==============================] - 1s 4ms/step - loss: 0.6053 - accuracy: 0.6957 - val_loss: 0.6003 - val_accuracy: 0.6997
# Epoch 3/200
# 178/178 [==============================] - 1s 4ms/step - loss: 0.5984 - accuracy: 0.6989 - val_loss: 0.5957 - val_accuracy: 0.7026
# Epoch 4/200
# 178/178 [==============================] - 1s 4ms/step - loss: 0.5974 - accuracy: 0.6992 - val_loss: 0.5950 - val_accuracy: 0.7042
# Epoch 5/200
# 178/178 [==============================] - 1s 4ms/step - loss: 0.5943 - accuracy: 0.7014 - val_loss: 0.5938 - val_accuracy: 0.6997
# Epoch 6/200
# 178/178 [==============================] - 1s 4ms/step - loss: 0.5935 - accuracy: 0.7014 - val_loss: 0.5910 - val_accuracy: 0.7009
# Epoch 7/200
# 178/178 [==============================] - 1s 6ms/step - loss: 0.5914 - accuracy: 0.7012 - val_loss: 0.5911 - val_accuracy: 0.7022
# Epoch 8/200
# 178/178 [==============================] - 1s 5ms/step - loss: 0.5909 - accuracy: 0.7012 - val_loss: 0.5877 - val_accuracy: 0.7044
# Epoch 9/200
# 178/178 [==============================] - 1s 4ms/step - loss: 0.5897 - accuracy: 0.7033 - val_loss: 0.5892 - val_accuracy: 0.7025
# Epoch 10/200
# 178/178 [==============================] - 1s 6ms/step - loss: 0.5890 - accuracy: 0.7039 - val_loss: 0.5875 - val_accuracy: 0.6998
# Epoch 11/200
# 178/178 [==============================] - 1s 5ms/step - loss: 0.5892 - accuracy: 0.7019 - val_loss: 0.5901 - val_accuracy: 0.7056
# Epoch 12/200
# 178/178 [==============================] - 1s 5ms/step - loss: 0.5888 - accuracy: 0.7019 - val_loss: 0.5885 - val_accuracy: 0.7029
# Epoch 13/200
# 178/178 [==============================] - 1s 4ms/step - loss: 0.5883 - accuracy: 0.7024 - val_loss: 0.5851 - val_accuracy: 0.7021
# Epoch 14/200
# 178/178 [==============================] - 1s 4ms/step - loss: 0.5871 - accuracy: 0.7038 - val_loss: 0.5855 - val_accuracy: 0.7050
# Epoch 15/200
# 178/178 [==============================] - 1s 4ms/step - loss: 0.5864 - accuracy: 0.7023 - val_loss: 0.5875 - val_accuracy: 0.7043
# Epoch 16/200
# 178/178 [==============================] - 1s 4ms/step - loss: 0.5858 - accuracy: 0.7037 - val_loss: 0.5847 - val_accuracy: 0.7051
# Epoch 17/200
# 178/178 [==============================] - 1s 4ms/step - loss: 0.5859 - accuracy: 0.7041 - val_loss: 0.5835 - val_accuracy: 0.7043
# Epoch 18/200
# 178/178 [==============================] - 1s 3ms/step - loss: 0.5850 - accuracy: 0.7048 - val_loss: 0.5837 - val_accuracy: 0.7039
# Epoch 19/200
# 178/178 [==============================] - 1s 4ms/step - loss: 0.5840 - accuracy: 0.7065 - val_loss: 0.5826 - val_accuracy: 0.7057
# Epoch 20/200
# 178/178 [==============================] - 1s 4ms/step - loss: 0.5835 - accuracy: 0.7052 - val_loss: 0.5828 - val_accuracy: 0.7047
# Epoch 21/200
# 178/178 [==============================] - 1s 3ms/step - loss: 0.5829 - accuracy: 0.7049 - val_loss: 0.5833 - val_accuracy: 0.7025
# Epoch 22/200
# 178/178 [==============================] - 1s 4ms/step - loss: 0.5827 - accuracy: 0.7059 - val_loss: 0.5824 - val_accuracy: 0.7052
# Epoch 23/200
# 178/178 [==============================] - 1s 4ms/step - loss: 0.5822 - accuracy: 0.7058 - val_loss: 0.5802 - val_accuracy: 0.7065
# Epoch 24/200
# 178/178 [==============================] - 1s 3ms/step - loss: 0.5814 - accuracy: 0.7063 - val_loss: 0.5816 - val_accuracy: 0.7082
# Epoch 25/200
# 178/178 [==============================] - 1s 3ms/step - loss: 0.5813 - accuracy: 0.7060 - val_loss: 0.5807 - val_accuracy: 0.7078
# Epoch 26/200
# 178/178 [==============================] - 1s 4ms/step - loss: 0.5811 - accuracy: 0.7069 - val_loss: 0.5804 - val_accuracy: 0.7074
# Epoch 27/200
# 178/178 [==============================] - 1s 4ms/step - loss: 0.5802 - accuracy: 0.7073 - val_loss: 0.5810 - val_accuracy: 0.7074
# Epoch 28/200
# 178/178 [==============================] - 1s 3ms/step - loss: 0.5807 - accuracy: 0.7064 - val_loss: 0.5810 - val_accuracy: 0.7044
# Epoch 29/200
# 178/178 [==============================] - 1s 4ms/step - loss: 0.5797 - accuracy: 0.7081 - val_loss: 0.5810 - val_accuracy: 0.7080
# Epoch 30/200
# 178/178 [==============================] - 1s 4ms/step - loss: 0.5789 - accuracy: 0.7080 - val_loss: 0.5778 - val_accuracy: 0.7117
# Epoch 31/200
# 178/178 [==============================] - 1s 3ms/step - loss: 0.5791 - accuracy: 0.7092 - val_loss: 0.5781 - val_accuracy: 0.7099
# Epoch 32/200
# 178/178 [==============================] - 1s 3ms/step - loss: 0.5790 - accuracy: 0.7085 - val_loss: 0.5775 - val_accuracy: 0.7119
# Epoch 33/200
# 178/178 [==============================] - 1s 3ms/step - loss: 0.5778 - accuracy: 0.7097 - val_loss: 0.5766 - val_accuracy: 0.7109
# Epoch 34/200
# 178/178 [==============================] - 1s 3ms/step - loss: 0.5770 - accuracy: 0.7095 - val_loss: 0.5755 - val_accuracy: 0.7122
# Epoch 35/200
# 178/178 [==============================] - 1s 4ms/step - loss: 0.5766 - accuracy: 0.7088 - val_loss: 0.5752 - val_accuracy: 0.7116
# Epoch 36/200
# 178/178 [==============================] - 1s 4ms/step - loss: 0.5777 - accuracy: 0.7074 - val_loss: 0.5771 - val_accuracy: 0.7113
# Epoch 37/200
# 178/178 [==============================] - 1s 3ms/step - loss: 0.5771 - accuracy: 0.7100 - val_loss: 0.5787 - val_accuracy: 0.7082
# Epoch 38/200
# 178/178 [==============================] - 1s 3ms/step - loss: 0.5762 - accuracy: 0.7102 - val_loss: 0.5747 - val_accuracy: 0.7120
# Epoch 39/200
# 178/178 [==============================] - 1s 3ms/step - loss: 0.5771 - accuracy: 0.7100 - val_loss: 0.5739 - val_accuracy: 0.7135
# Epoch 40/200
# 178/178 [==============================] - 1s 4ms/step - loss: 0.5758 - accuracy: 0.7111 - val_loss: 0.5739 - val_accuracy: 0.7149
# Epoch 41/200
# 178/178 [==============================] - 1s 3ms/step - loss: 0.5757 - accuracy: 0.7106 - val_loss: 0.5760 - val_accuracy: 0.7116
# Epoch 42/200
# 178/178 [==============================] - 1s 4ms/step - loss: 0.5752 - accuracy: 0.7121 - val_loss: 0.5728 - val_accuracy: 0.7132
# Epoch 43/200
# 178/178 [==============================] - 1s 4ms/step - loss: 0.5751 - accuracy: 0.7109 - val_loss: 0.5715 - val_accuracy: 0.7132
# Epoch 44/200
# 178/178 [==============================] - 1s 4ms/step - loss: 0.5739 - accuracy: 0.7123 - val_loss: 0.5745 - val_accuracy: 0.7113
# Epoch 45/200
# 178/178 [==============================] - 1s 4ms/step - loss: 0.5747 - accuracy: 0.7117 - val_loss: 0.5707 - val_accuracy: 0.7163
# Epoch 46/200
# 178/178 [==============================] - 1s 3ms/step - loss: 0.5737 - accuracy: 0.7122 - val_loss: 0.5727 - val_accuracy: 0.7150
# Epoch 47/200
# 178/178 [==============================] - 1s 4ms/step - loss: 0.5733 - accuracy: 0.7130 - val_loss: 0.5714 - val_accuracy: 0.7153
# Epoch 48/200
# 178/178 [==============================] - 1s 3ms/step - loss: 0.5733 - accuracy: 0.7122 - val_loss: 0.5735 - val_accuracy: 0.7113
# Epoch 49/200
# 178/178 [==============================] - 1s 4ms/step - loss: 0.5725 - accuracy: 0.7120 - val_loss: 0.5724 - val_accuracy: 0.7126
# Epoch 50/200
# 178/178 [==============================] - 1s 4ms/step - loss: 0.5724 - accuracy: 0.7117 - val_loss: 0.5730 - val_accuracy: 0.7132
# Epoch 51/200
# 178/178 [==============================] - 1s 4ms/step - loss: 0.5714 - accuracy: 0.7133 - val_loss: 0.5706 - val_accuracy: 0.7159
# Epoch 52/200
# 178/178 [==============================] - 1s 3ms/step - loss: 0.5715 - accuracy: 0.7124 - val_loss: 0.5712 - val_accuracy: 0.7153
# Epoch 53/200
# 178/178 [==============================] - 1s 5ms/step - loss: 0.5717 - accuracy: 0.7124 - val_loss: 0.5696 - val_accuracy: 0.7165
# Epoch 54/200
# 178/178 [==============================] - 1s 3ms/step - loss: 0.5706 - accuracy: 0.7131 - val_loss: 0.5703 - val_accuracy: 0.7200
# Epoch 55/200
# 178/178 [==============================] - 1s 4ms/step - loss: 0.5710 - accuracy: 0.7139 - val_loss: 0.5719 - val_accuracy: 0.7138
# Epoch 56/200
# 178/178 [==============================] - 1s 4ms/step - loss: 0.5685 - accuracy: 0.7145 - val_loss: 0.5693 - val_accuracy: 0.7169
# Epoch 57/200
# 178/178 [==============================] - 1s 3ms/step - loss: 0.5713 - accuracy: 0.7127 - val_loss: 0.5705 - val_accuracy: 0.7125
# Epoch 58/200
# 178/178 [==============================] - 1s 4ms/step - loss: 0.5694 - accuracy: 0.7136 - val_loss: 0.5669 - val_accuracy: 0.7192
# Epoch 59/200
# 178/178 [==============================] - 1s 3ms/step - loss: 0.5685 - accuracy: 0.7156 - val_loss: 0.5679 - val_accuracy: 0.7183
# Epoch 60/200
# 178/178 [==============================] - 1s 3ms/step - loss: 0.5693 - accuracy: 0.7148 - val_loss: 0.5661 - val_accuracy: 0.7183
# Epoch 61/200
# 178/178 [==============================] - 1s 3ms/step - loss: 0.5692 - accuracy: 0.7155 - val_loss: 0.5688 - val_accuracy: 0.7152
# Epoch 62/200
# 178/178 [==============================] - 1s 4ms/step - loss: 0.5682 - accuracy: 0.7172 - val_loss: 0.5688 - val_accuracy: 0.7156
# Epoch 63/200
# 178/178 [==============================] - 1s 3ms/step - loss: 0.
200
# 178/178 [==============================] - 1s 3ms/step - loss: 0.5564 - accuracy: 0.7228 - val_loss: 0.5576 - val_accuracy: 0.7243
# Epoch 124/200
# 178/178 [==============================] - 1s 4ms/step - loss: 0.5559 - accuracy: 0.7235 - val_loss: 0.5565 - val_accuracy: 0.7246
# Epoch 125/200
# 178/178 [==============================] - 1s 3ms/step - loss: 0.5554 - accuracy: 0.7211 - val_loss: 0.5571 - val_accuracy: 0.7226
# Epoch 126/200
# 178/178 [==============================] - 1s 3ms/step - loss: 0.5558 - accuracy: 0.7231 - val_loss: 0.5548 - val_accuracy: 0.7264
# Epoch 127/200
# 178/178 [==============================] - 1s 3ms/step - loss: 0.5565 - accuracy: 0.7212 - val_loss: 0.5568 - val_accuracy: 0.7238
# Epoch 128/200
# 178/178 [==============================] - 1s 3ms/step - loss: 0.5550 - accuracy: 0.7246 - val_loss: 0.5586 - val_accuracy: 0.7215
# Epoch 129/200
# 178/178 [==============================] - 1s 4ms/step - loss: 0.5546 - accuracy: 0.7232 - val_loss: 0.5570 - val_accuracy: 0.7249
# Epoch 130/200
# 178/178 [==============================] - 1s 3ms/step - loss: 0.5549 - accuracy: 0.7212 - val_loss: 0.5590 - val_accuracy: 0.7210
# Epoch 131/200
# 178/178 [==============================] - 1s 4ms/step - loss: 0.5557 - accuracy: 0.7208 - val_loss: 0.5549 - val_accuracy: 0.7233
# Epoch 132/200
# 178/178 [==============================] - 1s 3ms/step - loss: 0.5535 - accuracy: 0.7222 - val_loss: 0.5602 - val_accuracy: 0.7190
# Epoch 133/200
# 178/178 [==============================] - 1s 3ms/step - loss: 0.5548 - accuracy: 0.7230 - val_loss: 0.5561 - val_accuracy: 0.7262
# Epoch 134/200
# 178/178 [==============================] - 1s 3ms/step - loss: 0.5545 - accuracy: 0.7226 - val_loss: 0.5564 - val_accuracy: 0.7238
# Epoch 135/200
# 178/178 [==============================] - 1s 3ms/step - loss: 0.5541 - accuracy: 0.7214 - val_loss: 0.5570 - val_accuracy: 0.7211
# Epoch 136/200
# 178/178 [==============================] - 1s 3ms/step - loss: 0.5534 - accuracy: 0.7228 - val_loss: 0.5556 - val_accuracy: 0.7233
# Time taken: 90.8s

# %%
drop_model1 = models.Sequential()
drop_model1.add(layers.Dense(32,  kernel_initializer='normal', activation='selu', input_shape=(NDIM,)))
drop_model1.add(layers.Dropout(0.1))
drop_model1.add(layers.Dense(32,  kernel_initializer='normal', activation='selu'))
drop_model1.add(layers.Dropout(0.1))
drop_model1.add(layers.Dense(1, kernel_initializer='normal', activation='sigmoid'))

# compile the model
drop_model1.compile(optimizer='Adam', loss='binary_crossentropy', metrics=['accuracy'])
# print the model summary
drop_model1.summary()

# early stopping callback
from keras.callbacks import EarlyStopping
early_stopping = EarlyStopping(monitor='val_loss', patience=10, mode='min')

# Train classifier
import time
start = time.time() # time at start of whole processing

model_checkpoint = ModelCheckpoint(filepath='./models/testup_NN_opt_drop_model.h5', monitor='val_loss', 
                                   verbose=0, save_best_only=True, 
                                   save_weights_only=False, mode='auto', 
                                   period=1)

drop_history1 = drop_model1.fit(X_train_val, 
                    Y_train_val, 
                    epochs=500, 
                    batch_size=256, 
                    verbose=1, # switch to 1 for more verbosity 
                    callbacks=[early_stopping, model_checkpoint], 
                    validation_data=(X_test,Y_test))

elapsed = time.time() - start # time after whole processing
print("Time taken: "+str(round(elapsed,1))+"s") # print total time taken to process every file
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_11 (Dense)            (None, 32)                384
#
#  dropout_8 (Dropout)         (None, 32)                0
#
#  dense_12 (Dense)            (None, 32)                1056
#
#  dropout_9 (Dropout)         (None, 32)                0
#
#  dense_13 (Dense)            (None, 1)                 33
#
# =================================================================
# Total params: 1,473
# Trainable params: 1,473
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/500
# 178/178 [==============================] - 1s 2ms/step - loss: 0.6318 - accuracy: 0.6677 - val_loss: 0.6179 - val_accuracy: 0.6764
# Epoch 2/500
# 178/178 [==============================] - 0s 2ms/step - loss: 0.6163 - accuracy: 0.6840 - val_loss: 0.6152 - val_accuracy: 0.6817
# Epoch 3/500
# 178/178 [==============================] - 0s 2ms/step - loss: 0.6119 - accuracy: 0.6885 - val_loss: 0.6102 - val_accuracy: 0.6894
# Epoch 4/500
# 178/178 [==============================] - 0s 2ms/step - loss: 0.6075 - accuracy: 0.6924 - val_loss: 0.6075 - val_accuracy: 0.6946
# Epoch 5/500
# 178/178 [==============================] - 0s 2ms/step - loss: 0.6056 - accuracy: 0.6944 - val_loss: 0.6071 - val_accuracy: 0.6930
# Epoch 6/500
# 178/178 [==============================] - 0s 2ms/step - loss: 0.6041 - accuracy: 0.6950 - val_loss: 0.6055 - val_accuracy: 0.6955
# Epoch 7/500
# 178/178 [==============================] - 0s 2ms/step - loss: 0.6037 - accuracy: 0.6961 - val_loss: 0.6046 - val_accuracy: 0.6971
# Epoch 8/500
# 178/178 [==============================] - 0s 2ms/step - loss: 0.6030 - accuracy: 0.6977 - val_loss: 0.6042 - val_accuracy: 0.6931
# Epoch 9/500
# 178/178 [==============================] - 0s 2ms/step - loss: 0.
500
# 178/178 [==============================] - 0s 2ms/step - loss: 0.5929 - accuracy: 0.7012 - val_loss: 0.5911 - val_accuracy: 0.6998
# Epoch 41/500
# 178/178 [==============================] - 0s 2ms/step - loss: 0.5932 - accuracy: 0.7011 - val_loss: 0.5907 - val_accuracy: 0.7016
# Epoch 42/500
# 178/178 [==============================] - 0s 2ms/step - loss: 0.5927 - accuracy: 0.7005 - val_loss: 0.5900 - val_accuracy: 0.7029
# Epoch 43/500
# 178/178 [==============================] - 0s 2ms/step - loss: 0.5932 - accuracy: 0.6995 - val_loss: 0.5921 - val_accuracy: 0.7009
# Epoch 44/500
# 178/178 [==============================] - 0s 2ms/step - loss: 0.5927 - accuracy: 0.7008 - val_loss: 0.5913 - val_accuracy: 0.7010
# Epoch 45/500
# 178/178 [==============================] - 0s 2ms/step - loss: 0.5931 - accuracy: 0.7002 - val_loss: 0.5901 - val_accuracy: 0.7005
# Epoch 46/500
# 178/178 [==============================] - 0s 2ms/step - loss: 0.5914 - accuracy: 0.7005 - val_loss: 0.5914 - val_accuracy: 0.6985
# Epoch 47/500
# 178/178 [==============================] - 0s 2ms/step - loss: 0.5926 - accuracy: 0.6995 - val_loss: 0.5904 - val_accuracy: 0.7022
# Epoch 48/500
# 178/178 [==============================] - 0s 2ms/step - loss: 0.5926 - accuracy: 0.7003 - val_loss: 0.5893 - val_accuracy: 0.7021
# Epoch 49/500
# 178/178 [==============================] - 0s 2ms/step - loss: 0.5916 - accuracy: 0.6995 - val_loss: 0.5901 - val_accuracy: 0.7037
# Epoch 50/500
# 178/178 [==============================] - 0s 2ms/step - loss: 0.5924 - accuracy: 0.7013 - val_loss: 0.5892 - val_accuracy: 0.7035
# Epoch 51/500
# 178/178 [==============================] - 0s 2ms/step - loss: 0.5914 - accuracy: 0.7008 - val_loss: 0.5892 - val_accuracy: 0.7026
# Epoch 52/500
# 178/178 [==============================] - 0s 2ms/step - loss: 0.5910 - accuracy: 0.7027 - val_loss: 0.5900 - val_accuracy: 0.7010
# Epoch 53/500
# 178/178 [==============================] - 0s 2ms/step - loss: 0.5916 - accuracy: 0.7013 - val_loss: 0.5894 - val_accuracy: 0.7021
# Epoch 54/500
# 178/178 [==============================] - 0s 2ms/step - loss: 0.5918 - accuracy: 0.7010 - val_loss: 0.5893 - val_accuracy: 0.7019
# Epoch 55/500
# 178/178 [==============================] - 0s 2ms/step - loss: 0.5920 - accuracy: 0.7010 - val_loss: 0.5888 - val_accuracy: 0.7018
# Epoch 56/500
# 178/178 [==============================] - 0s 2ms/step - loss: 0.5907 - accuracy: 0.7007 - val_loss: 0.5897 - val_accuracy: 0.7024
# Epoch 57/500
# 178/178 [==============================] - 0s 2ms/step - loss: 0.5901 - accuracy: 0.7025 - val_loss: 0.5878 - val_accuracy: 0.7007
# Epoch 58/500
# 178/178 [==============================] - 0s 2ms/step - loss: 0.5907 - accuracy: 0.7002 - val_loss: 0.5884 - val_accuracy: 0.7007
# Epoch 59/500
# 178/178 [==============================] - 0s 2ms/step - loss: 0.5896 - accuracy: 0.7025 - val_loss: 0.5893 - val_accuracy: 0.7000
# Epoch 60/500
# 178/178 [==============================] - 0s 2ms/step - loss: 0.5909 - accuracy: 0.7006 - val_loss: 0.5882 - val_accuracy: 0.7027
# Epoch 61/500
# 178/178 [==============================] - 0s 2ms/step - loss: 0.5907 - accuracy: 0.7006 - val_loss: 0.5880 - val_accuracy: 0.7031
# Epoch 62/500
# 178/178 [==============================] - 0s 2ms/step - loss: 0.5904 - accuracy: 0.7015 - val_loss: 0.5878 - val_accuracy: 0.7035
# Epoch 63/500
# 178/178 [==============================] - 0s 2ms/step - loss: 0.5906 - accuracy: 0.7006 - val_loss: 0.5887 - val_accuracy: 0.7018
# Epoch 64/500
# 178/178 [==============================] - 0s 2ms/step - loss: 0.5908 - accuracy: 0.7015 - val_loss: 0.5872 - val_accuracy: 0.7011
# Epoch 65/500
# 178/178 [==============================] - 0s 2ms/step - loss: 0.5900 - accuracy: 0.7017 - val_loss: 0.5883 - val_accuracy: 0.7017
# Epoch 66/500
# 178/178 [==============================] - 0s 2ms/step - loss: 0.5892 - accuracy: 0.7012 - val_loss: 0.5878 - val_accuracy: 0.7005
# Epoch 67/500
# 178/178 [==============================] - 0s 2ms/step - loss: 0.5897 - accuracy: 0.7006 - val_loss: 0.5869 - val_accuracy: 0.7018
# Epoch 68/500
# 178/178 [==============================] - 0s 2ms/step - loss: 0.5893 - accuracy: 0.7014 - val_loss: 0.5881 - val_accuracy: 0.7011
# Epoch 69/500
# 178/178 [==============================] - 1s 3ms/step - loss: 0.5905 - accuracy: 0.7022 - val_loss: 0.5882 - val_accuracy: 0.7029
# Epoch 70/500
# 178/178 [==============================] - 0s 2ms/step - loss: 0.
500
# 178/178 [==============================] - 0s 2ms/step - loss: 0.5852 - accuracy: 0.7045 - val_loss: 0.5815 - val_accuracy: 0.7066
# Epoch 130/500
# 178/178 [==============================] - 0s 2ms/step - loss: 0.5846 - accuracy: 0.7048 - val_loss: 0.5831 - val_accuracy: 0.7061
# Epoch 131/500
# 178/178 [==============================] - 0s 2ms/step - loss: 0.5851 - accuracy: 0.7023 - val_loss: 0.5817 - val_accuracy: 0.7066
# Epoch 132/500
# 178/178 [==============================] - 0s 2ms/step - loss: 0.5841 - accuracy: 0.7064 - val_loss: 0.5817 - val_accuracy: 0.7050
# Epoch 133/500
# 178/178 [==============================] - 0s 2ms/step - loss: 0.5850 - accuracy: 0.7044 - val_loss: 0.5847 - val_accuracy: 0.7043
# Epoch 134/500
# 178/178 [==============================] - 0s 2ms/step - loss: 0.5850 - accuracy: 0.7049 - val_loss: 0.5816 - val_accuracy: 0.7062
# Epoch 135/500
# 178/178 [==============================] - 0s 2ms/step - loss: 0.5853 - accuracy: 0.7037 - val_loss: 0.5820 - val_accuracy: 0.7050
# Epoch 136/500
# 178/178 [==============================] - 0s 2ms/step - loss: 0.5844 - accuracy: 0.7045 - val_loss: 0.5813 - val_accuracy: 0.7067
# Epoch 137/500
# 178/178 [==============================] - 0s 2ms/step - loss: 0.5843 - accuracy: 0.7043 - val_loss: 0.5809 - val_accuracy: 0.7077
# Epoch 138/500
# 178/178 [==============================] - 0s 2ms/step - loss: 0.5834 - accuracy: 0.7047 - val_loss: 0.5818 - val_accuracy: 0.7068
# Epoch 139/500
# 178/178 [==============================] - 0s 2ms/step - loss: 0.5840 - accuracy: 0.7044 - val_loss: 0.5818 - val_accuracy: 0.7076
# Epoch 140/500
# 178/178 [==============================] - 0s 2ms/step - loss: 0.5844 - accuracy: 0.7063 - val_loss: 0.5810 - val_accuracy: 0.7081
# Epoch 141/500
# 178/178 [==============================] - 0s 2ms/step - loss: 0.5846 - accuracy: 0.7036 - val_loss: 0.5811 - val_accuracy: 0.7078
# Epoch 142/500
# 178/178 [==============================] - 0s 2ms/step - loss: 0.5842 - accuracy: 0.7051 - val_loss: 0.5821 - val_accuracy: 0.7075
# Epoch 143/500
# 178/178 [==============================] - 0s 2ms/step - loss: 0.5846 - accuracy: 0.7036 - val_loss: 0.5811 - val_accuracy: 0.7077
# Epoch 144/500
# 178/178 [==============================] - 0s 2ms/step - loss: 0.5839 - accuracy: 0.7037 - val_loss: 0.5807 - val_accuracy: 0.7072
# Epoch 145/500
# 178/178 [==============================] - 0s 2ms/step - loss: 0.5842 - accuracy: 0.7048 - val_loss: 0.5826 - val_accuracy: 0.7057
# Epoch 146/500
# 178/178 [==============================] - 0s 2ms/step - loss: 0.5839 - accuracy: 0.7036 - val_loss: 0.5815 - val_accuracy: 0.7080
# Epoch 147/500
# 178/178 [==============================] - 0s 2ms/step - loss: 0.5833 - accuracy: 0.7046 - val_loss: 0.5807 - val_accuracy: 0.7078
# Epoch 148/500
# 178/178 [==============================] - 0s 2ms/step - loss: 0.5827 - accuracy: 0.7059 - val_loss: 0.5803 - val_accuracy: 0.7091
# Epoch 149/500
# 178/178 [==============================] - 0s 2ms/step - loss: 0.5827 - accuracy: 0.7060 - val_loss: 0.5813 - val_accuracy: 0.7064
# Epoch 150/500
# 178/178 [==============================] - 0s 2ms/step - loss: 0.5836 - accuracy: 0.7039 - val_loss: 0.5807 - val_accuracy: 0.7082
# Epoch 151/500
# 178/178 [==============================] - 0s 2ms/step - loss: 0.5836 - accuracy: 0.7045 - val_loss: 0.5808 - val_accuracy: 0.7074
# Epoch 152/500
# 178/178 [==============================] - 0s 2ms/step - loss: 0.5834 - accuracy: 0.7045 - val_loss: 0.5805 - val_accuracy: 0.7073
# Epoch 153/500
# 178/178 [==============================] - 0s 2ms/step - loss: 0.5831 - accuracy: 0.7054 - val_loss: 0.5817 - val_accuracy: 0.7077
# Epoch 154/500
# 178/178 [==============================] - 0s 2ms/step - loss: 0.5838 - accuracy: 0.7042 - val_loss: 0.5802 - val_accuracy: 0.7072
# Epoch 155/500
# 178/178 [==============================] - 0s 2ms/step - loss: 0.5827 - accuracy: 0.7056 - val_loss: 0.5804 - val_accuracy: 0.7083
# Epoch 156/500
# 178/178 [==============================] - 0s 2ms/step - loss: 0.5836 - accuracy: 0.7050 - val_loss: 0.5802 - val_accuracy: 0.7075
# Epoch 157/500
# 178/178 [==============================] - 0s 2ms/step - loss: 0.5832 - accuracy: 0.7036 - val_loss: 0.5802 - val_accuracy: 0.7090
# Epoch 158/500
# 178/178 [==============================] - 0s 2ms/step - loss: 0.5829 - accuracy: 0.7062 - val_loss: 0.5817 - val_accuracy: 0.7079
# Epoch 159/500
# 178/178 [==============================] - 0s 2ms/step - loss: 0.5837 - accuracy: 0.7051 - val_loss: 0.5798 - val_accuracy: 0.7083
# Epoch 160/500
# 178/178 [==============================] - 0s 2ms/step - loss: 0.5835 - accuracy: 0.7040 - val_loss: 0.5812 - val_accuracy: 0.7068
# Epoch 161/500
# 178/178 [==============================] - 0s 2ms/step - loss: 0.5829 - accuracy: 0.7062 - val_loss: 0.5802 - val_accuracy: 0.7087
# Epoch 162/500
# 178/178 [==============================] - 0s 2ms/step - loss: 0.5835 - accuracy: 0.7046 - val_loss: 0.5797 - val_accuracy: 0.7102
# Epoch 163/500
# 178/178 [==============================] - 0s 2ms/step - loss: 0.5837 - accuracy: 0.7045 - val_loss: 0.5801 - val_accuracy: 0.7059
# Epoch 164/500
# 178/178 [==============================] - 0s 2ms/step - loss: 0.5837 - accuracy: 0.7030 - val_loss: 0.5799 - val_accuracy: 0.7070
# Epoch 165/500
# 178/178 [==============================] - 0s 2ms/step - loss: 0.5825 - accuracy: 0.7049 - val_loss: 0.5805 - val_accuracy: 0.7114
# Epoch 166/500
# 178/178 [==============================] - 0s 2ms/step - loss: 0.5820 - accuracy: 0.7064 - val_loss: 0.5817 - val_accuracy: 0.7080
# Epoch 167/500
# 178/178 [==============================] - 0s 2ms/step - loss: 0.5820 - accuracy: 0.7050 - val_loss: 0.5788 - val_accuracy: 0.7081
# Epoch 168/500
# 178/178 [==============================] - 0s 2ms/step - loss: 0.5828 - accuracy: 0.7040 - val_loss: 0.5798 - val_accuracy: 0.7076
# Epoch 169/500
# 178/178 [==============================] - 0s 2ms/step - loss: 0.5826 - accuracy: 0.7063 - val_loss: 0.5798 - val_accuracy: 0.7091
# Epoch 170/500
# 178/178 [==============================] - 0s 2ms/step - loss: 0.5820 - accuracy: 0.7063 - val_loss: 0.5802 - val_accuracy: 0.7082
# Epoch 171/500
# 178/178 [==============================] - 0s 2ms/step - loss: 0.5812 - accuracy: 0.7060 - val_loss: 0.5799 - val_accuracy: 0.7068
# Epoch 172/500
# 178/178 [==============================] - 0s 2ms/step - loss: 0.5834 - accuracy: 0.7056 - val_loss: 0.5792 - val_accuracy: 0.7092
# Epoch 173/500
# 178/178 [==============================] - 0s 2ms/step - loss: 0.5824 - accuracy: 0.7070 - val_loss: 0.5792 - val_accuracy: 0.7090
# Epoch 174/500
# 178/178 [==============================] - 0s 2ms/step - loss: 0.5826 - accuracy: 0.7048 - val_loss: 0.5790 - val_accuracy: 0.7097
# Epoch 175/500
# 178/178 [==============================] - 0s 2ms/step - loss: 0.5832 - accuracy: 0.7042 - val_loss: 0.5794 - val_accuracy: 0.7082
# Epoch 176/500
# 178/178 [==============================] - 0s 2ms/step - loss: 0.5818 - accuracy: 0.7066 - val_loss: 0.5795 - val_accuracy: 0.7099
# Epoch 177/500
# 178/178 [==============================] - 0s 2ms/step - loss: 0.5815 - accuracy: 0.7049 - val_loss: 0.5789 - val_accuracy: 0.7095
# Time taken: 52.7s

# %%
loss_accuracy_plotter(drop_history)

fpr_nn_opt_drop, tpr_nn_opt_drop, thresholds_nn_opt_drop = evaluate(drop_model, scaler, X, Y, X_train_val, Y_train_val, X_test, Y_test)
df_all['dense_NN_opt_drop'] = drop_model.predict(scaler.transform(X)).round() # add prediction to array
# Out:
# 356/356 [==============================] - 1s 2ms/step
# 1422/1422 [==============================] - 1s 719us/step
# 356/356 [==============================] - 0s 827us/step
# 1422/1422 [==============================] - 1s 871us/step
# 1778/1778 [==============================] - 2s 916us/step
# Test acc score: 0.7233406593406594
# Train acc score: 0.7320541562266474
# Classification report for the test set
#               precision    recall  f1-score   support
#
#   background       0.71      0.44      0.54      4249
#       signal       0.73      0.89      0.80      7126
#
#     accuracy                           0.72     11375
#    macro avg       0.72      0.67      0.67     11375
# weighted avg       0.72      0.72      0.71     11375
#
# Classification report for the total set
#               precision    recall  f1-score   support
#
#   background       0.71      0.45      0.55     21029
#       signal       0.74      0.89      0.81     35844
#
#     accuracy                           0.73     56873
#    macro avg       0.72      0.67      0.68     56873
# weighted avg       0.73      0.73      0.71     56873
#
# Confusion matrix for total set
# [[ 9534 11495]
#  [ 3843 32001]]
# 1778/1778 [==============================] - 2s 842us/step

# %%
# add TF NN probability
y_tot_prob_NN_opt_drop = drop_model.predict(scaler.transform(X))
y_tot_NN_opt_drop = drop_model.predict(scaler.transform(X)).round()

cumulative_events = 0 # start counter for total number of events for which output is saved
for key in filename.keys(): # loop over samples
    df[key]['NN_opt_drop_output_prob'] = y_tot_prob_NN_opt_drop[cumulative_events:cumulative_events+len(df[key])]
    df[key]['NN_opt_drop_output'] = y_tot_NN_opt_drop[cumulative_events:cumulative_events+len(df[key])]
    cumulative_events += len(df[key]) # increment counter for total number of events
    #print(df[key]['NN_output']) # print the dataframe column NN_output

# probability and significance plots
NN_opt_drop_output_prob = { # dictionary containing plotting parameters for the mllll histogram
    # change plotting parameters
    'bin_width':0.1, # width of each histogram bin
    'num_bins':8, # number of histogram bins
    'xrange_min':0, # minimum on x-axis
    'xlabel':'Neural Network optimized dropout', # x-axis label
}

SoverB_hist_dict = {'NN_opt_drop_output_prob':NN_opt_drop_output_prob}
plot_SoverB(df, SoverB_hist_dict)
# Out:
# 1778/1778 [==============================] - 2s 922us/step
# 1778/1778 [==============================] - 2s 1ms/step

# %% [markdown]
# ## Optimal model with early stopping

# %%
inputs = Input(shape=(NDIM,), name = 'input') 
hidden1 = Dense(128, name = 'hidden1', kernel_initializer='lecun_normal', activation='selu')(inputs)
hidden2 = Dense(128, name = 'hidden2', kernel_initializer='lecun_normal', activation='selu')(hidden1)
hidden3 = Dense(128, name = 'hidden3', kernel_initializer='lecun_normal', activation='selu')(hidden2)
outputs = Dense(1, name = 'output', kernel_initializer='lecun_normal', activation='sigmoid')(hidden3)

# create the model
opt_model = Model(inputs=inputs, outputs=outputs)
# compile the model
opt_model.compile(optimizer='Adam', loss='binary_crossentropy', metrics=['accuracy'])
# print the model summary
opt_model.summary()

# early stopping callback
from keras.callbacks import EarlyStopping
early_stopping = EarlyStopping(monitor='val_loss', patience=10, mode='min')

# model checkpoint callback
# this saves our model architecture + parameters into dense_model.h5
from keras.callbacks import ModelCheckpoint
model_checkpoint = ModelCheckpoint('./models/up_NN_opt_model.h5', monitor='val_loss', 
                                   verbose=0, save_best_only=True,                                    
                                   save_weights_only=False, mode='auto', 
                                   period=1)
# Out:
# Model: "model_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input (InputLayer)          [(None, 11)]              0
#
#  hidden1 (Dense)             (None, 128)               1536
#
#  hidden2 (Dense)             (None, 128)               16512
#
#  hidden3 (Dense)             (None, 128)               16512
#
#  output (Dense)              (None, 1)                 129
#
# =================================================================
# Total params: 34,689
# Trainable params: 34,689
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
# Train classifier
import time
start = time.time() # time at start of whole processing

opt_history = opt_model.fit(X_train_val, 
                    Y_train_val, 
                    epochs=500, 
                    batch_size=256, 
                    verbose=1, # switch to 1 for more verbosity 
                    callbacks=[early_stopping, model_checkpoint], 
                    validation_data=(X_test,Y_test))

elapsed = time.time() - start # time after whole processing
print("Time taken: "+str(round(elapsed,1))+"s") # print total time taken to process every file
# Out:
# Epoch 1/500
# 178/178 [==============================] - 1s 3ms/step - loss: 0.6091 - accuracy: 0.6838 - val_loss: 0.6140 - val_accuracy: 0.6749
# Epoch 2/500
# 178/178 [==============================] - 1s 3ms/step - loss: 0.5934 - accuracy: 0.6970 - val_loss: 0.5915 - val_accuracy: 0.7006
# Epoch 3/500
# 178/178 [==============================] - 1s 3ms/step - loss: 0.5857 - accuracy: 0.7047 - val_loss: 0.5893 - val_accuracy: 0.7047
# Epoch 4/500
# 178/178 [==============================] - 1s 3ms/step - loss: 0.5824 - accuracy: 0.7069 - val_loss: 0.5874 - val_accuracy: 0.7018
# Epoch 5/500
# 178/178 [==============================] - 1s 3ms/step - loss: 0.5785 - accuracy: 0.7066 - val_loss: 0.5832 - val_accuracy: 0.7010
# Epoch 6/500
# 178/178 [==============================] - 1s 3ms/step - loss: 0.5759 - accuracy: 0.7104 - val_loss: 0.5806 - val_accuracy: 0.7061
# Epoch 7/500
# 178/178 [==============================] - 1s 3ms/step - loss: 0.5744 - accuracy: 0.7098 - val_loss: 0.5817 - val_accuracy: 0.7087
# Epoch 8/500
# 178/178 [==============================] - 0s 3ms/step - loss: 0.5727 - accuracy: 0.7091 - val_loss: 0.5789 - val_accuracy: 0.7085
# Epoch 9/500
# 178/178 [==============================] - 0s 2ms/step - loss: 0.5702 - accuracy: 0.7118 - val_loss: 0.5776 - val_accuracy: 0.7090
# Epoch 10/500
# 178/178 [==============================] - 0s 3ms/step - loss: 0.5703 - accuracy: 0.7121 - val_loss: 0.5770 - val_accuracy: 0.7095
# Epoch 11/500
# 178/178 [==============================] - 0s 3ms/step - loss: 0.5680 - accuracy: 0.7128 - val_loss: 0.5728 - val_accuracy: 0.7157
# Epoch 12/500
# 178/178 [==============================] - 0s 2ms/step - loss: 0.5674 - accuracy: 0.7150 - val_loss: 0.5739 - val_accuracy: 0.7127
# Epoch 13/500
# 178/178 [==============================] - 0s 2ms/step - loss: 0.5665 - accuracy: 0.7145 - val_loss: 0.5869 - val_accuracy: 0.7051
# Epoch 14/500
# 178/178 [==============================] - 0s 2ms/step - loss: 0.5648 - accuracy: 0.7158 - val_loss: 0.5706 - val_accuracy: 0.7142
# Epoch 15/500
# 178/178 [==============================] - 0s 3ms/step - loss: 0.5641 - accuracy: 0.7164 - val_loss: 0.5708 - val_accuracy: 0.7118
# Epoch 16/500
# 178/178 [==============================] - 0s 2ms/step - loss: 0.5636 - accuracy: 0.7169 - val_loss: 0.5706 - val_accuracy: 0.7124
# Epoch 17/500
# 178/178 [==============================] - 0s 2ms/step - loss: 0.5620 - accuracy: 0.7173 - val_loss: 0.5733 - val_accuracy: 0.7117
# Epoch 18/500
# 178/178 [==============================] - 0s 2ms/step - loss: 0.5604 - accuracy: 0.7174 - val_loss: 0.5710 - val_accuracy: 0.7137
# Epoch 19/500
# 178/178 [==============================] - 0s 2ms/step - loss: 0.5605 - accuracy: 0.7186 - val_loss: 0.5742 - val_accuracy: 0.7140
# Epoch 20/500
# 178/178 [==============================] - 1s 3ms/step - loss: 0.5615 - accuracy: 0.7186 - val_loss: 0.5704 - val_accuracy: 0.7156
# Epoch 21/500
# 178/178 [==============================] - 0s 3ms/step - loss: 0.5589 - accuracy: 0.7193 - val_loss: 0.5687 - val_accuracy: 0.7149
# Epoch 22/500
# 178/178 [==============================] - 0s 2ms/step - loss: 0.5569 - accuracy: 0.7201 - val_loss: 0.5776 - val_accuracy: 0.7052
# Epoch 23/500
# 178/178 [==============================] - 0s 2ms/step - loss: 0.5580 - accuracy: 0.7192 - val_loss: 0.5690 - val_accuracy: 0.7148
# Epoch 24/500
# 178/178 [==============================] - 0s 2ms/step - loss: 0.
500
# 178/178 [==============================] - 0s 2ms/step - loss: 0.5348 - accuracy: 0.7339 - val_loss: 0.5653 - val_accuracy: 0.7170
# Epoch 53/500
# 178/178 [==============================] - 0s 2ms/step - loss: 0.5337 - accuracy: 0.7349 - val_loss: 0.5628 - val_accuracy: 0.7231
# Epoch 54/500
# 178/178 [==============================] - 0s 2ms/step - loss: 0.5334 - accuracy: 0.7338 - val_loss: 0.5644 - val_accuracy: 0.7198
# Epoch 55/500
# 178/178 [==============================] - 0s 2ms/step - loss: 0.5313 - accuracy: 0.7355 - val_loss: 0.5637 - val_accuracy: 0.7152
# Epoch 56/500
# 178/178 [==============================] - 0s 2ms/step - loss: 0.5302 - accuracy: 0.7369 - val_loss: 0.5589 - val_accuracy: 0.7204
# Epoch 57/500
# 178/178 [==============================] - 0s 2ms/step - loss: 0.5305 - accuracy: 0.7379 - val_loss: 0.5665 - val_accuracy: 0.7148
# Epoch 58/500
# 178/178 [==============================] - 1s 3ms/step - loss: 0.5294 - accuracy: 0.7392 - val_loss: 0.5603 - val_accuracy: 0.7164
# Epoch 59/500
# 178/178 [==============================] - 0s 3ms/step - loss: 0.5293 - accuracy: 0.7368 - val_loss: 0.5601 - val_accuracy: 0.7217
# Epoch 60/500
# 178/178 [==============================] - 0s 2ms/step - loss: 0.5292 - accuracy: 0.7350 - val_loss: 0.5635 - val_accuracy: 0.7216
# Epoch 61/500
# 178/178 [==============================] - 0s 2ms/step - loss: 0.5275 - accuracy: 0.7388 - val_loss: 0.5629 - val_accuracy: 0.7141
# Epoch 62/500
# 178/178 [==============================] - 0s 2ms/step - loss: 0.5249 - accuracy: 0.7400 - val_loss: 0.5642 - val_accuracy: 0.7134
# Epoch 63/500
# 178/178 [==============================] - 0s 2ms/step - loss: 0.5264 - accuracy: 0.7379 - val_loss: 0.5629 - val_accuracy: 0.7170
# Epoch 64/500
# 178/178 [==============================] - 0s 2ms/step - loss: 0.5229 - accuracy: 0.7406 - val_loss: 0.5623 - val_accuracy: 0.7147
# Epoch 65/500
# 178/178 [==============================] - 0s 2ms/step - loss: 0.5243 - accuracy: 0.7389 - val_loss: 0.5637 - val_accuracy: 0.7202
# Epoch 66/500
# 178/178 [==============================] - 0s 2ms/step - loss: 0.5232 - accuracy: 0.7410 - val_loss: 0.5610 - val_accuracy: 0.7189
# Time taken: 30.9s

# %%
loss_accuracy_plotter(opt_history)

fpr_nn_opt, tpr_nn_opt, thresholds_nn_opt = evaluate(opt_model, scaler, X, Y, X_train_val, Y_train_val, X_test, Y_test)
df_all['dense_NN_opt'] = opt_model.predict(scaler.transform(X)).round() # add prediction to array
# Out:
# 356/356 [==============================] - 0s 691us/step
# 1422/1422 [==============================] - 1s 779us/step
# 356/356 [==============================] - 0s 748us/step
# 1422/1422 [==============================] - 1s 735us/step
# 1778/1778 [==============================] - 1s 811us/step
# Test acc score: 0.7188571428571429
# Train acc score: 0.7478130906853049
# Classification report for the test set
#               precision    recall  f1-score   support
#
#   background       0.68      0.47      0.56      4249
#       signal       0.73      0.87      0.79      7126
#
#     accuracy                           0.72     11375
#    macro avg       0.71      0.67      0.67     11375
# weighted avg       0.71      0.72      0.71     11375
#
# Classification report for the total set
#               precision    recall  f1-score   support
#
#   background       0.71      0.51      0.59     21029
#       signal       0.75      0.88      0.81     35844
#
#     accuracy                           0.74     56873
#    macro avg       0.73      0.69      0.70     56873
# weighted avg       0.74      0.74      0.73     56873
#
# Confusion matrix for total set
# [[10653 10376]
#  [ 4296 31548]]
# 1778/1778 [==============================] - 1s 753us/step

# %%
# add TF NN probability
y_tot_prob_NN_opt = opt_model.predict(scaler.transform(X))
y_tot_NN_opt = opt_model.predict(scaler.transform(X)).round()

cumulative_events = 0 # start counter for total number of events for which output is saved
for key in filename.keys(): # loop over samples
    df[key]['NN_opt_output_prob'] = y_tot_prob_NN_opt[cumulative_events:cumulative_events+len(df[key])]
    df[key]['NN_opt_output'] = y_tot_NN_opt[cumulative_events:cumulative_events+len(df[key])]
    cumulative_events += len(df[key]) # increment counter for total number of events
    #print(df[key]['NN_output']) # print the dataframe column NN_output

# probability and significance plots
NN_opt_output_prob = { # dictionary containing plotting parameters for the mllll histogram
    # change plotting parameters
    'bin_width':0.1, # width of each histogram bin
    'num_bins':8, # number of histogram bins
    'xrange_min':0, # minimum on x-axis
    'xlabel':'Neural Network optimized output', # x-axis label
}

SoverB_hist_dict = {'NN_opt_output_prob':NN_opt_output_prob}
plot_SoverB(df, SoverB_hist_dict)
# Out:
# 1778/1778 [==============================] - 1s 742us/step
# 1778/1778 [==============================] - 1s 811us/step

# %%
# plot ROC curve
plt.plot(fpr_nn, tpr_nn, label='Neural Network') # plot neural network ROC
plt.plot(fpr_nn_opt, tpr_nn_opt, linestyle='dashed', label='Neural Network optimized') # plot neural network optimized ROC
plt.plot(fpr_nn_opt_drop, tpr_nn_opt_drop, linestyle='dashed', label='Neural Network optimized (dropout)') # plot neural network optimized and dropout ROC
plt.plot([0, 1], [0, 1], linestyle='dotted', color='grey', label='Luck') # plot diagonal line to indicate luck
plt.xlabel('False Positive Rate') # x-axis label
plt.ylabel('True Positive Rate') # y-axis label
plt.grid() # add a grid to the plot
plt.legend() # add a legend

# %%
ams_nn = AMS(tpr_nn, fpr_nn, 0.001) # get AMS for NN classifier
ams_nn_opt = AMS(tpr_nn_opt, fpr_nn_opt, 0.001) # get AMS for NN-opt classifier
ams_nn_opt_drop = AMS(tpr_nn_opt_drop, fpr_nn_opt_drop, 0.001) # get AMS for NN-opt classifier


plt.plot(thresholds_nn, ams_nn, label="Neural Netwrok")  # plot NN AMS
plt.plot(thresholds_nn_opt, ams_nn_opt, linestyle='dashed', label="Neural Netwrok optimized")  # plot NN-opt AMS
plt.plot(thresholds_nn_opt_drop, ams_nn_opt_drop, linestyle='dashed', label="Neural Netwrok optimized (dropout)")  # plot NN-opt AMS
plt.xlabel("Threshold")  # x-axis label
plt.ylabel("AMS")  # y-axis label
plt.title("AMS with $b_r=0.001$")  # add plot title
plt.legend()  # add legend

# %%
ams_nn = AMS(tpr_nn, fpr_nn, 1) # get AMS for NN classifier
ams_nn_opt = AMS(tpr_nn_opt, fpr_nn_opt, 1) # get AMS for NN-opt classifier
ams_nn_opt_drop = AMS(tpr_nn_opt_drop, fpr_nn_opt_drop, 1) # get AMS for NN-opt classifier


plt.plot(thresholds_nn, ams_nn, label="Neural Netwrok")  # plot NN AMS
plt.plot(thresholds_nn_opt, ams_nn_opt, linestyle='dashed', label="Neural Netwrok optimized")  # plot NN-opt AMS
plt.plot(thresholds_nn_opt_drop, ams_nn_opt_drop, linestyle='dashed', label="Neural Netwrok optimized (dropout)")  # plot NN-opt AMS
plt.xlabel("Threshold")  # x-axis label
plt.ylabel("AMS")  # y-axis label
plt.title("AMS with $b_r=1$")  # add plot title
plt.legend()  # add legend

# %% [markdown]
# ## Overfit checking

# %%
new_compare_train_test(model, X_train_val, Y_train_val, X_test, Y_test, 'Neural Netwrok output')
# Out:
# 308/308 [==============================] - 0s 901us/step
# 499/499 [==============================] - 0s 783us/step
# 75/75 [==============================] - 0s 909us/step
# 127/127 [==============================] - 0s 833us/step
# Signal: ks = [0.0100042] (p-value = [0.89915736], are equal = [ True])
# Background: ks = [0.02401509] (p-value = [0.21489541], are equal = [ True])

# %%
new_compare_train_test(opt_model, X_train_val, Y_train_val, X_test, Y_test, 'Neural Netwrok optimized output')
# Out:
# 308/308 [==============================] - 0s 734us/step
# 499/499 [==============================] - 0s 719us/step
# 75/75 [==============================] - 0s 759us/step
# 127/127 [==============================] - 0s 770us/step
# Signal: ks = [0.06470548] (p-value = [3.21874341e-12], are equal = [False])
# Background: ks = [0.0934753] (p-value = [4.82057078e-15], are equal = [False])

# %%
new_compare_train_test(drop_model, X_train_val, Y_train_val, X_test, Y_test, 'Neural Netwrok optimized dropoutoutput')
# Out:
# 308/308 [==============================] - 0s 705us/step
# 499/499 [==============================] - 0s 725us/step
# 75/75 [==============================] - 0s 726us/step
# 127/127 [==============================] - 0s 708us/step
# Signal: ks = [0.01461888] (p-value = [0.48933004], are equal = [ True])
# Background: ks = [0.01524889] (p-value = [0.75758902], are equal = [ True])

# %% [markdown]
# ## Save all models

# %%
# simple NN
#model.save('models/tt_charm_NN/')
model.save('models/tW_up_NN.h5')
#new_model = keras.models.load_model('models/tt_charm_NN/')

# NN optimized 
#opt_model.save('models/tt_charm_NN_opt/')
opt_model.save('models/tW_up_NN_opt.h5')
#new_model = keras.models.load_model('models/tt_charm_NN_opt/')

# NN optimized with drop
#drop_model.save('models/tt_charm_NN_drop/')
drop_model.save('models/tW_up_NN_drop.h5')
#new_model = keras.models.load_model('models/tt_charm_NN_drop/')

# %% [markdown]
# ## Extend to the whole dataset

# %%
filename = {
    'tZ':'/Users/mghasemi/Desktop/IPM/plotter/newtrees/tZ.root',
    'WZ':'/Users/mghasemi/Desktop/IPM/plotter/newtrees/WZ.root',
    'ZZ':'/Users/mghasemi/Desktop/IPM/plotter/newtrees/ZZ.root',
    'signal_tW_up_TRR':'/Users/mghasemi/Desktop/IPM/plotter/newtrees/signal_tW_up_TRR.root'
    }

VARS = ['jetNo','jetPTLeading', 'jetETA', 'jetPHI',
        'elecPTLeading', 'elecETA', 'elecPHI',
        'dielecCOS', 'dielecETA', 'met','testnonTopMass', 'weight'] 

upfile = {}
params = {}
df = {}
NDIM = len(VARS)

# define trees and branches to make DataFrame
for treename in filename.keys():
    upfile[treename] = uproot.open(filename[treename])
    params[treename] = upfile[treename][treename].arrays(VARS)
    df[treename] = ak.to_dataframe(params[treename])
    # add isSignal variable
    if treename.startswith("signal"): 
        df[treename]['isSignal'] = np.ones(len(df[treename])) 
    else:
        df[treename]['isSignal'] = np.zeros(len(df[treename])) 
    tmp_dataset = df[treename].values
    X_tmp = tmp_dataset[:,0:NDIM-1]
    Y_tmp = tmp_dataset[:,NDIM]
    df[treename]['dense_NN'] = model.predict(scaler.transform(X_tmp)) # add prediction to array   
    df[treename]['dense_NN_opt'] = opt_model.predict(scaler.transform(X_tmp)) # add prediction to array
    df[treename]['dense_NN_opt_drop'] = drop_model.predict(scaler.transform(X_tmp)) # add prediction to array
    df[treename].to_csv("~/Desktop/IPM/Analysis/Dataframes/tW_up/"+treename+"_df.csv")
    

df_all = pd.concat([df[treename] for treename in filename.keys()])
dataset = df_all.values
X = dataset[:,0:NDIM-1]
Y = dataset[:,NDIM]
# Out:
# 9992/9992 [==============================] - 10s 1ms/step
# 9992/9992 [==============================] - 8s 828us/step
# 9992/9992 [==============================] - 8s 820us/step
# 340/340 [==============================] - 0s 846us/step
# 340/340 [==============================] - 0s 933us/step
# 340/340 [==============================] - 0s 947us/step
# 6/6 [==============================] - 0s 1ms/step
# 6/6 [==============================] - 0s 1ms/step
# 6/6 [==============================] - 0s 1ms/step
# 1121/1121 [==============================] - 1s 747us/step
# 1121/1121 [==============================] - 1s 960us/step
# 1121/1121 [==============================] - 1s 792us/step

# %%
y_pred_NN_opt = opt_model.predict(X_test).round() # make predictions on the test data
y_pred_NN_train_opt = opt_model.predict(X_train_val).round()
y_pred_NN_tot_opt = opt_model.predict(scaler.transform(X)).round()

# See how well the classifier does, Acc = correct data / tot data
print("Total accuracy", accuracy_score(Y, y_pred_NN_tot_opt))

print("Classification report for the total set")
print(classification_report(Y.round(), y_pred_NN_tot_opt.round(), target_names=['background', 'signal']))

print("Confusion matrix:\n", confusion_matrix(Y.round(), y_pred_NN_tot_opt.round()))

fpr_nn_opt_tot, tpr_nn_opt_tot, thresholds_nn_opt_tot = roc_curve(Y, y_pred_NN_tot_opt.round()) # get FPRs, TPRs and thresholds for neural network

df_all['dense_NN_opt'] = opt_model.predict(scaler.transform(X)) # add prediction to array
df_all['dense_NN'] = model.predict(scaler.transform(X)) # add prediction to array
# Out:
# 356/356 [==============================] - 0s 1ms/step
# 1422/1422 [==============================] - 1s 898us/step
# 11457/11457 [==============================] - 10s 901us/step
# Total accuracy 0.5291811917971883
# Classification report for the total set
#               precision    recall  f1-score   support
#
#   background       0.97      0.49      0.65    330762
#       signal       0.16      0.88      0.27     35844
#
#     accuracy                           0.53    366606
#    macro avg       0.57      0.69      0.46    366606
# weighted avg       0.89      0.53      0.62    366606
#
# Confusion matrix:
#  [[162453 168309]
#  [  4296  31548]]
# 11457/11457 [==============================] - 10s 853us/step
# 11457/11457 [==============================] - 9s 822us/step

# %%
y_pred_NN_opt_fit = drop_model.predict(X_test).round() # make predictions on the test data
y_pred_NN_train_opt_fit = drop_model.predict(X_train_val).round()
y_pred_NN_tot_opt_fit = drop_model.predict(scaler.transform(X)).round()

# See how well the classifier does, Acc = correct data / tot data
print("Total accuracy", accuracy_score(Y, y_pred_NN_tot_opt_fit))

print("Classification report for the total set")
print(classification_report(Y.round(), y_pred_NN_tot_opt_fit.round(), target_names=['background', 'signal']))

print("Confusion matrix:\n", confusion_matrix(Y.round(), y_pred_NN_tot_opt_fit.round()))

fpr_nn_opt_tot_fit, tpr_nn_opt_tot_fit, thresholds_nn_opt_tot_fit = roc_curve(Y, y_pred_NN_tot_opt_fit.round()) # get FPRs, TPRs and thresholds for neural network

df_all['dense_NN_opt_drop'] = opt_model.predict(scaler.transform(X)) # add prediction to array
# Out:
# 356/356 [==============================] - 0s 848us/step
# 1422/1422 [==============================] - 1s 877us/step
# 11457/11457 [==============================] - 9s 820us/step
# Total accuracy 0.5178829588168224
# Classification report for the total set
#               precision    recall  f1-score   support
#
#   background       0.98      0.48      0.64    330762
#       signal       0.16      0.89      0.27     35844
#
#     accuracy                           0.52    366606
#    macro avg       0.57      0.69      0.45    366606
# weighted avg       0.90      0.52      0.60    366606
#
# Confusion matrix:
#  [[157858 172904]
#  [  3843  32001]]
# 11457/11457 [==============================] - 11s 964us/step

# %%
# add TF NN probability
y_TOT_prob_NN_opt = opt_model.predict(scaler.transform(X))
y_TOT_NN_opt = opt_model.predict(scaler.transform(X)).round()

cumulative_events = 0 # start counter for total number of events for which output is saved
for key in filename.keys(): # loop over samples
    df[key]['NN_opt_tot_output_prob'] = y_TOT_prob_NN_opt[cumulative_events:cumulative_events+len(df[key])]
    df[key]['NN_opt_tot_output'] = y_TOT_NN_opt[cumulative_events:cumulative_events+len(df[key])]
    cumulative_events += len(df[key]) # increment counter for total number of events
    #print(df[key]['NN_output']) # print the dataframe column NN_output

# probability and significance plots
NN_opt_tot_output_prob = { # dictionary containing plotting parameters for the mllll histogram
    # change plotting parameters
    'bin_width':0.1, # width of each histogram bin
    'num_bins':8, # number of histogram bins
    'xrange_min':0, # minimum on x-axis
    'xlabel':'Neural Network optimized output', # x-axis label
}

SoverB_hist_dict = {'NN_opt_tot_output_prob':NN_opt_tot_output_prob}
plot_SoverB(df, SoverB_hist_dict)
# Out:
# 11457/11457 [==============================] - 10s 871us/step
# 11457/11457 [==============================] - 9s 809us/step

# %%
# add TF NN probability
y_TOT_prob_NN_opt_fit = drop_model.predict(scaler.transform(X))
y_TOT_NN_opt_fit = drop_model.predict(scaler.transform(X)).round()

cumulative_events = 0 # start counter for total number of events for which output is saved
for key in filename.keys(): # loop over samples
    df[key]['NN_opt_tot_output_prob_overfit'] = y_TOT_prob_NN_opt_fit[cumulative_events:cumulative_events+len(df[key])]
    df[key]['NN_opt_tot_output_overfit'] = y_TOT_NN_opt_fit[cumulative_events:cumulative_events+len(df[key])]
    cumulative_events += len(df[key]) # increment counter for total number of events
    #print(df[key]['NN_output']) # print the dataframe column NN_output

# probability and significance plots
NN_opt_tot_output_prob_fit = { # dictionary containing plotting parameters for the mllll histogram
    # change plotting parameters
    'bin_width':0.1, # width of each histogram bin
    'num_bins':8, # number of histogram bins
    'xrange_min':0, # minimum on x-axis
    'xlabel':'Neural Network optimized output', # x-axis label
}

SoverB_hist_dict = {'NN_opt_tot_output_prob_overfit':NN_opt_tot_output_prob_fit}
plot_SoverB(df, SoverB_hist_dict)
# Out:
# 11457/11457 [==============================] - 9s 744us/step
# 11457/11457 [==============================] - 9s 765us/step

# %%
# plot ROC curve
plt.plot(fpr_nn_opt_tot, tpr_nn_opt_tot, label='Neural Network total') # plot Neural net-opt ROC
plt.plot(fpr_nn_opt_tot_fit, tpr_nn_opt_tot_fit, label='Neural Network overfit total') # plot Neural net-opt w overfit ROC
plt.plot([0, 1], [0, 1], linestyle='dotted', color='grey', label='Luck') # plot diagonal line to indicate luck
plt.xlabel('False Positive Rate') # x-axis label
plt.ylabel('True Positive Rate') # y-axis label
plt.grid() # add a grid to the plot
plt.legend() # add a legend

# %%
#ams_rf = AMS(tpr_rf, fpr_rf, 0.001) # get AMS for random forest classifier
ams_rf_opt_tot = AMS(tpr_nn_opt_tot, fpr_nn_opt_tot, 0.001) # get AMS for random forest classifier
ams_rf_opt_tot_fit = AMS(tpr_nn_opt_tot_fit, fpr_nn_opt_tot_fit, 0.001) # get AMS for random forest classifier

plt.plot(thresholds_nn_opt_tot, ams_rf_opt_tot, label="Neural Netwrok")  # plot Random forest AMS
plt.plot(thresholds_nn_opt_tot_fit, ams_rf_opt_tot_fit, label="Neural Netwrok overfit")  # plot Random forest AMS
plt.xlabel("Threshold")  # x-axis label
plt.ylabel("AMS")  # y-axis label
plt.title("AMS with $b_r=0.001$")  # add plot title
plt.legend()  # add legend

# %% [markdown]
# ## Baysian Optimization for NN model

# %%
# Import packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from keras.models import Sequential
from keras.layers import Dense, BatchNormalization, Dropout
from keras.optimizers import Adam, SGD, RMSprop, Adadelta, Adagrad, Adamax, Nadam, Ftrl
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.wrappers.scikit_learn import KerasClassifier
from math import floor
from sklearn.metrics import make_scorer, accuracy_score
#from bayes_opt import BayesianOptimization
from kerastuner.tuners import BayesianOptimization
from sklearn.model_selection import StratifiedKFold
from keras.layers import LeakyReLU
from sklearn.model_selection import RandomizedSearchCV

LeakyReLU = LeakyReLU(alpha=0.1)
import warnings
warnings.filterwarnings('ignore')
pd.set_option("display.max_columns", None)

# Load dataset
trainSet = pd.read_csv('/Users/mghasemi/Desktop/Code-factory/Python/ML/Kaggle/competitions/Titanic/input/train.csv')
# Feature generation: training data
train = trainSet.drop(columns=['Name', 'Ticket', 'Cabin'])
train = train.dropna(axis=0)
train = pd.get_dummies(train)
# train validation split
X_train, X_val, y_train, y_val = train_test_split(train.drop(columns=['PassengerId','Survived'], axis=0),
                                                  train['Survived'],
                                                  test_size=0.2, random_state=111,
                                                  stratify=train['Survived'])                                                  

# Create function
def nn_cl_bo(neurons, activation, optimizer, learning_rate,  batch_size, epochs ):
    optimizerL = ['SGD', 'Adam', 'RMSprop', 'Adadelta', 'Adagrad', 'Adamax', 'Nadam', 'Ftrl','SGD']
    optimizerD= {'Adam':Adam(lr=learning_rate), 'SGD':SGD(lr=learning_rate),
                 'RMSprop':RMSprop(lr=learning_rate), 'Adadelta':Adadelta(lr=learning_rate),
                 'Adagrad':Adagrad(lr=learning_rate), 'Adamax':Adamax(lr=learning_rate),
                 'Nadam':Nadam(lr=learning_rate), 'Ftrl':Ftrl(lr=learning_rate)}
    activationL = ['relu', 'sigmoid', 'softplus', 'softsign', 'tanh', 'selu',
                   'elu', 'exponential', LeakyReLU,'relu']
    neurons = round(neurons)
    activation = activationL[round(activation)]
    batch_size = round(batch_size)
    epochs = round(epochs)
    def nn_cl_fun():
        opt = Adam(lr = learning_rate)
        nn = Sequential()
        nn.add(Dense(neurons, input_dim=10, activation=activation))
        nn.add(Dense(neurons, activation=activation))
        nn.add(Dense(1, activation='sigmoid'))
        nn.compile(loss='binary_crossentropy', optimizer=opt, metrics=['accuracy'])
        return nn
    es = EarlyStopping(monitor='accuracy', mode='max', verbose=0, patience=20)
    nn = KerasClassifier(build_fn=nn_cl_fun, epochs=epochs, batch_size=batch_size,
                         verbose=0)
    kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=123)
    score = cross_val_score(nn, X_train, y_train, scoring=score_acc, cv=kfold, fit_params={'callbacks':[es]}).mean()
    return score


# Set paramaters
params_nn ={
    'neurons': (10, 100),
    'activation':(0, 9),
    'optimizer':(0,7),
    'learning_rate':(0.01, 1),
    'batch_size':(200, 1000),
    'epochs':(20, 100)
}
# Run Bayesian Optimization
nn_bo = BayesianOptimization(nn_cl_bo, params_nn, random_state=111)
nn_bo.maximize(init_points=25, n_iter=4)

# %% [markdown]
# ## Add prediction to `ROOT` trees and Excel
# Here we'll add the precition we've computed to `ROOT` trees.

# %%
df_all.to_csv("~/Desktop/IPM/Analysis/Dataframes/tW_charm/df_all.csv")
df_all.head()
# Out:
#                 jetNo  jetPTLeading    jetETA    jetPHI  elecPTLeading  \
# entry subentry
# 0     0             2    593.544006 -0.827549 -2.505330     161.116547
#       1             2    593.544006  2.312157  0.628942     161.116547
# 1     0             3     83.230309 -1.575640  2.576972      64.688957
#       1             3     83.230309 -0.409602 -0.792389      64.688957
#       2             3     83.230309 -2.592391 -0.269172      64.688957
#
#                  elecETA   elecPHI  dielecCOS  dielecETA         met  \
# entry subentry
# 0     0        -0.827549 -2.505330   0.980999  -1.594191  208.471558
#       1         2.312157  0.628942   0.980999  -1.594191  208.471558
# 1     0        -1.575640  2.576972   0.563291  -0.118241   60.681705
#       1        -0.409602 -0.792389   0.563291  -0.118241   60.681705
#       2        -2.592391 -0.269172   0.563291  -0.118241   60.681705
#
#                 testnonTopMass  weight  isSignal  dense_NN  dense_NN_opt  \
# entry subentry
# 0     0             848.823936     0.0       0.0  0.507506      0.176575
#       1             848.823936     0.0       0.0  0.478027      0.193435
# 1     0             183.760581     0.0       0.0  0.788231      0.831855
#       1             183.760581     0.0       0.0  0.800311      0.767399
#       2             183.760581     0.0       0.0  0.804235      0.700955
#
#                 dense_NN_opt_drop
# entry subentry
# 0     0                  0.176575
#       1                  0.193435
# 1     0                  0.831855
#       1                  0.767399
#       2                  0.700955

# %%
with uproot.recreate("./signalC_NN_weights.root") as sig_file:    
    #sig_file['signalC_NN_weights'] = df_all
    sig_file['signalC_NN_weights'] = {"signalC_NN_weights": ak.zip({"dense_NN": df_all['dense_NN'], "dense_NN_opt": df_all['dense_NN_opt'], "dense_NN_opt_drop": df_all['dense_NN_opt_drop'], 'jetNo':df_all['jetNo'], 'jetETA':df_all['jetETA']})}    
with uproot.open("./signalC_NN_weights.root") as sig_file:
    tree = sig_file['signalC_NN_weights']
    print(tree.keys())
    print("arrays:", tree.arrays())
    print("arrays[10]",tree.arrays()[0].tolist())
    print(tree.arrays()[20])
    #sig_file['signalC_NN_weights'].show()
#df_all[df_all['entry']==10].head()
# Out:
# ['signalC_NN_weights_dense_NN', 'signalC_NN_weights_dense_NN_opt', 'signalC_NN_weights_dense_NN_opt_drop', 'signalC_NN_weights_jetNo', 'signalC_NN_weights_jetETA']
# arrays: [{signalC_NN_weights_dense_NN: 0.341, ...}, {...}, {...}, ..., {...}, {...}]
# arrays[10] {'signalC_NN_weights_dense_NN': 0.3411282002925873, 'signalC_NN_weights_dense_NN_opt': 0.3715079128742218, 'signalC_NN_weights_dense_NN_opt_drop': 0.3715079128742218, 'signalC_NN_weights_jetNo': 2, 'signalC_NN_weights_jetETA': -0.827549159526825}
# {signalC_NN_weights_dense_NN: 0.258, signalC_NN_weights_dense_NN_opt: ..., ...}

# %%
from root_numpy import root2array, array2root


def get_features_from_file(filename='', treename='', branches=[]):
    t = root2array(filename, treename=treename, branches=branches) # structured numpy array 
    #print t.shape 
    t = t.view(np.float32).reshape(t.shape + (-1,)) # normal numpy array (trick from https://stackoverflow.com/questions/5957380/convert-structured-array-to-regular-numpy-array)
    #print t.shape
    return t

def write_prediction_to_file(features, model, filename='',treename='',branch=''):
    y_predict_all = model.predict(features) # normal numpy array
    #print y_predict_all.shape
    y_predict_all = np.array(y_predict_all, dtype=[(branch, np.float32)]) # structured numpy array
    #print y_predict_all.shape
    array2root(y_predict_all, filename, treename=treename, mode='recreate')
    
X_all = get_features_from_file('data/ntuple_4mu_VV.root', 
                               treename='HZZ4LeptonsAnalysisReduced', 
                               branches=VARS)

X_all = scaler.transform(X_all)

write_prediction_to_file(X_all, 
                         model, 
                         filename='data/ntuple_4mu_VV_predict.root', 
                         treename='HZZ4LeptonsAnalysisReduced', 
                         branch='dense')

X_all = get_features_from_file('data/ntuple_4mu_bkg.root', 
                               treename='HZZ4LeptonsAnalysisReduced', 
                               branches=VARS)

X_all = scaler.transform(X_all)

write_prediction_to_file(X_all, 
                         model, 
                         filename='data/ntuple_4mu_bkg_predict.root', 
                         treename='HZZ4LeptonsAnalysisReduced', 
                         branch='dense')

# %% [markdown]
# ## Significance

# %%
df_all.head()
#print(df_all[df_all['isSignal']==0]['weight'].unique())
# Out:
#                 jetNo  jetPTLeading    jetETA    jetPHI  elecPTLeading  \
# entry subentry
# 0     0             2    593.544006 -0.827549 -2.505330     161.116547
#       1             2    593.544006  2.312157  0.628942     161.116547
# 1     0             3     83.230309 -1.575640  2.576972      64.688957
#       1             3     83.230309 -0.409602 -0.792389      64.688957
#       2             3     83.230309 -2.592391 -0.269172      64.688957
#
#                  elecETA   elecPHI  dielecCOS  dielecETA         met  \
# entry subentry
# 0     0        -0.827549 -2.505330   0.980999  -1.594191  208.471558
#       1         2.312157  0.628942   0.980999  -1.594191  208.471558
# 1     0        -1.575640  2.576972   0.563291  -0.118241   60.681705
#       1        -0.409602 -0.792389   0.563291  -0.118241   60.681705
#       2        -2.592391 -0.269172   0.563291  -0.118241   60.681705
#
#                 testnonTopMass  weight  isSignal  dense_NN  dense_NN_opt  \
# entry subentry
# 0     0             848.823936     0.0       0.0  0.507506      0.176575
#       1             848.823936     0.0       0.0  0.478027      0.193435
# 1     0             183.760581     0.0       0.0  0.788231      0.831855
#       1             183.760581     0.0       0.0  0.800311      0.767399
#       2             183.760581     0.0       0.0  0.804235      0.700955
#
#                 dense_NN_opt_drop
# entry subentry
# 0     0                  0.176575
#       1                  0.193435
# 1     0                  0.831855
#       1                  0.767399
#       2                  0.700955

# %% [markdown]
# ###

# %%
sig_weight = df_all[df_all['isSignal']==1]['weight'].unique()[0]
#sig_weight = 0.0007
df_sig_75 = df_all[(df_all['dense_NN']>=0.60) & (df_all['isSignal']==1)]
n_sig_75 = df_sig_75.shape[0] * sig_weight
df_sig_80 = df_all[(df_all['dense_NN']>=0.65) & (df_all['isSignal']==1)]
n_sig_80 = df_sig_80.shape[0] * sig_weight
df_sig_85 = df_all[(df_all['dense_NN']>=0.70) & (df_all['isSignal']==1)]
n_sig_85 = df_sig_85.shape[0] * sig_weight

bkg_weights = df_all[df_all['isSignal']==0]['weight'].unique()
list_bkg_75 = [df_all[(df_all['dense_NN']>=0.60) & (df_all['isSignal']==0) & (df_all['weight'] == bkg_w)].shape[0] * bkg_w for bkg_w in bkg_weights]
list_bkg_80 = [df_all[(df_all['dense_NN']>=0.65) & (df_all['isSignal']==0) & (df_all['weight'] == bkg_w)].shape[0] * bkg_w for bkg_w in bkg_weights]
list_bkg_85 = [df_all[(df_all['dense_NN']>=0.70) & (df_all['isSignal']==0) & (df_all['weight'] == bkg_w)].shape[0] * bkg_w for bkg_w in bkg_weights]

print("60% : sig_n {:.1f}\tbkg_n {:.1f}\tsig/bkg {:.3f}".format(n_sig_75, sum(list_bkg_75), n_sig_75/sum(list_bkg_75)))
print("65% : sig_n {:.1f}\tbkg_n {:.1f}\tsig/bkg {:.3f}".format(n_sig_80, sum(list_bkg_80), n_sig_75/sum(list_bkg_80)))
print("70% : sig_n {:.1f}\tbkg_n {:.1f}\tsig/bkg {:.3f}".format(n_sig_85, sum(list_bkg_85), n_sig_75/sum(list_bkg_85)))
# Out:
# 60% : sig_n 19.8	bkg_n 211.1	sig/bkg 0.094
# 65% : sig_n 17.8	bkg_n 173.7	sig/bkg 0.114
# 70% : sig_n 14.9	bkg_n 133.3	sig/bkg 0.148

# %%
df_sig_75 = df_all[(df_all['dense_NN_opt']>=0.60) & (df_all['isSignal']==1)]
n_sig_75 = df_sig_75.shape[0] * sig_weight
df_sig_80 = df_all[(df_all['dense_NN_opt']>=0.65) & (df_all['isSignal']==1)]
n_sig_80 = df_sig_80.shape[0] * sig_weight
df_sig_85 = df_all[(df_all['dense_NN_opt']>=0.70) & (df_all['isSignal']==1)]
n_sig_85 = df_sig_85.shape[0] * sig_weight

bkg_weights = df_all[df_all['isSignal']==0]['weight'].unique()
list_bkg_75 = [df_all[(df_all['dense_NN_opt']>=0.75) & (df_all['isSignal']==0) & (df_all['weight'] == bkg_w)].shape[0] * bkg_w for bkg_w in bkg_weights]
list_bkg_80 = [df_all[(df_all['dense_NN_opt']>=0.80) & (df_all['isSignal']==0) & (df_all['weight'] == bkg_w)].shape[0] * bkg_w for bkg_w in bkg_weights]
list_bkg_85 = [df_all[(df_all['dense_NN_opt']>=0.85) & (df_all['isSignal']==0) & (df_all['weight'] == bkg_w)].shape[0] * bkg_w for bkg_w in bkg_weights]

print("60% : sig_n {:.1f}\tbkg_n {:.1f}\tsig/bkg {:.3f}".format(n_sig_75, sum(list_bkg_75), n_sig_75/sum(list_bkg_75)))
print("65% : sig_n {:.1f}\tbkg_n {:.1f}\tsig/bkg {:.3f}".format(n_sig_80, sum(list_bkg_80), n_sig_75/sum(list_bkg_80)))
print("70% : sig_n {:.1f}\tbkg_n {:.1f}\tsig/bkg {:.3f}".format(n_sig_85, sum(list_bkg_85), n_sig_75/sum(list_bkg_85)))
# Out:
# 60% : sig_n 19.8	bkg_n 86.4	sig/bkg 0.229
# 65% : sig_n 18.1	bkg_n 53.0	sig/bkg 0.374
# 70% : sig_n 16.1	bkg_n 31.3	sig/bkg 0.634

# %%
df_sig_75 = df_all[(df_all['dense_NN_opt_drop']>=0.60) & (df_all['isSignal']==1)]
n_sig_75 = df_sig_75.shape[0] * sig_weight
df_sig_80 = df_all[(df_all['dense_NN_opt_drop']>=0.65) & (df_all['isSignal']==1)]
n_sig_80 = df_sig_80.shape[0] * sig_weight
df_sig_85 = df_all[(df_all['dense_NN_opt_drop']>=0.70) & (df_all['isSignal']==1)]
n_sig_85 = df_sig_85.shape[0] * sig_weight

bkg_weights = df_all[df_all['isSignal']==0]['weight'].unique()
list_bkg_75 = [df_all[(df_all['dense_NN_opt_drop']>=0.75) & (df_all['isSignal']==0) & (df_all['weight'] == bkg_w)].shape[0] * bkg_w for bkg_w in bkg_weights]
list_bkg_80 = [df_all[(df_all['dense_NN_opt_drop']>=0.80) & (df_all['isSignal']==0) & (df_all['weight'] == bkg_w)].shape[0] * bkg_w for bkg_w in bkg_weights]
list_bkg_85 = [df_all[(df_all['dense_NN_opt_drop']>=0.85) & (df_all['isSignal']==0) & (df_all['weight'] == bkg_w)].shape[0] * bkg_w for bkg_w in bkg_weights]

print("60% : sig_n {:.1f}\tbkg_n {:.1f}\tsig/bkg {:.3f}".format(n_sig_75, sum(list_bkg_75), n_sig_75/sum(list_bkg_75)))
print("65% : sig_n {:.1f}\tbkg_n {:.1f}\tsig/bkg {:.3f}".format(n_sig_80, sum(list_bkg_80), n_sig_75/sum(list_bkg_80)))
print("70% : sig_n {:.1f}\tbkg_n {:.1f}\tsig/bkg {:.3f}".format(n_sig_85, sum(list_bkg_85), n_sig_75/sum(list_bkg_85)))
# Out:
# 60% : sig_n 19.8	bkg_n 86.4	sig/bkg 0.229
# 65% : sig_n 18.1	bkg_n 53.0	sig/bkg 0.374
# 70% : sig_n 16.1	bkg_n 31.3	sig/bkg 0.634
