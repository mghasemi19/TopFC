# %%
# Basic packages
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
filename = "./tWcharm_NN_opt.txt"
lines = open(filename).read().splitlines()

mu_sig = [1, 1.25, 1.5, 1.75, 2, 2.25, 2.5, 2.75, 3]
relativeBkgUncert = [0.25, 0.5, 1]

# %%
import itertools
def split_list(lst, val):
    return [list(group) for k, group in itertools.groupby(lst, lambda x: x==val) if not k]
split_lst = split_list(lines, '')

# %%
# AMS 0.60
pval_25 = list(map(float, split_lst[0][:9]))
pval_50 = list(map(float, split_lst[2][:9]))
pval_100 = list(map(float, split_lst[4][:9]))
zval_25 = list(map(float, split_lst[1][:9]))
zval_50 = list(map(float, split_lst[3][:9]))
zval_100 = list(map(float, split_lst[5][:9]))

print(zval_25)

#plt.rcParams['figure.figsize'] = [4, 4]
#plt.figure(figsize=(10,6))

plt.figure(0)
plt.plot(mu_sig, zval_25, label = "$\sigma_{B}=$25%")
plt.plot(mu_sig, zval_50, label = "$\sigma_{B}=$50%")
plt.plot(mu_sig, zval_100, label = "$\sigma_{B}=$100%")

plt.grid(True) 
plt.legend(loc="upper left", fontsize=16)

plt.xlabel("mu_sig", fontsize=14)
plt.ylabel("Z score", fontsize=14)
plt.title("tW_charm signal with 0.60 AMS")
plt.axis([1, 3, 0, 5])

plt.figure(1)
plt.plot(mu_sig, pval_25, label = "$\sigma_{B}=$25%")
plt.plot(mu_sig, pval_50, label = "$\sigma_{B}=$50%")
plt.plot(mu_sig, pval_100, label = "$\sigma_{B}=$100%")

plt.grid(True) 
plt.legend(loc="upper right", fontsize=16)

plt.xlabel("mu_sig", fontsize=14)
plt.ylabel("p-val", fontsize=14)
plt.title("tW_charm signal with 0.60 AMS")
plt.axis([1, 3, 0, 0.8])
# Out:
# [1.02098, 1.28722, 1.54356, 1.79093, 2.03013, 2.26185, 2.48668, 2.70516, 2.91775]
# (1.0, 3.0, 0.0, 0.8)

# %%
# AMS 0.80
pval_25 = list(map(float, split_lst[0][9:18]))
pval_50 = list(map(float, split_lst[2][9:18]))
pval_100 = list(map(float, split_lst[4][9:18]))
zval_25 = list(map(float, split_lst[1][9:18]))
zval_50 = list(map(float, split_lst[3][9:18]))
zval_100 = list(map(float, split_lst[5][9:18]))

print(zval_25)

plt.figure(0)
plt.plot(mu_sig, zval_25, label = "$\sigma_{B}=$25%")
plt.plot(mu_sig, zval_50, label = "$\sigma_{B}=$50%")
plt.plot(mu_sig, zval_100, label = "$\sigma_{B}=$100%")

plt.grid(True) 
plt.legend(loc="upper left", fontsize=16)

plt.xlabel("mu_sig", fontsize=14)
plt.ylabel("Z score", fontsize=14)
plt.title("tW_charm signal with 0.65 AMS")
plt.axis([1, 3, 0, 5])

plt.figure(1)
plt.plot(mu_sig, pval_25, label = "$\sigma_{B}=$25%")
plt.plot(mu_sig, pval_50, label = "$\sigma_{B}=$50%")
plt.plot(mu_sig, pval_100, label = "$\sigma_{B}=$100%")

plt.grid(True) 
plt.legend(loc="upper right", fontsize=16)

plt.xlabel("mu_sig", fontsize=14)
plt.ylabel("p-val", fontsize=14)
plt.title("tW_charm signal with 0.65 AMS")
plt.axis([1, 3, 0, 0.8])
# Out:
# [1.41078, 1.75359, 2.08069, 2.39388, 2.69467, 2.98432, 3.26388, 3.53427, 3.79626]
# (1.0, 3.0, 0.0, 0.8)

# %%
# AMS 0.85
pval_25 = list(map(float, split_lst[0][18:27]))
pval_50 = list(map(float, split_lst[2][18:27]))
pval_100 = list(map(float, split_lst[4][18:27]))
zval_25 = list(map(float, split_lst[1][18:27]))
zval_50 = list(map(float, split_lst[3][18:27]))
zval_100 = list(map(float, split_lst[5][18:27]))

print(zval_25)

plt.figure(0)
plt.plot(mu_sig, zval_25, label = "$\sigma_{B}=$25%")
plt.plot(mu_sig, zval_50, label = "$\sigma_{B}=$50%")
plt.plot(mu_sig, zval_100, label = "$\sigma_{B}=$100%")

plt.grid(True) 
plt.legend(loc="upper left", fontsize=16)

plt.xlabel("mu_sig", fontsize=14)
plt.ylabel("Z score", fontsize=14)
plt.title("tW_charm signal with 0.70 AMS")
plt.axis([1, 3, 0, 5])

plt.figure(1)
plt.plot(mu_sig, pval_25, label = "$\sigma_{B}=$25%")
plt.plot(mu_sig, pval_50, label = "$\sigma_{B}=$50%")
plt.plot(mu_sig, pval_100, label = "$\sigma_{B}=$100%")

plt.grid(True) 
plt.legend(loc="upper right", fontsize=16)

plt.xlabel("mu_sig", fontsize=14)
plt.ylabel("p-val", fontsize=14)
plt.title("tW_charm signal with 0.70 AMS")
plt.axis([1, 3, 0, 0.5])
# Out:
# [1.82691, 2.24618, 2.64273, 3.01969, 3.37952, 3.72422, 4.05543, 4.37453, 4.68268]
# (1.0, 3.0, 0.0, 0.5)

# %%
filename = "./ttup.txt"
lines = open(filename).read().splitlines()

mu_sig = [1, 1.25, 1.5, 1.75, 2, 2.25, 2.5, 2.75, 3]
relativeBkgUncert = [0.25, 0.5, 1]

# %%
import itertools
def split_list(lst, val):
    return [list(group) for k, group in itertools.groupby(lst, lambda x: x==val) if not k]
split_lst = split_list(lines, '')

# %%
# AMS 0.75
pval_25 = list(map(float, split_lst[0][:9]))
pval_50 = list(map(float, split_lst[2][:9]))
pval_100 = list(map(float, split_lst[4][:9]))
zval_25 = list(map(float, split_lst[1][:9]))
zval_50 = list(map(float, split_lst[3][:9]))
zval_100 = list(map(float, split_lst[5][:9]))

print(zval_25)

plt.figure(0)
plt.plot(mu_sig, zval_25, label = "$\sigma_{B}=$25%")
plt.plot(mu_sig, zval_50, label = "$\sigma_{B}=$50%")
plt.plot(mu_sig, zval_100, label = "$\sigma_{B}=$100%")

plt.grid(True) 
plt.legend(loc="upper left", fontsize=16)

plt.xlabel("mu_sig", fontsize=14)
plt.ylabel("Z score", fontsize=14)
plt.title("ttbar_charm signal")
plt.axis([1, 3, 0, 9])

plt.figure(1)
plt.plot(mu_sig, pval_25, label = "$\sigma_{B}=$25%")
plt.plot(mu_sig, pval_50, label = "$\sigma_{B}=$50%")
plt.plot(mu_sig, pval_100, label = "$\sigma_{B}=$100%")

plt.grid(True) 
plt.legend(loc="upper right", fontsize=16)

plt.xlabel("mu_sig", fontsize=14)
plt.ylabel("p-val", fontsize=14)
plt.title("ttbar_charm signal")
plt.axis([1, 3, 0, 0.3])
# Out:
# [3.94733, 4.71373, 5.42216, 6.08331, 6.70502, 7.29321, 7.8525, 8.38654, 8.8983]
# (1.0, 3.0, 0.0, 0.3)

# %%
# AMS 0.80
pval_25 = list(map(float, split_lst[0][9:18]))
pval_50 = list(map(float, split_lst[2][9:18]))
pval_100 = list(map(float, split_lst[4][9:18]))
zval_25 = list(map(float, split_lst[1][9:18]))
zval_50 = list(map(float, split_lst[3][9:18]))
zval_100 = list(map(float, split_lst[5][9:18]))

print(zval_25)

plt.figure(0)
plt.plot(mu_sig, zval_25, label = "$\sigma_{B}=$25%")
plt.plot(mu_sig, zval_50, label = "$\sigma_{B}=$50%")
plt.plot(mu_sig, zval_100, label = "$\sigma_{B}=$100%")

plt.grid(True) 
plt.legend(loc="upper left", fontsize=16)

plt.xlabel("mu_sig", fontsize=14)
plt.ylabel("Z score", fontsize=14)
plt.title("ttbar_charm signal")
plt.axis([1, 3, 0, 9])

plt.figure(1)
plt.plot(mu_sig, pval_25, label = "$\sigma_{B}=$25%")
plt.plot(mu_sig, pval_50, label = "$\sigma_{B}=$50%")
plt.plot(mu_sig, pval_100, label = "$\sigma_{B}=$100%")

plt.grid(True) 
plt.legend(loc="upper right", fontsize=16)

plt.xlabel("mu_sig", fontsize=14)
plt.ylabel("p-val", fontsize=14)
plt.title("ttbar_charm signal")
plt.axis([1, 3, 0, 0.3])
# Out:
# [4.21959, 5.02617, 5.77024, 6.46359, 7.11482, 7.73036, 8.31522, 8.87333, 9.40789]
# (1.0, 3.0, 0.0, 0.3)

# %%
# AMS 0.85
pval_25 = list(map(float, split_lst[0][18:27]))
pval_50 = list(map(float, split_lst[2][18:27]))
pval_100 = list(map(float, split_lst[4][18:27]))
zval_25 = list(map(float, split_lst[1][18:27]))
zval_50 = list(map(float, split_lst[3][18:27]))
zval_100 = list(map(float, split_lst[5][18:27]))

print(zval_25)

plt.figure(0)
plt.plot(mu_sig, zval_25, label = "$\sigma_{B}=$25%")
plt.plot(mu_sig, zval_50, label = "$\sigma_{B}=$50%")
plt.plot(mu_sig, zval_100, label = "$\sigma_{B}=$100%")

plt.grid(True) 
plt.legend(loc="upper left", fontsize=16)

plt.xlabel("mu_sig", fontsize=14)
plt.ylabel("Z score", fontsize=14)
plt.title("ttbar_charm signal")
plt.axis([1, 3, 0, 9])

plt.figure(1)
plt.plot(mu_sig, pval_25, label = "$\sigma_{B}=$25%")
plt.plot(mu_sig, pval_50, label = "$\sigma_{B}=$50%")
plt.plot(mu_sig, pval_100, label = "$\sigma_{B}=$100%")

plt.grid(True) 
plt.legend(loc="upper right", fontsize=16)

plt.xlabel("mu_sig", fontsize=14)
plt.ylabel("p-val", fontsize=14)
plt.title("ttbar_charm signal")
plt.axis([1, 3, 0, 0.3])
# Out:
# [4.60438, 5.46654, 6.25984, 6.99767, 7.68965, 8.34297, 8.96315, 9.55454, 10.1206]
# (1.0, 3.0, 0.0, 0.3)
