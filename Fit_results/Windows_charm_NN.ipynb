# %% [markdown]
# # DNN in TopFC analysis
# Author: Meisam Ghasemi Bostanabad

# %% [markdown]
# ## Loading `pandas` DataFrames
# Now we load two different `NumPy` arrays. One corresponding to the VV signal and one corresponding to the background.

# %%
import numpy as np
import pandas as pd
import h5py
import awkward as ak
import seaborn as sns
import matplotlib.pyplot as plt
import math
from scipy import stats
import random


# Set seeds for reproducibility
seed_value = 100 # Choose any integer
random.seed(seed_value)
np.random.seed(seed_value)

VARS = ['jetNo','jetPTLeading', 'jetETA', 'jetPHI','bjetPT', 'bjetETA',
        'elecPTLeading', 'elecETA', 'elecPHI',
        'dielecCOS', 'dielecETA', 'met','testnonTopMass'] # choose which vars to use (2d)
filename = {
    'ttbar':'/Users/mghasemi/Desktop/IPM/plotter/newtrees/ttbar_trees/ttbar.root',
    'WZ':'/Users/mghasemi/Desktop/IPM/plotter/newtrees/ttbar_trees/WZ.root',
    'ZZ':'/Users/mghasemi/Desktop/IPM/plotter/newtrees/ttbar_trees/ZZ.root',
    'signal_charm':'/Users/mghasemi/Desktop/IPM/plotter/newtrees/ttbar_trees/signal_charm.root'
    }

# %%
# Set seeds for reproducibility
seed_value = 50 # Choose any integer
random.seed(seed_value)
np.random.seed(seed_value)

# %%
# Reload the dictionary from HDF5
df = {}
with pd.HDFStore("data.h5", mode="r") as store:
    for key in store.keys():
        df[key.strip("/")] = store[key]

print("Loaded keys:", df.keys())
# Out:
# Loaded keys: dict_keys(['WZ', 'ZZ', 'signal_charm', 'ttbar'])

# %%
print(df['signal_charm'].shape)
df['signal_charm'].head()
# Out:
# (94643, 14)
#                 jetNo  jetPTLeading    jetETA    jetPHI      bjetPT   bjetETA  \
# entry subentry
# 0     0             2     52.077969 -1.835774  2.228185  216.971283 -1.835774
#       1             2     52.077969 -0.613786 -1.335376  216.971283 -1.835774
# 1     0             2     51.172218  4.199902  2.957153   34.315346 -2.735974
#       1             2     51.172218 -2.735974  2.084447   34.315346 -2.735974
# 2     0             2     48.883533 -1.547867 -0.107220  106.937912 -1.547867
#
#                 elecPTLeading   elecETA   elecPHI  dielecCOS  dielecETA  \
# entry subentry
# 0     0             94.921661  0.705369 -1.077370  -0.114869   0.647933
#       1             94.921661 -2.118405  1.269983  -0.114869   0.647933
# 1     0            142.296906  0.814325 -1.075413   0.969773   1.215590
#       1            142.296906 -0.401264 -1.321912   0.969773   1.215590
# 2     0            112.505493 -0.274112  2.768057   0.988006  -1.543363
#
#                        met  testnonTopMass  isSignal
# entry subentry
# 0     0          22.260880      202.733345       1.0
#       1          22.260880      202.733345       1.0
# 1     0         127.151787      740.675961       1.0
#       1         127.151787      740.675961       1.0
# 2     0          92.219826      269.701851       1.0

# %%
df['signal_charm'].iloc[38501]
# Out:
# jetNo               2.000000
# jetPTLeading       39.280785
# jetETA             -0.159846
# jetPHI             -2.122958
# bjetPT             58.937031
# bjetETA            -0.159846
# elecPTLeading      60.568047
# elecETA            -1.161297
# elecPHI             0.335389
# dielecCOS          -0.236093
# dielecETA          -2.977706
# met                63.398247
# testnonTopMass    175.964228
# isSignal            1.000000
# Name: (15684, 0), dtype: float64

# %% [markdown]
# ## Functions

# %%
# function to plot all distributions
def hist(df1, df2, cols, bins, ncols = 3):
    nrows = math.ceil(len(cols) / ncols)
    fig, ax = plt.subplots(nrows, ncols, figsize = (5 * ncols, 4.2 * nrows), sharey = False)
    for i in range(len(cols)):
        #sns.histplot(data = df, x = cols[i], bins = bins, hue = 'isSignal', palette = ['grey', 'red'], ax = ax[i // ncols, i % ncols], stat="probability")
        sns.histplot(data = df1, x = cols[i], bins = bins, color = 'red',
                      ax = ax[i // ncols, i % ncols], stat="density", label='bkg')
        sns.histplot(data = df2, x = cols[i], bins = bins, color = 'grey',
                      ax = ax[i // ncols, i % ncols], stat="density", label='sig')       
        ax[i // ncols, i % ncols].set_xlabel(cols[i])
        ax[i // ncols, i % ncols].legend()
        if i % ncols != 0:
            ax[i // ncols, i % ncols].set_ylabel(" ")
        
    plt.tight_layout()
    plt.show()


# function to make ML output and significant plot
samples =['ttbar', 'WZ', 'ZZ', 'signal_charm']

def plot_SoverB(data, SoverB_hist_dict):
    
    signal = r'signal_charm' # which sample is the signal

    # *******************
    # general definitions (shouldn't need to change)

    for x_variable,hist in SoverB_hist_dict.items(): # access the dictionary of histograms defined in the cell above

        h_bin_width = hist['bin_width'] # get the bin width defined in the cell above
        h_num_bins = hist['num_bins'] # get the number of bins defined in the cell above
        h_xrange_min = hist['xrange_min'] # get the x-range minimum defined in the cell above
        h_xlabel = hist['xlabel'] # get the x-axis label defined in the cell above
    
        bin_edges = [ h_xrange_min + x*h_bin_width for x in range(h_num_bins+1) ] # bin limits
        bin_centres = [ h_xrange_min+h_bin_width/2 + x*h_bin_width for x in range(h_num_bins) ] # bin centres
        
        signal_x = data[signal][x_variable] # histogram the signal
    
        mc_x = [] # define list to hold the Monte Carlo histogram entries

        for s in samples: # loop over samples
            if s not in ['data', signal]: # if not data nor signal
                mc_x = [*mc_x, *data[s][x_variable] ] # append to the list of Monte Carlo histogram entries
                #test=[]; test.append(df[s]['NN_output_prob'].values)

        # *************
        # Signal and background distributions
        # *************
        distributions_axes = plt.gca() # get current axes
 
        mc_heights = distributions_axes.hist(mc_x, bins=bin_edges, color='red', 
                                             label='Total background',
                                             histtype='step', # lineplot that's unfilled
                                             density=True ) # normalize to form probability density
        signal_heights = distributions_axes.hist(signal_x, bins=bin_edges, color='blue',
                                                 label=signal, 
                                                 histtype='step', # lineplot that's unfilled
                                                 density=True, # normalize to form probability density
                                                 linestyle='--' ) # dashed line
        
        distributions_axes.set_xlim( left=bin_edges[0], right=bin_edges[-1] ) # x-limits of the distributions axes
        distributions_axes.set_ylabel('Arbitrary units' ) # y-axis label for distributions axes
        y_max = max(max(signal_heights[0]), max(mc_heights[0]) )
        #distributions_axes.set_ylim( top=max(signal_heights[0])*1.3 ) # set y-axis limits
        distributions_axes.set_ylim( top=y_max*1.2 ) # set y-axis limits
        #distributions_axes.set_ylim( top=max(signal_heights[0])*1.3 ) # set y-axis limits
        plt.title('Signal and background '+x_variable+' distributions') # add title
        distributions_axes.legend() # draw the legend
        distributions_axes.set_xlabel( h_xlabel ) # x-axis label
            
        plt.show() # show the Signal and background distributions
    
        # *************
        # Signal to background ratio
        # *************
        plt.figure() # start new figure
        SoverB = [] # list to hold S/B values
        for cut_value in bin_edges: # loop over bins
            #signal_weights_passing_cut = sum(data[signal][data[signal][x_variable]>cut_value].totalWeight)
            signal_weights_passing_cut = len(data[signal][data[signal][x_variable]>cut_value])
            background_weights_passing_cut = 0 # start counter for background weights passing cut
            for s in samples: # loop over samples
                if s not in ['data', signal]: # if not data nor signal
                    #background_weights_passing_cut += sum(data[s][data[s][x_variable]>cut_value].totalWeight)
                    background_weights_passing_cut += len(data[s][data[s][x_variable]>cut_value])
            if background_weights_passing_cut!=0: # some background passes cut
                SoverB_value = signal_weights_passing_cut/background_weights_passing_cut
                SoverB_percent = 100*SoverB_value # multiply by 100 for percentage
                SoverB.append(SoverB_percent) # append to list of S/B values
        
        SoverB_axes = plt.gca() # get current axes
        SoverB_axes.plot( bin_edges[:len(SoverB)], SoverB ) # plot the data points
        SoverB_axes.set_xlim( left=bin_edges[0], right=bin_edges[-1] ) # set the x-limit of the main axes
        #SoverB_axes.set_ylim( 100, 1000)
        SoverB_axes.set_ylabel( 'S/B (%)' ) # write y-axis label for main axes
        plt.title('Signal to background ratio for different '+x_variable+' cut values', family='sans-serif')
        SoverB_axes.set_xlabel( h_xlabel ) # x-axis label 
        
        plt.show() # show S/B plot
    
    return    

# function to draw loss-accuracy vs epoch and ROC curve
from sklearn.metrics import roc_curve, auc, classification_report, accuracy_score, confusion_matrix, roc_auc_score

# %matplotlib inline
def loss_accuracy_plotter(history, model, X_train_val, Y_train_val, X_test, Y_test):
    # plot loss vs epoch
    plt.figure(figsize=(15,10))
    ax = plt.subplot(2, 2, 1)
    ax.plot(history.history['loss'], label='loss')
    ax.plot(history.history['val_loss'], label='val_loss')
    ax.legend(loc="upper right")
    ax.set_title('Loss over epochs')
    ax.set_xlabel('epoch')
    ax.set_ylabel('loss')

    # plot accuracy vs epoch
    ax = plt.subplot(2, 2, 2)
    ax.plot(history.history['accuracy'], label='acc')
    ax.plot(history.history['val_accuracy'], label='val_acc')
    ax.legend(loc="lower right")
    ax.set_title('Accuracy over epochs')
    ax.set_xlabel('epoch')
    ax.set_ylabel('acc')

    # Plot ROC
    Y_predict = model.predict(X_test)
    Y_predict_train = model.predict(X_train_val)
    fpr, tpr, thresholds = roc_curve(Y_test, Y_predict)
    auc_score = roc_auc_score(Y_test, Y_predict)
    print(f"AUC: {auc_score:.4f}")
    roc_auc = auc(fpr, tpr)
    ax = plt.subplot(2, 2, 3)
    ax.plot(fpr, tpr, lw=2, color='cyan', label='auc = %.3f' % (roc_auc))
    ax.plot([0, 1], [0, 1], linestyle='--', lw=2, color='k', label='random chance')
    ax.set_xlim([0, 1.0])
    ax.set_ylim([0, 1.0])
    ax.set_xlabel('false positive rate')
    ax.set_ylabel('true positive rate')
    ax.set_title('receiver operating curve')
    ax.legend(loc="lower right")
    plt.show()

# function to report all metrics evaluation
def evaluate(model, scaler, X, Y, X_train_val, Y_train_val, X_test, Y_test):
    Y_pred_test = model.predict(X_test)
    Y_pred_test = Y_pred_test.reshape(Y_pred_test.shape[0])
    Y_pred_train = model.predict(X_train_val)
    Y_pred_train = Y_pred_train.reshape(Y_pred_train.shape[0])
    Y_pred_tot = model.predict(scaler.transform(X)).round()
    Y_pred_tot = Y_pred_tot.reshape(Y_pred_tot.shape[0])

    # accuracy score
    print("Test acc score:", accuracy_score(Y_test.round(), Y_pred_test.round()))
    print("Train acc score:", accuracy_score(Y_train_val.round(), Y_pred_train.round()))

    # classification report for the test and total sets
    print("Classification report for the test set")
    print(classification_report(Y_test.round(), Y_pred_test.round(), target_names=['background', 'signal']))
    print("Classification report for the total set")
    print(classification_report(Y.round(), Y_pred_tot.round(), target_names=['background', 'signal']))

    print("Confusion matrix for total set")
    print(confusion_matrix(Y.round(), Y_pred_tot.round()))

    fpr, tpr, thresholds = roc_curve(Y_test, Y_pred_test) # get FPRs, TPRs and thresholds for neural network
    return fpr, tpr, thresholds

# plot AMS
def AMS(tpr, fpr, b_reg): # define function to calculate AMS
    return np.sqrt(2*((tpr+fpr+b_reg)*np.log(1+tpr/(fpr+b_reg))-tpr)) # equation for AMS

def significance(tpr, fpr, s_total, b_total, b_reg=1e-3):
    S = tpr * s_total
    B = fpr * b_total
    return S / np.sqrt(B + b_reg)

def cdf(sample, x, sort = False):
    '''
    Return the value of the Cumulative Distribution Function, evaluated for a given sample and a value x.
    
    Args:
        sample: The list or array of observations.
        x: The value for which the numerical cdf is evaluated.
    
    Returns:
        cdf = CDF_{sample}(x)
    '''
    
    # Sorts the sample, if needed
    if sort:
        sample.sort()
    
    # Counts how many observations are below x
    cdf = sum(sample <= x)
    
    # Divides by the total number of observations
    cdf = cdf / len(sample)
    
    return cdf

def ks_2samp_test(sample1, sample2):
    
    # Gets all observations
    observations = np.concatenate((sample1, sample2))
    observations.sort()
    
    # Sorts the samples
    sample1.sort()
    sample2.sort()
    
    # Evaluates the KS statistic
    D_ks = [] # KS Statistic list
    for x in observations:
        cdf_sample1 = cdf(sample = sample1, x  = x)
        cdf_sample2 = cdf(sample = sample2, x  = x)
        D_ks.append(abs(cdf_sample1 - cdf_sample2))
    ks_stat = max(D_ks)
    
    # Calculates the P-Value based on the two-sided test
    # The P-Value comes from the KS Distribution Survival Function (SF = 1-CDF)
    m, n = float(len(sample1)), float(len(sample2))
    en = m * n / (m + n)
    p_value = stats.kstwo.sf(ks_stat, np.round(en))
    
    return {"ks_stat": ks_stat, "p_value" : p_value}

# plot train and test CLF distributions
def new_compare_train_test(clf, X_train, y_train, X_test, y_test, xlabel):
    decisions = [] # list to hold decisions of classifier
    for X,y in ((X_train, y_train), (X_test, y_test)): # train and test
        d1 = clf.predict(X[y<0.5]) # background
        d2 = clf.predict(X[y>0.5]) # signal
        decisions += [d1, d2] # add to list of classifier decision

    highest_decision = max(np.max(d) for d in decisions) # get maximum score
    bin_edges = [] # list to hold bin edges
    bin_edge = -0.1 # start counter for bin_edges
    while bin_edge < highest_decision: # up to highest score
        bin_edge += 0.1 # increment
        bin_edges.append(bin_edge)

    # Training plots
    plt.hist(decisions[0], # background in train set
            bins=bin_edges, # lower and upper range of the bins
            density=True, # area under the histogram will sum to 1
            histtype='stepfilled', # lineplot that's filled
            color='blue', label='Background (train)', # Background (train)
            alpha=0.5 ) # half transparency
    plt.hist(decisions[1], # signal in train set
            bins=bin_edges, # lower and upper range of the bins
            density=True, # area under the histogram will sum to 1
            histtype='stepfilled', # lineplot that's filled
            color='orange', label='Signal (train)', # Signal (train)
            alpha=0.5 ) # half transparency

    # Testing plots
    hist_background, bin_edges = np.histogram(decisions[2], # background test
                                            bins=bin_edges, # number of bins in function definition
                                            density=True ) # area under the histogram will sum to 1

    scale = len(decisions[2]) / sum(hist_background) # between raw and normalised
    err_background = np.sqrt(hist_background * scale) / scale # error on test background

    width = 0.1 # histogram bin width
    center = (bin_edges[:-1] + bin_edges[1:]) / 2 # bin centres

    plt.errorbar(x=center, y=hist_background, yerr=err_background, fmt='o', # circles
                c='blue', label='Background (test)' ) # Background (test)

    hist_signal, bin_edges = np.histogram(decisions[3], # siganl test
                                        bins=bin_edges, # number of bins in function definition
                                        density=True ) # area under the histogram will sum to 1

    scale = len(decisions[3]) / sum(hist_signal) # between raw and normalised
    err_signal = np.sqrt(hist_signal * scale) / scale # error on test background

    plt.errorbar(x=center, y=hist_signal, yerr=err_signal, fmt='*', # circles
                c='orange', label='Signal (test)' ) # Signal (test)

    plt.xlabel(xlabel) # write x-axis label
    plt.ylabel("Arbitrary units") # write y-axis label
    plt.legend() # add legend
    ks_signal = ks_2samp_test(np.array(decisions[1]), np.array(decisions[3]))
    ks_background = ks_2samp_test(np.array(decisions[0]), np.array(decisions[2]))
    print(f"Signal: ks = {ks_signal['ks_stat']} (p-value = {ks_signal['p_value']}, are equal = {ks_signal['p_value'] > 0.05})")
    print(f"Background: ks = {ks_background['ks_stat']} (p-value = {ks_background['p_value']}, are equal = {ks_background['p_value'] > 0.05})")
    #return (decisions[0], decisions[2])

# %% [markdown]
# ## Data exploration

# %%
#df_all = pd.read_hdf("data_df.h5")
#df_all.shape

# %%
# reduce signal DF size to have resonable Sig/Bkg ratio
df['signal_charm'] = df['signal_charm'][:20000]
df_all = pd.concat([df[treename] for treename in filename.keys()])

# %%
# number of entries in the backgrounds and signals
sns.set_theme(style="white")

tot_bkg = 0
for treename in filename.keys():
    if not 'signal' in treename: tot_bkg += df[treename].shape[0]
    print(treename, ":", df[treename].shape)

print("signal/tot bkg:", round((df['signal_charm'].shape[0]/ tot_bkg),1))
#print("Null entries:", df['signal_charm'].isna().sum())

counts_signal = df['signal_charm'].shape[0]
counts_background = tot_bkg

plt.figure(figsize=(8,6))
plt.pie([counts_signal, counts_background], explode=[0.1,0.1], shadow=True, labels=['Signal ','Background'], textprops={'fontsize': 14}, autopct='%1.1f%%');
#plt.pie([counts_signal, counts_background], explode=[0.1,0.1], shadow=True, labels=['Signal ','Background'], textprops={'color':"b"}, autopct='%1.1f%%');
# Out:
# ttbar : (1181, 14)
# WZ : (10855, 14)
# ZZ : (174, 14)
# signal_charm : (20000, 14)
# signal/tot bkg: 1.6

# %%
'''
# show the correlation between features
plt.figure(figsize=(10,8))
#sns.heatmap(df_all.corr(), annot=True, linewidth=.5)
sns.heatmap(df_all.corr(), annot=True, linewidth=.5, vmin = -1, vmax = 1,cmap = plt.cm.CMRmap_r, fmt=".1f");
'''

plt.figure(figsize=(13,10))
#sns.set_theme(style="white")

# Getting the Upper Triangle of the co-relation matrix
corr = df_all.corr()
#matrix = np.triu(corr)
#mask = np.triu(np.ones_like(corr, dtype=bool))
#matrix = np.triu(np.ones_like(corr))
matrix = np.triu(np.ones_like(corr), k=1)



cmap = sns.diverging_palette(200, 7, s=75, l=40,
                            n=5, center="light", as_cmap=True)

#sns.heatmap(df_test.corr(), annot=True, linewidth=.5, vmin = -1, vmax = 1,cmap = plt.cm.CMRmap_r, fmt=".1f", mask=matrix);
ax = sns.heatmap(df_all.corr(), annot=True, linewidth=.5, vmin = -1, vmax = 1,cmap = cmap, fmt=".2f", mask=matrix);
ax.set_xticklabels([r'$N_{\text{jet}}$', r'$P_{\text{T}}^{\text{leading jet}}$', r'$\eta_{\text{jet}}$', r'$\phi_{\text{jet}}$', r'$P_{\text{T}}^{\text{b-jet}}$', r'$\eta_{\text{b-jet}}$',
                    r'$P_{\text{T}}^{\text{leading electron}}$', r'$\eta_{\text{electron}}$', r'$\phi_{\text{electron}}$', r'$Cos(\Delta \phi_{\text{di-electron}})$', r'$\Delta \eta_{\text{di-electron}}$', r'$P_{\text{T}}^{\text{miss}}$', r'$ M_{\text{top}}^{\text{non-SM}}$', 'isSignal'],
                   rotation=45, ha="right")
ax.set_yticklabels([r'$N_{\text{jet}}$', r'$P_{\text{T}}^{\text{leading jet}}$', r'$\eta_{\text{jet}}$', r'$\phi_{\text{jet}}$', r'$P_{\text{T}}^{\text{b-jet}}$', r'$\eta_{\text{b-jet}}$',
                    r'$P_{\text{T}}^{\text{leading electron}}$', r'$\eta_{\text{electron}}$', r'$\phi_{\text{electron}}$', r'$Cos(\Delta \phi_{\text{di-electron}})$', r'$\Delta \eta_{\text{di-electron}}$', r'$P_{\text{T}}^{\text{miss}}$', r'$ M_{\text{top}}^{\text{non-SM}}$', 'isSignal'],
                   rotation=0)
# Out:
# [Text(0, 0.5, '$N_{\\text{jet}}$'),
#  Text(0, 1.5, '$P_{\\text{T}}^{\\text{leading jet}}$'),
#  Text(0, 2.5, '$\\eta_{\\text{jet}}$'),
#  Text(0, 3.5, '$\\phi_{\\text{jet}}$'),
#  Text(0, 4.5, '$P_{\\text{T}}^{\\text{b-jet}}$'),
#  Text(0, 5.5, '$\\eta_{\\text{b-jet}}$'),
#  Text(0, 6.5, '$P_{\\text{T}}^{\\text{leading electron}}$'),
#  Text(0, 7.5, '$\\eta_{\\text{electron}}$'),
#  Text(0, 8.5, '$\\phi_{\\text{electron}}$'),
#  Text(0, 9.5, '$Cos(\\Delta \\phi_{\\text{di-electron}})$'),
#  Text(0, 10.5, '$\\Delta \\eta_{\\text{di-electron}}$'),
#  Text(0, 11.5, '$P_{\\text{T}}^{\\text{miss}}$'),
#  Text(0, 12.5, '$ M_{\\text{top}}^{\\text{non-SM}}$'),
#  Text(0, 13.5, 'isSignal')]

# %%
df_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 32210 entries, (np.int64(0), np.int64(0)) to (np.int64(8135), np.int64(1))
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   jetNo           32210 non-null  int32
#  1   jetPTLeading    32210 non-null  float64
#  2   jetETA          32210 non-null  float64
#  3   jetPHI          32210 non-null  float64
#  4   bjetPT          32210 non-null  float64
#  5   bjetETA         32210 non-null  float64
#  6   elecPTLeading   32210 non-null  float64
#  7   elecETA         32210 non-null  float64
#  8   elecPHI         32210 non-null  float64
#  9   dielecCOS       32210 non-null  float64
#  10  dielecETA       32210 non-null  float64
#  11  met             32210 non-null  float64
#  12  testnonTopMass  32210 non-null  float64
#  13  isSignal        32210 non-null  float64
# dtypes: float64(13), int32(1)
# memory usage: 4.8 MB

# %%
# Distributions of the float features
hist(df_all[df_all['isSignal']==0].replace(-999, np.nan),
     df_all[df_all['isSignal']==1].replace(-999, np.nan),
     #list(df_all.columns[df_all.dtypes == 'float64']),
     list(df_all.columns),
     bins = math.floor(len(df_all)**(1/3)),
     ncols = 3)

# %% [markdown]
# ## Define the models

# %% [markdown]
# ## simple NN from Tensorflow
# We'll start with a dense (fully-connected) NN layer.
# Our model will have a single fully-connected hidden layer with the same number of neurons as input variables.
# The weights are initialized using a small Gaussian random number.
# We will switch between linear and tanh activation functions for the hidden layer.
# The output layer contains a single neuron in order to make predictions.
# It uses the sigmoid activation function in order to produce a probability output in the range of 0 to 1.
#
# We are using the `binary_crossentropy` loss function during training, a standard loss function for binary classification problems.
# We will optimize the model with the Adam algorithm for stochastic gradient descent and we will collect accuracy metrics while the model is trained.

# %% [markdown]
# ## Dividing the data into testing and training dataset
#
# We will split the data into two parts (one for training+validation and one for testing).
# We will also apply "standard scaling" preprocessing: http://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.StandardScaler.html i.e. making the mean = 0 and the RMS = 1 for all input variables (based **only** on the training/validation dataset).
# We will also define our early stopping criteria to prevent over-fitting and we will save the model based on the best `val_loss`.

# %%
NDIM = len(VARS)
dataset = df_all.values
X = dataset[:,0:NDIM]
Y = dataset[:,NDIM]

from sklearn.model_selection import train_test_split
X_train_val, X_test, Y_train_val, Y_test = train_test_split(X, Y, test_size=0.2, shuffle=True, random_state=seed_value)

# preprocessing: standard scalar
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler().fit(X_train_val)
X_train_val = scaler.transform(X_train_val)
X_test = scaler.transform(X_test)

# baseline keras model
from keras.models import Sequential, Model
from tensorflow.keras.optimizers import SGD
#from keras.optimizers import SGD
from keras.layers import Input, Activation, Dense, Convolution2D, MaxPooling2D, Dropout, Flatten
#from keras.utils import np_utils
from sklearn.model_selection import RandomizedSearchCV
from sklearn.pipeline import Pipeline
from tensorflow import keras
import tensorflow as tf

tf.random.set_seed(seed_value)

inputs = Input(shape=(NDIM,), name = 'input') 
hidden1 = Dense(20, name = 'hidden1', kernel_initializer='normal', activation='relu')(inputs)
hidden2 = Dense(20, name = 'hidden2', kernel_initializer='normal', activation='relu')(hidden1)
outputs = Dense(1, name = 'output', kernel_initializer='normal', activation='sigmoid')(hidden2)

# create the model
model = Model(inputs=inputs, outputs=outputs)
# compile the model
optimizer = SGD(learning_rate=1e-3) # define the optimizer
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
#model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])
# print the model summary
model.summary()

# early stopping callback
from keras.callbacks import EarlyStopping
early_stopping = EarlyStopping(monitor='val_loss', patience=10, mode='min')

# model checkpoint callback
# this saves our model architecture + parameters into dense_model.h5
from keras.callbacks import ModelCheckpoint
model_checkpoint = ModelCheckpoint('tt_charm_NN_model.keras', monitor='val_loss', 
                                   verbose=0, save_best_only=True, 
                                   save_weights_only=False, mode='auto', 
                                   #period=1)
)
# Out:
# Model: "functional_50"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input (InputLayer)              │ (None, 13)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ hidden1 (Dense)                 │ (None, 20)             │           280 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ hidden2 (Dense)                 │ (None, 20)             │           420 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output (Dense)                  │ (None, 1)              │            21 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 721 (2.82 KB)
#  Trainable params: 721 (2.82 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## Run training
# Here, we run the training.

# %%
# Train classifier
import time
start = time.time() # time at start of whole processing

history = model.fit(X_train_val, 
                    Y_train_val, 
                    epochs=1000, 
                    batch_size=512, 
                    verbose=1, # switch to 1 for more verbosity 
                    callbacks=[early_stopping, model_checkpoint], 
                    validation_data=(X_test,Y_test))

elapsed = time.time() - start # time after whole processing
print("Time taken: "+str(round(elapsed,1))+"s") # print total time taken to process every file
# Out:
# Epoch 1/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5930 - loss: 0.6892 - val_accuracy: 0.6509 - val_loss: 0.6630
# Epoch 2/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6493 - loss: 0.6498 - val_accuracy: 0.6748 - val_loss: 0.6073
# Epoch 3/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6708 - loss: 0.6070 - val_accuracy: 0.6830 - val_loss: 0.5971
# Epoch 4/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6801 - loss: 0.5974 - val_accuracy: 0.6900 - val_loss: 0.5898
# Epoch 5/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6881 - loss: 0.5892 - val_accuracy: 0.6971 - val_loss: 0.5806
# Epoch 6/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7001 - loss: 0.5802 - val_accuracy: 0.7048 - val_loss: 0.5715
# Epoch 7/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7085 - loss: 0.5723 - val_accuracy: 0.7093 - val_loss: 0.5654
# Epoch 8/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7128 - loss: 0.5671 - val_accuracy: 0.7136 - val_loss: 0.5617
# Epoch 9/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7151 - loss: 0.5633 - val_accuracy: 0.7167 - val_loss: 0.5590
# Epoch 10/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7181 - loss: 0.5601 - val_accuracy: 0.7195 - val_loss: 0.5565
# Epoch 11/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7198 - loss: 0.5572 - val_accuracy: 0.7190 - val_loss: 0.5543
# Epoch 12/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7210 - loss: 0.5546 - val_accuracy: 0.7201 - val_loss: 0.5523
# Epoch 13/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7222 - loss: 0.5524 - val_accuracy: 0.7201 - val_loss: 0.5508
# Epoch 14/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7234 - loss: 0.5507 - val_accuracy: 0.7212 - val_loss: 0.5495
# Epoch 15/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7241 - loss: 0.5492 - val_accuracy: 0.7220 - val_loss: 0.5487
# Epoch 16/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7239 - loss: 0.5481 - val_accuracy: 0.7228 - val_loss: 0.5480
# Epoch 17/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7244 - loss: 0.5471 - val_accuracy: 0.7242 - val_loss: 0.5475
# Epoch 18/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7247 - loss: 0.5463 - val_accuracy: 0.7245 - val_loss: 0.5470
# Epoch 19/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7264 - loss: 0.5455 - val_accuracy: 0.7254 - val_loss: 0.5465
# Epoch 20/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7277 - loss: 0.5448 - val_accuracy: 0.7260 - val_loss: 0.5461
# Epoch 21/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7284 - loss: 0.5441 - val_accuracy: 0.7259 - val_loss: 0.5457
# Epoch 22/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7301 - loss: 0.5434 - val_accuracy: 0.7259 - val_loss: 0.5454
# Epoch 23/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7308 - loss: 0.5428 - val_accuracy: 0.7269 - val_loss: 0.5451
# Epoch 24/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7309 - loss: 0.5422 - val_accuracy: 0.7280 - val_loss: 0.5448
# Epoch 25/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7311 - loss: 0.5416 - val_accuracy: 0.7288 - val_loss: 0.5446
# Epoch 26/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7315 - loss: 0.5411 - val_accuracy: 0.7283 - val_loss: 0.5444
# Epoch 27/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7325 - loss: 0.5407 - val_accuracy: 0.7291 - val_loss: 0.5443
# Epoch 28/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7330 - loss: 0.5403 - val_accuracy: 0.7299 - val_loss: 0.5441
# Epoch 29/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7328 - loss: 0.5399 - val_accuracy: 0.7305 - val_loss: 0.5441
# Epoch 30/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7328 - loss: 0.5395 - val_accuracy: 0.7301 - val_loss: 0.5440
# Epoch 31/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7324 - loss: 0.5392 - val_accuracy: 0.7296 - val_loss: 0.5440
# Epoch 32/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7329 - loss: 0.5388 - val_accuracy: 0.7304 - val_loss: 0.5440
# Epoch 33/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7334 - loss: 0.5385 - val_accuracy: 0.7293 - val_loss: 0.5439
# Epoch 34/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7340 - loss: 0.5381 - val_accuracy: 0.7288 - val_loss: 0.5439
# Epoch 35/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7340 - loss: 0.5377 - val_accuracy: 0.7291 - val_loss: 0.5439
# Epoch 36/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7340 - loss: 0.5374 - val_accuracy: 0.7297 - val_loss: 0.5437
# Epoch 37/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7343 - loss: 0.5371 - val_accuracy: 0.7307 - val_loss: 0.5437
# Epoch 38/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7346 - loss: 0.5368 - val_accuracy: 0.7308 - val_loss: 0.5436
# Epoch 39/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7344 - loss: 0.5365 - val_accuracy: 0.7307 - val_loss: 0.5435
# Epoch 40/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7346 - loss: 0.5363 - val_accuracy: 0.7311 - val_loss: 0.5434
# Epoch 41/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7350 - loss: 0.5360 - val_accuracy: 0.7308 - val_loss: 0.5433
# Epoch 42/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7348 - loss: 0.5357 - val_accuracy: 0.7316 - val_loss: 0.5432
# Epoch 43/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7351 - loss: 0.5354 - val_accuracy: 0.7311 - val_loss: 0.5431
# Epoch 44/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7356 - loss: 0.5351 - val_accuracy: 0.7307 - val_loss: 0.5431
# Epoch 45/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7363 - loss: 0.5349 - val_accuracy: 0.7296 - val_loss: 0.5430
# Epoch 46/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7371 - loss: 0.5347 - val_accuracy: 0.7299 - val_loss: 0.5429
# Epoch 47/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7371 - loss: 0.5344 - val_accuracy: 0.7302 - val_loss: 0.5428
# Epoch 48/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7369 - loss: 0.5341 - val_accuracy: 0.7305 - val_loss: 0.5426
# Epoch 49/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7366 - loss: 0.5339 - val_accuracy: 0.7302 - val_loss: 0.5425
# Epoch 50/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7367 - loss: 0.5337 - val_accuracy: 0.7305 - val_loss: 0.5423
# Epoch 51/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7370 - loss: 0.5334 - val_accuracy: 0.7307 - val_loss: 0.5422
# Epoch 52/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7375 - loss: 0.5332 - val_accuracy: 0.7313 - val_loss: 0.5420
# Epoch 53/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7373 - loss: 0.5330 - val_accuracy: 0.7319 - val_loss: 0.5418
# Epoch 54/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7375 - loss: 0.5328 - val_accuracy: 0.7318 - val_loss: 0.5415
# Epoch 55/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7379 - loss: 0.5326 - val_accuracy: 0.7313 - val_loss: 0.5413
# Epoch 56/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7377 - loss: 0.5324 - val_accuracy: 0.7316 - val_loss: 0.5411
# Epoch 57/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7377 - loss: 0.5322 - val_accuracy: 0.7310 - val_loss: 0.5409
# Epoch 58/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7378 - loss: 0.5319 - val_accuracy: 0.7313 - val_loss: 0.5407
# Epoch 59/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7378 - loss: 0.5317 - val_accuracy: 0.7314 - val_loss: 0.5405
# Epoch 60/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7384 - loss: 0.5316 - val_accuracy: 0.7322 - val_loss: 0.5403
# Epoch 61/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7390 - loss: 0.5314 - val_accuracy: 0.7321 - val_loss: 0.5400
# Epoch 62/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7394 - loss: 0.5312 - val_accuracy: 0.7324 - val_loss: 0.5398
# Epoch 63/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7396 - loss: 0.5310 - val_accuracy: 0.7324 - val_loss: 0.5397
# Epoch 64/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7400 - loss: 0.5308 - val_accuracy: 0.7316 - val_loss: 0.5396
# Epoch 65/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7396 - loss: 0.5307 - val_accuracy: 0.7310 - val_loss: 0.5395
# Epoch 66/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7397 - loss: 0.5305 - val_accuracy: 0.7307 - val_loss: 0.5394
# Epoch 67/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7399 - loss: 0.5303 - val_accuracy: 0.7314 - val_loss: 0.5393
# Epoch 68/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7399 - loss: 0.5301 - val_accuracy: 0.7318 - val_loss: 0.5391
# Epoch 69/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7397 - loss: 0.5299 - val_accuracy: 0.7322 - val_loss: 0.5390
# Epoch 70/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7399 - loss: 0.5298 - val_accuracy: 0.7325 - val_loss: 0.5389
# Epoch 71/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7403 - loss: 0.5296 - val_accuracy: 0.7325 - val_loss: 0.5388
# Epoch 72/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7406 - loss: 0.5294 - val_accuracy: 0.7324 - val_loss: 0.5388
# Epoch 73/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7407 - loss: 0.5293 - val_accuracy: 0.7332 - val_loss: 0.5388
# Epoch 74/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7403 - loss: 0.5292 - val_accuracy: 0.7327 - val_loss: 0.5388
# Epoch 75/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7402 - loss: 0.5290 - val_accuracy: 0.7327 - val_loss: 0.5387
# Epoch 76/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7402 - loss: 0.5288 - val_accuracy: 0.7327 - val_loss: 0.5386
# Epoch 77/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7403 - loss: 0.5287 - val_accuracy: 0.7335 - val_loss: 0.5386
# Epoch 78/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7408 - loss: 0.5285 - val_accuracy: 0.7338 - val_loss: 0.5385
# Epoch 79/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7406 - loss: 0.5283 - val_accuracy: 0.7336 - val_loss: 0.5385
# Epoch 80/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7411 - loss: 0.5282 - val_accuracy: 0.7336 - val_loss: 0.5384
# Epoch 81/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7412 - loss: 0.5280 - val_accuracy: 0.7336 - val_loss: 0.5383
# Epoch 82/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7414 - loss: 0.5279 - val_accuracy: 0.7338 - val_loss: 0.5382
# Epoch 83/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7411 - loss: 0.5277 - val_accuracy: 0.7338 - val_loss: 0.5381
# Epoch 84/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7417 - loss: 0.5276 - val_accuracy: 0.7342 - val_loss: 0.5380
# Epoch 85/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7417 - loss: 0.5274 - val_accuracy: 0.7342 - val_loss: 0.5379
# Epoch 86/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7421 - loss: 0.5273 - val_accuracy: 0.7342 - val_loss: 0.5378
# Epoch 87/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7419 - loss: 0.5271 - val_accuracy: 0.7336 - val_loss: 0.5377
# Epoch 88/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7421 - loss: 0.5270 - val_accuracy: 0.7336 - val_loss: 0.5375
# Epoch 89/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7422 - loss: 0.5268 - val_accuracy: 0.7330 - val_loss: 0.5374
# Epoch 90/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7421 - loss: 0.5267 - val_accuracy: 0.7327 - val_loss: 0.5373
# Epoch 91/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7418 - loss: 0.5266 - val_accuracy: 0.7327 - val_loss: 0.5371
# Epoch 92/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7418 - loss: 0.5264 - val_accuracy: 0.7324 - val_loss: 0.5370
# Epoch 93/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7419 - loss: 0.5263 - val_accuracy: 0.7328 - val_loss: 0.5369
# Epoch 94/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7423 - loss: 0.5262 - val_accuracy: 0.7327 - val_loss: 0.5368
# Epoch 95/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7422 - loss: 0.5260 - val_accuracy: 0.7325 - val_loss: 0.5367
# Epoch 96/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7421 - loss: 0.5259 - val_accuracy: 0.7324 - val_loss: 0.5367
# Epoch 97/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7423 - loss: 0.5258 - val_accuracy: 0.7321 - val_loss: 0.5365
# Epoch 98/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7423 - loss: 0.5257 - val_accuracy: 0.7324 - val_loss: 0.5365
# Epoch 99/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7420 - loss: 0.5255 - val_accuracy: 0.7321 - val_loss: 0.5364
# Epoch 100/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7418 - loss: 0.5254 - val_accuracy: 0.7328 - val_loss: 0.5363
# Epoch 101/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7417 - loss: 0.5253 - val_accuracy: 0.7330 - val_loss: 0.5363
# Epoch 102/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7417 - loss: 0.5252 - val_accuracy: 0.7333 - val_loss: 0.5363
# Epoch 103/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7419 - loss: 0.5251 - val_accuracy: 0.7328 - val_loss: 0.5362
# Epoch 104/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7419 - loss: 0.5250 - val_accuracy: 0.7332 - val_loss: 0.5362
# Epoch 105/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7422 - loss: 0.5248 - val_accuracy: 0.7332 - val_loss: 0.5362
# Epoch 106/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7423 - loss: 0.5247 - val_accuracy: 0.7332 - val_loss: 0.5362
# Epoch 107/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7425 - loss: 0.5246 - val_accuracy: 0.7333 - val_loss: 0.5362
# Epoch 108/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7424 - loss: 0.5245 - val_accuracy: 0.7325 - val_loss: 0.5361
# Epoch 109/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7424 - loss: 0.5244 - val_accuracy: 0.7330 - val_loss: 0.5361
# Epoch 110/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7427 - loss: 0.5243 - val_accuracy: 0.7327 - val_loss: 0.5360
# Epoch 111/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7422 - loss: 0.5242 - val_accuracy: 0.7330 - val_loss: 0.5360
# Epoch 112/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7423 - loss: 0.5241 - val_accuracy: 0.7336 - val_loss: 0.5359
# Epoch 113/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7423 - loss: 0.5240 - val_accuracy: 0.7336 - val_loss: 0.5359
# Epoch 114/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7428 - loss: 0.5239 - val_accuracy: 0.7339 - val_loss: 0.5358
# Epoch 115/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7428 - loss: 0.5238 - val_accuracy: 0.7339 - val_loss: 0.5358
# Epoch 116/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7428 - loss: 0.5237 - val_accuracy: 0.7338 - val_loss: 0.5357
# Epoch 117/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7424 - loss: 0.5236 - val_accuracy: 0.7335 - val_loss: 0.5357
# Epoch 118/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7425 - loss: 0.5235 - val_accuracy: 0.7332 - val_loss: 0.5357
# Epoch 119/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7423 - loss: 0.5235 - val_accuracy: 0.7327 - val_loss: 0.5357
# Epoch 120/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7424 - loss: 0.5234 - val_accuracy: 0.7328 - val_loss: 0.5357
# Epoch 121/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7430 - loss: 0.5233 - val_accuracy: 0.7328 - val_loss: 0.5357
# Epoch 122/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7432 - loss: 0.5233 - val_accuracy: 0.7327 - val_loss: 0.5357
# Epoch 123/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7429 - loss: 0.5232 - val_accuracy: 0.7327 - val_loss: 0.5357
# Epoch 124/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7429 - loss: 0.5231 - val_accuracy: 0.7328 - val_loss: 0.5356
# Epoch 125/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7430 - loss: 0.5230 - val_accuracy: 0.7333 - val_loss: 0.5356
# Epoch 126/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7430 - loss: 0.5230 - val_accuracy: 0.7338 - val_loss: 0.5355
# Epoch 127/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7428 - loss: 0.5229 - val_accuracy: 0.7344 - val_loss: 0.5355
# Epoch 128/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7428 - loss: 0.5228 - val_accuracy: 0.7346 - val_loss: 0.5354
# Epoch 129/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7426 - loss: 0.5228 - val_accuracy: 0.7341 - val_loss: 0.5354
# Epoch 130/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7423 - loss: 0.5227 - val_accuracy: 0.7339 - val_loss: 0.5354
# Epoch 131/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7428 - loss: 0.5226 - val_accuracy: 0.7333 - val_loss: 0.5354
# Epoch 132/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7431 - loss: 0.5225 - val_accuracy: 0.7338 - val_loss: 0.5353
# Epoch 133/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7431 - loss: 0.5224 - val_accuracy: 0.7336 - val_loss: 0.5353
# Epoch 134/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7429 - loss: 0.5224 - val_accuracy: 0.7333 - val_loss: 0.5353
# Epoch 135/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7429 - loss: 0.5223 - val_accuracy: 0.7332 - val_loss: 0.5353
# Epoch 136/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7427 - loss: 0.5222 - val_accuracy: 0.7339 - val_loss: 0.5353
# Epoch 137/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7427 - loss: 0.5222 - val_accuracy: 0.7336 - val_loss: 0.5353
# Epoch 138/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7426 - loss: 0.5221 - val_accuracy: 0.7339 - val_loss: 0.5354
# Epoch 139/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7429 - loss: 0.5220 - val_accuracy: 0.7339 - val_loss: 0.5354
# Epoch 140/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7430 - loss: 0.5220 - val_accuracy: 0.7339 - val_loss: 0.5354
# Epoch 141/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7429 - loss: 0.5219 - val_accuracy: 0.7342 - val_loss: 0.5354
# Epoch 142/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7430 - loss: 0.5219 - val_accuracy: 0.7338 - val_loss: 0.5354
# Epoch 143/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7429 - loss: 0.5218 - val_accuracy: 0.7338 - val_loss: 0.5354
# Epoch 144/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7431 - loss: 0.5218 - val_accuracy: 0.7336 - val_loss: 0.5353
# Epoch 145/1000
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7431 - loss: 0.5217 - val_accuracy: 0.7332 - val_loss: 0.5353
# Time taken: 18.2s

# %% [markdown]
# ## Plot performance and reports
# Here, we plot the history of the training and the peNNormance in a ROC curve

# %%
loss_accuracy_plotter(history, model, X_train_val, Y_train_val, X_test, Y_test)

fpr_nn, tpr_nn, thresholds_nn = evaluate(model, scaler, X, Y, X_train_val, Y_train_val, X_test, Y_test)
df_all['dense_NN'] = model.predict(scaler.transform(X)).round() # add prediction to array
# Out:
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 0s 454us/step
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 0s 324us/step
# AUC: 0.7766
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 0s 377us/step
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 0s 322us/step
# 1007/1007 ━━━━━━━━━━━━━━━━━━━━ 0s 319us/step
# Test acc score: 0.7331574045327538
# Train acc score: 0.7427817447997517
# Classification report for the test set
#               precision    recall  f1-score   support
#
#   background       0.69      0.50      0.58      2367
#       signal       0.75      0.87      0.80      4075
#
#     accuracy                           0.73      6442
#    macro avg       0.72      0.68      0.69      6442
# weighted avg       0.73      0.73      0.72      6442
#
# Classification report for the total set
#               precision    recall  f1-score   support
#
#   background       0.72      0.52      0.60     12210
#       signal       0.75      0.88      0.81     20000
#
#     accuracy                           0.74     32210
#    macro avg       0.73      0.70      0.71     32210
# weighted avg       0.74      0.74      0.73     32210
#
# Confusion matrix for total set
# [[ 6345  5865]
#  [ 2482 17518]]
# 1007/1007 ━━━━━━━━━━━━━━━━━━━━ 0s 330us/step

# %% [markdown]
# ## NN Hyperparameter optimization

# %%
def main():
        
    keras_pipeline = Pipeline([("scaler", StandardScaler()),
                               ("clf", keras.wrappers.scikit_learn.KerasClassifier(
                                   build_fn=make_model))
    ])
    
    param_grid = {'clf__network_layers': [(32, 32), (64, 64), (128, 128, 128)],
     'clf__batch_size': [64, 128, 256, 512],
     'clf__epochs': [5, 10, 15, 50, 100, 200],
     'clf__dropout_rate': [0.1, 0.01],
     'clf__optimizer': ['Nadam', 'Adam', 'SGD'],
     'clf__activation': ['selu', 'relu', 'tanh'],
     'clf__k_initializer': ['lecun_normal', 'normal'],
     'clf__verbose': [0]
    }
    
    rs_keras = RandomizedSearchCV(keras_pipeline,
                                  param_distributions=param_grid,
                                  cv=5, refit=True,
                                  verbose=0,
                                  n_iter=5,
                                  scoring="accuracy")
    
    history = rs_keras.fit(np.array(X_train_val),
                 np.array(Y_train_val))
    
    print('Best score obtained: {0}'.format(rs_keras.best_score_))
    print('Parameters:')
    for param, value in rs_keras.best_params_.items():
        print('\t{}: {}'.format(param, value))
    return  rs_keras  

def make_model(network_layers=[(32, 32)],
               dropout_rate=0,
               optimizer="Nadam",
               activation="selu",
               k_initializer='lecun_normal',
               n_input=NDIM,
               n_class=1):
    
    model = keras.models.Sequential()

    for index, layers in enumerate(network_layers):
        if not index:
            model.add(keras.layers.Dense(layers,
                                         input_dim=n_input,
                                         activation=activation,
                                         kernel_initializer=k_initializer))
        else:
            model.add(keras.layers.Dense(layers,
                                         kernel_initializer=k_initializer,
                                         activation=activation))
        if dropout_rate and index:
            model.add(keras.layers.AlphaDropout(dropout_rate))

    model.add(keras.layers.Dense(n_class,
                                 activation="sigmoid"))
    
    model.compile(loss='binary_crossentropy',
                  optimizer=optimizer,
                  metrics=['accuracy'])
    #print(model.summary())
    return model

do_opt = False
if (do_opt):
    if __name__ == '__main__':
        opt_model = main()

# %%
'''
Best score obtained: 0.7943613693928067
Parameters:
	clf__verbose: 0
	clf__optimizer: Nadam
	clf__network_layers: (128, 128, 128)
	clf__k_initializer: normal
	clf__epochs: 200
	clf__dropout_rate: 0.1
	clf__batch_size: 256
	clf__activation: selu
    
Best score obtained: 0.7577227185718864
Parameters:
	clf__verbose: 0
	clf__optimizer: Nadam
	clf__network_layers: (128, 128, 128)
	clf__k_initializer: normal
	clf__epochs: 200
	clf__dropout_rate: 0.1
	clf__batch_size: 256
	clf__activation: selu
'''
# Out:
# '\nBest score obtained: 0.7943613693928067\nParameters:\n\tclf__verbose: 0\n\tclf__optimizer: Nadam\n\tclf__network_layers: (128, 128, 128)\n\tclf__k_initializer: normal\n\tclf__epochs: 200\n\tclf__dropout_rate: 0.1\n\tclf__batch_size: 256\n\tclf__activation: selu\n    \nBest score obtained: 0.7577227185718864\nParameters:\n\tclf__verbose: 0\n\tclf__optimizer: Nadam\n\tclf__network_layers: (128, 128, 128)\n\tclf__k_initializer: normal\n\tclf__epochs: 200\n\tclf__dropout_rate: 0.1\n\tclf__batch_size: 256\n\tclf__activation: selu\n'

# %% [markdown]
# ## NN with dropout layer for overfit checking

# %%
# Packages for modeling
from keras import models
from keras import layers
from keras import regularizers

drop_model = models.Sequential()
drop_model.add(layers.Dense(128,  kernel_initializer='lecun_normal', activation='selu', input_shape=(NDIM,)))
drop_model.add(layers.Dropout(0.1))
drop_model.add(layers.Dense(128,  kernel_initializer='lecun_normal', activation='selu'))
drop_model.add(layers.Dropout(0.1))
drop_model.add(layers.Dense(128,  kernel_initializer='lecun_normal', activation='selu'))
drop_model.add(layers.Dropout(0.1))
drop_model.add(layers.Dense(1, kernel_initializer='lecun_normal', activation='sigmoid'))

# compile the model
drop_model.compile(optimizer='Adam', loss='binary_crossentropy', metrics=['accuracy'])
# print the model summary
drop_model.summary()

# early stopping callback
from keras.callbacks import EarlyStopping
early_stopping = EarlyStopping(monitor='val_loss', patience=10, mode='min')

# Train classifier
import time
start = time.time() # time at start of whole processing

drop_history = drop_model.fit(X_train_val,
                    Y_train_val,
                    epochs=500,
                    batch_size=256,
                    verbose=1, # switch to 1 for more verbosity 
                    callbacks=[early_stopping],
                    validation_data=(X_test,Y_test))

elapsed = time.time() - start # time after whole processing
print("Time taken: "+str(round(elapsed,1))+"s") # print total time taken to process every file
# Out:
# C:\Users\meisa\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_20 (Dense)                │ (None, 128)            │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_15 (Dropout)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_21 (Dense)                │ (None, 128)            │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_16 (Dropout)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_22 (Dense)                │ (None, 128)            │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_17 (Dropout)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_23 (Dense)                │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 34,945 (136.50 KB)
#  Trainable params: 34,945 (136.50 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6256 - loss: 0.6693 - val_accuracy: 0.7072 - val_loss: 0.5702
# Epoch 2/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6957 - loss: 0.5843 - val_accuracy: 0.7156 - val_loss: 0.5555
# Epoch 3/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7055 - loss: 0.5727 - val_accuracy: 0.7189 - val_loss: 0.5522
# Epoch 4/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7076 - loss: 0.5659 - val_accuracy: 0.7223 - val_loss: 0.5476
# Epoch 5/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7130 - loss: 0.5630 - val_accuracy: 0.7245 - val_loss: 0.5460
# Epoch 6/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7137 - loss: 0.5589 - val_accuracy: 0.7263 - val_loss: 0.5436
# Epoch 7/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7163 - loss: 0.5569 - val_accuracy: 0.7265 - val_loss: 0.5415
# Epoch 8/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7189 - loss: 0.5537 - val_accuracy: 0.7291 - val_loss: 0.5393
# Epoch 9/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7242 - loss: 0.5489 - val_accuracy: 0.7290 - val_loss: 0.5373
# Epoch 10/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7244 - loss: 0.5467 - val_accuracy: 0.7283 - val_loss: 0.5372
# Epoch 11/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7258 - loss: 0.5449 - val_accuracy: 0.7279 - val_loss: 0.5361
# Epoch 12/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7261 - loss: 0.5420 - val_accuracy: 0.7287 - val_loss: 0.5361
# Epoch 13/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7241 - loss: 0.5434 - val_accuracy: 0.7276 - val_loss: 0.5347
# Epoch 14/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7304 - loss: 0.5396 - val_accuracy: 0.7310 - val_loss: 0.5342
# Epoch 15/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7309 - loss: 0.5390 - val_accuracy: 0.7296 - val_loss: 0.5345
# Epoch 16/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7287 - loss: 0.5396 - val_accuracy: 0.7304 - val_loss: 0.5321
# Epoch 17/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7308 - loss: 0.5379 - val_accuracy: 0.7294 - val_loss: 0.5323
# Epoch 18/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7333 - loss: 0.5363 - val_accuracy: 0.7333 - val_loss: 0.5315
# Epoch 19/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7352 - loss: 0.5364 - val_accuracy: 0.7350 - val_loss: 0.5306
# Epoch 20/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7347 - loss: 0.5338 - val_accuracy: 0.7335 - val_loss: 0.5312
# Epoch 21/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7367 - loss: 0.5323 - val_accuracy: 0.7346 - val_loss: 0.5292
# Epoch 22/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7354 - loss: 0.5329 - val_accuracy: 0.7322 - val_loss: 0.5294
# Epoch 23/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7369 - loss: 0.5316 - val_accuracy: 0.7316 - val_loss: 0.5287
# Epoch 24/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7356 - loss: 0.5300 - val_accuracy: 0.7318 - val_loss: 0.5302
# Epoch 25/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7390 - loss: 0.5288 - val_accuracy: 0.7338 - val_loss: 0.5272
# Epoch 26/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7407 - loss: 0.5282 - val_accuracy: 0.7350 - val_loss: 0.5270
# Epoch 27/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7378 - loss: 0.5271 - val_accuracy: 0.7328 - val_loss: 0.5282
# Epoch 28/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7378 - loss: 0.5269 - val_accuracy: 0.7314 - val_loss: 0.5277
# Epoch 29/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7415 - loss: 0.5275 - val_accuracy: 0.7332 - val_loss: 0.5265
# Epoch 30/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7402 - loss: 0.5247 - val_accuracy: 0.7327 - val_loss: 0.5267
# Epoch 31/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7402 - loss: 0.5243 - val_accuracy: 0.7333 - val_loss: 0.5265
# Epoch 32/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7420 - loss: 0.5239 - val_accuracy: 0.7350 - val_loss: 0.5252
# Epoch 33/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7407 - loss: 0.5213 - val_accuracy: 0.7383 - val_loss: 0.5249
# Epoch 34/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7432 - loss: 0.5199 - val_accuracy: 0.7367 - val_loss: 0.5258
# Epoch 35/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7437 - loss: 0.5200 - val_accuracy: 0.7333 - val_loss: 0.5254
# Epoch 36/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7408 - loss: 0.5201 - val_accuracy: 0.7387 - val_loss: 0.5236
# Epoch 37/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7435 - loss: 0.5212 - val_accuracy: 0.7352 - val_loss: 0.5256
# Epoch 38/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7461 - loss: 0.5185 - val_accuracy: 0.7366 - val_loss: 0.5242
# Epoch 39/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7479 - loss: 0.5159 - val_accuracy: 0.7383 - val_loss: 0.5241
# Epoch 40/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7468 - loss: 0.5168 - val_accuracy: 0.7401 - val_loss: 0.5231
# Epoch 41/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7484 - loss: 0.5156 - val_accuracy: 0.7403 - val_loss: 0.5217
# Epoch 42/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7446 - loss: 0.5162 - val_accuracy: 0.7434 - val_loss: 0.5222
# Epoch 43/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7489 - loss: 0.5137 - val_accuracy: 0.7373 - val_loss: 0.5218
# Epoch 44/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7474 - loss: 0.5131 - val_accuracy: 0.7417 - val_loss: 0.5196
# Epoch 45/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7509 - loss: 0.5111 - val_accuracy: 0.7397 - val_loss: 0.5214
# Epoch 46/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7506 - loss: 0.5115 - val_accuracy: 0.7408 - val_loss: 0.5208
# Epoch 47/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7460 - loss: 0.5109 - val_accuracy: 0.7417 - val_loss: 0.5207
# Epoch 48/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7483 - loss: 0.5135 - val_accuracy: 0.7446 - val_loss: 0.5204
# Epoch 49/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7525 - loss: 0.5098 - val_accuracy: 0.7443 - val_loss: 0.5190
# Epoch 50/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7469 - loss: 0.5104 - val_accuracy: 0.7411 - val_loss: 0.5208
# Epoch 51/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7537 - loss: 0.5083 - val_accuracy: 0.7446 - val_loss: 0.5169
# Epoch 52/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7562 - loss: 0.5046 - val_accuracy: 0.7437 - val_loss: 0.5186
# Epoch 53/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7488 - loss: 0.5096 - val_accuracy: 0.7457 - val_loss: 0.5184
# Epoch 54/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7492 - loss: 0.5096 - val_accuracy: 0.7465 - val_loss: 0.5181
# Epoch 55/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7528 - loss: 0.5042 - val_accuracy: 0.7431 - val_loss: 0.5187
# Epoch 56/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7587 - loss: 0.5040 - val_accuracy: 0.7482 - val_loss: 0.5167
# Epoch 57/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7586 - loss: 0.5007 - val_accuracy: 0.7437 - val_loss: 0.5186
# Epoch 58/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7522 - loss: 0.5055 - val_accuracy: 0.7442 - val_loss: 0.5172
# Epoch 59/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7543 - loss: 0.5045 - val_accuracy: 0.7440 - val_loss: 0.5162
# Epoch 60/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7544 - loss: 0.5035 - val_accuracy: 0.7459 - val_loss: 0.5170
# Epoch 61/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7549 - loss: 0.5054 - val_accuracy: 0.7457 - val_loss: 0.5155
# Epoch 62/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7562 - loss: 0.5039 - val_accuracy: 0.7477 - val_loss: 0.5150
# Epoch 63/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7571 - loss: 0.5021 - val_accuracy: 0.7482 - val_loss: 0.5165
# Epoch 64/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7547 - loss: 0.5016 - val_accuracy: 0.7504 - val_loss: 0.5150
# Epoch 65/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7587 - loss: 0.4990 - val_accuracy: 0.7468 - val_loss: 0.5168
# Epoch 66/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7547 - loss: 0.5027 - val_accuracy: 0.7495 - val_loss: 0.5135
# Epoch 67/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7516 - loss: 0.5027 - val_accuracy: 0.7521 - val_loss: 0.5126
# Epoch 68/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7562 - loss: 0.4981 - val_accuracy: 0.7488 - val_loss: 0.5155
# Epoch 69/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7580 - loss: 0.4993 - val_accuracy: 0.7513 - val_loss: 0.5134
# Epoch 70/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7619 - loss: 0.4958 - val_accuracy: 0.7495 - val_loss: 0.5130
# Epoch 71/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7553 - loss: 0.4988 - val_accuracy: 0.7493 - val_loss: 0.5142
# Epoch 72/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7596 - loss: 0.4957 - val_accuracy: 0.7468 - val_loss: 0.5129
# Epoch 73/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7559 - loss: 0.4969 - val_accuracy: 0.7473 - val_loss: 0.5126
# Epoch 74/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7590 - loss: 0.4949 - val_accuracy: 0.7482 - val_loss: 0.5126
# Epoch 75/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7600 - loss: 0.4978 - val_accuracy: 0.7479 - val_loss: 0.5143
# Epoch 76/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7607 - loss: 0.4932 - val_accuracy: 0.7482 - val_loss: 0.5152
# Epoch 77/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7620 - loss: 0.4945 - val_accuracy: 0.7491 - val_loss: 0.5101
# Epoch 78/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7665 - loss: 0.4890 - val_accuracy: 0.7530 - val_loss: 0.5121
# Epoch 79/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7621 - loss: 0.4892 - val_accuracy: 0.7498 - val_loss: 0.5116
# Epoch 80/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7614 - loss: 0.4930 - val_accuracy: 0.7499 - val_loss: 0.5121
# Epoch 81/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7604 - loss: 0.4909 - val_accuracy: 0.7519 - val_loss: 0.5095
# Epoch 82/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7603 - loss: 0.4954 - val_accuracy: 0.7509 - val_loss: 0.5102
# Epoch 83/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7652 - loss: 0.4890 - val_accuracy: 0.7507 - val_loss: 0.5106
# Epoch 84/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7592 - loss: 0.4915 - val_accuracy: 0.7529 - val_loss: 0.5109
# Epoch 85/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7621 - loss: 0.4874 - val_accuracy: 0.7526 - val_loss: 0.5098
# Epoch 86/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7660 - loss: 0.4865 - val_accuracy: 0.7523 - val_loss: 0.5102
# Epoch 87/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7636 - loss: 0.4905 - val_accuracy: 0.7515 - val_loss: 0.5108
# Epoch 88/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7654 - loss: 0.4887 - val_accuracy: 0.7516 - val_loss: 0.5086
# Epoch 89/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7616 - loss: 0.4914 - val_accuracy: 0.7509 - val_loss: 0.5087
# Epoch 90/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7629 - loss: 0.4864 - val_accuracy: 0.7509 - val_loss: 0.5076
# Epoch 91/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7697 - loss: 0.4849 - val_accuracy: 0.7530 - val_loss: 0.5085
# Epoch 92/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7634 - loss: 0.4849 - val_accuracy: 0.7519 - val_loss: 0.5079
# Epoch 93/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7675 - loss: 0.4812 - val_accuracy: 0.7524 - val_loss: 0.5082
# Epoch 94/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7621 - loss: 0.4883 - val_accuracy: 0.7529 - val_loss: 0.5082
# Epoch 95/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7651 - loss: 0.4856 - val_accuracy: 0.7502 - val_loss: 0.5082
# Epoch 96/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7698 - loss: 0.4797 - val_accuracy: 0.7549 - val_loss: 0.5069
# Epoch 97/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7681 - loss: 0.4831 - val_accuracy: 0.7535 - val_loss: 0.5082
# Epoch 98/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7637 - loss: 0.4841 - val_accuracy: 0.7513 - val_loss: 0.5056
# Epoch 99/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7701 - loss: 0.4804 - val_accuracy: 0.7519 - val_loss: 0.5072
# Epoch 100/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7651 - loss: 0.4827 - val_accuracy: 0.7557 - val_loss: 0.5061
# Epoch 101/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7687 - loss: 0.4793 - val_accuracy: 0.7504 - val_loss: 0.5066
# Epoch 102/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7695 - loss: 0.4829 - val_accuracy: 0.7541 - val_loss: 0.5066
# Epoch 103/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7713 - loss: 0.4758 - val_accuracy: 0.7536 - val_loss: 0.5071
# Epoch 104/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7694 - loss: 0.4803 - val_accuracy: 0.7586 - val_loss: 0.5043
# Epoch 105/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7737 - loss: 0.4730 - val_accuracy: 0.7555 - val_loss: 0.5049
# Epoch 106/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7749 - loss: 0.4731 - val_accuracy: 0.7544 - val_loss: 0.5043
# Epoch 107/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7674 - loss: 0.4805 - val_accuracy: 0.7541 - val_loss: 0.5036
# Epoch 108/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7688 - loss: 0.4777 - val_accuracy: 0.7550 - val_loss: 0.5063
# Epoch 109/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7720 - loss: 0.4772 - val_accuracy: 0.7547 - val_loss: 0.5033
# Epoch 110/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7719 - loss: 0.4702 - val_accuracy: 0.7581 - val_loss: 0.5053
# Epoch 111/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7712 - loss: 0.4747 - val_accuracy: 0.7575 - val_loss: 0.5061
# Epoch 112/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7715 - loss: 0.4746 - val_accuracy: 0.7572 - val_loss: 0.5043
# Epoch 113/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7773 - loss: 0.4683 - val_accuracy: 0.7541 - val_loss: 0.5036
# Epoch 114/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7751 - loss: 0.4701 - val_accuracy: 0.7564 - val_loss: 0.5042
# Epoch 115/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7728 - loss: 0.4720 - val_accuracy: 0.7552 - val_loss: 0.5051
# Epoch 116/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7741 - loss: 0.4742 - val_accuracy: 0.7572 - val_loss: 0.5061
# Epoch 117/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7720 - loss: 0.4709 - val_accuracy: 0.7563 - val_loss: 0.5050
# Epoch 118/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7738 - loss: 0.4708 - val_accuracy: 0.7569 - val_loss: 0.5031
# Epoch 119/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7707 - loss: 0.4736 - val_accuracy: 0.7566 - val_loss: 0.5031
# Epoch 120/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7745 - loss: 0.4697 - val_accuracy: 0.7543 - val_loss: 0.5060
# Epoch 121/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7746 - loss: 0.4688 - val_accuracy: 0.7599 - val_loss: 0.5033
# Epoch 122/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7753 - loss: 0.4685 - val_accuracy: 0.7563 - val_loss: 0.5043
# Epoch 123/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7731 - loss: 0.4709 - val_accuracy: 0.7546 - val_loss: 0.5029
# Epoch 124/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7797 - loss: 0.4669 - val_accuracy: 0.7571 - val_loss: 0.5036
# Epoch 125/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7741 - loss: 0.4697 - val_accuracy: 0.7530 - val_loss: 0.5060
# Epoch 126/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7742 - loss: 0.4690 - val_accuracy: 0.7594 - val_loss: 0.4996
# Epoch 127/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7714 - loss: 0.4715 - val_accuracy: 0.7575 - val_loss: 0.5017
# Epoch 128/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7747 - loss: 0.4669 - val_accuracy: 0.7550 - val_loss: 0.5031
# Epoch 129/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7792 - loss: 0.4644 - val_accuracy: 0.7558 - val_loss: 0.5019
# Epoch 130/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7775 - loss: 0.4623 - val_accuracy: 0.7599 - val_loss: 0.5006
# Epoch 131/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7753 - loss: 0.4650 - val_accuracy: 0.7572 - val_loss: 0.5046
# Epoch 132/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7754 - loss: 0.4689 - val_accuracy: 0.7577 - val_loss: 0.5047
# Epoch 133/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7768 - loss: 0.4643 - val_accuracy: 0.7605 - val_loss: 0.5022
# Epoch 134/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7806 - loss: 0.4628 - val_accuracy: 0.7591 - val_loss: 0.5012
# Epoch 135/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7781 - loss: 0.4656 - val_accuracy: 0.7557 - val_loss: 0.5020
# Epoch 136/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7795 - loss: 0.4591 - val_accuracy: 0.7591 - val_loss: 0.4997
# Time taken: 29.5s

# %%
loss_accuracy_plotter(drop_history, drop_model, X_train_val, Y_train_val, X_test, Y_test)

fpr_nn_opt_drop, tpr_nn_opt_drop, thresholds_nn_opt_drop = evaluate(drop_model, scaler, X, Y, X_train_val, Y_train_val, X_test, Y_test)
df_all['dense_NN_opt_drop'] = drop_model.predict(scaler.transform(X)).round() # add prediction to array
# Out:
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 0s 515us/step
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 0s 370us/step
# AUC: 0.8140
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 0s 411us/step
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 0s 376us/step
# 1007/1007 ━━━━━━━━━━━━━━━━━━━━ 0s 365us/step
# Test acc score: 0.7590810307357964
# Train acc score: 0.8141881403290904
# Classification report for the test set
#               precision    recall  f1-score   support
#
#   background       0.72      0.57      0.63      2367
#       signal       0.78      0.87      0.82      4075
#
#     accuracy                           0.76      6442
#    macro avg       0.75      0.72      0.73      6442
# weighted avg       0.75      0.76      0.75      6442
#
# Classification report for the total set
#               precision    recall  f1-score   support
#
#   background       0.80      0.64      0.71     12210
#       signal       0.80      0.90      0.85     20000
#
#     accuracy                           0.80     32210
#    macro avg       0.80      0.77      0.78     32210
# weighted avg       0.80      0.80      0.80     32210
#
# Confusion matrix for total set
# [[ 7790  4420]
#  [ 1920 18080]]
# 1007/1007 ━━━━━━━━━━━━━━━━━━━━ 0s 371us/step

# %% [markdown]
# ## Optimal model with early stopping

# %%
inputs = Input(shape=(NDIM,), name = 'input') 
hidden1 = Dense(128, name = 'hidden1', kernel_initializer='lecun_normal', activation='selu')(inputs)
hidden2 = Dense(128, name = 'hidden2', kernel_initializer='lecun_normal', activation='selu')(hidden1)
hidden3 = Dense(128, name = 'hidden3', kernel_initializer='lecun_normal', activation='selu')(hidden2)
outputs = Dense(1, name = 'output', kernel_initializer='lecun_normal', activation='sigmoid')(hidden3)

# create the model
opt_model = Model(inputs=inputs, outputs=outputs)
# compile the model
opt_model.compile(optimizer='Adam', loss='binary_crossentropy', metrics=['accuracy'])
# print the model summary
opt_model.summary()

# early stopping callback
from keras.callbacks import EarlyStopping
early_stopping = EarlyStopping(monitor='val_loss', patience=10, mode='min')

# model checkpoint callback
# this saves our model architecture + parameters into dense_model.h5
from keras.callbacks import ModelCheckpoint
model_checkpoint = ModelCheckpoint('TopFC_opt_dense_model.h5', monitor='val_loss', 
                                   verbose=0, save_best_only=True,                                    
                                   save_weights_only=False, mode='auto', )
                                   #period=1)
# Out:
# Model: "functional_58"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input (InputLayer)              │ (None, 13)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ hidden1 (Dense)                 │ (None, 128)            │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ hidden2 (Dense)                 │ (None, 128)            │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ hidden3 (Dense)                 │ (None, 128)            │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output (Dense)                  │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 34,945 (136.50 KB)
#  Trainable params: 34,945 (136.50 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Train classifier
import time
start = time.time() # time at start of whole processing

opt_history = opt_model.fit(X_train_val, 
                    Y_train_val, 
                    epochs=500, 
                    batch_size=256, 
                    verbose=1, # switch to 1 for more verbosity 
                    callbacks=[early_stopping, model_checkpoint], 
                    validation_data=(X_test,Y_test))

elapsed = time.time() - start # time after whole processing
print("Time taken: "+str(round(elapsed,1))+"s") # print total time taken to process every file
# Out:
# Epoch 1/500
#  91/101 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6469 - loss: 0.6320
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6506 - loss: 0.6282 - val_accuracy: 0.7183 - val_loss: 0.5563
# Epoch 2/500
# 100/101 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7191 - loss: 0.5548
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7191 - loss: 0.5547 - val_accuracy: 0.7243 - val_loss: 0.5466
# Epoch 3/500
#  98/101 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7300 - loss: 0.5442
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7300 - loss: 0.5441 - val_accuracy: 0.7277 - val_loss: 0.5432
# Epoch 4/500
#  49/101 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7381 - loss: 0.5371
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7344 - loss: 0.5377 - val_accuracy: 0.7271 - val_loss: 0.5411
# Epoch 5/500
#  52/101 ━━━━━━━━━━━━━━━━━━━━ 0s 995us/step - accuracy: 0.7367 - loss: 0.5319
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7354 - loss: 0.5326 - val_accuracy: 0.7294 - val_loss: 0.5392
# Epoch 6/500
#  99/101 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7382 - loss: 0.5283
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7382 - loss: 0.5283 - val_accuracy: 0.7299 - val_loss: 0.5376
# Epoch 7/500
#  96/101 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7394 - loss: 0.5246
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7394 - loss: 0.5246 - val_accuracy: 0.7282 - val_loss: 0.5360
# Epoch 8/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7432 - loss: 0.5214
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7432 - loss: 0.5214 - val_accuracy: 0.7296 - val_loss: 0.5348
# Epoch 9/500
# 100/101 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7458 - loss: 0.5185
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7458 - loss: 0.5185 - val_accuracy: 0.7313 - val_loss: 0.5338
# Epoch 10/500
#  51/101 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7465 - loss: 0.5148
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7457 - loss: 0.5157 - val_accuracy: 0.7316 - val_loss: 0.5328
# Epoch 11/500
# 100/101 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7479 - loss: 0.5131
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7480 - loss: 0.5131 - val_accuracy: 0.7322 - val_loss: 0.5320
# Epoch 12/500
#  97/101 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7488 - loss: 0.5107
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7489 - loss: 0.5107 - val_accuracy: 0.7338 - val_loss: 0.5310
# Epoch 13/500
#  95/101 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7507 - loss: 0.5084
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7507 - loss: 0.5083 - val_accuracy: 0.7355 - val_loss: 0.5299
# Epoch 14/500
#  99/101 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7524 - loss: 0.5061
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7525 - loss: 0.5060 - val_accuracy: 0.7349 - val_loss: 0.5293
# Epoch 15/500
# 100/101 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7530 - loss: 0.5039
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7531 - loss: 0.5039 - val_accuracy: 0.7349 - val_loss: 0.5289
# Epoch 16/500
#  50/101 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7542 - loss: 0.5013
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7540 - loss: 0.5019 - val_accuracy: 0.7350 - val_loss: 0.5285
# Epoch 17/500
#  99/101 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7560 - loss: 0.4998
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7560 - loss: 0.4998 - val_accuracy: 0.7346 - val_loss: 0.5281
# Epoch 18/500
#  99/101 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7579 - loss: 0.4978
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7580 - loss: 0.4978 - val_accuracy: 0.7352 - val_loss: 0.5279
# Epoch 19/500
#  99/101 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7593 - loss: 0.4958
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7594 - loss: 0.4958 - val_accuracy: 0.7349 - val_loss: 0.5278
# Epoch 20/500
#  99/101 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7601 - loss: 0.4940
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7602 - loss: 0.4940 - val_accuracy: 0.7347 - val_loss: 0.5278
# Epoch 21/500
#  51/101 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7600 - loss: 0.4920
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7607 - loss: 0.4921 - val_accuracy: 0.7346 - val_loss: 0.5275
# Epoch 22/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7625 - loss: 0.4902
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7625 - loss: 0.4902 - val_accuracy: 0.7350 - val_loss: 0.5272
# Epoch 23/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7634 - loss: 0.4883 - val_accuracy: 0.7356 - val_loss: 0.5273
# Epoch 24/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7648 - loss: 0.4865 - val_accuracy: 0.7349 - val_loss: 0.5274
# Epoch 25/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7656 - loss: 0.4848 - val_accuracy: 0.7336 - val_loss: 0.5272
# Epoch 26/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7669 - loss: 0.4830
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7670 - loss: 0.4830 - val_accuracy: 0.7360 - val_loss: 0.5269
# Epoch 27/500
#  98/101 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7668 - loss: 0.4811
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7669 - loss: 0.4810 - val_accuracy: 0.7366 - val_loss: 0.5269
# Epoch 28/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7677 - loss: 0.4793 - val_accuracy: 0.7364 - val_loss: 0.5273
# Epoch 29/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7688 - loss: 0.4774 - val_accuracy: 0.7373 - val_loss: 0.5274
# Epoch 30/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7710 - loss: 0.4755 - val_accuracy: 0.7366 - val_loss: 0.5273
# Epoch 31/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7716 - loss: 0.4737 - val_accuracy: 0.7372 - val_loss: 0.5273
# Epoch 32/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7725 - loss: 0.4718 - val_accuracy: 0.7369 - val_loss: 0.5275
# Epoch 33/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7738 - loss: 0.4699 - val_accuracy: 0.7367 - val_loss: 0.5279
# Epoch 34/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7749 - loss: 0.4681 - val_accuracy: 0.7377 - val_loss: 0.5284
# Epoch 35/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7764 - loss: 0.4662 - val_accuracy: 0.7372 - val_loss: 0.5289
# Epoch 36/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7774 - loss: 0.4644 - val_accuracy: 0.7370 - val_loss: 0.5293
# Epoch 37/500
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7783 - loss: 0.4624 - val_accuracy: 0.7366 - val_loss: 0.5296
# Time taken: 7.8s

# %%
loss_accuracy_plotter(opt_history, opt_model, X_train_val, Y_train_val, X_test, Y_test)

fpr_nn_opt, tpr_nn_opt, thresholds_nn_opt = evaluate(opt_model, scaler, X, Y, X_train_val, Y_train_val, X_test, Y_test)
df_all['dense_NN_opt'] = opt_model.predict(scaler.transform(X)).round() # add prediction to array
# Out:
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 0s 510us/step
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 0s 378us/step
# AUC: 0.7932
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 0s 418us/step
# 806/806 ━━━━━━━━━━━━━━━━━━━━ 0s 377us/step
# 1007/1007 ━━━━━━━━━━━━━━━━━━━━ 0s 375us/step
# Test acc score: 0.7365724930145917
# Train acc score: 0.7847718099968953
# Classification report for the test set
#               precision    recall  f1-score   support
#
#   background       0.66      0.59      0.62      2367
#       signal       0.77      0.82      0.80      4075
#
#     accuracy                           0.74      6442
#    macro avg       0.72      0.71      0.71      6442
# weighted avg       0.73      0.74      0.73      6442
#
# Classification report for the total set
#               precision    recall  f1-score   support
#
#   background       0.73      0.64      0.68     12210
#       signal       0.80      0.86      0.83     20000
#
#     accuracy                           0.78     32210
#    macro avg       0.76      0.75      0.75     32210
# weighted avg       0.77      0.78      0.77     32210
#
# Confusion matrix for total set
# [[ 7856  4354]
#  [ 2889 17111]]
# 1007/1007 ━━━━━━━━━━━━━━━━━━━━ 0s 372us/step

# %%
# plot ROC curve
plt.figure(figsize=(10, 6), dpi=300)  # Increase figure size and set DPI
plt.plot(fpr_nn, tpr_nn, label='Neural Network') # plot neural network ROC
plt.plot(fpr_nn_opt, tpr_nn_opt, linestyle='dashed', label='Neural Network optimized') # plot neural network optimized ROC
plt.plot(fpr_nn_opt_drop, tpr_nn_opt_drop, linestyle='dashed', label='Neural Network optimized (dropout)') # plot neural network optimized and dropout ROC
plt.plot([0, 1], [0, 1], linestyle='dotted', color='grey', label='Random classifier') # plot diagonal line to indicate luck
plt.xlabel('False Positive Rate') # x-axis label
plt.ylabel('True Positive Rate') # y-axis label
plt.grid() # add a grid to the plot
plt.legend() # add a legend

# %%
text_x = [x for x in range(10)]
def text_y(x): return np.sin(x)
plt.plot(text_x, text_y)

# %%
print(tpr_nn.shape)
print(tpr_nn.shape)
print(Y_test.shape)

s_total = np.sum(Y_test == 1)
b_total = np.sum(Y_test == 0)
# Out:
# (2288,)
# (2288,)
# (6442,)

# %%
plt.figure(figsize=(10, 6), dpi=300)  # Increase figure size and set DPI

ams_nn = AMS(tpr_nn, fpr_nn, 0.001) # get AMS for NN classifier
ams_nn_opt = AMS(tpr_nn_opt, fpr_nn_opt, 0.001) # get AMS for NN-opt classifier
ams_nn_opt_drop = AMS(tpr_nn_opt_drop, fpr_nn_opt_drop, 0.001) # get AMS for NN-opt classifier


plt.plot(thresholds_nn, ams_nn, label="Neural Netwrok")  # plot NN AMS
plt.plot(thresholds_nn_opt, ams_nn_opt, linestyle='dashed', label="Neural Netwrok optimized")  # plot NN-opt AMS
plt.plot(thresholds_nn_opt_drop, ams_nn_opt_drop, linestyle='dashed', label="Neural Netwrok optimized (dropout)")  # plot NN-opt AMS
plt.xlabel("Threshold")  # x-axis label
plt.ylabel("AMS")  # y-axis label
plt.title("AMS with $b_r=0.001$")  # add plot title
plt.grid() # add a grid to the plot
plt.legend()  # add legend

# %%
plt.figure(figsize=(10, 6), dpi=300)  # Increase figure size and set DPI

sig_nn = significance(tpr_nn, fpr_nn, s_total, b_total, 0.001) # get AMS for NN classifier
sig_nn_opt = significance(tpr_nn_opt, fpr_nn_opt, s_total, b_total, 0.001) # get AMS for NN-opt classifier
sig_nn_opt_drop = significance(tpr_nn_opt_drop, fpr_nn_opt_drop, s_total, b_total, 0.001) # get AMS for NN-opt classifier

plt.plot(thresholds_nn, sig_nn, label="Neural Netwrok")  # plot NN AMS
plt.plot(thresholds_nn_opt, sig_nn_opt, linestyle='dashed', label="Neural Netwrok optimized")  # plot NN-opt AMS
plt.plot(thresholds_nn_opt_drop, sig_nn_opt_drop, linestyle='dashed', label="Neural Netwrok optimized (dropout)")  # plot NN-opt AMS
plt.xlabel("Threshold")  # x-axis label
plt.ylabel("Significance")  # y-axis label
plt.title("Significance with $b_r=0.001$")  # add plot title
plt.grid() # add a grid to the plot
plt.legend()  # add legend

# %%
ams_nn = AMS(tpr_nn, fpr_nn, 1) # get AMS for NN classifier
ams_nn_opt = AMS(tpr_nn_opt, fpr_nn_opt, 1) # get AMS for NN-opt classifier
ams_nn_opt_drop = AMS(tpr_nn_opt_drop, fpr_nn_opt_drop, 1) # get AMS for NN-opt classifier


plt.plot(thresholds_nn, ams_nn, label="Neural Netwrok")  # plot NN AMS
plt.plot(thresholds_nn_opt, ams_nn_opt, linestyle='dashed', label="Neural Netwrok optimized")  # plot NN-opt AMS
plt.plot(thresholds_nn_opt_drop, ams_nn_opt_drop, linestyle='dashed', label="Neural Netwrok optimized (dropout)")  # plot NN-opt AMS
plt.xlabel("Threshold")  # x-axis label
plt.ylabel("AMS")  # y-axis label
plt.title("AMS with $b_r=1$")  # add plot title
plt.legend()  # add legend

# %% [markdown]
# ## Overfit checking

# %%
new_compare_train_test(model, X_train_val, Y_train_val, X_test, Y_test, 'Neural Netwrok output')
# Out:
# 308/308 [==============================] - 0s 877us/step
# 499/499 [==============================] - 0s 743us/step
# 75/75 [==============================] - 0s 844us/step
# 127/127 [==============================] - 0s 748us/step
# Signal: ks = [0.01133869] (p-value = [0.79539234], are equal = [ True])
# Background: ks = [0.01712806] (p-value = [0.62029313], are equal = [ True])

# %%
new_compare_train_test(opt_model, X_train_val, Y_train_val, X_test, Y_test, 'Neural Netwrok optimized output')
# Out:
# 308/308 [==============================] - 0s 1ms/step
# 499/499 [==============================] - 0s 920us/step
# 75/75 [==============================] - 0s 973us/step
# 127/127 [==============================] - 0s 841us/step
# Signal: ks = [0.03445564] (p-value = [0.00090059], are equal = [False])
# Background: ks = [0.0471134] (p-value = [0.00038564], are equal = [False])

# %%
new_compare_train_test(drop_model, X_train_val, Y_train_val, X_test, Y_test, 'Neural Netwrok optimized dropoutoutput')
# Out:
# 308/308 [==============================] - 0s 959us/step
# 499/499 [==============================] - 0s 894us/step
# 75/75 [==============================] - 0s 905us/step
# 127/127 [==============================] - 0s 909us/step
# Signal: ks = [0.05072726] (p-value = [1.12755576e-07], are equal = [False])
# Background: ks = [0.06052836] (p-value = [1.48766608e-06], are equal = [False])

# %% [markdown]
# ## Save all models

# %%
# simple NN
#model.save('models/tt_charm_NN/')
model.save('models/tt_charm_NN.h5')
#new_model = keras.models.load_model('models/tt_charm_NN/')

# NN optimized 
#opt_model.save('models/tt_charm_NN_opt/')
opt_model.save('models/tt_charm_NN_opt.h5')
#new_model = keras.models.load_model('models/tt_charm_NN_opt/')

# NN optimized with drop
#drop_model.save('models/tt_charm_NN_drop/')
drop_model.save('models/tt_charm_NN_drop.h5')
#new_model = keras.models.load_model('models/tt_charm_NN_drop/')

# %%
read_model = False
if read_model:
    model = keras.models.load_model('models/tt_charm_NN/')
    opt_model = keras.models.load_model('models/tt_charm_NN_opt/')
    drop_model = keras.models.load_model('models/tt_charm_NN_drop/')

# %% [markdown]
# ## Extend to the whole dataset

# %%
filename = {
    'ttbar':'/Users/mghasemi/Desktop/IPM/plotter/newtrees/ttbar.root',
    'WZ':'/Users/mghasemi/Desktop/IPM/plotter/newtrees/WZ.root',
    'ZZ':'/Users/mghasemi/Desktop/IPM/plotter/newtrees/ZZ.root',
    'signal_charm':'/Users/mghasemi/Desktop/IPM/plotter/newtrees/signal_charm.root'
    }

VARS = ['jetNo','jetPTLeading', 'jetETA', 'jetPHI','bjetPT', 'bjetETA',
        'elecPTLeading', 'elecETA', 'elecPHI',
        'dielecCOS', 'dielecETA', 'met','testnonTopMass', 'weight'] 

upfile = {}
params = {}
df = {}
NDIM = len(VARS)

# define trees and branches to make DataFrame
for treename in filename.keys():
    upfile[treename] = uproot.open(filename[treename])
    params[treename] = upfile[treename][treename].arrays(VARS)
    df[treename] = ak.to_dataframe(params[treename])
    # add isSignal variable
    if treename.startswith("signal"): 
        df[treename]['isSignal'] = np.ones(len(df[treename])) 
    else:
        df[treename]['isSignal'] = np.zeros(len(df[treename])) 
    tmp_dataset = df[treename].values
    X_tmp = tmp_dataset[:,0:NDIM-1]
    Y_tmp = tmp_dataset[:,NDIM]
    df[treename]['dense_NN'] = model.predict(scaler.transform(X_tmp)) # add prediction to array   
    df[treename]['dense_NN_opt'] = opt_model.predict(scaler.transform(X_tmp)) # add prediction to array
    df[treename]['dense_NN_opt_drop'] = drop_model.predict(scaler.transform(X_tmp)) # add prediction to array
    df[treename].to_csv("~/Desktop/IPM/Analysis/Dataframes/tt_charm/"+treename+"_df.csv")
    

df_all = pd.concat([df[treename] for treename in filename.keys()])
dataset = df_all.values
X = dataset[:,0:NDIM-1]
Y = dataset[:,NDIM]
# Out:
# 37/37 [==============================] - 0s 830us/step
# 37/37 [==============================] - 0s 867us/step
# 37/37 [==============================] - 0s 779us/step
# 340/340 [==============================] - 0s 748us/step
# 340/340 [==============================] - 0s 771us/step
# 340/340 [==============================] - 0s 744us/step
# 6/6 [==============================] - 0s 959us/step
# 6/6 [==============================] - 0s 1ms/step
# 6/6 [==============================] - 0s 910us/step
# 2958/2958 [==============================] - 2s 722us/step
# 2958/2958 [==============================] - 3s 978us/step
# 2958/2958 [==============================] - 3s 930us/step

# %%
y_pred_NN_opt = opt_model.predict(X_test).round() # make predictions on the test data
y_pred_NN_train_opt = opt_model.predict(X_train_val).round()
y_pred_NN_tot_opt = opt_model.predict(scaler.transform(X)).round()

# See how well the classifier does, Acc = correct data / tot data
print("Total accuracy", accuracy_score(Y, y_pred_NN_tot_opt))

print("Classification report for the total set")
print(classification_report(Y.round(), y_pred_NN_tot_opt.round(), target_names=['background', 'signal']))

print("Confusion matrix:\n", confusion_matrix(Y.round(), y_pred_NN_tot_opt.round()))

fpr_nn_opt_tot, tpr_nn_opt_tot, thresholds_nn_opt_tot = roc_curve(Y, y_pred_NN_tot_opt.round()) # get FPRs, TPRs and thresholds for neural network

#df_all['dense_NN_opt'] = opt_model.predict(scaler.transform(X)).round() # add prediction to array
df_all['dense_NN_opt'] = opt_model.predict(scaler.transform(X)) # add prediction to array
df_all['dense_NN'] = model.predict(scaler.transform(X)) # add prediction to array
# Out:
# 202/202 [==============================] - 0s 965us/step
# 806/806 [==============================] - 1s 862us/step
# 3340/3340 [==============================] - 3s 878us/step
# Total accuracy 0.7832629874687655
# Classification report for the total set
#               precision    recall  f1-score   support
#
#   background       0.27      0.52      0.36     12210
#       signal       0.93      0.82      0.87     94643
#
#     accuracy                           0.78    106853
#    macro avg       0.60      0.67      0.61    106853
# weighted avg       0.85      0.78      0.81    106853
#
# Confusion matrix:
#  [[ 6401  5809]
#  [17350 77293]]
# 3340/3340 [==============================] - 3s 768us/step
# 3340/3340 [==============================] - 3s 745us/step

# %%
y_pred_NN_opt_fit = drop_model.predict(X_test).round() # make predictions on the test data
y_pred_NN_train_opt_fit = drop_model.predict(X_train_val).round()
y_pred_NN_tot_opt_fit = drop_model.predict(scaler.transform(X)).round()

# See how well the classifier does, Acc = correct data / tot data
print("Total accuracy", accuracy_score(Y, y_pred_NN_tot_opt_fit))

print("Classification report for the total set")
print(classification_report(Y.round(), y_pred_NN_tot_opt_fit.round(), target_names=['background', 'signal']))

print("Confusion matrix:\n", confusion_matrix(Y.round(), y_pred_NN_tot_opt_fit.round()))

fpr_nn_opt_tot_fit, tpr_nn_opt_tot_fit, thresholds_nn_opt_tot_fit = roc_curve(Y, y_pred_NN_tot_opt_fit.round()) # get FPRs, TPRs and thresholds for neural network

df_all['dense_NN_opt_drop'] = drop_model.predict(scaler.transform(X)) # add prediction to array
# Out:
# 202/202 [==============================] - 0s 816us/step
# 806/806 [==============================] - 1s 902us/step
# 3340/3340 [==============================] - 3s 883us/step
# Total accuracy 0.824815400597082
# Classification report for the total set
#               precision    recall  f1-score   support
#
#   background       0.32      0.47      0.38     12210
#       signal       0.93      0.87      0.90     94643
#
#     accuracy                           0.82    106853
#    macro avg       0.62      0.67      0.64    106853
# weighted avg       0.86      0.82      0.84    106853
#
# Confusion matrix:
#  [[ 5764  6446]
#  [12273 82370]]
# 3340/3340 [==============================] - 3s 779us/step

# %%
# add TF NN probability
y_TOT_prob_NN_opt = opt_model.predict(scaler.transform(X))
y_TOT_NN_opt = opt_model.predict(scaler.transform(X)).round()

cumulative_events = 0 # start counter for total number of events for which output is saved
for key in filename.keys(): # loop over samples
    df[key]['NN_opt_tot_output_prob'] = y_TOT_prob_NN_opt[cumulative_events:cumulative_events+len(df[key])]
    df[key]['NN_opt_tot_output'] = y_TOT_NN_opt[cumulative_events:cumulative_events+len(df[key])]
    cumulative_events += len(df[key]) # increment counter for total number of events
    #print(df[key]['NN_output']) # print the dataframe column NN_output

# probability and significance plots
NN_opt_tot_output_prob = { # dictionary containing plotting parameters for the mllll histogram
    # change plotting parameters
    'bin_width':0.1, # width of each histogram bin
    'num_bins':8, # number of histogram bins
    'xrange_min':0, # minimum on x-axis
    'xlabel':'Neural Network optimized output', # x-axis label
}

SoverB_hist_dict = {'NN_opt_tot_output_prob':NN_opt_tot_output_prob}
plot_SoverB(df, SoverB_hist_dict)
# Out:
#    1/3340 [..............................] - ETA: 2:12
# 3340/3340 [==============================] - 3s 819us/step
# 3340/3340 [==============================] - 2s 732us/step

# %%
# add TF NN probability
y_TOT_prob_NN_opt_fit = drop_model.predict(scaler.transform(X))
y_TOT_NN_opt_fit = drop_model.predict(scaler.transform(X)).round()

cumulative_events = 0 # start counter for total number of events for which output is saved
for key in filename.keys(): # loop over samples
    df[key]['NN_opt_tot_output_prob_overfit'] = y_TOT_prob_NN_opt_fit[cumulative_events:cumulative_events+len(df[key])]
    df[key]['NN_opt_tot_output_overfit'] = y_TOT_NN_opt_fit[cumulative_events:cumulative_events+len(df[key])]
    cumulative_events += len(df[key]) # increment counter for total number of events
    #print(df[key]['NN_output']) # print the dataframe column NN_output

# probability and significance plots
NN_opt_tot_output_prob_fit = { # dictionary containing plotting parameters for the mllll histogram
    # change plotting parameters
    'bin_width':0.1, # width of each histogram bin
    'num_bins':8, # number of histogram bins
    'xrange_min':0, # minimum on x-axis
    'xlabel':'Neural Network optimized output', # x-axis label
}

SoverB_hist_dict = {'NN_opt_tot_output_prob_overfit':NN_opt_tot_output_prob_fit}
plot_SoverB(df, SoverB_hist_dict)
# Out:
# 3340/3340 [==============================] - 3s 745us/step
# 3340/3340 [==============================] - 2s 737us/step

# %%
# plot ROC curve
plt.plot(fpr_nn_opt_tot, tpr_nn_opt_tot, label='Neural Network total') # plot Neural net-opt ROC
plt.plot(fpr_nn_opt_tot_fit, tpr_nn_opt_tot_fit, label='Neural Network overfit total') # plot Neural net-opt w overfit ROC
plt.plot([0, 1], [0, 1], linestyle='dotted', color='grey', label='Luck') # plot diagonal line to indicate luck
plt.xlabel('False Positive Rate') # x-axis label
plt.ylabel('True Positive Rate') # y-axis label
plt.grid() # add a grid to the plot
plt.legend() # add a legend

# %%
#ams_rf = AMS(tpr_rf, fpr_rf, 0.001) # get AMS for random forest classifier
ams_rf_opt_tot = AMS(tpr_nn_opt_tot, fpr_nn_opt_tot, 0.001) # get AMS for random forest classifier
ams_rf_opt_tot_fit = AMS(tpr_nn_opt_tot_fit, fpr_nn_opt_tot_fit, 0.001) # get AMS for random forest classifier

plt.plot(thresholds_nn_opt_tot, ams_rf_opt_tot, label="Neural Netwrok")  # plot Random forest AMS
plt.plot(thresholds_nn_opt_tot_fit, ams_rf_opt_tot_fit, label="Neural Netwrok overfit")  # plot Random forest AMS
plt.xlabel("Threshold")  # x-axis label
plt.ylabel("AMS")  # y-axis label
plt.title("AMS with $b_r=0.001$")  # add plot title
plt.legend()  # add legend

# %% [markdown]
# ## Baysian Optimization for NN model

# %%
# Import packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from keras.models import Sequential
from keras.layers import Dense, BatchNormalization, Dropout
from keras.optimizers import Adam, SGD, RMSprop, Adadelta, Adagrad, Adamax, Nadam, Ftrl
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.wrappers.scikit_learn import KerasClassifier
from math import floor
from sklearn.metrics import make_scorer, accuracy_score
#from bayes_opt import BayesianOptimization
from kerastuner.tuners import BayesianOptimization
from sklearn.model_selection import StratifiedKFold
from keras.layers import LeakyReLU
from sklearn.model_selection import RandomizedSearchCV

LeakyReLU = LeakyReLU(alpha=0.1)
import warnings
warnings.filterwarnings('ignore')
pd.set_option("display.max_columns", None)

# Load dataset
trainSet = pd.read_csv('/Users/mghasemi/Desktop/Code-factory/Python/ML/Kaggle/competitions/Titanic/input/train.csv')
# Feature generation: training data
train = trainSet.drop(columns=['Name', 'Ticket', 'Cabin'])
train = train.dropna(axis=0)
train = pd.get_dummies(train)
# train validation split
X_train, X_val, y_train, y_val = train_test_split(train.drop(columns=['PassengerId','Survived'], axis=0),
                                                  train['Survived'],
                                                  test_size=0.2, random_state=111,
                                                  stratify=train['Survived'])                                                  

# Create function
def nn_cl_bo(neurons, activation, optimizer, learning_rate,  batch_size, epochs ):
    optimizerL = ['SGD', 'Adam', 'RMSprop', 'Adadelta', 'Adagrad', 'Adamax', 'Nadam', 'Ftrl','SGD']
    optimizerD= {'Adam':Adam(lr=learning_rate), 'SGD':SGD(lr=learning_rate),
                 'RMSprop':RMSprop(lr=learning_rate), 'Adadelta':Adadelta(lr=learning_rate),
                 'Adagrad':Adagrad(lr=learning_rate), 'Adamax':Adamax(lr=learning_rate),
                 'Nadam':Nadam(lr=learning_rate), 'Ftrl':Ftrl(lr=learning_rate)}
    activationL = ['relu', 'sigmoid', 'softplus', 'softsign', 'tanh', 'selu',
                   'elu', 'exponential', LeakyReLU,'relu']
    neurons = round(neurons)
    activation = activationL[round(activation)]
    batch_size = round(batch_size)
    epochs = round(epochs)
    def nn_cl_fun():
        opt = Adam(lr = learning_rate)
        nn = Sequential()
        nn.add(Dense(neurons, input_dim=10, activation=activation))
        nn.add(Dense(neurons, activation=activation))
        nn.add(Dense(1, activation='sigmoid'))
        nn.compile(loss='binary_crossentropy', optimizer=opt, metrics=['accuracy'])
        return nn
    es = EarlyStopping(monitor='accuracy', mode='max', verbose=0, patience=20)
    nn = KerasClassifier(build_fn=nn_cl_fun, epochs=epochs, batch_size=batch_size,
                         verbose=0)
    kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=123)
    score = cross_val_score(nn, X_train, y_train, scoring=score_acc, cv=kfold, fit_params={'callbacks':[es]}).mean()
    return score


# Set paramaters
params_nn ={
    'neurons': (10, 100),
    'activation':(0, 9),
    'optimizer':(0,7),
    'learning_rate':(0.01, 1),
    'batch_size':(200, 1000),
    'epochs':(20, 100)
}
# Run Bayesian Optimization
nn_bo = BayesianOptimization(nn_cl_bo, params_nn, random_state=111)
nn_bo.maximize(init_points=25, n_iter=4)

# %% [markdown]
# ## Add prediction to `ROOT` trees and Excel
# Here we'll add the precitions we've computed to `ROOT` trees and Excel format.

# %%
df_all.to_csv("~/Desktop/IPM/Analysis/Dataframes/tt_charm/df_all.csv")

# %%
with uproot.recreate("./signalC_NN_weights.root") as sig_file:    
    #sig_file['signalC_NN_weights'] = df_all
    sig_file['signalC_NN_weights'] = {"signalC_NN_weights": ak.zip({"dense_NN": df_all['dense_NN'], "dense_NN_opt": df_all['dense_NN_opt'], "dense_NN_opt_drop": df_all['dense_NN_opt_drop'], 'jetNo':df_all['jetNo'], 'jetETA':df_all['jetETA']})}    
with uproot.open("./signalC_NN_weights.root") as sig_file:
    tree = sig_file['signalC_NN_weights']
    print(tree.keys())
    print("arrays:", tree.arrays())
    print("arrays[10]",tree.arrays()[0].tolist())
    print(tree.arrays()[20])
    #sig_file['signalC_NN_weights'].show()
#df_all[df_all['entry']==10].head()
# Out:
# ['signalC_NN_weights_dense_NN', 'signalC_NN_weights_dense_NN_opt', 'signalC_NN_weights_dense_NN_opt_drop', 'signalC_NN_weights_jetNo', 'signalC_NN_weights_jetETA']
# arrays: [{signalC_NN_weights_dense_NN: 0, ...}, {...}, {...}, ..., {...}, {...}, {...}]
# arrays[10] {'signalC_NN_weights_dense_NN': 0.0, 'signalC_NN_weights_dense_NN_opt': 0.0, 'signalC_NN_weights_dense_NN_opt_drop': 0.0, 'signalC_NN_weights_jetNo': 2, 'signalC_NN_weights_jetETA': -1.844299554824829}
# {signalC_NN_weights_dense_NN: 1, signalC_NN_weights_dense_NN_opt: 1, ...}

# %%
from root_numpy import root2array, array2root


def get_features_from_file(filename='', treename='', branches=[]):
    t = root2array(filename, treename=treename, branches=branches) # structured numpy array 
    #print t.shape 
    t = t.view(np.float32).reshape(t.shape + (-1,)) # normal numpy array (trick from https://stackoverflow.com/questions/5957380/convert-structured-array-to-regular-numpy-array)
    #print t.shape
    return t

def write_prediction_to_file(features, model, filename='',treename='',branch=''):
    y_predict_all = model.predict(features) # normal numpy array
    #print y_predict_all.shape
    y_predict_all = np.array(y_predict_all, dtype=[(branch, np.float32)]) # structured numpy array
    #print y_predict_all.shape
    array2root(y_predict_all, filename, treename=treename, mode='recreate')
    
X_all = get_features_from_file('data/ntuple_4mu_VV.root', 
                               treename='HZZ4LeptonsAnalysisReduced', 
                               branches=VARS)

X_all = scaler.transform(X_all)

write_prediction_to_file(X_all, 
                         model, 
                         filename='data/ntuple_4mu_VV_predict.root', 
                         treename='HZZ4LeptonsAnalysisReduced', 
                         branch='dense')

X_all = get_features_from_file('data/ntuple_4mu_bkg.root', 
                               treename='HZZ4LeptonsAnalysisReduced', 
                               branches=VARS)

X_all = scaler.transform(X_all)

write_prediction_to_file(X_all, 
                         model, 
                         filename='data/ntuple_4mu_bkg_predict.root', 
                         treename='HZZ4LeptonsAnalysisReduced', 
                         branch='dense')

# %% [markdown]
# ## Significance

# %%
df_all.head()
# Out:
#                 jetNo  jetPTLeading    jetETA    jetPHI      bjetPT   bjetETA  \
# entry subentry
# 0     0             2    181.824814 -1.844300 -1.531607  163.677521 -0.187704
#       1             2    181.824814 -0.187704  1.283405  163.677521 -0.187704
# 1     0             3     67.292442  2.523575 -0.349919   32.879086  2.148290
#       1             3     67.292442 -0.431749  0.605245   32.879086  2.148290
#       2             3     67.292442  2.148290 -1.598545   32.879086  2.148290
#
#                 elecPTLeading   elecETA   elecPHI  dielecCOS  dielecETA  \
# entry subentry
# 0     0             88.220581 -1.844300 -1.531607  -0.952927   1.256450
#       1             88.220581 -0.187704  1.283405  -0.952927   1.256450
# 1     0             87.680885  2.523575 -0.349919   0.520453  -1.629848
#       1             87.680885 -0.431749  0.605245   0.520453  -1.629848
#       2             87.680885  2.148290 -1.598545   0.520453  -1.629848
#
#                       met  testnonTopMass  weight  isSignal  dense_NN  \
# entry subentry
# 0     0         63.312572      475.149068    0.74       0.0  0.258469
#       1         63.312572      475.149068    0.74       0.0  0.478137
# 1     0         32.989780      206.483257    0.74       0.0  0.519942
#       1         32.989780      206.483257    0.74       0.0  0.395846
#       2         32.989780      206.483257    0.74       0.0  0.506826
#
#                 dense_NN_opt  dense_NN_opt_drop
# entry subentry
# 0     0             0.116831           0.329033
#       1             0.411286           0.337658
# 1     0             0.602508           0.415218
#       1             0.252807           0.269995
#       2             0.547332           0.391985

# %%
df_all[df_all['isSignal']==0]['weight'].unique()
# Out:
# array([0.74, 0.03, 0.67])

# %% [markdown]
# ### Cut-and-count analysis

# %%
sig_weight = df_all[df_all['isSignal']==1]['weight'].unique()[0]
df_sig_75 = df_all[(df_all['testnonTopMass']>=150) & (df_all['testnonTopMass']<=200) & (df_all['isSignal']==1)]
n_sig_75 = df_sig_75.shape[0] * sig_weight

bkg_weights = df_all[df_all['isSignal']==0]['weight'].unique()
list_bkg_75 = [df_all[(df_all['testnonTopMass']>=150) & (df_all['testnonTopMass']<=200) & (df_all['isSignal']==0) & (df_all['weight'] == bkg_w)].shape[0] * bkg_w for bkg_w in bkg_weights]

print("75% : sig_n {:.1f}\tbkg_n {:.1f}\tsig/bkg {:.1f}".format(n_sig_75, sum(list_bkg_75), n_sig_75/sum(list_bkg_75)))
# Out:
# 75% : sig_n 489.2	bkg_n 503.1	sig/bkg 1.0

# %% [markdown]
# ### Stats for simple NN

# %%
sig_weight = df_all[df_all['isSignal']==1]['weight'].unique()[0]
df_sig_75 = df_all[(df_all['dense_NN']>=0.75) & (df_all['isSignal']==1)]
n_sig_75 = df_sig_75.shape[0] * sig_weight
df_sig_80 = df_all[(df_all['dense_NN']>=0.80) & (df_all['isSignal']==1)]
n_sig_80 = df_sig_80.shape[0] * sig_weight
df_sig_85 = df_all[(df_all['dense_NN']>=0.85) & (df_all['isSignal']==1)]
n_sig_85 = df_sig_85.shape[0] * sig_weight

bkg_weights = df_all[df_all['isSignal']==0]['weight'].unique()
list_bkg_75 = [df_all[(df_all['dense_NN']>=0.75) & (df_all['isSignal']==0) & (df_all['weight'] == bkg_w)].shape[0] * bkg_w for bkg_w in bkg_weights]
list_bkg_80 = [df_all[(df_all['dense_NN']>=0.80) & (df_all['isSignal']==0) & (df_all['weight'] == bkg_w)].shape[0] * bkg_w for bkg_w in bkg_weights]
list_bkg_85 = [df_all[(df_all['dense_NN']>=0.85) & (df_all['isSignal']==0) & (df_all['weight'] == bkg_w)].shape[0] * bkg_w for bkg_w in bkg_weights]

print("75% : sig_n {:.1f}\tbkg_n {:.1f}\tsig/bkg {:.1f}".format(n_sig_75, sum(list_bkg_75), n_sig_75/sum(list_bkg_75)))
print("80% : sig_n {:.1f}\tbkg_n {:.1f}\tsig/bkg {:.1f}".format(n_sig_80, sum(list_bkg_80), n_sig_80/sum(list_bkg_80)))
print("85% : sig_n {:.1f}\tbkg_n {:.1f}\tsig/bkg {:.1f}".format(n_sig_85, sum(list_bkg_85), n_sig_85/sum(list_bkg_85)))
# Out:
# 75% : sig_n 512.5	bkg_n 444.5	sig/bkg 1.2
# 80% : sig_n 409.2	bkg_n 348.1	sig/bkg 1.2
# 85% : sig_n 290.7	bkg_n 224.3	sig/bkg 1.3

# %% [markdown]
# ### Stats for optimized NN

# %%
sig_weight = df_all[df_all['isSignal']==1]['weight'].unique()[0]
df_sig_75 = df_all[(df_all['dense_NN_opt']>=0.75) & (df_all['isSignal']==1)]
n_sig_75 = df_sig_75.shape[0] * sig_weight
df_sig_80 = df_all[(df_all['dense_NN_opt']>=0.80) & (df_all['isSignal']==1)]
n_sig_80 = df_sig_80.shape[0] * sig_weight
df_sig_85 = df_all[(df_all['dense_NN_opt']>=0.85) & (df_all['isSignal']==1)]
n_sig_85 = df_sig_85.shape[0] * sig_weight

bkg_weights = df_all[df_all['isSignal']==0]['weight'].unique()
list_bkg_75 = [df_all[(df_all['dense_NN_opt']>=0.75) & (df_all['isSignal']==0) & (df_all['weight'] == bkg_w)].shape[0] * bkg_w for bkg_w in bkg_weights]
list_bkg_80 = [df_all[(df_all['dense_NN_opt']>=0.80) & (df_all['isSignal']==0) & (df_all['weight'] == bkg_w)].shape[0] * bkg_w for bkg_w in bkg_weights]
list_bkg_85 = [df_all[(df_all['dense_NN_opt']>=0.85) & (df_all['isSignal']==0) & (df_all['weight'] == bkg_w)].shape[0] * bkg_w for bkg_w in bkg_weights]

print("75% : sig_n {:.1f}\tbkg_n {:.1f}\tsig/bkg {:.1f}".format(n_sig_75, sum(list_bkg_75), n_sig_75/sum(list_bkg_75)))
print("80% : sig_n {:.1f}\tbkg_n {:.1f}\tsig/bkg {:.1f}".format(n_sig_80, sum(list_bkg_80), n_sig_75/sum(list_bkg_80)))
print("85% : sig_n {:.1f}\tbkg_n {:.1f}\tsig/bkg {:.1f}".format(n_sig_85, sum(list_bkg_85), n_sig_75/sum(list_bkg_85)))
# Out:
# 75% : sig_n 567.2	bkg_n 337.9	sig/bkg 1.7
# 80% : sig_n 487.0	bkg_n 246.6	sig/bkg 2.3
# 85% : sig_n 387.7	bkg_n 160.1	sig/bkg 3.5

# %% [markdown]
# ### Stats for optimized NN with drop out layers

# %%
sig_weight = df_all[df_all['isSignal']==1]['weight'].unique()[0]
df_sig_75 = df_all[(df_all['dense_NN_opt_drop']>=0.75) & (df_all['isSignal']==1)]
n_sig_75 = df_sig_75.shape[0] * sig_weight
df_sig_80 = df_all[(df_all['dense_NN_opt_drop']>=0.80) & (df_all['isSignal']==1)]
n_sig_80 = df_sig_80.shape[0] * sig_weight
df_sig_85 = df_all[(df_all['dense_NN_opt_drop']>=0.85) & (df_all['isSignal']==1)]
n_sig_85 = df_sig_85.shape[0] * sig_weight

bkg_weights = df_all[df_all['isSignal']==0]['weight'].unique()
list_bkg_75 = [df_all[(df_all['dense_NN_opt_drop']>=0.75) & (df_all['isSignal']==0) & (df_all['weight'] == bkg_w)].shape[0] * bkg_w for bkg_w in bkg_weights]
list_bkg_80 = [df_all[(df_all['dense_NN_opt_drop']>=0.80) & (df_all['isSignal']==0) & (df_all['weight'] == bkg_w)].shape[0] * bkg_w for bkg_w in bkg_weights]
list_bkg_85 = [df_all[(df_all['dense_NN_opt_drop']>=0.85) & (df_all['isSignal']==0) & (df_all['weight'] == bkg_w)].shape[0] * bkg_w for bkg_w in bkg_weights]

print("75% : sig_n {:.1f}\tbkg_n {:.1f}\tsig/bkg {:.1f}".format(n_sig_75, sum(list_bkg_75), n_sig_75/sum(list_bkg_75)))
print("80% : sig_n {:.1f}\tbkg_n {:.1f}\tsig/bkg {:.1f}".format(n_sig_80, sum(list_bkg_80), n_sig_75/sum(list_bkg_80)))
print("85% : sig_n {:.1f}\tbkg_n {:.1f}\tsig/bkg {:.1f}".format(n_sig_85, sum(list_bkg_85), n_sig_75/sum(list_bkg_85)))
# Out:
# 75% : sig_n 570.8	bkg_n 240.7	sig/bkg 2.4
# 80% : sig_n 492.8	bkg_n 173.9	sig/bkg 3.3
# 85% : sig_n 397.1	bkg_n 116.7	sig/bkg 4.9
